# %%
import tensorflow           as tf
import matplotlib.pyplot    as plt
import pandas               as pd
import seaborn              as sns

from keras.applications         import ResNet50
from keras.models               import Sequential, load_model
from keras.layers               import Dense, Flatten, Dropout
from keras.optimizers           import Adam
from keras.preprocessing.image  import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, auc

from pathlib import Path


import shutil, splitfolders, os

# %% [markdown]
# Configurar TensorFlow para usar la GPU

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# Elimina y recrea directorio split_imagenes, divide imágenes en carpetas de entrenamiento y validación

# %%
transformada = "cgau1"

#Ruta al directoria split_imagenes
ruta_imagenes = Path(f"../../../../imagenes/{transformada}")
ruta_split_imagenes = Path(f"../../../../split_imagenes/{transformada}")

#Si el directorio ya existe, eliminarlo junto con su contendio
if ruta_split_imagenes.exists():
    shutil.rmtree(ruta_split_imagenes)

#Crear el split de las imágenes de la transformada
splitfolders.ratio(input=ruta_imagenes, output=ruta_split_imagenes, ratio=(.8,.2))
# Out:
# Copying files: 4000 files [00:09, 441.51 files/s]

# %% [markdown]
# Se definen parámetros

# %%
# Definir rutas de las carpetas que contienen las imágenes
img_width, img_height   = 250, 250
input_shape             = (img_width, img_height, 3)

# Hiperparámetros
epochs      = 100
batch_size  = 16

# %% [markdown]
# Se crean los generadores de datos de imágenes

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagem = ImageDataGenerator(rescale=1./255)

# Cargar y dividir los datos en conjuntos de entrenamiento y prueba
generador_entrenamiento = train_datagen.flow_from_directory(
    ruta_split_imagenes/"train",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Cargar imágenes de validación
generador_validacion = valid_datagem.flow_from_directory(
    ruta_split_imagenes/"val",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %% [markdown]
# Se carga el modelo preentrenado

# %%
# Cargar el modelo ResNet50 pre-entrenado sin la parte superior (include_top = False)
ResNet50_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

# Congelar las capas de la ResNet50 pre-entrenada
for layer in ResNet50_model.layers:
    layer.trainable = False

# %% [markdown]
# Se agregan capas al final del modelo

# %%
# Construir el modelo
model = Sequential()
model.add(ResNet50_model)
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Entrenamiento del modelo

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
historia = model.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3606 - accuracy: 0.4959
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 61s 271ms/step - loss: 1.3606 - accuracy: 0.4959 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 2: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 88ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4906
# Epoch 3: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 89ms/step - loss: 0.6932 - accuracy: 0.4906 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4900
# Epoch 4: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 89ms/step - loss: 0.6932 - accuracy: 0.4900 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 5: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 90ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4969
# Epoch 6: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 90ms/step - loss: 0.6932 - accuracy: 0.4969 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4781
# Epoch 7: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 90ms/step - loss: 0.6932 - accuracy: 0.4781 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 8: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4906
# Epoch 9: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 91ms/step - loss: 0.6932 - accuracy: 0.4906 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4894
# Epoch 10: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 92ms/step - loss: 0.6932 - accuracy: 0.4894 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4944
# Epoch 11: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 92ms/step - loss: 0.6932 - accuracy: 0.4944 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4975
# Epoch 12: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 18s 92ms/step - loss: 0.6932 - accuracy: 0.4975 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4831
# Epoch 13: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6932 - accuracy: 0.4831 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4900
# Epoch 14: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6932 - accuracy: 0.4900 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4931
# Epoch 15: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6932 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4944
# Epoch 16: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6932 - accuracy: 0.4944 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4894
# Epoch 17: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6932 - accuracy: 0.4894 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4863
# Epoch 18: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 94ms/step - loss: 0.6932 - accuracy: 0.4863 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4856
# Epoch 19: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 19s 94ms/step - loss: 0.6932 - accuracy: 0.4856 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 20: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 22s 110ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4938
# Epoch 21: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4938 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 22: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 23s 117ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 23/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4900
# Epoch 23: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6932 - accuracy: 0.4900 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 24/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4856
# Epoch 24: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6932 - accuracy: 0.4856 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 25/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5013
# Epoch 25: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 26/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4831
# Epoch 26: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 30s 148ms/step - loss: 0.6933 - accuracy: 0.4831 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 27/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 27: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 28/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4888
# Epoch 28: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 29s 143ms/step - loss: 0.6932 - accuracy: 0.4888 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 29/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5006
# Epoch 29: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.5006 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 30/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4925
# Epoch 30: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 118ms/step - loss: 0.6932 - accuracy: 0.4925 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 31/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4850
# Epoch 31: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 129ms/step - loss: 0.6932 - accuracy: 0.4850 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 32/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4988
# Epoch 32: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 128ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 33/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4906
# Epoch 33: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 130ms/step - loss: 0.6932 - accuracy: 0.4906 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 34/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4975
# Epoch 34: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 132ms/step - loss: 0.6932 - accuracy: 0.4975 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 35/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4994
# Epoch 35: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 36/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4906
# Epoch 36: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6932 - accuracy: 0.4906 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 37/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4812
# Epoch 37: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 29s 144ms/step - loss: 0.6932 - accuracy: 0.4812 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 38/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4869
# Epoch 38: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 135ms/step - loss: 0.6932 - accuracy: 0.4869 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 39/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 39: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 40/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4806
# Epoch 40: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 128ms/step - loss: 0.6933 - accuracy: 0.4806 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 41/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4913
# Epoch 41: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4913 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 42/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 42: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 43/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4938
# Epoch 43: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4938 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 44/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 44: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 45/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 45: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 46/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 46: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 47/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 47: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 48/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4894
# Epoch 48: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4894 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 49/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4931
# Epoch 49: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 118ms/step - loss: 0.6932 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 50/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4938
# Epoch 50: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4938 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 51/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 51: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 52/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4925
# Epoch 52: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4925 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 53/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4850
# Epoch 53: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 133ms/step - loss: 0.6932 - accuracy: 0.4850 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 54/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4950
# Epoch 54: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 122ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 55/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 55: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 118ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 56/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4844
# Epoch 56: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4844 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 57/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4894
# Epoch 57: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4894 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 58/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4888
# Epoch 58: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.6932 - accuracy: 0.4888 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 59/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4950
# Epoch 59: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 60/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4775
# Epoch 60: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.6932 - accuracy: 0.4775 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 61/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4944
# Epoch 61: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4944 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 62/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 62: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 63/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4913
# Epoch 63: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 27s 134ms/step - loss: 0.6932 - accuracy: 0.4913 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 64/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4844
# Epoch 64: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4844 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 65/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4875
# Epoch 65: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4875 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 66/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4969
# Epoch 66: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4969 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 67/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4969
# Epoch 67: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4969 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 68/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 68: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 126ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 69/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 69: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 125ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 70/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4844
# Epoch 70: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 28s 139ms/step - loss: 0.6932 - accuracy: 0.4844 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 71/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4856
# Epoch 71: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.6932 - accuracy: 0.4856 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 72/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4775
# Epoch 72: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4775 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 73/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 73: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 122ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 74/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 74: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 75/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4888
# Epoch 75: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 129ms/step - loss: 0.6932 - accuracy: 0.4888 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 76/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4969
# Epoch 76: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4969 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 77/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5000
# Epoch 77: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 78/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4787
# Epoch 78: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 125ms/step - loss: 0.6932 - accuracy: 0.4787 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 79/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 79: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 128ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 80/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4963
# Epoch 80: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 26s 128ms/step - loss: 0.6932 - accuracy: 0.4963 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 81/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4775
# Epoch 81: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.6932 - accuracy: 0.4775 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 82/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4931
# Epoch 82: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 126ms/step - loss: 0.6932 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 83/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4894
# Epoch 83: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4894 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 84/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4800
# Epoch 84: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 122ms/step - loss: 0.6932 - accuracy: 0.4800 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 85/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4931
# Epoch 85: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.6933 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 86/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 86: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 28s 138ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 87/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 87: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 88/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4837
# Epoch 88: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.6932 - accuracy: 0.4837 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 89/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4919
# Epoch 89: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 119ms/step - loss: 0.6932 - accuracy: 0.4919 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 90/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4869
# Epoch 90: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 23s 116ms/step - loss: 0.6932 - accuracy: 0.4869 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 91/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4944
# Epoch 91: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.6932 - accuracy: 0.4944 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 92/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4950
# Epoch 92: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 93/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4856
# Epoch 93: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 118ms/step - loss: 0.6932 - accuracy: 0.4856 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 94/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4944
# Epoch 94: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 118ms/step - loss: 0.6932 - accuracy: 0.4944 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 95/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4956
# Epoch 95: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 96/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4931
# Epoch 96: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 97/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4931
# Epoch 97: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4931 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 98/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4994
# Epoch 98: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 99/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4888
# Epoch 99: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 120ms/step - loss: 0.6932 - accuracy: 0.4888 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 100/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4938
# Epoch 100: val_accuracy did not improve from 0.50000
# 200/200 [==============================] - 24s 121ms/step - loss: 0.6932 - accuracy: 0.4938 - val_loss: 0.6931 - val_accuracy: 0.5000

# %% [markdown]
# Resumen del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 40,365,185
# Trainable params: 16,777,473
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %%
# Curvas de pérdida
plt.figure(figsize=(13,6))
plt.subplot(1, 2, 1)
plt.plot(historia.history['loss'], label='Entrenamiento')
plt.plot(historia.history['val_loss'], label='Validación')
plt.title('Curvas Loss')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(historia.history['accuracy'], label='Entrenamiento')
plt.plot(historia.history['val_accuracy'], label='Validación')
plt.title('Curvas Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.tight_layout()

# Obteniendo el nombre de la imagen para la gráfica de entrenamiento
cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo
#
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.69
# Accuracy: 50.00%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	50.00%
# Sensitivity:	100.00%
# Specificity:	0.00%
# Precision:	50.00%
# F1-score:	66.67%

# %% [markdown]
# Curva roc y auc

# %%
# Calcular la curva ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Visualizar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid()

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

# Imprimir el AUC
print(f"Área Bajo la Curva (AUC): {roc_auc:.2f}")
# Out:
# Área Bajo la Curva (AUC): 0.50

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
