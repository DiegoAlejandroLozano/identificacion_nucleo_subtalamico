# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.applications import VGG19
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Definir rutas de las carpetas que contienen las imágenes
directorio = "../../../../split_imagenes/cmor/"
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)

# Hiperparámetros
epochs = 50
batch_size = 16

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagem = ImageDataGenerator(rescale=1./255)
test_datagem = ImageDataGenerator(rescale=1./255)

#Directorios de las imágenes
train_dir = "../../../../split_imagenes/cmor/train/"
valid_dir = "../../../../split_imagenes/cmor/val/"
test_dir = "../../../../split_imagenes/cmor/test/"

# Cargar y dividir los datos en conjuntos de entrenamiento y prueba
generador_entrenamiento = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Cargar imágenes de validación
generador_validacion = valid_datagem.flow_from_directory(
    valid_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Cargar imágenes de prueba
generador_prueba = test_datagem.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary',  # 'categorical' para más de dos clases
    shuffle=False  # No mezclar las imágenes de prueba para mantener el orden
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %%
# Cargar el modelo ResNet50 pre-entrenado sin la parte superior (include_top = False)
vgg19_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)

# Congelar las capas de la ResNet50 pre-entrenada
for layer in vgg19_model.layers:
    layer.trainable = False

# %%
# Construir el modelo
model = Sequential()
model.add(vgg19_model)
model.add(Flatten())
model.add(Dense(255, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
historia = model.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.7464 - accuracy: 0.6109
# Epoch 1: val_accuracy improved from -inf to 0.71500, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 36s 172ms/step - loss: 0.7464 - accuracy: 0.6109 - val_loss: 0.5777 - val_accuracy: 0.7150
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.6747
# Epoch 2: val_accuracy improved from 0.71500 to 0.71750, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 35s 173ms/step - loss: 0.5599 - accuracy: 0.6747 - val_loss: 0.5389 - val_accuracy: 0.7175
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5158 - accuracy: 0.7281
# Epoch 3: val_accuracy improved from 0.71750 to 0.74000, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 34s 170ms/step - loss: 0.5158 - accuracy: 0.7281 - val_loss: 0.5407 - val_accuracy: 0.7400
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4886 - accuracy: 0.7328
# Epoch 4: val_accuracy improved from 0.74000 to 0.78250, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4886 - accuracy: 0.7328 - val_loss: 0.4756 - val_accuracy: 0.7825
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.7534
# Epoch 5: val_accuracy did not improve from 0.78250
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4712 - accuracy: 0.7534 - val_loss: 0.4677 - val_accuracy: 0.7550
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.7394
# Epoch 6: val_accuracy did not improve from 0.78250
# 200/200 [==============================] - 34s 172ms/step - loss: 0.4920 - accuracy: 0.7394 - val_loss: 0.5011 - val_accuracy: 0.7450
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5005 - accuracy: 0.7325
# Epoch 7: val_accuracy did not improve from 0.78250
# 200/200 [==============================] - 37s 187ms/step - loss: 0.5005 - accuracy: 0.7325 - val_loss: 0.4886 - val_accuracy: 0.7475
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.7244
# Epoch 8: val_accuracy did not improve from 0.78250
# 200/200 [==============================] - 37s 183ms/step - loss: 0.4987 - accuracy: 0.7244 - val_loss: 0.4509 - val_accuracy: 0.7800
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.7381
# Epoch 9: val_accuracy did not improve from 0.78250
# 200/200 [==============================] - 39s 194ms/step - loss: 0.4890 - accuracy: 0.7381 - val_loss: 0.4772 - val_accuracy: 0.7450
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4746 - accuracy: 0.7409
# Epoch 10: val_accuracy improved from 0.78250 to 0.80250, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4746 - accuracy: 0.7409 - val_loss: 0.4313 - val_accuracy: 0.8025
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4689 - accuracy: 0.7359
# Epoch 11: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 36s 181ms/step - loss: 0.4689 - accuracy: 0.7359 - val_loss: 0.4333 - val_accuracy: 0.7950
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4333 - accuracy: 0.7525
# Epoch 12: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 37s 187ms/step - loss: 0.4333 - accuracy: 0.7525 - val_loss: 0.4276 - val_accuracy: 0.7925
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.7325
# Epoch 13: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 38s 192ms/step - loss: 0.4440 - accuracy: 0.7325 - val_loss: 0.4574 - val_accuracy: 0.7800
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4239 - accuracy: 0.7581
# Epoch 14: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 40s 201ms/step - loss: 0.4239 - accuracy: 0.7581 - val_loss: 0.4316 - val_accuracy: 0.7850
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4068 - accuracy: 0.7622
# Epoch 15: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 38s 188ms/step - loss: 0.4068 - accuracy: 0.7622 - val_loss: 0.4149 - val_accuracy: 0.7950
# Epoch 16/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4080 - accuracy: 0.7619
# Epoch 16: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 39s 193ms/step - loss: 0.4080 - accuracy: 0.7619 - val_loss: 0.4050 - val_accuracy: 0.7975
# Epoch 17/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.7763
# Epoch 17: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 42s 211ms/step - loss: 0.4245 - accuracy: 0.7763 - val_loss: 0.4042 - val_accuracy: 0.8025
# Epoch 18/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4416 - accuracy: 0.7434
# Epoch 18: val_accuracy did not improve from 0.80250
# 200/200 [==============================] - 40s 199ms/step - loss: 0.4416 - accuracy: 0.7434 - val_loss: 0.3933 - val_accuracy: 0.8000
# Epoch 19/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.7613
# Epoch 19: val_accuracy improved from 0.80250 to 0.80500, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 43s 213ms/step - loss: 0.4299 - accuracy: 0.7613 - val_loss: 0.4053 - val_accuracy: 0.8050
# Epoch 20/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4451 - accuracy: 0.7609
# Epoch 20: val_accuracy did not improve from 0.80500
# 200/200 [==============================] - 42s 208ms/step - loss: 0.4451 - accuracy: 0.7609 - val_loss: 0.4072 - val_accuracy: 0.8050
# Epoch 21/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.7678
# Epoch 21: val_accuracy improved from 0.80500 to 0.81500, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 43s 212ms/step - loss: 0.3965 - accuracy: 0.7678 - val_loss: 0.4168 - val_accuracy: 0.8150
# Epoch 22/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.7681
# Epoch 22: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 42s 209ms/step - loss: 0.3989 - accuracy: 0.7681 - val_loss: 0.4840 - val_accuracy: 0.7750
# Epoch 23/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4142 - accuracy: 0.7634
# Epoch 23: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 44s 219ms/step - loss: 0.4142 - accuracy: 0.7634 - val_loss: 0.4989 - val_accuracy: 0.7850
# Epoch 24/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4536 - accuracy: 0.7509
# Epoch 24: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 40s 198ms/step - loss: 0.4536 - accuracy: 0.7509 - val_loss: 0.4196 - val_accuracy: 0.8050
# Epoch 25/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4277 - accuracy: 0.7719
# Epoch 25: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 44s 218ms/step - loss: 0.4277 - accuracy: 0.7719 - val_loss: 0.4089 - val_accuracy: 0.7900
# Epoch 26/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4171 - accuracy: 0.7734
# Epoch 26: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 44s 219ms/step - loss: 0.4171 - accuracy: 0.7734 - val_loss: 0.4294 - val_accuracy: 0.8000
# Epoch 27/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4131 - accuracy: 0.7859
# Epoch 27: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 40s 198ms/step - loss: 0.4131 - accuracy: 0.7859 - val_loss: 0.3950 - val_accuracy: 0.8150
# Epoch 28/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.7800
# Epoch 28: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 43s 215ms/step - loss: 0.4102 - accuracy: 0.7800 - val_loss: 0.4138 - val_accuracy: 0.7850
# Epoch 29/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.7778
# Epoch 29: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 43s 213ms/step - loss: 0.4073 - accuracy: 0.7778 - val_loss: 0.4076 - val_accuracy: 0.7950
# Epoch 30/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.7900
# Epoch 30: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 41s 204ms/step - loss: 0.3913 - accuracy: 0.7900 - val_loss: 0.4158 - val_accuracy: 0.8025
# Epoch 31/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3999 - accuracy: 0.7850
# Epoch 31: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 42s 208ms/step - loss: 0.3999 - accuracy: 0.7850 - val_loss: 0.4225 - val_accuracy: 0.7675
# Epoch 32/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4002 - accuracy: 0.7781
# Epoch 32: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 44s 222ms/step - loss: 0.4002 - accuracy: 0.7781 - val_loss: 0.4537 - val_accuracy: 0.7725
# Epoch 33/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3999 - accuracy: 0.7775
# Epoch 33: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 49s 247ms/step - loss: 0.3999 - accuracy: 0.7775 - val_loss: 0.4441 - val_accuracy: 0.7950
# Epoch 34/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4144 - accuracy: 0.7731
# Epoch 34: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 44s 219ms/step - loss: 0.4144 - accuracy: 0.7731 - val_loss: 0.3968 - val_accuracy: 0.8050
# Epoch 35/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.7909
# Epoch 35: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 41s 204ms/step - loss: 0.3901 - accuracy: 0.7909 - val_loss: 0.4201 - val_accuracy: 0.7975
# Epoch 36/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3813 - accuracy: 0.7944
# Epoch 36: val_accuracy did not improve from 0.81500
# 200/200 [==============================] - 46s 230ms/step - loss: 0.3813 - accuracy: 0.7944 - val_loss: 0.4077 - val_accuracy: 0.8100
# Epoch 37/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3750 - accuracy: 0.7962
# Epoch 37: val_accuracy improved from 0.81500 to 0.82000, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 39s 196ms/step - loss: 0.3750 - accuracy: 0.7962 - val_loss: 0.3849 - val_accuracy: 0.8200
# Epoch 38/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.7941
# Epoch 38: val_accuracy did not improve from 0.82000
# 200/200 [==============================] - 40s 202ms/step - loss: 0.3743 - accuracy: 0.7941 - val_loss: 0.4215 - val_accuracy: 0.8100
# Epoch 39/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3682 - accuracy: 0.7975
# Epoch 39: val_accuracy improved from 0.82000 to 0.82750, saving model to modelo_generado\mejor_modelo.keras
# 200/200 [==============================] - 43s 214ms/step - loss: 0.3682 - accuracy: 0.7975 - val_loss: 0.3915 - val_accuracy: 0.8275
# Epoch 40/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3591 - accuracy: 0.8056
# Epoch 40: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 46s 230ms/step - loss: 0.3591 - accuracy: 0.8056 - val_loss: 0.3814 - val_accuracy: 0.8200
# Epoch 41/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3883 - accuracy: 0.7919
# Epoch 41: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 47s 233ms/step - loss: 0.3883 - accuracy: 0.7919 - val_loss: 0.4064 - val_accuracy: 0.8100
# Epoch 42/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.7991
# Epoch 42: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 43s 216ms/step - loss: 0.3836 - accuracy: 0.7991 - val_loss: 0.4547 - val_accuracy: 0.7975
# Epoch 43/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3719 - accuracy: 0.7947
# Epoch 43: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 46s 230ms/step - loss: 0.3719 - accuracy: 0.7947 - val_loss: 0.4085 - val_accuracy: 0.8025
# Epoch 44/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.7994
# Epoch 44: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 43s 213ms/step - loss: 0.3588 - accuracy: 0.7994 - val_loss: 0.3902 - val_accuracy: 0.8175
# Epoch 45/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8016
# Epoch 45: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 42s 209ms/step - loss: 0.3596 - accuracy: 0.8016 - val_loss: 0.4153 - val_accuracy: 0.8150
# Epoch 46/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3794 - accuracy: 0.7900
# Epoch 46: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 46s 230ms/step - loss: 0.3794 - accuracy: 0.7900 - val_loss: 0.3927 - val_accuracy: 0.7775
# Epoch 47/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8019
# Epoch 47: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 40s 200ms/step - loss: 0.3661 - accuracy: 0.8019 - val_loss: 0.4004 - val_accuracy: 0.8150
# Epoch 48/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3560 - accuracy: 0.8125
# Epoch 48: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 42s 209ms/step - loss: 0.3560 - accuracy: 0.8125 - val_loss: 0.4072 - val_accuracy: 0.8100
# Epoch 49/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8156
# Epoch 49: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 44s 220ms/step - loss: 0.3553 - accuracy: 0.8156 - val_loss: 0.3958 - val_accuracy: 0.8050
# Epoch 50/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8103
# Epoch 50: val_accuracy did not improve from 0.82750
# 200/200 [==============================] - 46s 232ms/step - loss: 0.3673 - accuracy: 0.8103 - val_loss: 0.4070 - val_accuracy: 0.8150

# %%
# Curvas de pérdida
plt.figure(figsize=(13,6))
plt.subplot(1, 2, 1)
plt.plot(historia.history['loss'], label='Entrenamiento')
plt.plot(historia.history['val_loss'], label='Validación')
plt.title('Curvas de pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(historia.history['accuracy'], label='Entrenamiento')
plt.plot(historia.history['val_accuracy'], label='Validación')
plt.title('Curvas de precisión')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo
#
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

print("Perdida: {:.2f}".format(resul_eva[0]))
print("Accuracy: {:.2%}".format(resul_eva[1]))
# Out:
# Perdida: 0.39
# Accuracy: 82.75%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_prueba, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.7).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	80.00%
# Sensitivity:	67.00%
# Specificity:	93.00%
# Precision:	90.54%
# F1-score:	77.01%
