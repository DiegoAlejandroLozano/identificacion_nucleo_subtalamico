# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.applications import InceptionV3
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %%
# Definir rutas de las carpetas que contienen las imágenes
directorio = "../../../imagenes/mexh/"
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)

# %%
# Hiperparámetros
epochs = 20
batch_size = 62

# %%
# Configurar el generador de datos de imágenes
generador_datos = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Cargar y dividir los datos en conjuntos de entrenamiento y prueba
generador_entrenamiento = generador_datos.flow_from_directory(
    directorio,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

generador_prueba = generador_datos.flow_from_directory(
    directorio,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Cargar el modelo ResNet50 pre-entrenado sin la parte superior (include_top = False)
resnet_model = InceptionV3(weights='imagenet', include_top=False, input_shape=input_shape)

# Congelar las capas de la ResNet50 pre-entrenada
for layer in resnet_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 2s 0us/step

# %%
# Construir el modelo
model = Sequential()
model.add(resnet_model)
model.add(Flatten())
model.add(Dense(4, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Entrenar el modelo
historia = model.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_prueba,
    validation_steps=generador_prueba.samples // batch_size
)
# Out:
# Epoch 1/20
# 51/51 [==============================] - 12s 165ms/step - loss: 1.0423 - accuracy: 0.5051 - val_loss: 0.6932 - val_accuracy: 0.4987
# Epoch 2/20
# 51/51 [==============================] - 7s 144ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4906
# Epoch 3/20
# 51/51 [==============================] - 7s 145ms/step - loss: 1.1992 - accuracy: 0.5038 - val_loss: 0.6932 - val_accuracy: 0.4987
# Epoch 4/20
# 51/51 [==============================] - 7s 145ms/step - loss: 0.6933 - accuracy: 0.4936 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 5/20
# 51/51 [==============================] - 8s 146ms/step - loss: 0.6932 - accuracy: 0.5038 - val_loss: 0.6930 - val_accuracy: 0.5081
# Epoch 6/20
# 51/51 [==============================] - 8s 146ms/step - loss: 0.6933 - accuracy: 0.4946 - val_loss: 0.6932 - val_accuracy: 0.4987
# Epoch 7/20
# 51/51 [==============================] - 8s 148ms/step - loss: 0.6934 - accuracy: 0.5006 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 8/20
# 51/51 [==============================] - 8s 148ms/step - loss: 0.6934 - accuracy: 0.4984 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 9/20
# 51/51 [==============================] - 8s 147ms/step - loss: 0.6933 - accuracy: 0.4987 - val_loss: 0.6932 - val_accuracy: 0.4987
# Epoch 10/20
# 51/51 [==============================] - 8s 147ms/step - loss: 0.6933 - accuracy: 0.4853 - val_loss: 0.6931 - val_accuracy: 0.5027
# Epoch 11/20
# 51/51 [==============================] - 8s 148ms/step - loss: 0.6934 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 12/20
# 51/51 [==============================] - 8s 147ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4906
# Epoch 13/20
# 51/51 [==============================] - 8s 149ms/step - loss: 0.6934 - accuracy: 0.4796 - val_loss: 0.6933 - val_accuracy: 0.4933
# Epoch 14/20
# 51/51 [==============================] - 8s 148ms/step - loss: 0.6932 - accuracy: 0.4930 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 15/20
# 51/51 [==============================] - 8s 152ms/step - loss: 0.6935 - accuracy: 0.5006 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 16/20
# 51/51 [==============================] - 8s 149ms/step - loss: 0.6934 - accuracy: 0.5010 - val_loss: 0.6931 - val_accuracy: 0.5094
# Epoch 17/20
# 51/51 [==============================] - 8s 149ms/step - loss: 0.6933 - accuracy: 0.4767 - val_loss: 0.6932 - val_accuracy: 0.4987
# Epoch 18/20
# 51/51 [==============================] - 8s 148ms/step - loss: 0.6934 - accuracy: 0.4892 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 19/20
# 51/51 [==============================] - 8s 148ms/step - loss: 0.6936 - accuracy: 0.4917 - val_loss: 0.6932 - val_accuracy: 0.5013
# Epoch 20/20
# 51/51 [==============================] - 8s 149ms/step - loss: 0.6933 - accuracy: 0.4978 - val_loss: 0.6933 - val_accuracy: 0.4946

# %%
# Curvas de pérdida
plt.figure(figsize=(13,6))
plt.subplot(1, 2, 1)
plt.plot(historia.history['loss'], label='Entrenamiento')
plt.plot(historia.history['val_loss'], label='Validación')
plt.title('Curvas de pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(historia.history['accuracy'], label='Entrenamiento')
plt.plot(historia.history['val_accuracy'], label='Validación')
plt.title('Curvas de precisión')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
