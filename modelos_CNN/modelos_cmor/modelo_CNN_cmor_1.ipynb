# %%
from keras.models import Sequential
from keras.layers import Convolution2D        
from keras.layers import MaxPooling2D       
from keras.layers import Flatten            
from keras.layers import Dense 
from keras.layers import Dropout

from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.preprocessing import image

from sklearn.model_selection import train_test_split

import numpy as np

# %%
#Definir rutas de las carétas que contienen las imágenes
data_dir = "../../imagenes2/cmor/"
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)

# %%
#Hiperparámetros
epochs =20
batch_size = 10

# %%
#Generador de datos para procesamiento y aumento de datos
datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Obtener todas las imágenes y sus etiquetas
image_data = datagen.flow_from_directory(
    data_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = "binary",
    classes = ["stn", "otras"] # clases correspondientes a las carpetas stn y otras
)
# Out:
# Found 4000 images belonging to 2 classes.

# %%
# Inicializar listas para almacenar todos los datos generados
all_X = []
all_y = []

# %%
# Iterar sobre el generador y recopilar todos los lotes de datos
for i in range(len(image_data)):
    batch_X, batch_y = image_data[i]
    all_X.append(batch_X)
    all_y.append(batch_y)

# %%
# Concatenar todos los lotes de datos en un solo conjunto
all_X = np.concatenate(all_X)
all_y = np.concatenate(all_y)

# %%
#Dividir los datos en conjuntos de entranamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    all_X, 
    all_y,
    test_size=0.3,
    random_state=42
)

# %%
X_train.shape
# Out:
# (2800, 250, 250, 3)

# %%
y_train.shape
# Out:
# (2800,)

# %%
X_test.shape
# Out:
# (1200, 250, 250, 3)

# %%
y_test.shape
# Out:
# (1200,)

# %%
#Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Convolution2D(input_shape = input_shape,filters=16,kernel_size=(5,5),activation="relu"))
clasificador.add(MaxPooling2D(pool_size=(4,4)))
clasificador.add(Convolution2D(filters=32,kernel_size=(5,5),activation="relu"))
clasificador.add(MaxPooling2D(pool_size=(4,4)))

#Capa de aplanamiento
clasificador.add(Flatten())

#Se agregan las capas densas
clasificador.add(Dense(units=16, activation="relu"))
clasificador.add(Dropout(rate=0.5))

#Capa de salida
clasificador.add(Dense(units=1,activation="sigmoid"))

# %%
#Compilar el modelo
clasificador.compile(
    optimizer = "adam",
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

# %%
#Entrenar el modelo
history = clasificador.fit(
    X_train,
    y_train,
    steps_per_epoch=32,
    epochs = epochs,
    validation_data = (X_test, y_test)
)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 138s 4s/step - loss: 0.6628 - accuracy: 0.5982 - val_loss: 0.6198 - val_accuracy: 0.6350
# Epoch 2/20
# 32/32 [==============================] - 158s 5s/step - loss: 0.6015 - accuracy: 0.6600 - val_loss: 0.5691 - val_accuracy: 0.6725
# Epoch 3/20
# 32/32 [==============================] - 143s 4s/step - loss: 0.5544 - accuracy: 0.6971 - val_loss: 0.5278 - val_accuracy: 0.7433
# Epoch 4/20
# 32/32 [==============================] - 157s 5s/step - loss: 0.5242 - accuracy: 0.7525 - val_loss: 0.5122 - val_accuracy: 0.7350
# Epoch 5/20
# 32/32 [==============================] - 153s 5s/step - loss: 0.5185 - accuracy: 0.7607 - val_loss: 0.4955 - val_accuracy: 0.7508
# Epoch 6/20
# 32/32 [==============================] - 155s 5s/step - loss: 0.4979 - accuracy: 0.7811 - val_loss: 0.4930 - val_accuracy: 0.7825
# Epoch 7/20
# 32/32 [==============================] - 153s 5s/step - loss: 0.4734 - accuracy: 0.7964 - val_loss: 0.4792 - val_accuracy: 0.7892
# Epoch 8/20
# 32/32 [==============================] - 152s 5s/step - loss: 0.4790 - accuracy: 0.7839 - val_loss: 0.4847 - val_accuracy: 0.7758
# Epoch 9/20
# 32/32 [==============================] - 153s 5s/step - loss: 0.4666 - accuracy: 0.8036 - val_loss: 0.4931 - val_accuracy: 0.7867
# Epoch 10/20
# 32/32 [==============================] - 154s 5s/step - loss: 0.4507 - accuracy: 0.8175 - val_loss: 0.4712 - val_accuracy: 0.8025
# Epoch 11/20
# 32/32 [==============================] - 152s 5s/step - loss: 0.4433 - accuracy: 0.8121 - val_loss: 0.4885 - val_accuracy: 0.7858
# Epoch 12/20
# 32/32 [==============================] - 154s 5s/step - loss: 0.4330 - accuracy: 0.8214 - val_loss: 0.4653 - val_accuracy: 0.8100
# Epoch 13/20
# 32/32 [==============================] - 151s 5s/step - loss: 0.4276 - accuracy: 0.8336 - val_loss: 0.4907 - val_accuracy: 0.7925
# Epoch 14/20
# 32/32 [==============================] - 153s 5s/step - loss: 0.4189 - accuracy: 0.8343 - val_loss: 0.4764 - val_accuracy: 0.8033
# Epoch 15/20
# 32/32 [==============================] - 151s 5s/step - loss: 0.4147 - accuracy: 0.8336 - val_loss: 0.4753 - val_accuracy: 0.7958
# Epoch 16/20
# 32/32 [==============================] - 151s 5s/step - loss: 0.4092 - accuracy: 0.8257 - val_loss: 0.4913 - val_accuracy: 0.7925
# Epoch 17/20
# 32/32 [==============================] - 151s 5s/step - loss: 0.3972 - accuracy: 0.8471 - val_loss: 0.4555 - val_accuracy: 0.8050
# Epoch 18/20
# 32/32 [==============================] - 151s 5s/step - loss: 0.3768 - accuracy: 0.8496 - val_loss: 0.4644 - val_accuracy: 0.8117
# Epoch 19/20
# 32/32 [==============================] - 151s 5s/step - loss: 0.3694 - accuracy: 0.8439 - val_loss: 0.5108 - val_accuracy: 0.7942
# Epoch 20/20
# 32/32 [==============================] - 150s 5s/step - loss: 0.3595 - accuracy: 0.8621 - val_loss: 0.5009 - val_accuracy: 0.8000

# %%
import matplotlib.pyplot as plt

# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de precisión')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

plt.tight_layout()
plt.show()
