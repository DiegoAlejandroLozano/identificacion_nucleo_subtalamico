# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import seaborn as sns
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %%
#Definir rutas de las carétas que contienen las imágenes
directorio = "../../../imagenes/cmor/"
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)

#Hiperparámetros
epochs = 100
batch_size = 32

# %%
# Configurar el generador de datos de imágenes
generador_datos = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Cargar y dividir los datos en conjuntos de entrenamiento y prueba
generador_entrenamiento = generador_datos.flow_from_directory(
    directorio,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

generador_validacion = generador_datos.flow_from_directory(
    directorio,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(128, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=128, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9948 - accuracy: 0.4903
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 18s 140ms/step - loss: 0.9948 - accuracy: 0.4903 - val_loss: 0.7088 - val_accuracy: 0.5000
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7031 - accuracy: 0.4981
# Epoch 2: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 115ms/step - loss: 0.7031 - accuracy: 0.4981 - val_loss: 0.6995 - val_accuracy: 0.5000
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6981 - accuracy: 0.4925
# Epoch 3: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6981 - accuracy: 0.4925 - val_loss: 0.6970 - val_accuracy: 0.5000
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.5009
# Epoch 4: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6960 - accuracy: 0.5009 - val_loss: 0.6952 - val_accuracy: 0.5000
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6952 - accuracy: 0.4991
# Epoch 5: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6952 - accuracy: 0.4991 - val_loss: 0.6943 - val_accuracy: 0.5000
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5181
# Epoch 6: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6939 - accuracy: 0.5181 - val_loss: 0.6939 - val_accuracy: 0.5000
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.5013
# Epoch 7: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6941 - accuracy: 0.5013 - val_loss: 0.6939 - val_accuracy: 0.5000
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.4966
# Epoch 8: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6939 - accuracy: 0.4966 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5153
# Epoch 9: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6933 - accuracy: 0.5153 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4913
# Epoch 10: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6936 - accuracy: 0.4913 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5141
# Epoch 11: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6932 - accuracy: 0.5141 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4881
# Epoch 12: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6937 - accuracy: 0.4881 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4978
# Epoch 13: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 12s 119ms/step - loss: 0.6934 - accuracy: 0.4978 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4969
# Epoch 14: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 13s 132ms/step - loss: 0.6934 - accuracy: 0.4969 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4953
# Epoch 15: val_accuracy did not improve from 0.50000
# 100/100 [==============================] -
- val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5125
# Epoch 77: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 216ms/step - loss: 0.6932 - accuracy: 0.5125 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4988
# Epoch 78: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 221ms/step - loss: 0.6936 - accuracy: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4931
# Epoch 79: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 219ms/step - loss: 0.6934 - accuracy: 0.4931 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4900
# Epoch 80: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 225ms/step - loss: 0.6934 - accuracy: 0.4900 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4975
# Epoch 81: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 218ms/step - loss: 0.6934 - accuracy: 0.4975 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5000
# Epoch 82: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 218ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5000
# Epoch 83: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 220ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4913
# Epoch 84: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 218ms/step - loss: 0.6936 - accuracy: 0.4913 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4931
# Epoch 85: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 220ms/step - loss: 0.6936 - accuracy: 0.4931 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4906
# Epoch 86: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 218ms/step - loss: 0.6936 - accuracy: 0.4906 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4787
# Epoch 87: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 219ms/step - loss: 0.6937 - accuracy: 0.4787 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4831
# Epoch 88: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 224ms/step - loss: 0.6935 - accuracy: 0.4831 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4875
# Epoch 89: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 222ms/step - loss: 0.6935 - accuracy: 0.4875 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4975
# Epoch 90: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 221ms/step - loss: 0.6934 - accuracy: 0.4975 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4944
# Epoch 91: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 225ms/step - loss: 0.6934 - accuracy: 0.4944 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5006
# Epoch 92: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 222ms/step - loss: 0.6934 - accuracy: 0.5006 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5038
# Epoch 93: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 222ms/step - loss: 0.6934 - accuracy: 0.5038 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4938
# Epoch 94: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 223ms/step - loss: 0.6935 - accuracy: 0.4938 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5094
# Epoch 95: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 22s 224ms/step - loss: 0.6931 - accuracy: 0.5094 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4981
# Epoch 96: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 228ms/step - loss: 0.6935 - accuracy: 0.4981 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5031
# Epoch 97: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 227ms/step - loss: 0.6934 - accuracy: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4931
# Epoch 98: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 228ms/step - loss: 0.6936 - accuracy: 0.4931 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5006
# Epoch 99: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 226ms/step - loss: 0.6935 - accuracy: 0.5006 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4888
# Epoch 100: val_accuracy did not improve from 0.50000
# 100/100 [==============================] - 23s 229ms/step - loss: 0.6934 - accuracy: 0.4888 - val_loss: 0.6932 - val_accuracy: 0.5000

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de precisión')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo
#
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

print("Perdida: {:.2f}".format(resul_eva[0]))
print("Accuracy: {:.2%}".format(resul_eva[1]))
# Out:
# Perdida: 0.71
# Accuracy: 50.00%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.7).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# c:\Users\mmmm\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy:	50.00%
# Sensitivity:	0.00%
# Specificity:	100.00%
# Precision:	0.00%
# F1-score:	0.00%
