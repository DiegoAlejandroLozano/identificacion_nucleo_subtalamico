# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %%
#Definir rutas de las carétas que contienen las imágenes
directorio = "../../../imagenes/mexh/"
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 1)

#Hiperparámetros
epochs =50
batch_size = 32

# %%
# Configurar el generador de datos de imágenes
generador_datos = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Cargar y dividir los datos en conjuntos de entrenamiento y prueba
generador_entrenamiento = generador_datos.flow_from_directory(
    directorio,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='grayscale',
    subset='training'
)

generador_validacion = generador_datos.flow_from_directory(
    directorio,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='grayscale',
    subset='validation'
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
tamanio_ventana = (5,5)

# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(64, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))
clasificador.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))
clasificador.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=64, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 1.0155 - accuracy: 0.5306
# Epoch 1: val_accuracy improved from -inf to 0.67125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 83ms/step - loss: 1.0155 - accuracy: 0.5306 - val_loss: 0.7095 - val_accuracy: 0.6712
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6809 - accuracy: 0.6384
# Epoch 2: val_accuracy improved from 0.67125 to 0.68625, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 81ms/step - loss: 0.6809 - accuracy: 0.6384 - val_loss: 0.6516 - val_accuracy: 0.6862
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6449 - accuracy: 0.6825
# Epoch 3: val_accuracy improved from 0.68625 to 0.70000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 81ms/step - loss: 0.6449 - accuracy: 0.6825 - val_loss: 0.6268 - val_accuracy: 0.7000
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6259 - accuracy: 0.6934
# Epoch 4: val_accuracy improved from 0.70000 to 0.70875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 81ms/step - loss: 0.6259 - accuracy: 0.6934 - val_loss: 0.6076 - val_accuracy: 0.7088
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6196 - accuracy: 0.7000
# Epoch 5: val_accuracy improved from 0.70875 to 0.72375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 85ms/step - loss: 0.6196 - accuracy: 0.7000 - val_loss: 0.5980 - val_accuracy: 0.7237
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6131 - accuracy: 0.7125
# Epoch 6: val_accuracy improved from 0.72375 to 0.72750, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 95ms/step - loss: 0.6131 - accuracy: 0.7125 - val_loss: 0.5924 - val_accuracy: 0.7275
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5924 - accuracy: 0.7419
# Epoch 7: val_accuracy improved from 0.72750 to 0.73375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 91ms/step - loss: 0.5924 - accuracy: 0.7419 - val_loss: 0.5823 - val_accuracy: 0.7337
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5854 - accuracy: 0.7462
# Epoch 8: val_accuracy improved from 0.73375 to 0.75625, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 91ms/step - loss: 0.5854 - accuracy: 0.7462 - val_loss: 0.5771 - val_accuracy: 0.7563
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5875 - accuracy: 0.7372
# Epoch 9: val_accuracy improved from 0.75625 to 0.76250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5875 - accuracy: 0.7372 - val_loss: 0.5680 - val_accuracy: 0.7625
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.7472
# Epoch 10: val_accuracy did not improve from 0.76250
# 100/100 [==============================] - 9s 87ms/step - loss: 0.5796 - accuracy: 0.7472 - val_loss: 0.5634 - val_accuracy: 0.7600
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5771 - accuracy: 0.7503
# Epoch 11: val_accuracy improved from 0.76250 to 0.77750, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 86ms/step - loss: 0.5771 - accuracy: 0.7503 - val_loss: 0.5644 - val_accuracy: 0.7775
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5648 - accuracy: 0.7584
# Epoch 12: val_accuracy did not improve from 0.77750
# 100/100 [==============================] - 8s 81ms/step - loss: 0.5648 - accuracy: 0.7584 - val_loss: 0.5552 - val_accuracy: 0.7738
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5622 - accuracy: 0.7644
# Epoch 13: val_accuracy did not improve from 0.77750
# 100/100 [==============================] - 8s 81ms/step - loss: 0.5622 - accuracy: 0.7644 - val_loss: 0.5493 - val_accuracy: 0.7638
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.7697
# Epoch 14: val_accuracy improved from 0.77750 to 0.78125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 81ms/step - loss: 0.5554 - accuracy: 0.7697 - val_loss: 0.5395 - val_accuracy: 0.7812
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5620 - accuracy: 0.7641
# Epoch 15: val_accuracy did not improve from 0.78125
# 100/100 [==============================] - 9s 88ms/step - loss: 0.5620 - accuracy: 0.7641 - val_loss: 0.5584 - val_accuracy: 0.7750
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5455 - accuracy: 0.7816
# Epoch 16: val_accuracy did not improve from 0.78125
# 100/100 [==============================] - 10s 96ms/step - loss: 0.5455 - accuracy: 0.7816 - val_loss: 0.5770 - val_accuracy: 0.7513
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.7797
# Epoch 17: val_accuracy did not improve from 0.78125
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5421 - accuracy: 0.7797 - val_loss: 0.5470 - val_accuracy: 0.7738
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7881
# Epoch 18: val_accuracy did not improve from 0.78125
# 100/100 [==============================] - 8s 83ms/step - loss: 0.5392 - accuracy: 0.7881 - val_loss: 0.5401 - val_accuracy: 0.7763
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5373 - accuracy: 0.7822
# Epoch 19: val_accuracy improved from 0.78125 to 0.78500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5373 - accuracy: 0.7822 - val_loss: 0.5289 - val_accuracy: 0.7850
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5315 - accuracy: 0.7903
# Epoch 20: val_accuracy improved from 0.78500 to 0.78625, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 86ms/step - loss: 0.5315 - accuracy: 0.7903 - val_loss: 0.5278 - val_accuracy: 0.7862
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5246 - accuracy: 0.7916
# Epoch 21: val_accuracy did not improve from 0.78625
# 100/100 [==============================] - 9s 89ms/step - loss: 0.5246 - accuracy: 0.7916 - val_loss: 0.5233 - val_accuracy: 0.7800
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.7916
# Epoch 22: val_accuracy improved from 0.78625 to 0.79125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 87ms/step - loss: 0.5268 - accuracy: 0.7916 - val_loss: 0.5232 - val_accuracy: 0.7912
# Epoch 23/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5256 - accuracy: 0.7950
# Epoch 23: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 88ms/step - loss: 0.5256 - accuracy: 0.7950 - val_loss: 0.5393 - val_accuracy: 0.7725
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.7959
# Epoch 24: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5186 - accuracy: 0.7959 - val_loss: 0.5252 - val_accuracy: 0.7775
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5083 - accuracy: 0.8053
# Epoch 25: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5083 - accuracy: 0.8053 - val_loss: 0.5230 - val_accuracy: 0.7900
# Epoch 26/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5154 - accuracy: 0.7987
# Epoch 26: val_accuracy improved from 0.79125 to 0.79500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5154 - accuracy: 0.7987 - val_loss: 0.5066 - val_accuracy: 0.7950
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.7991
# Epoch 27: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 8s 85ms/step - loss: 0.5089 - accuracy: 0.7991 - val_loss: 0.5389 - val_accuracy: 0.7788
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.8078
# Epoch 28: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5045 - accuracy: 0.8078 - val_loss: 0.5158 - val_accuracy: 0.7812
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5057 - accuracy: 0.8044
# Epoch 29: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5057 - accuracy: 0.8044 - val_loss: 0.5279 - val_accuracy: 0.7775
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.8231
# Epoch 30: val_accuracy improved from 0.79500 to 0.79875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 85ms/step - loss: 0.4835 - accuracy: 0.8231 - val_loss: 0.5129 - val_accuracy: 0.7987
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.8334
# Epoch 31: val_accuracy improved from 0.79875 to 0.80750, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 87ms/step - loss: 0.4721 - accuracy: 0.8334 - val_loss: 0.4896 - val_accuracy: 0.8075
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.8259
# Epoch 32: val_accuracy did not improve from 0.80750
# 100/100 [==============================] - 9s 88ms/step - loss: 0.4747 - accuracy: 0.8259 - val_loss: 0.4915 - val_accuracy: 0.8037
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.8269
# Epoch 33: val_accuracy improved from 0.80750 to 0.81375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4729 - accuracy: 0.8269 - val_loss: 0.4849 - val_accuracy: 0.8138
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8275
# Epoch 34: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 9s 85ms/step - loss: 0.4654 - accuracy: 0.8275 - val_loss: 0.4966 - val_accuracy: 0.8000
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4689 - accuracy: 0.8319
# Epoch 35: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 9s 86ms/step - loss: 0.4689 - accuracy: 0.8319 - val_loss: 0.5375 - val_accuracy: 0.7750
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.8253
# Epoch 36: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 9s 86ms/step - loss: 0.4669 - accuracy: 0.8253 - val_loss: 0.4907 - val_accuracy: 0.8125
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.8322
# Epoch 37: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 13s 132ms/step - loss: 0.4495 - accuracy: 0.8322 - val_loss: 0.4893 - val_accuracy: 0.8112
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.8450
# Epoch 38: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 16s 158ms/step - loss: 0.4490 - accuracy: 0.8450 - val_loss: 0.5433 - val_accuracy: 0.7738
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.8313
# Epoch 39: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 170ms/step - loss: 0.4600 - accuracy: 0.8313 - val_loss: 0.4941 - val_accuracy: 0.7987
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4553 - accuracy: 0.8438
# Epoch 40: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 169ms/step - loss: 0.4553 - accuracy: 0.8438 - val_loss: 0.4801 - val_accuracy: 0.8125
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.8419
# Epoch 41: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 167ms/step - loss: 0.4464 - accuracy: 0.8419 - val_loss: 0.4922 - val_accuracy: 0.8050
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4741 - accuracy: 0.8294
# Epoch 42: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 174ms/step - loss: 0.4741 - accuracy: 0.8294 - val_loss: 0.5173 - val_accuracy: 0.7950
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.8356
# Epoch 43: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 16s 161ms/step - loss: 0.4510 - accuracy: 0.8356 - val_loss: 0.4860 - val_accuracy: 0.8025
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8462
# Epoch 44: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 16s 162ms/step - loss: 0.4365 - accuracy: 0.8462 - val_loss: 0.4806 - val_accuracy: 0.8062
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4243 - accuracy: 0.8506
# Epoch 45: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 168ms/step - loss: 0.4243 - accuracy: 0.8506 - val_loss: 0.4786 - val_accuracy: 0.8087
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.8469
# Epoch 46: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 170ms/step - loss: 0.4311 - accuracy: 0.8469 - val_loss: 0.4913 - val_accuracy: 0.8062
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4263 - accuracy: 0.8509
# Epoch 47: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 17s 169ms/step - loss: 0.4263 - accuracy: 0.8509 - val_loss: 0.5027 - val_accuracy: 0.7987
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.8484
# Epoch 48: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 16s 155ms/step - loss: 0.4286 - accuracy: 0.8484 - val_loss: 0.5035 - val_accuracy: 0.8012
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8522
# Epoch 49: val_accuracy did not improve from 0.81375
# 100/100 [==============================] - 15s 145ms/step - loss: 0.4326 - accuracy: 0.8522 - val_loss: 0.4899 - val_accuracy: 0.8075
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.8472
# Epoch 50: val_accuracy improved from 0.81375 to 0.81500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 15s 149ms/step - loss: 0.4286 - accuracy: 0.8472 - val_loss: 0.4901 - val_accuracy: 0.8150

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de precisión')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

print("Perdida: {:.2f}".format(resul_eva[0]))
print("Accuracy: {:.2%}".format(resul_eva[1]))
# Out:
# Perdida: 0.49
# Accuracy: 81.50%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	50.25%
# Sensitivity:	50.75%
# Specificity:	49.75%
# Precision:	50.25%
# F1-score:	50.50%
