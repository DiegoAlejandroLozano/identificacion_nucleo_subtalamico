# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from pathlib import Path

import pandas as pd
import seaborn as sns
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import shutil
import splitfolders
import os

# %% [markdown]
# Configurar TensorFlow para usar la GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %% [markdown]
# Elimina y recrea directorio split_imagenes, divide imágenes en carpetas de entrenamiento y validación

# %%
transformada = "mexh"

#Ruta al directoria split_imagenes
ruta_imagenes = Path(f"../../../imagenes/{transformada}")
ruta_split_imagenes = Path(f"../../../split_imagenes/{transformada}")

#Si el directorio ya existe, eliminarlo junto con su contendio
if ruta_split_imagenes.exists():
    shutil.rmtree(ruta_split_imagenes)

#Crear el split de las imágenes de la transformada
splitfolders.ratio(input=ruta_imagenes, output=ruta_split_imagenes, ratio=(.8,.2))
# Out:
# Copying files: 4000 files [00:39, 100.17 files/s]

# %% [markdown]
# Se definen algunos parámetros

# %%
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)
epochs = 100
batch_size = 32

# %% [markdown]
# Se crean los generadores de datos de imágenes

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Cargar imágenes de entrenamiento
generador_entrenamiento = train_datagen.flow_from_directory(
    ruta_split_imagenes/"train",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Cargar imágenes de validación
generador_validacion = valid_datagen.flow_from_directory(
    ruta_split_imagenes/"val",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
tamanio_ventana = (2,2)

# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(32, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))
clasificador.add(Conv2D(16, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))
clasificador.add(Conv2D(8, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=32, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8430 - accuracy: 0.6394
# Epoch 1: val_accuracy improved from -inf to 0.64250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 85s 804ms/step - loss: 0.8430 - accuracy: 0.6394 - val_loss: 0.7171 - val_accuracy: 0.6425
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6788 - accuracy: 0.6653
# Epoch 2: val_accuracy improved from 0.64250 to 0.66750, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 87ms/step - loss: 0.6788 - accuracy: 0.6653 - val_loss: 0.6571 - val_accuracy: 0.6675
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6274 - accuracy: 0.6875
# Epoch 3: val_accuracy improved from 0.66750 to 0.68500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 86ms/step - loss: 0.6274 - accuracy: 0.6875 - val_loss: 0.6204 - val_accuracy: 0.6850
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5998 - accuracy: 0.6941
# Epoch 4: val_accuracy did not improve from 0.68500
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5998 - accuracy: 0.6941 - val_loss: 0.6117 - val_accuracy: 0.6775
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5784 - accuracy: 0.7069
# Epoch 5: val_accuracy improved from 0.68500 to 0.72125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 8s 85ms/step - loss: 0.5784 - accuracy: 0.7069 - val_loss: 0.5843 - val_accuracy: 0.7212
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.7206
# Epoch 6: val_accuracy improved from 0.72125 to 0.73625, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 85ms/step - loss: 0.5554 - accuracy: 0.7206 - val_loss: 0.5675 - val_accuracy: 0.7362
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5499 - accuracy: 0.7163
# Epoch 7: val_accuracy did not improve from 0.73625
# 100/100 [==============================] - 8s 84ms/step - loss: 0.5499 - accuracy: 0.7163 - val_loss: 0.5814 - val_accuracy: 0.7200
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5318 - accuracy: 0.7275
# Epoch 8: val_accuracy improved from 0.73625 to 0.74500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 86ms/step - loss: 0.5318 - accuracy: 0.7275 - val_loss: 0.5825 - val_accuracy: 0.7450
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5194 - accuracy: 0.7538
# Epoch 9: val_accuracy did not improve from 0.74500
# 100/100 [==============================] - 9s 89ms/step - loss: 0.5194 - accuracy: 0.7538 - val_loss: 0.5577 - val_accuracy: 0.7450
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.7525
# Epoch 10: val_accuracy improved from 0.74500 to 0.75625, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 86ms/step - loss: 0.5026 - accuracy: 0.7525 - val_loss: 0.5968 - val_accuracy: 0.7563
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.7588
# Epoch 11: val_accuracy did not improve from 0.75625
# 100/100 [==============================] - 9s 86ms/step - loss: 0.5125 - accuracy: 0.7588 - val_loss: 0.5669 - val_accuracy: 0.7525
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7728
# Epoch 12: val_accuracy improved from 0.75625 to 0.77000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 85ms/step - loss: 0.4792 - accuracy: 0.7728 - val_loss: 0.5726 - val_accuracy: 0.7700
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.7709
# Epoch 13: val_accuracy did not improve from 0.77000
# 100/100 [==============================] - 9s 85ms/step - loss: 0.4873 - accuracy: 0.7709 - val_loss: 0.5980 - val_accuracy: 0.7563
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.7788
# Epoch 14: val_accuracy did not improve from 0.77000
# 100/100 [==============================] - 9s 85ms/step - loss: 0.4722 - accuracy: 0.7788 - val_loss: 0.5678 - val_accuracy: 0.7613
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.7763
# Epoch 15: val_accuracy did not improve from 0.77000
# 100/100 [==============================] - 9s 86ms/step - loss: 0.4700 - accuracy: 0.7763 - val_loss: 0.6435 - val_accuracy: 0.7300
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.7834
# Epoch 16: val_accuracy did not improve from 0.77000
# 100/100 [==============================] - 9s 87ms/step - loss: 0.4724 - accuracy: 0.7834 - val_loss: 0.5959 - val_accuracy: 0.7688
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4631 - accuracy: 0.7878
# Epoch 17: val_accuracy did not improve from 0.77000
# 100/100 [==============================] - 9s 86ms/step - loss: 0.4631 - accuracy: 0.7878 - val_loss: 0.6090 - val_accuracy: 0.7425
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8047
# Epoch 18: val_accuracy did not improve from 0.77000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.4511 - accuracy: 0.8047 - val_loss: 0.6077 - val_accuracy: 0.7600
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4459 - accuracy: 0.8044
# Epoch 19: val_accuracy improved from 0.77000 to 0.79125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4459 - accuracy: 0.8044 - val_loss: 0.5702 - val_accuracy: 0.7912
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4460 - accuracy: 0.8000
# Epoch 20: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 10s 95ms/step - loss: 0.4460 - accuracy: 0.8000 - val_loss: 0.6094 - val_accuracy: 0.7663
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.8034
# Epoch 21: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4319 - accuracy: 0.8034 - val_loss: 0.6130 - val_accuracy: 0.7788
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4395 - accuracy: 0.8100
# Epoch 22: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 94ms/step - loss: 0.4395 - accuracy: 0.8100 - val_loss: 0.5734 - val_accuracy: 0.7837
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4200 - accuracy: 0.8213
# Epoch 23: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 91ms/step - loss: 0.4200 - accuracy: 0.8213 - val_loss: 0.6182 - val_accuracy: 0.7700
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4225 - accuracy: 0.8219
# Epoch 24: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 89ms/step - loss: 0.4225 - accuracy: 0.8219 - val_loss: 0.6247 - val_accuracy: 0.7700
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4281 - accuracy: 0.8109
# Epoch 25: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 87ms/step - loss: 0.4281 - accuracy: 0.8109 - val_loss: 0.6114 - val_accuracy: 0.7575
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8247
# Epoch 26: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 9s 88ms/step - loss: 0.4219 - accuracy: 0.8247 - val_loss: 0.6368 - val_accuracy: 0.7663
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4197 - accuracy: 0.8275
# Epoch 27: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 10s 98ms/step - loss: 0.4197 - accuracy: 0.8275 - val_loss: 0.6384 - val_accuracy: 0.7825
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3985 - accuracy: 0.8553
# Epoch 28: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 120ms/step - loss: 0.3985 - accuracy: 0.8553 - val_loss: 0.6631 - val_accuracy: 0.7800
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4046 - accuracy: 0.8438
# Epoch 29: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 11s 112ms/step - loss: 0.4046 - accuracy: 0.8438 - val_loss: 0.6436 - val_accuracy: 0.7812
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8466
# Epoch 30: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4095 - accuracy: 0.8466 - val_loss: 0.6435 - val_accuracy: 0.7713
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3937 - accuracy: 0.8478
# Epoch 31: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3937 - accuracy: 0.8478 - val_loss: 0.7036 - val_accuracy: 0.7625
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.8509
# Epoch 32: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 118ms/step - loss: 0.3859 - accuracy: 0.8509 - val_loss: 0.7238 - val_accuracy: 0.7713
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8528
# Epoch 33: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 125ms/step - loss: 0.3905 - accuracy: 0.8528 - val_loss: 0.7324 - val_accuracy: 0.7738
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.8541
# Epoch 34: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 124ms/step - loss: 0.3901 - accuracy: 0.8541 - val_loss: 0.7316 - val_accuracy: 0.7538
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.8544
# Epoch 35: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3954 - accuracy: 0.8544 - val_loss: 0.6512 - val_accuracy: 0.7663
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3847 - accuracy: 0.8631
# Epoch 36: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3847 - accuracy: 0.8631 - val_loss: 0.7637 - val_accuracy: 0.7462
# Epoch 37/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3740 - accuracy: 0.8659
# Epoch 37: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 11s 106ms/step - loss: 0.3740 - accuracy: 0.8659 - val_loss: 0.7835 - val_accuracy: 0.7675
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8594
# Epoch 38: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 11s 113ms/step - loss: 0.3931 - accuracy: 0.8594 - val_loss: 0.7880 - val_accuracy: 0.7588
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8637
# Epoch 39: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 12s 116ms/step - loss: 0.3756 - accuracy: 0.8637 - val_loss: 0.7485 - val_accuracy: 0.7613
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8722
# Epoch 40: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 11s 114ms/step - loss: 0.3804 - accuracy: 0.8722 - val_loss: 0.7632 - val_accuracy: 0.7525
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.8741
# Epoch 41: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 10s 104ms/step - loss: 0.3647 - accuracy: 0.8741 - val_loss: 0.7279 - val_accuracy: 0.7575
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8709
# Epoch 42: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 176ms/step - loss: 0.3614 - accuracy: 0.8709 - val_loss: 0.7358 - val_accuracy: 0.7600
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.8769
# Epoch 43: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 19s 186ms/step - loss: 0.3680 - accuracy: 0.8769 - val_loss: 0.7256 - val_accuracy: 0.7550
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3557 - accuracy: 0.8797
# Epoch 44: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 171ms/step - loss: 0.3557 - accuracy: 0.8797 - val_loss: 0.8579 - val_accuracy: 0.7450
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3611 - accuracy: 0.8769
# Epoch 45: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 19s 187ms/step - loss: 0.3611 - accuracy: 0.8769 - val_loss: 0.9360 - val_accuracy: 0.7437
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.8731
# Epoch 46: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 20s 203ms/step - loss: 0.3621 - accuracy: 0.8731 - val_loss: 0.7370 - val_accuracy: 0.7763
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3616 - accuracy: 0.8772
# Epoch 47: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 163ms/step - loss: 0.3616 - accuracy: 0.8772 - val_loss: 0.7269 - val_accuracy: 0.7525
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8781
# Epoch 48: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 172ms/step - loss: 0.3559 - accuracy: 0.8781 - val_loss: 0.7038 - val_accuracy: 0.7563
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.8797
# Epoch 49: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3493 - accuracy: 0.8797 - val_loss: 0.7729 - val_accuracy: 0.7713
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8844
# Epoch 50: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 171ms/step - loss: 0.3463 - accuracy: 0.8844 - val_loss: 0.7642 - val_accuracy: 0.7750
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.8831
# Epoch 51: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 15s 150ms/step - loss: 0.3561 - accuracy: 0.8831 - val_loss: 0.7512 - val_accuracy: 0.7725
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.8866
# Epoch 52: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3508 - accuracy: 0.8866 - val_loss: 0.6925 - val_accuracy: 0.7638
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8844
# Epoch 53: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 133ms/step - loss: 0.3444 - accuracy: 0.8844 - val_loss: 0.8177 - val_accuracy: 0.7600
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8956
# Epoch 54: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 133ms/step - loss: 0.3358 - accuracy: 0.8956 - val_loss: 0.7767 - val_accuracy: 0.7625
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8941
# Epoch 55: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 130ms/step - loss: 0.3307 - accuracy: 0.8941 - val_loss: 0.8819 - val_accuracy: 0.7613
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.8847
# Epoch 56: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 131ms/step - loss: 0.3493 - accuracy: 0.8847 - val_loss: 0.7656 - val_accuracy: 0.7650
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8897
# Epoch 57: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3488 - accuracy: 0.8897 - val_loss: 0.7418 - val_accuracy: 0.7613
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.8847
# Epoch 58: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 133ms/step - loss: 0.3526 - accuracy: 0.8847 - val_loss: 0.7073 - val_accuracy: 0.7688
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8778
# Epoch 59: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 133ms/step - loss: 0.3559 - accuracy: 0.8778 - val_loss: 0.7447 - val_accuracy: 0.7600
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8859
# Epoch 60: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3465 - accuracy: 0.8859 - val_loss: 0.8510 - val_accuracy: 0.7575
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3426 - accuracy: 0.8928
# Epoch 61: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 131ms/step - loss: 0.3426 - accuracy: 0.8928 - val_loss: 0.8179 - val_accuracy: 0.7825
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3270 - accuracy: 0.8997
# Epoch 62: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 134ms/step - loss: 0.3270 - accuracy: 0.8997 - val_loss: 0.9496 - val_accuracy: 0.7550
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3441 - accuracy: 0.8928
# Epoch 63: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 14s 142ms/step - loss: 0.3441 - accuracy: 0.8928 - val_loss: 0.8192 - val_accuracy: 0.7575
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8981
# Epoch 64: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 15s 145ms/step - loss: 0.3290 - accuracy: 0.8981 - val_loss: 0.8446 - val_accuracy: 0.7650
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8972
# Epoch 65: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3326 - accuracy: 0.8972 - val_loss: 0.8391 - val_accuracy: 0.7625
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3299 - accuracy: 0.8997
# Epoch 66: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 134ms/step - loss: 0.3299 - accuracy: 0.8997 - val_loss: 0.8193 - val_accuracy: 0.7725
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8963
# Epoch 67: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 161ms/step - loss: 0.3316 - accuracy: 0.8963 - val_loss: 0.8613 - val_accuracy: 0.7563
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3312 - accuracy: 0.9019
# Epoch 68: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 14s 140ms/step - loss: 0.3312 - accuracy: 0.9019 - val_loss: 0.8146 - val_accuracy: 0.7663
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8981
# Epoch 69: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 14s 134ms/step - loss: 0.3281 - accuracy: 0.8981 - val_loss: 0.8355 - val_accuracy: 0.7775
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.9059
# Epoch 70: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 133ms/step - loss: 0.3234 - accuracy: 0.9059 - val_loss: 0.9006 - val_accuracy: 0.7613
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8997
# Epoch 71: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3327 - accuracy: 0.8997 - val_loss: 0.8788 - val_accuracy: 0.7575
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.9050
# Epoch 72: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3210 - accuracy: 0.9050 - val_loss: 0.8546 - val_accuracy: 0.7600
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.9025
# Epoch 73: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3257 - accuracy: 0.9025 - val_loss: 0.7915 - val_accuracy: 0.7638
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.9041
# Epoch 74: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.3277 - accuracy: 0.9041 - val_loss: 0.8083 - val_accuracy: 0.7663
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.9072
# Epoch 75: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 130ms/step - loss: 0.3125 - accuracy: 0.9072 - val_loss: 0.8480 - val_accuracy: 0.7688
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8984
# Epoch 76: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 14s 135ms/step - loss: 0.3247 - accuracy: 0.8984 - val_loss: 0.8130 - val_accuracy: 0.7800
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.9159
# Epoch 77: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 13s 132ms/step - loss: 0.2954 - accuracy: 0.9159 - val_loss: 0.8095 - val_accuracy: 0.7775
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.9103
# Epoch 78: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 15s 148ms/step - loss: 0.3103 - accuracy: 0.9103 - val_loss: 0.9707 - val_accuracy: 0.7625
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2969 - accuracy: 0.9191
# Epoch 79: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 163ms/step - loss: 0.2969 - accuracy: 0.9191 - val_loss: 0.8519 - val_accuracy: 0.7613
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.9087
# Epoch 80: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 174ms/step - loss: 0.3156 - accuracy: 0.9087 - val_loss: 0.8239 - val_accuracy: 0.7575
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.9141
# Epoch 81: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 169ms/step - loss: 0.3124 - accuracy: 0.9141 - val_loss: 0.8042 - val_accuracy: 0.7688
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3013 - accuracy: 0.9222
# Epoch 82: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3013 - accuracy: 0.9222 - val_loss: 0.8294 - val_accuracy: 0.7625
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.9178
# Epoch 83: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3034 - accuracy: 0.9178 - val_loss: 0.8706 - val_accuracy: 0.7575
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.9181
# Epoch 84: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 19s 184ms/step - loss: 0.3024 - accuracy: 0.9181 - val_loss: 0.7902 - val_accuracy: 0.7750
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.9241
# Epoch 85: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 169ms/step - loss: 0.2944 - accuracy: 0.9241 - val_loss: 0.8932 - val_accuracy: 0.7663
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.9128
# Epoch 86: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3060 - accuracy: 0.9128 - val_loss: 0.9720 - val_accuracy: 0.7600
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.9112
# Epoch 87: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 166ms/step - loss: 0.3072 - accuracy: 0.9112 - val_loss: 0.9041 - val_accuracy: 0.7713
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9162
# Epoch 88: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 162ms/step - loss: 0.3019 - accuracy: 0.9162 - val_loss: 0.8866 - val_accuracy: 0.7713
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.9231
# Epoch 89: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 162ms/step - loss: 0.2990 - accuracy: 0.9231 - val_loss: 0.8207 - val_accuracy: 0.7600
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.9237
# Epoch 90: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 18s 175ms/step - loss: 0.2896 - accuracy: 0.9237 - val_loss: 0.8609 - val_accuracy: 0.7675
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.9303
# Epoch 91: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 164ms/step - loss: 0.2881 - accuracy: 0.9303 - val_loss: 0.9610 - val_accuracy: 0.7625
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.9109
# Epoch 92: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 163ms/step - loss: 0.3018 - accuracy: 0.9109 - val_loss: 0.8288 - val_accuracy: 0.7638
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.9147
# Epoch 93: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 162ms/step - loss: 0.2996 - accuracy: 0.9147 - val_loss: 0.8900 - val_accuracy: 0.7750
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.9237
# Epoch 94: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 165ms/step - loss: 0.2913 - accuracy: 0.9237 - val_loss: 0.8790 - val_accuracy: 0.7738
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.9241
# Epoch 95: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 165ms/step - loss: 0.2865 - accuracy: 0.9241 - val_loss: 0.8876 - val_accuracy: 0.7563
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.9216
# Epoch 96: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 164ms/step - loss: 0.2869 - accuracy: 0.9216 - val_loss: 0.9271 - val_accuracy: 0.7525
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.9275
# Epoch 97: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 164ms/step - loss: 0.2830 - accuracy: 0.9275 - val_loss: 0.8321 - val_accuracy: 0.7513
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.9159
# Epoch 98: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 164ms/step - loss: 0.3054 - accuracy: 0.9159 - val_loss: 1.0315 - val_accuracy: 0.7700
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.9216
# Epoch 99: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 16s 160ms/step - loss: 0.2972 - accuracy: 0.9216 - val_loss: 0.9342 - val_accuracy: 0.7663
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.9331
# Epoch 100: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 17s 164ms/step - loss: 0.2749 - accuracy: 0.9331 - val_loss: 0.9863 - val_accuracy: 0.7600

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de Loss')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.57
# Accuracy: 79.12%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	50.88%
# Sensitivity:	49.25%
# Specificity:	52.50%
# Precision:	50.90%
# F1-score:	50.06%
