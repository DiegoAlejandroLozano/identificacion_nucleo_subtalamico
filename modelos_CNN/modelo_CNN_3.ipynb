# %%
from keras.models import Sequential
from keras.layers import Convolution2D        
from keras.layers import MaxPooling2D       
from keras.layers import Flatten            
from keras.layers import Dense 
from keras.layers import Dropout

from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.preprocessing import image

from sklearn.model_selection import train_test_split

import numpy as np

# %%
#Definir rutas de las carétas que contienen las imágenes
data_dir = "../imagenes2/cgau1"
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)

# %%
#Hiperparámetros
epochs =20
batch_size = 100

# %%
#Generador de datos para procesamiento y aumento de datos
datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Obtener todas las imágenes y sus etiquetas
image_data = datagen.flow_from_directory(
    data_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = "binary",
    classes = ["stn", "otras"] # clases correspondientes a las carpetas stn y otras
)
# Out:
# Found 4000 images belonging to 2 classes.

# %%
# Inicializar listas para almacenar todos los datos generados
all_X = []
all_y = []

# %%
# Iterar sobre el generador y recopilar todos los lotes de datos
for i in range(len(image_data)):
    batch_X, batch_y = image_data[i]
    all_X.append(batch_X)
    all_y.append(batch_y)

# %%
# Concatenar todos los lotes de datos en un solo conjunto
all_X = np.concatenate(all_X)
all_y = np.concatenate(all_y)

# %%
#Dividir los datos en conjuntos de entranamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    all_X, 
    all_y,
    test_size=0.3,
    random_state=42
)

# %%
X_train.shape
# Out:
# (2800, 250, 250, 3)

# %%
y_train.shape
# Out:
# (2800,)

# %%
X_test.shape
# Out:
# (1200, 250, 250, 3)

# %%
y_test.shape
# Out:
# (1200,)

# %%
#Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Convolution2D(input_shape = input_shape,filters=16,kernel_size=(5,5),activation="relu"))
clasificador.add(MaxPooling2D(pool_size=(4,4)))
clasificador.add(Convolution2D(filters=32,kernel_size=(5,5),activation="relu"))
clasificador.add(MaxPooling2D(pool_size=(4,4)))

#Capa de aplanamiento
clasificador.add(Flatten())

#Se agregan las capas densas
clasificador.add(Dense(units=16, activation="relu"))
clasificador.add(Dropout(rate=0.5))

#Capa de salida
clasificador.add(Dense(units=1,activation="sigmoid"))

# %%
#Compilar el modelo
clasificador.compile(
    optimizer = "adam",
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

# %%
#Entrenar el modelo
history = clasificador.fit(
    X_train,
    y_train,
    steps_per_epoch=32,
    epochs = epochs,
    validation_data = (X_test, y_test)
)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 224s 7s/step - loss: 0.6951 - accuracy: 0.5414 - val_loss: 0.6716 - val_accuracy: 0.7042
# Epoch 2/20
# 32/32 [==============================] - 207s 6s/step - loss: 0.6846 - accuracy: 0.5625 - val_loss: 0.6808 - val_accuracy: 0.7050
# Epoch 3/20
# 32/32 [==============================] - 208s 6s/step - loss: 0.6711 - accuracy: 0.6000 - val_loss: 0.6567 - val_accuracy: 0.6867
# Epoch 4/20
# 32/32 [==============================] - 204s 6s/step - loss: 0.6504 - accuracy: 0.6304 - val_loss: 0.6281 - val_accuracy: 0.7025
# Epoch 5/20
# 32/32 [==============================] - 203s 6s/step - loss: 0.5944 - accuracy: 0.6675 - val_loss: 0.5423 - val_accuracy: 0.7208
# Epoch 6/20
# 32/32 [==============================] - 211s 7s/step - loss: 0.5731 - accuracy: 0.6414 - val_loss: 0.5622 - val_accuracy: 0.6883
# Epoch 7/20
# 32/32 [==============================] - 201s 6s/step - loss: 0.5741 - accuracy: 0.6829 - val_loss: 0.5367 - val_accuracy: 0.7625
# Epoch 8/20
# 32/32 [==============================] - 202s 6s/step - loss: 0.5359 - accuracy: 0.7182 - val_loss: 0.5369 - val_accuracy: 0.7567
# Epoch 9/20
# 32/32 [==============================] - 202s 6s/step - loss: 0.5404 - accuracy: 0.7250 - val_loss: 0.5395 - val_accuracy: 0.7650
# Epoch 10/20
# 32/32 [==============================] - 216s 7s/step - loss: 0.5217 - accuracy: 0.7239 - val_loss: 0.4961 - val_accuracy: 0.7883
# Epoch 11/20
# 32/32 [==============================] - 168s 5s/step - loss: 0.5075 - accuracy: 0.7411 - val_loss: 0.4952 - val_accuracy: 0.7775
# Epoch 12/20
# 32/32 [==============================] - 230s 7s/step - loss: 0.4986 - accuracy: 0.7425 - val_loss: 0.4896 - val_accuracy: 0.7975
# Epoch 13/20
# 32/32 [==============================] - 215s 7s/step - loss: 0.4903 - accuracy: 0.7511 - val_loss: 0.4856 - val_accuracy: 0.8008
# Epoch 14/20
# 32/32 [==============================] - 202s 6s/step - loss: 0.4819 - accuracy: 0.7650 - val_loss: 0.5025 - val_accuracy: 0.7933
# Epoch 15/20
# 32/32 [==============================] - 206s 6s/step - loss: 0.4748 - accuracy: 0.7525 - val_loss: 0.4892 - val_accuracy: 0.7992
# Epoch 16/20
# 32/32 [==============================] - 207s 6s/step - loss: 0.4694 - accuracy: 0.7661 - val_loss: 0.4829 - val_accuracy: 0.7983
# Epoch 17/20
# 32/32 [==============================] - 199s 6s/step - loss: 0.4661 - accuracy: 0.7589 - val_loss: 0.4705 - val_accuracy: 0.7917
# Epoch 18/20
# 32/32 [==============================] - 205s 6s/step - loss: 0.4573 - accuracy: 0.7693 - val_loss: 0.4859 - val_accuracy: 0.8050
# Epoch 19/20
# 32/32 [==============================] - 198s 6s/step - loss: 0.4606 - accuracy: 0.7650 - val_loss: 0.5100 - val_accuracy: 0.7900
# Epoch 20/20
# 32/32 [==============================] - 198s 6s/step - loss: 0.4460 - accuracy: 0.7746 - val_loss: 0.5179 - val_accuracy: 0.7808

# %%
import matplotlib.pyplot as plt

# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de precisión')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

plt.tight_layout()
plt.show()
