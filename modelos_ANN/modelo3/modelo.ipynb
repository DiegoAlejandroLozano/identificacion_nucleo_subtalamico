# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))


modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/200
# 6/7 [========================>.....] - ETA: 0s - loss: 2.9597 - accuracy: 0.5212
# Epoch 1: val_accuracy improved from -inf to 0.68625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 2s 99ms/step - loss: 2.9147 - accuracy: 0.5206 - val_loss: 1.6393 - val_accuracy: 0.6862
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.3395 - accuracy: 0.6221
# Epoch 2: val_accuracy improved from 0.68625 to 0.73375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 1.3316 - accuracy: 0.6147 - val_loss: 1.0522 - val_accuracy: 0.7337
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.0037 - accuracy: 0.6410
# Epoch 3: val_accuracy did not improve from 0.73375
# 7/7 [==============================] - 0s 62ms/step - loss: 1.0006 - accuracy: 0.6419 - val_loss: 0.9143 - val_accuracy: 0.6812
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8733 - accuracy: 0.6979
# Epoch 4: val_accuracy did not improve from 0.73375
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8705 - accuracy: 0.6981 - val_loss: 0.7823 - val_accuracy: 0.6712
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7207 - accuracy: 0.7484
# Epoch 5: val_accuracy improved from 0.73375 to 0.76375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.7190 - accuracy: 0.7466 - val_loss: 0.6827 - val_accuracy: 0.7638
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6353 - accuracy: 0.7673
# Epoch 6: val_accuracy did not improve from 0.76375
# 7/7 [==============================] - 0s 64ms/step - loss: 0.6360 - accuracy: 0.7663 - val_loss: 0.6552 - val_accuracy: 0.6837
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5833 - accuracy: 0.7721
# Epoch 7: val_accuracy improved from 0.76375 to 0.77750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 0.5843 - accuracy: 0.7709 - val_loss: 0.5679 - val_accuracy: 0.7775
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.7928
# Epoch 8: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5389 - accuracy: 0.7928 - val_loss: 0.5588 - val_accuracy: 0.7675
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5249 - accuracy: 0.7845
# Epoch 9: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.5240 - accuracy: 0.7853 - val_loss: 0.5207 - val_accuracy: 0.7750
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.7875
# Epoch 10: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5110 - accuracy: 0.7875 - val_loss: 0.5028 - val_accuracy: 0.7738
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4847 - accuracy: 0.8001
# Epoch 11: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4838 - accuracy: 0.8000 - val_loss: 0.5914 - val_accuracy: 0.7150
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5387 - accuracy: 0.7646
# Epoch 12: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5425 - accuracy: 0.7619 - val_loss: 0.5062 - val_accuracy: 0.7675
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5104 - accuracy: 0.7871
# Epoch 13: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5139 - accuracy: 0.7841 - val_loss: 0.5137 - val_accuracy: 0.7650
# Epoch 14/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5074 - accuracy: 0.7839
# Epoch 14: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5066 - accuracy: 0.7831 - val_loss: 0.4916 - val_accuracy: 0.7750
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4929 - accuracy: 0.7887
# Epoch 15: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4913 - accuracy: 0.7887 - val_loss: 0.5001 - val_accuracy: 0.7688
# Epoch 16/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4982 - accuracy: 0.7832
# Epoch 16: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4954 - accuracy: 0.7847 - val_loss: 0.5697 - val_accuracy: 0.7437
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4922 - accuracy: 0.7874
# Epoch 17: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4915 - accuracy: 0.7875 - val_loss: 0.4835 - val_accuracy: 0.7763
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.8019
# Epoch 18: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4590 - accuracy: 0.8019 - val_loss: 0.4679 - val_accuracy: 0.7775
# Epoch 19/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4613 - accuracy: 0.8073
# Epoch 19: val_accuracy improved from 0.77750 to 0.80750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4642 - accuracy: 0.8047 - val_loss: 0.4602 - val_accuracy: 0.8075
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4517 - accuracy: 0.8118
# Epoch 20: val_accuracy did not improve from 0.80750
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4550 - accuracy: 0.8100 - val_loss: 0.4677 - val_accuracy: 0.7912
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4634 - accuracy: 0.7962
# Epoch 21: val_accuracy did not improve from 0.80750
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4661 - accuracy: 0.7947 - val_loss: 0.4657 - val_accuracy: 0.7763
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4550 - accuracy: 0.8041
# Epoch 22: val_accuracy improved from 0.80750 to 0.81000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4550 - accuracy: 0.8041 - val_loss: 0.4996 - val_accuracy: 0.8100
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.7991
# Epoch 23: val_accuracy improved from 0.81000 to 0.81625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 71ms/step - loss: 0.4690 - accuracy: 0.7991 - val_loss: 0.4665 - val_accuracy: 0.8163
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4833 - accuracy: 0.7936
# Epoch 24: val_accuracy did not improve from 0.81625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4809 - accuracy: 0.7953 - val_loss: 0.4854 - val_accuracy: 0.7800
# Epoch 25/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4765 - accuracy: 0.7962
# Epoch 25: val_accuracy did not improve from 0.81625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4764 - accuracy: 0.7962 - val_loss: 0.4664 - val_accuracy: 0.7725
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4549 - accuracy: 0.8073
# Epoch 26: val_accuracy did not improve from 0.81625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4542 - accuracy: 0.8069 - val_loss: 0.4514 - val_accuracy: 0.7750
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4412 - accuracy: 0.8063
# Epoch 27: val_accuracy did not improve from 0.81625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4397 - accuracy: 0.8075 - val_loss: 0.4481 - val_accuracy: 0.8138
# Epoch 28/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4430 - accuracy: 0.8132
# Epoch 28: val_accuracy did not improve from 0.81625
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4412 - accuracy: 0.8153 - val_loss: 0.4539 - val_accuracy: 0.8163
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4338 - accuracy: 0.8161
# Epoch 29: val_accuracy improved from 0.81625 to 0.82375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4334 - accuracy: 0.8169 - val_loss: 0.4615 - val_accuracy: 0.8238
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4452 - accuracy: 0.8125
# Epoch 30: val_accuracy improved from 0.82375 to 0.82625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4460 - accuracy: 0.8119 - val_loss: 0.4892 - val_accuracy: 0.8263
# Epoch 31/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4677 - accuracy: 0.8089
# Epoch 31: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4663 - accuracy: 0.8091 - val_loss: 0.4570 - val_accuracy: 0.7775
# Epoch 32/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4298 - accuracy: 0.8324
# Epoch 32: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4293 - accuracy: 0.8322 - val_loss: 0.4605 - val_accuracy: 0.7837
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4384 - accuracy: 0.8291
# Epoch 33: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4384 - accuracy: 0.8288 - val_loss: 0.4505 - val_accuracy: 0.7887
# Epoch 34/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4437 - accuracy: 0.8190
# Epoch 34: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4449 - accuracy: 0.8184 - val_loss: 0.4875 - val_accuracy: 0.8100
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4536 - accuracy: 0.8158
# Epoch 35: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4543 - accuracy: 0.8153 - val_loss: 0.4848 - val_accuracy: 0.8112
# Epoch 36/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4423 - accuracy: 0.8327
# Epoch 36: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4415 - accuracy: 0.8334 - val_loss: 0.4839 - val_accuracy: 0.7900
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4415 - accuracy: 0.8197
# Epoch 37: val_accuracy improved from 0.82625 to 0.83625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4425 - accuracy: 0.8191 - val_loss: 0.4458 - val_accuracy: 0.8363
# Epoch 38/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4197 - accuracy: 0.8532
# Epoch 38: val_accuracy did not improve from 0.83625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4219 - accuracy: 0.8516 - val_loss: 0.4381 - val_accuracy: 0.8163
# Epoch 39/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4273 - accuracy: 0.8340
# Epoch 39: val_accuracy did not improve from 0.83625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4289 - accuracy: 0.8334 - val_loss: 0.4960 - val_accuracy: 0.7937
# Epoch 40/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4434 - accuracy: 0.8346
# Epoch 40: val_accuracy did not improve from 0.83625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4396 - accuracy: 0.8366 - val_loss: 0.4591 - val_accuracy: 0.7937
# Epoch 41/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4430 - accuracy: 0.8239
# Epoch 41: val_accuracy improved from 0.83625 to 0.84250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 70ms/step - loss: 0.4441 - accuracy: 0.8225 - val_loss: 0.4338 - val_accuracy: 0.8425
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4473 - accuracy: 0.8262
# Epoch 42: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4464 - accuracy: 0.8263 - val_loss: 0.4258 - val_accuracy: 0.8238
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4177 - accuracy: 0.8447
# Epoch 43: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4171 - accuracy: 0.8447 - val_loss: 0.4360 - val_accuracy: 0.8112
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.8450
# Epoch 44: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4124 - accuracy: 0.8450 - val_loss: 0.4834 - val_accuracy: 0.8175
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4525 - accuracy: 0.8255
# Epoch 45: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4504 - accuracy: 0.8259 - val_loss: 0.4565 - val_accuracy: 0.7962
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4352 - accuracy: 0.8372
# Epoch 46: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4352 - accuracy: 0.8372 - val_loss: 0.5312 - val_accuracy: 0.7887
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4478 - accuracy: 0.8271
# Epoch 47: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4493 - accuracy: 0.8272 - val_loss: 0.4609 - val_accuracy: 0.8200
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4484 - accuracy: 0.8278
# Epoch 48: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4462 - accuracy: 0.8294 - val_loss: 0.5307 - val_accuracy: 0.7812
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4750 - accuracy: 0.8096
# Epoch 49: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4729 - accuracy: 0.8131 - val_loss: 0.4822 - val_accuracy: 0.8012
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4390 - accuracy: 0.8245
# Epoch 50: val_accuracy improved from 0.84250 to 0.85375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4376 - accuracy: 0.8250 - val_loss: 0.4125 - val_accuracy: 0.8537
# Epoch 51/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4257 - accuracy: 0.8428
# Epoch 51: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4255 - accuracy: 0.8434 - val_loss: 0.4259 - val_accuracy: 0.8512
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4214 - accuracy: 0.8490
# Epoch 52: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4194 - accuracy: 0.8506 - val_loss: 0.4368 - val_accuracy: 0.8263
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4071 - accuracy: 0.8418
# Epoch 53: val_accuracy improved from 0.85375 to 0.86375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4086 - accuracy: 0.8419 - val_loss: 0.4094 - val_accuracy: 0.8637
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4153 - accuracy: 0.8578
# Epoch 54: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4153 - accuracy: 0.8578 - val_loss: 0.4241 - val_accuracy: 0.8363
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4042 - accuracy: 0.8584
# Epoch 55: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4063 - accuracy: 0.8566 - val_loss: 0.5704 - val_accuracy: 0.7738
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4772 - accuracy: 0.8086
# Epoch 56: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4735 - accuracy: 0.8125 - val_loss: 0.4803 - val_accuracy: 0.7975
# Epoch 57/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4467 - accuracy: 0.8411
# Epoch 57: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4442 - accuracy: 0.8422 - val_loss: 0.4470 - val_accuracy: 0.8388
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4200 - accuracy: 0.8529
# Epoch 58: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4196 - accuracy: 0.8528 - val_loss: 0.4390 - val_accuracy: 0.8475
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4103 - accuracy: 0.8600
# Epoch 59: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4086 - accuracy: 0.8616 - val_loss: 0.4126 - val_accuracy: 0.8562
# Epoch 60/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3926 - accuracy: 0.8691
# Epoch 60: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3914 - accuracy: 0.8697 - val_loss: 0.4037 - val_accuracy: 0.8587
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3997 - accuracy: 0.8620
# Epoch 61: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4031 - accuracy: 0.8603 - val_loss: 0.4032 - val_accuracy: 0.8587
# Epoch 62/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4119 - accuracy: 0.8564
# Epoch 62: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4100 - accuracy: 0.8578 - val_loss: 0.4730 - val_accuracy: 0.8025
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4123 - accuracy: 0.8473
# Epoch 63: val_accuracy improved from 0.86375 to 0.86500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 75ms/step - loss: 0.4127 - accuracy: 0.8478 - val_loss: 0.3966 - val_accuracy: 0.8650
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3990 - accuracy: 0.8634
# Epoch 64: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3990 - accuracy: 0.8634 - val_loss: 0.4085 - val_accuracy: 0.8587
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4102 - accuracy: 0.8561
# Epoch 65: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4094 - accuracy: 0.8562 - val_loss: 0.4254 - val_accuracy: 0.8400
# Epoch 66/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3916 - accuracy: 0.8688
# Epoch 66: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3920 - accuracy: 0.8691 - val_loss: 0.3795 - val_accuracy: 0.8462
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3775 - accuracy: 0.8685
# Epoch 67: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3784 - accuracy: 0.8681 - val_loss: 0.3796 - val_accuracy: 0.8575
# Epoch 68/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3706 - accuracy: 0.8779
# Epoch 68: val_accuracy improved from 0.86500 to 0.86625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 71ms/step - loss: 0.3708 - accuracy: 0.8778 - val_loss: 0.3848 - val_accuracy: 0.8662
# Epoch 69/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3719 - accuracy: 0.8803
# Epoch 69: val_accuracy improved from 0.86625 to 0.86750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3719 - accuracy: 0.8803 - val_loss: 0.3774 - val_accuracy: 0.8675
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3679 - accuracy: 0.8822
# Epoch 70: val_accuracy improved from 0.86750 to 0.86875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3671 - accuracy: 0.8822 - val_loss: 0.3645 - val_accuracy: 0.8687
# Epoch 71/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3792 - accuracy: 0.8727
# Epoch 71: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3814 - accuracy: 0.8697 - val_loss: 0.3828 - val_accuracy: 0.8600
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3728 - accuracy: 0.8737
# Epoch 72: val_accuracy improved from 0.86875 to 0.87125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3720 - accuracy: 0.8744 - val_loss: 0.3810 - val_accuracy: 0.8712
# Epoch 73/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3694 - accuracy: 0.8750
# Epoch 73: val_accuracy improved from 0.87125 to 0.87375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3710 - accuracy: 0.8737 - val_loss: 0.3688 - val_accuracy: 0.8737
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3584 - accuracy: 0.8841
# Epoch 74: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3570 - accuracy: 0.8838 - val_loss: 0.3878 - val_accuracy: 0.8537
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4145 - accuracy: 0.8457
# Epoch 75: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4128 - accuracy: 0.8462 - val_loss: 0.4929 - val_accuracy: 0.8388
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4250 - accuracy: 0.8490
# Epoch 76: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4224 - accuracy: 0.8509 - val_loss: 0.4108 - val_accuracy: 0.8575
# Epoch 77/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4028 - accuracy: 0.8652
# Epoch 77: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4004 - accuracy: 0.8662 - val_loss: 0.4525 - val_accuracy: 0.8150
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4201 - accuracy: 0.8597
# Epoch 78: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4193 - accuracy: 0.8609 - val_loss: 0.4191 - val_accuracy: 0.8562
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4036 - accuracy: 0.8646
# Epoch 79: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4028 - accuracy: 0.8650 - val_loss: 0.3854 - val_accuracy: 0.8600
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3740 - accuracy: 0.8760
# Epoch 80: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3754 - accuracy: 0.8759 - val_loss: 0.4023 - val_accuracy: 0.8637
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3888 - accuracy: 0.8682
# Epoch 81: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3860 - accuracy: 0.8697 - val_loss: 0.3972 - val_accuracy: 0.8537
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3825 - accuracy: 0.8766
# Epoch 82: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3825 - accuracy: 0.8766 - val_loss: 0.4205 - val_accuracy: 0.8475
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3779 - accuracy: 0.8701
# Epoch 83: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3766 - accuracy: 0.8703 - val_loss: 0.3825 - val_accuracy: 0.8600
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3555 - accuracy: 0.8796
# Epoch 84: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3566 - accuracy: 0.8788 - val_loss: 0.3826 - val_accuracy: 0.8625
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3751 - accuracy: 0.8743
# Epoch 85: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3753 - accuracy: 0.8741 - val_loss: 0.3657 - val_accuracy: 0.8737
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3613 - accuracy: 0.8828
# Epoch 86: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3586 - accuracy: 0.8841 - val_loss: 0.4354 - val_accuracy: 0.8413
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3859 - accuracy: 0.8714
# Epoch 87: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3877 - accuracy: 0.8687 - val_loss: 0.3803 - val_accuracy: 0.8712
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4016 - accuracy: 0.8678
# Epoch 88: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3999 - accuracy: 0.8684 - val_loss: 0.4573 - val_accuracy: 0.8425
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4041 - accuracy: 0.8630
# Epoch 89: val_accuracy did not improve from 0.87375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4025 - accuracy: 0.8637 - val_loss: 0.3844 - val_accuracy: 0.8650
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3546 - accuracy: 0.8857
# Epoch 90: val_accuracy improved from 0.87375 to 0.87875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3550 - accuracy: 0.8847 - val_loss: 0.3612 - val_accuracy: 0.8788
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3460 - accuracy: 0.8919
# Epoch 91: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3437 - accuracy: 0.8931 - val_loss: 0.3654 - val_accuracy: 0.8712
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3367 - accuracy: 0.8988
# Epoch 92: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3371 - accuracy: 0.8988 - val_loss: 0.3587 - val_accuracy: 0.8788
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3493 - accuracy: 0.8916
# Epoch 93: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3447 - accuracy: 0.8947 - val_loss: 0.3543 - val_accuracy: 0.8750
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3428 - accuracy: 0.8923
# Epoch 94: val_accuracy improved from 0.87875 to 0.88125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 75ms/step - loss: 0.3418 - accuracy: 0.8925 - val_loss: 0.3573 - val_accuracy: 0.8813
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3347 - accuracy: 0.8955
# Epoch 95: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3342 - accuracy: 0.8956 - val_loss: 0.3565 - val_accuracy: 0.8775
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3938 - accuracy: 0.8574
# Epoch 96: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3922 - accuracy: 0.8600 - val_loss: 0.5775 - val_accuracy: 0.7950
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4169 - accuracy: 0.8597
# Epoch 97: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4164 - accuracy: 0.8597 - val_loss: 0.4068 - val_accuracy: 0.8550
# Epoch 98/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3895 - accuracy: 0.8685
# Epoch 98: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3894 - accuracy: 0.8687 - val_loss: 0.4046 - val_accuracy: 0.8575
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3774 - accuracy: 0.8773
# Epoch 99: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3758 - accuracy: 0.8772 - val_loss: 0.4264 - val_accuracy: 0.8487
# Epoch 100/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.8816
# Epoch 100: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3651 - accuracy: 0.8816 - val_loss: 0.3590 - val_accuracy: 0.8763
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3371 - accuracy: 0.8932
# Epoch 101: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3359 - accuracy: 0.8938 - val_loss: 0.5803 - val_accuracy: 0.7700
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5235 - accuracy: 0.8057
# Epoch 102: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5233 - accuracy: 0.8062 - val_loss: 0.4628 - val_accuracy: 0.8400
# Epoch 103/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4801 - accuracy: 0.8125
# Epoch 103: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4752 - accuracy: 0.8159 - val_loss: 0.4578 - val_accuracy: 0.8062
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4663 - accuracy: 0.8249
# Epoch 104: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4638 - accuracy: 0.8266 - val_loss: 0.4559 - val_accuracy: 0.8438
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3987 - accuracy: 0.8669
# Epoch 105: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4000 - accuracy: 0.8662 - val_loss: 0.3718 - val_accuracy: 0.8700
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3596 - accuracy: 0.8861
# Epoch 106: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3619 - accuracy: 0.8859 - val_loss: 0.3889 - val_accuracy: 0.8650
# Epoch 107/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8766
# Epoch 107: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3652 - accuracy: 0.8766 - val_loss: 0.3860 - val_accuracy: 0.8712
# Epoch 108/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3510 - accuracy: 0.8913
# Epoch 108: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3505 - accuracy: 0.8925 - val_loss: 0.3934 - val_accuracy: 0.8550
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3638 - accuracy: 0.8828
# Epoch 109: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3655 - accuracy: 0.8819 - val_loss: 0.4535 - val_accuracy: 0.8225
# Epoch 110/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3838 - accuracy: 0.8649
# Epoch 110: val_accuracy improved from 0.88125 to 0.88375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3845 - accuracy: 0.8641 - val_loss: 0.3554 - val_accuracy: 0.8838
# Epoch 111/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3390 - accuracy: 0.8968
# Epoch 111: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3406 - accuracy: 0.8953 - val_loss: 0.3577 - val_accuracy: 0.8775
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3344 - accuracy: 0.8971
# Epoch 112: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3374 - accuracy: 0.8956 - val_loss: 0.3646 - val_accuracy: 0.8712
# Epoch 113/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3272 - accuracy: 0.8991
# Epoch 113: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3278 - accuracy: 0.8997 - val_loss: 0.4301 - val_accuracy: 0.8500
# Epoch 114/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3891 - accuracy: 0.8636
# Epoch 114: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3883 - accuracy: 0.8637 - val_loss: 0.4005 - val_accuracy: 0.8662
# Epoch 115/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8881
# Epoch 115: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3468 - accuracy: 0.8881 - val_loss: 0.3624 - val_accuracy: 0.8662
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3329 - accuracy: 0.8971
# Epoch 116: val_accuracy improved from 0.88375 to 0.88750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3356 - accuracy: 0.8966 - val_loss: 0.3430 - val_accuracy: 0.8875
# Epoch 117/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3274 - accuracy: 0.8978
# Epoch 117: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3281 - accuracy: 0.8981 - val_loss: 0.3399 - val_accuracy: 0.8813
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3204 - accuracy: 0.9033
# Epoch 118: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3227 - accuracy: 0.9019 - val_loss: 0.3497 - val_accuracy: 0.8737
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3162 - accuracy: 0.8997
# Epoch 119: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3154 - accuracy: 0.9009 - val_loss: 0.3552 - val_accuracy: 0.8725
# Epoch 120/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3359 - accuracy: 0.8900
# Epoch 120: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3402 - accuracy: 0.8897 - val_loss: 0.3988 - val_accuracy: 0.8687
# Epoch 121/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4376 - accuracy: 0.8428
# Epoch 121: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4407 - accuracy: 0.8397 - val_loss: 0.4435 - val_accuracy: 0.8375
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4784 - accuracy: 0.8167
# Epoch 122: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4738 - accuracy: 0.8188 - val_loss: 0.4891 - val_accuracy: 0.7925
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4315 - accuracy: 0.8382
# Epoch 123: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4333 - accuracy: 0.8388 - val_loss: 0.4284 - val_accuracy: 0.8300
# Epoch 124/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3825 - accuracy: 0.8766
# Epoch 124: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3831 - accuracy: 0.8756 - val_loss: 0.3572 - val_accuracy: 0.8825
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3563 - accuracy: 0.8861
# Epoch 125: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3577 - accuracy: 0.8850 - val_loss: 0.3890 - val_accuracy: 0.8637
# Epoch 126/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3382 - accuracy: 0.8952
# Epoch 126: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3419 - accuracy: 0.8938 - val_loss: 0.3585 - val_accuracy: 0.8737
# Epoch 127/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3581 - accuracy: 0.8805
# Epoch 127: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3575 - accuracy: 0.8819 - val_loss: 0.3551 - val_accuracy: 0.8712
# Epoch 128/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3430 - accuracy: 0.8867
# Epoch 128: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3441 - accuracy: 0.8869 - val_loss: 0.3540 - val_accuracy: 0.8775
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3395 - accuracy: 0.8877
# Epoch 129: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3419 - accuracy: 0.8869 - val_loss: 0.3628 - val_accuracy: 0.8737
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3427 - accuracy: 0.8887
# Epoch 130: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3407 - accuracy: 0.8903 - val_loss: 0.3997 - val_accuracy: 0.8462
# Epoch 131/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3741 - accuracy: 0.8747
# Epoch 131: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3720 - accuracy: 0.8756 - val_loss: 0.3792 - val_accuracy: 0.8650
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3448 - accuracy: 0.8910
# Epoch 132: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3482 - accuracy: 0.8878 - val_loss: 0.3714 - val_accuracy: 0.8700
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3259 - accuracy: 0.9033
# Epoch 133: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3265 - accuracy: 0.9022 - val_loss: 0.3613 - val_accuracy: 0.8712
# Epoch 134/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3299 - accuracy: 0.8932
# Epoch 134: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3288 - accuracy: 0.8934 - val_loss: 0.3457 - val_accuracy: 0.8850
# Epoch 135/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3370 - accuracy: 0.8981
# Epoch 135: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3376 - accuracy: 0.8969 - val_loss: 0.4420 - val_accuracy: 0.8425
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3470 - accuracy: 0.8929
# Epoch 136: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3449 - accuracy: 0.8941 - val_loss: 0.3393 - val_accuracy: 0.8813
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3088 - accuracy: 0.9036
# Epoch 137: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3123 - accuracy: 0.9016 - val_loss: 0.3377 - val_accuracy: 0.8863
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3192 - accuracy: 0.8988
# Epoch 138: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3183 - accuracy: 0.9000 - val_loss: 0.3479 - val_accuracy: 0.8788
# Epoch 139/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3120 - accuracy: 0.8997
# Epoch 139: val_accuracy improved from 0.88750 to 0.88875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3115 - accuracy: 0.9000 - val_loss: 0.3289 - val_accuracy: 0.8888
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3164 - accuracy: 0.8968
# Epoch 140: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3157 - accuracy: 0.8975 - val_loss: 0.3536 - val_accuracy: 0.8750
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3075 - accuracy: 0.8991
# Epoch 141: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3065 - accuracy: 0.9000 - val_loss: 0.3467 - val_accuracy: 0.8825
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3219 - accuracy: 0.8984
# Epoch 142: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3246 - accuracy: 0.8969 - val_loss: 0.3466 - val_accuracy: 0.8775
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3305 - accuracy: 0.8903
# Epoch 143: val_accuracy improved from 0.88875 to 0.89000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3283 - accuracy: 0.8916 - val_loss: 0.3385 - val_accuracy: 0.8900
# Epoch 144/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3148 - accuracy: 0.9023
# Epoch 144: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3143 - accuracy: 0.9028 - val_loss: 0.3361 - val_accuracy: 0.8775
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2976 - accuracy: 0.9059
# Epoch 145: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3010 - accuracy: 0.9041 - val_loss: 0.3352 - val_accuracy: 0.8800
# Epoch 146/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3106 - accuracy: 0.9030
# Epoch 146: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3099 - accuracy: 0.9034 - val_loss: 0.3659 - val_accuracy: 0.8763
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3208 - accuracy: 0.8945
# Epoch 147: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3220 - accuracy: 0.8944 - val_loss: 0.3359 - val_accuracy: 0.8788
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3016 - accuracy: 0.9053
# Epoch 148: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3027 - accuracy: 0.9047 - val_loss: 0.3375 - val_accuracy: 0.8863
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3577 - accuracy: 0.8796
# Epoch 149: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3563 - accuracy: 0.8784 - val_loss: 0.4611 - val_accuracy: 0.8338
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3544 - accuracy: 0.8831
# Epoch 150: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3530 - accuracy: 0.8838 - val_loss: 0.3818 - val_accuracy: 0.8737
# Epoch 151/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3312 - accuracy: 0.8968
# Epoch 151: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3340 - accuracy: 0.8963 - val_loss: 0.3569 - val_accuracy: 0.8788
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3186 - accuracy: 0.8978
# Epoch 152: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3195 - accuracy: 0.8975 - val_loss: 0.3364 - val_accuracy: 0.8813
# Epoch 153/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3191 - accuracy: 0.8965
# Epoch 153: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3192 - accuracy: 0.8959 - val_loss: 0.3599 - val_accuracy: 0.8700
# Epoch 154/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3209 - accuracy: 0.8932
# Epoch 154: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3180 - accuracy: 0.8953 - val_loss: 0.3545 - val_accuracy: 0.8737
# Epoch 155/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3148 - accuracy: 0.9027
# Epoch 155: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3128 - accuracy: 0.9038 - val_loss: 0.3315 - val_accuracy: 0.8888
# Epoch 156/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3072 - accuracy: 0.9072
# Epoch 156: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3091 - accuracy: 0.9066 - val_loss: 0.3771 - val_accuracy: 0.8637
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3052 - accuracy: 0.9036
# Epoch 157: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3034 - accuracy: 0.9044 - val_loss: 0.3439 - val_accuracy: 0.8750
# Epoch 158/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3246 - accuracy: 0.8949
# Epoch 158: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3255 - accuracy: 0.8947 - val_loss: 0.3584 - val_accuracy: 0.8813
# Epoch 159/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3382 - accuracy: 0.8874
# Epoch 159: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3358 - accuracy: 0.8891 - val_loss: 0.3929 - val_accuracy: 0.8525
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3314 - accuracy: 0.8945
# Epoch 160: val_accuracy did not improve from 0.89000
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3306 - accuracy: 0.8947 - val_loss: 0.3349 - val_accuracy: 0.8888
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3081 - accuracy: 0.9033
# Epoch 161: val_accuracy improved from 0.89000 to 0.89125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3049 - accuracy: 0.9044 - val_loss: 0.3262 - val_accuracy: 0.8913
# Epoch 162/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3022 - accuracy: 0.8988
# Epoch 162: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3022 - accuracy: 0.9000 - val_loss: 0.3309 - val_accuracy: 0.8825
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2992 - accuracy: 0.9020
# Epoch 163: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3006 - accuracy: 0.9022 - val_loss: 0.3249 - val_accuracy: 0.8838
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2989 - accuracy: 0.9033
# Epoch 164: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.2987 - accuracy: 0.9041 - val_loss: 0.3238 - val_accuracy: 0.8913
# Epoch 165/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2910 - accuracy: 0.9089
# Epoch 165: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.2908 - accuracy: 0.9094 - val_loss: 0.3414 - val_accuracy: 0.8863
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3026 - accuracy: 0.8991
# Epoch 166: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3010 - accuracy: 0.9006 - val_loss: 0.3390 - val_accuracy: 0.8813
# Epoch 167/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3013 - accuracy: 0.9023
# Epoch 167: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3024 - accuracy: 0.9016 - val_loss: 0.3205 - val_accuracy: 0.8875
# Epoch 168/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2909 - accuracy: 0.9056
# Epoch 168: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 63ms/step - loss: 0.2912 - accuracy: 0.9050 - val_loss: 0.3329 - val_accuracy: 0.8888
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3203 - accuracy: 0.8913
# Epoch 169: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3214 - accuracy: 0.8903 - val_loss: 0.3265 - val_accuracy: 0.8838
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3086 - accuracy: 0.9069
# Epoch 170: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3097 - accuracy: 0.9053 - val_loss: 0.3581 - val_accuracy: 0.8813
# Epoch 171/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3093 - accuracy: 0.9049
# Epoch 171: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3114 - accuracy: 0.9038 - val_loss: 0.3538 - val_accuracy: 0.8712
# Epoch 172/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.9006
# Epoch 172: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3064 - accuracy: 0.9006 - val_loss: 0.3232 - val_accuracy: 0.8900
# Epoch 173/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2910 - accuracy: 0.9066
# Epoch 173: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.2911 - accuracy: 0.9062 - val_loss: 0.3266 - val_accuracy: 0.8825
# Epoch 174/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3013 - accuracy: 0.9036
# Epoch 174: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.2996 - accuracy: 0.9041 - val_loss: 0.3263 - val_accuracy: 0.8813
# Epoch 175/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2840 - accuracy: 0.9141
# Epoch 175: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 62ms/step - loss: 0.2866 - accuracy: 0.9125 - val_loss: 0.3249 - val_accuracy: 0.8838
# Epoch 176/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2955 - accuracy: 0.9105
# Epoch 176: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.2966 - accuracy: 0.9103 - val_loss: 0.3429 - val_accuracy: 0.8788
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3200 - accuracy: 0.8984
# Epoch 177: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3165 - accuracy: 0.8994 - val_loss: 0.7821 - val_accuracy: 0.7513
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7571 - accuracy: 0.6966
# Epoch 178: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.7574 - accuracy: 0.6966 - val_loss: 0.5780 - val_accuracy: 0.7725
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5897 - accuracy: 0.7585
# Epoch 179: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5875 - accuracy: 0.7606 - val_loss: 0.5953 - val_accuracy: 0.7563
# Epoch 180/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.7763
# Epoch 180: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5756 - accuracy: 0.7763 - val_loss: 0.5934 - val_accuracy: 0.7563
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5707 - accuracy: 0.7757
# Epoch 181: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5728 - accuracy: 0.7734 - val_loss: 0.5867 - val_accuracy: 0.7613
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5584 - accuracy: 0.7812
# Epoch 182: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5589 - accuracy: 0.7800 - val_loss: 0.5784 - val_accuracy: 0.7613
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5452 - accuracy: 0.7865
# Epoch 183: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5447 - accuracy: 0.7869 - val_loss: 0.5641 - val_accuracy: 0.7675
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5322 - accuracy: 0.7871
# Epoch 184: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5331 - accuracy: 0.7881 - val_loss: 0.5568 - val_accuracy: 0.7775
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5234 - accuracy: 0.7907
# Epoch 185: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5244 - accuracy: 0.7897 - val_loss: 0.5418 - val_accuracy: 0.7788
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5170 - accuracy: 0.7952
# Epoch 186: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.5148 - accuracy: 0.7972 - val_loss: 0.5429 - val_accuracy: 0.7825
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5057 - accuracy: 0.7972
# Epoch 187: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5062 - accuracy: 0.7975 - val_loss: 0.5273 - val_accuracy: 0.7837
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4974 - accuracy: 0.7956
# Epoch 188: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4992 - accuracy: 0.7944 - val_loss: 0.5233 - val_accuracy: 0.7850
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4962 - accuracy: 0.7952
# Epoch 189: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4974 - accuracy: 0.7950 - val_loss: 0.5250 - val_accuracy: 0.7862
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4867 - accuracy: 0.7982
# Epoch 190: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4904 - accuracy: 0.7969 - val_loss: 0.5150 - val_accuracy: 0.7887
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4831 - accuracy: 0.7975
# Epoch 191: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4810 - accuracy: 0.7997 - val_loss: 0.5064 - val_accuracy: 0.7812
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4805 - accuracy: 0.8008
# Epoch 192: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4791 - accuracy: 0.8006 - val_loss: 0.5036 - val_accuracy: 0.7887
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4772 - accuracy: 0.7982
# Epoch 193: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4755 - accuracy: 0.8000 - val_loss: 0.5073 - val_accuracy: 0.7925
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4714 - accuracy: 0.8014
# Epoch 194: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4748 - accuracy: 0.7991 - val_loss: 0.5001 - val_accuracy: 0.7900
# Epoch 195/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4655 - accuracy: 0.8025
# Epoch 195: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4655 - accuracy: 0.8025 - val_loss: 0.4928 - val_accuracy: 0.7837
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4648 - accuracy: 0.8031
# Epoch 196: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4647 - accuracy: 0.8031 - val_loss: 0.4919 - val_accuracy: 0.7887
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4620 - accuracy: 0.8005
# Epoch 197: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4626 - accuracy: 0.8003 - val_loss: 0.4904 - val_accuracy: 0.7962
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4638 - accuracy: 0.8005
# Epoch 198: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4633 - accuracy: 0.8009 - val_loss: 0.4867 - val_accuracy: 0.7950
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4559 - accuracy: 0.8073
# Epoch 199: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4552 - accuracy: 0.8084 - val_loss: 0.4809 - val_accuracy: 0.7900
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4609 - accuracy: 0.8018
# Epoch 200: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4610 - accuracy: 0.8028 - val_loss: 0.4815 - val_accuracy: 0.7862

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.3262
# Accuracy: 89.1250%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	89.12%
# Sensitivity:	97.84%
# Specificity:	79.63%
# Precision:	83.95%
# F1-score:	90.37%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.96
