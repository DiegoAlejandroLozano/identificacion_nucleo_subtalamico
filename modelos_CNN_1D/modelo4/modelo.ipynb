# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))


modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 3.4182 - accuracy: 0.5381
# Epoch 1: val_accuracy improved from -inf to 0.77875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 7s 224ms/step - loss: 3.4182 - accuracy: 0.5381 - val_loss: 1.4806 - val_accuracy: 0.7788
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.1060 - accuracy: 0.6449
# Epoch 2: val_accuracy did not improve from 0.77875
# 7/7 [==============================] - 0s 71ms/step - loss: 1.0931 - accuracy: 0.6484 - val_loss: 0.9771 - val_accuracy: 0.5612
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.9022 - accuracy: 0.5456
# Epoch 3: val_accuracy did not improve from 0.77875
# 7/7 [==============================] - 1s 70ms/step - loss: 0.9025 - accuracy: 0.5437 - val_loss: 0.8717 - val_accuracy: 0.6538
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8569 - accuracy: 0.6429
# Epoch 4: val_accuracy did not improve from 0.77875
# 7/7 [==============================] - 0s 68ms/step - loss: 0.8546 - accuracy: 0.6466 - val_loss: 0.7842 - val_accuracy: 0.6900
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7357 - accuracy: 0.7181
# Epoch 5: val_accuracy did not improve from 0.77875
# 7/7 [==============================] - 0s 72ms/step - loss: 0.7329 - accuracy: 0.7181 - val_loss: 0.6771 - val_accuracy: 0.6925
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6692 - accuracy: 0.7119
# Epoch 6: val_accuracy did not improve from 0.77875
# 7/7 [==============================] - 1s 77ms/step - loss: 0.6684 - accuracy: 0.7109 - val_loss: 0.6303 - val_accuracy: 0.7613
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6449 - accuracy: 0.7116
# Epoch 7: val_accuracy improved from 0.77875 to 0.78250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 108ms/step - loss: 0.6444 - accuracy: 0.7125 - val_loss: 0.5928 - val_accuracy: 0.7825
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6178 - accuracy: 0.7272
# Epoch 8: val_accuracy did not improve from 0.78250
# 7/7 [==============================] - 0s 72ms/step - loss: 0.6164 - accuracy: 0.7300 - val_loss: 0.6366 - val_accuracy: 0.7188
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6020 - accuracy: 0.7409
# Epoch 9: val_accuracy improved from 0.78250 to 0.79375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 97ms/step - loss: 0.6010 - accuracy: 0.7428 - val_loss: 0.5502 - val_accuracy: 0.7937
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5626 - accuracy: 0.7738
# Epoch 10: val_accuracy did not improve from 0.79375
# 7/7 [==============================] - 1s 73ms/step - loss: 0.5622 - accuracy: 0.7756 - val_loss: 0.5370 - val_accuracy: 0.7862
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5428 - accuracy: 0.7767
# Epoch 11: val_accuracy did not improve from 0.79375
# 7/7 [==============================] - 0s 70ms/step - loss: 0.5433 - accuracy: 0.7766 - val_loss: 0.5238 - val_accuracy: 0.7887
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5415 - accuracy: 0.7819
# Epoch 12: val_accuracy improved from 0.79375 to 0.79625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 89ms/step - loss: 0.5391 - accuracy: 0.7844 - val_loss: 0.5045 - val_accuracy: 0.7962
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5335 - accuracy: 0.7835
# Epoch 13: val_accuracy did not improve from 0.79625
# 7/7 [==============================] - 0s 74ms/step - loss: 0.5317 - accuracy: 0.7850 - val_loss: 0.5021 - val_accuracy: 0.7887
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.7887
# Epoch 14: val_accuracy did not improve from 0.79625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.5272 - accuracy: 0.7887 - val_loss: 0.5093 - val_accuracy: 0.7887
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5411 - accuracy: 0.7780
# Epoch 15: val_accuracy improved from 0.79625 to 0.80250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 90ms/step - loss: 0.5457 - accuracy: 0.7747 - val_loss: 0.5130 - val_accuracy: 0.8025
# Epoch 16/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5336 - accuracy: 0.7878
# Epoch 16: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 78ms/step - loss: 0.5366 - accuracy: 0.7844 - val_loss: 0.5036 - val_accuracy: 0.7950
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5334 - accuracy: 0.7816
# Epoch 17: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 76ms/step - loss: 0.5313 - accuracy: 0.7837 - val_loss: 0.5085 - val_accuracy: 0.7975
# Epoch 18/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5264 - accuracy: 0.7858
# Epoch 18: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 80ms/step - loss: 0.5248 - accuracy: 0.7878 - val_loss: 0.5055 - val_accuracy: 0.7800
# Epoch 19/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5259 - accuracy: 0.7826
# Epoch 19: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 76ms/step - loss: 0.5266 - accuracy: 0.7828 - val_loss: 0.5270 - val_accuracy: 0.7763
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5187 - accuracy: 0.7878
# Epoch 20: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 0s 73ms/step - loss: 0.5201 - accuracy: 0.7881 - val_loss: 0.4908 - val_accuracy: 0.7975
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5100 - accuracy: 0.7946
# Epoch 21: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 0s 70ms/step - loss: 0.5087 - accuracy: 0.7966 - val_loss: 0.5034 - val_accuracy: 0.7962
# Epoch 22/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5253 - accuracy: 0.7965
# Epoch 22: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 72ms/step - loss: 0.5279 - accuracy: 0.7947 - val_loss: 0.5157 - val_accuracy: 0.7750
# Epoch 23/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5267 - accuracy: 0.7839
# Epoch 23: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 82ms/step - loss: 0.5268 - accuracy: 0.7831 - val_loss: 0.4915 - val_accuracy: 0.7950
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5084 - accuracy: 0.7900
# Epoch 24: val_accuracy did not improve from 0.80250
# 7/7 [==============================] - 1s 73ms/step - loss: 0.5078 - accuracy: 0.7909 - val_loss: 0.4972 - val_accuracy: 0.7925
# Epoch 25/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4927 - accuracy: 0.8066
# Epoch 25: val_accuracy improved from 0.80250 to 0.82500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 91ms/step - loss: 0.5018 - accuracy: 0.8009 - val_loss: 0.4643 - val_accuracy: 0.8250
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.
200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4181 - accuracy: 0.8594
# Epoch 72: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.4193 - accuracy: 0.8587 - val_loss: 0.4056 - val_accuracy: 0.8650
# Epoch 73/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4168 - accuracy: 0.8620
# Epoch 73: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 72ms/step - loss: 0.4172 - accuracy: 0.8622 - val_loss: 0.6515 - val_accuracy: 0.7638
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5126 - accuracy: 0.8073
# Epoch 74: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.5132 - accuracy: 0.8072 - val_loss: 0.4186 - val_accuracy: 0.8525
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4403 - accuracy: 0.8571
# Epoch 75: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 1s 76ms/step - loss: 0.4409 - accuracy: 0.8572 - val_loss: 0.4173 - val_accuracy: 0.8550
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4353 - accuracy: 0.8584
# Epoch 76: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 72ms/step - loss: 0.4367 - accuracy: 0.8578 - val_loss: 0.4025 - val_accuracy: 0.8675
# Epoch 77/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4184 - accuracy: 0.8665
# Epoch 77: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 1s 82ms/step - loss: 0.4164 - accuracy: 0.8681 - val_loss: 0.4586 - val_accuracy: 0.8425
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4524 - accuracy: 0.8503
# Epoch 78: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 1s 92ms/step - loss: 0.4512 - accuracy: 0.8503 - val_loss: 0.4247 - val_accuracy: 0.8425
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4469 - accuracy: 0.8490
# Epoch 79: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 1s 84ms/step - loss: 0.4503 - accuracy: 0.8472 - val_loss: 0.4675 - val_accuracy: 0.8263
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5469 - accuracy: 0.7731
# Epoch 80: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 1s 81ms/step - loss: 0.5473 - accuracy: 0.7747 - val_loss: 0.4476 - val_accuracy: 0.8313
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5002 - accuracy: 0.8236
# Epoch 81: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 69ms/step - loss: 0.5000 - accuracy: 0.8241 - val_loss: 0.4965 - val_accuracy: 0.8288
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4859 - accuracy: 0.8382
# Epoch 82: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.4854 - accuracy: 0.8378 - val_loss: 0.4754 - val_accuracy: 0.8288
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4779 - accuracy: 0.8398
# Epoch 83: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 1s 73ms/step - loss: 0.4765 - accuracy: 0.8400 - val_loss: 0.4750 - val_accuracy: 0.8363
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4599 - accuracy: 0.8499
# Epoch 84: val_accuracy did not improve from 0.87000
# 7/7 [==============================] - 0s 71ms/step - loss: 0.4582 - accuracy: 0.8509 - val_loss: 0.4895 - val_accuracy: 0.8125
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4673 - accuracy: 0.8366
# Epoch 85: val_accuracy improved from 0.87000 to 0.87125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 93ms/step - loss: 0.4621 - accuracy: 0.8406 - val_loss: 0.4114 - val_accuracy: 0.8712
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4262 - accuracy: 0.8623
# Epoch 86: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 1s 75ms/step - loss: 0.4257 - accuracy: 0.8625 - val_loss: 0.4081 - val_accuracy: 0.8675
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4153 - accuracy: 0.8669
# Epoch 87: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4165 - accuracy: 0.8653 - val_loss: 0.3931 - val_accuracy: 0.8687
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4128 - accuracy: 0.8688
# Epoch 88: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 1s 86ms/step - loss: 0.4109 - accuracy: 0.8697 - val_loss: 0.3899 - val_accuracy: 0.8687
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3996 - accuracy: 0.8770
# Epoch 89: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 0s 73ms/step - loss: 0.4050 - accuracy: 0.8737 - val_loss: 0.3897 - val_accuracy: 0.8700
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3994 - accuracy: 0.8743
# Epoch 90: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 0s 73ms/step - loss: 0.4011 - accuracy: 0.8734 - val_loss: 0.3899 - val_accuracy: 0.8662
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4016 - accuracy: 0.8740
# Epoch 91: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 1s 74ms/step - loss: 0.4039 - accuracy: 0.8722 - val_loss: 0.3892 - val_accuracy: 0.8700
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3979 - accuracy: 0.8740
# Epoch 92: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3984 - accuracy: 0.8734 - val_loss: 0.4142 - val_accuracy: 0.8587
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4192 - accuracy: 0.8678
# Epoch 93: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4179 - accuracy: 0.8681 - val_loss: 0.4336 - val_accuracy: 0.8500
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4135 - accuracy: 0.8698
# Epoch 94: val_accuracy improved from 0.87125 to 0.87625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 88ms/step - loss: 0.4138 - accuracy: 0.8691 - val_loss: 0.3856 - val_accuracy: 0.8763
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3979 - accuracy: 0.8809
# Epoch 95: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 72ms/step - loss: 0.3997 - accuracy: 0.8791 - val_loss: 0.4444 - val_accuracy: 0.8500
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4340 - accuracy: 0.8571
# Epoch 96: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 76ms/step - loss: 0.4318 - accuracy: 0.8581 - val_loss: 0.3951 - val_accuracy: 0.8675
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4135 - accuracy: 0.8662
# Epoch 97: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 78ms/step - loss: 0.4159 - accuracy: 0.8653 - val_loss: 0.3868 - val_accuracy: 0.8725
# Epoch 98/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4054 - accuracy: 0.8750
# Epoch 98: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 72ms/step - loss: 0.4036 - accuracy: 0.8759 - val_loss: 0.4023 - val_accuracy: 0.8712
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4104 - accuracy: 0.8717
# Epoch 99: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 74ms/step - loss: 0.4096 - accuracy: 0.8719 - val_loss: 0.4196 - val_accuracy: 0.8612
# Epoch 100/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4177 - accuracy: 0.8626
# Epoch 100: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 77ms/step - loss: 0.4186 - accuracy: 0.8625 - val_loss: 0.4091 - val_accuracy: 0.8662
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3870 - accuracy: 0.8841 - val_loss: 0.3921 - val_accuracy: 0.8687
# Epoch 136/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3953 - accuracy: 0.8800
# Epoch 136: val_accuracy improved from 0.87875 to 0.88125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 112ms/step - loss: 0.3953 - accuracy: 0.8800 - val_loss: 0.3726 - val_accuracy: 0.8813
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3855 - accuracy: 0.8802
# Epoch 137: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 75ms/step - loss: 0.3861 - accuracy: 0.8797 - val_loss: 0.3810 - val_accuracy: 0.8788
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3902 - accuracy: 0.8818
# Epoch 138: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 74ms/step - loss: 0.3888 - accuracy: 0.8825 - val_loss: 0.3901 - val_accuracy: 0.8675
# Epoch 139/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3800 - accuracy: 0.8854
# Epoch 139: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 78ms/step - loss: 0.3783 - accuracy: 0.8859 - val_loss: 0.3810 - val_accuracy: 0.8750
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3714 - accuracy: 0.8896
# Epoch 140: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 83ms/step - loss: 0.3718 - accuracy: 0.8891 - val_loss: 0.3728 - val_accuracy: 0.8775
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3749 - accuracy: 0.8890
# Epoch 141: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 79ms/step - loss: 0.3755 - accuracy: 0.8888 - val_loss: 0.3740 - val_accuracy: 0.8750
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3634 - accuracy: 0.8929
# Epoch 142: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 80ms/step - loss: 0.3654 - accuracy: 0.8919 - val_loss: 0.3743 - val_accuracy: 0.8788
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3678 - accuracy: 0.8916
# Epoch 143: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 88ms/step - loss: 0.3667 - accuracy: 0.8909 - val_loss: 0.3724 - val_accuracy: 0.8737
# Epoch 144/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3793 - accuracy: 0.8809
# Epoch 144: val_accuracy improved from 0.88125 to 0.88250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 93ms/step - loss: 0.3769 - accuracy: 0.8828 - val_loss: 0.3780 - val_accuracy: 0.8825
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3638 - accuracy: 0.8919
# Epoch 145: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3658 - accuracy: 0.8913 - val_loss: 0.3984 - val_accuracy: 0.8637
# Epoch 146/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3679 - accuracy: 0.8870
# Epoch 146: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3683 - accuracy: 0.8875 - val_loss: 0.3669 - val_accuracy: 0.8788
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3679 - accuracy: 0.8923
# Epoch 147: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3679 - accuracy: 0.8922 - val_loss: 0.3741 - val_accuracy: 0.8825
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3903 - accuracy: 0.8763
# Epoch 148: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 73ms/step - loss: 0.3866 - accuracy: 0.8788 - val_loss: 0.4176 - val_accuracy: 0.8637
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3892 - accuracy: 0.8763
# Epoch 149: val_accuracy improved from 0.88250 to 0.88375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 110ms/step - loss: 0.3896 - accuracy: 0.8766 - val_loss: 0.3677 - val_accuracy: 0.8838
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3765 - accuracy: 0.8870
# Epoch 150: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 1s 82ms/step - loss: 0.3799 - accuracy: 0.8853 - val_loss: 0.3834 - val_accuracy: 0.8725
# Epoch 151/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3828 - accuracy: 0.8822
# Epoch 151: val_accuracy did not improve from 0.88375
# 7/7 [==============================] -
val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 77ms/step - loss: 0.3824 - accuracy: 0.8825 - val_loss: 0.3777 - val_accuracy: 0.8788
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4015 - accuracy: 0.8776
# Epoch 187: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 93ms/step - loss: 0.4006 - accuracy: 0.8778 - val_loss: 0.3779 - val_accuracy: 0.8813
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3851 - accuracy: 0.8844
# Epoch 188: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 86ms/step - loss: 0.3874 - accuracy: 0.8838 - val_loss: 0.3733 - val_accuracy: 0.8838
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3658 - accuracy: 0.8906
# Epoch 189: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 83ms/step - loss: 0.3669 - accuracy: 0.8897 - val_loss: 0.3695 - val_accuracy: 0.8838
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3808 - accuracy: 0.8818
# Epoch 190: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 78ms/step - loss: 0.3796 - accuracy: 0.8828 - val_loss: 0.3703 - val_accuracy: 0.8788
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3590 - accuracy: 0.8955
# Epoch 191: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 80ms/step - loss: 0.3603 - accuracy: 0.8941 - val_loss: 0.3690 - val_accuracy: 0.8825
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3635 - accuracy: 0.8900
# Epoch 192: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 87ms/step - loss: 0.3601 - accuracy: 0.8922 - val_loss: 0.3531 - val_accuracy: 0.8900
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3662 - accuracy: 0.8880
# Epoch 193: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3689 - accuracy: 0.8869 - val_loss: 0.3592 - val_accuracy: 0.8888
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3556 - accuracy: 0.8893
# Epoch 194: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 90ms/step - loss: 0.3546 - accuracy: 0.8906 - val_loss: 0.3598 - val_accuracy: 0.8850
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3535 - accuracy: 0.8932
# Epoch 195: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 81ms/step - loss: 0.3538 - accuracy: 0.8934 - val_loss: 0.3967 - val_accuracy: 0.8662
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3782 - accuracy: 0.8835
# Epoch 196: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 80ms/step - loss: 0.3800 - accuracy: 0.8822 - val_loss: 0.3875 - val_accuracy: 0.8737
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3796 - accuracy: 0.8809
# Epoch 197: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 85ms/step - loss: 0.3773 - accuracy: 0.8822 - val_loss: 0.3732 - val_accuracy: 0.8775
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8950
# Epoch 198: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3586 - accuracy: 0.8950 - val_loss: 0.3635 - val_accuracy: 0.8888
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3544 - accuracy: 0.8971
# Epoch 199: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 81ms/step - loss: 0.3533 - accuracy: 0.8978 - val_loss: 0.3679 - val_accuracy: 0.8788
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3740 - accuracy: 0.8835
# Epoch 200: val_accuracy did not improve from 0.89125
# 7/7 [==============================] - 1s 84ms/step - loss: 0.3717 - accuracy: 0.8850 - val_loss: 0.3595 - val_accuracy: 0.8838

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 96, 64)            12352
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 16, 64)            12352
#
#  max_pooling1d_3 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 70,465
# Trainable params: 70,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.3659
# Accuracy: 89.1250%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	89.12%
# Sensitivity:	97.92%
# Specificity:	81.01%
# Precision:	82.64%
# F1-score:	89.63%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.94

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
