# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import os

import tensorflow           as tf
import pandas               as pd
import seaborn              as sns
import matplotlib.pyplot    as plt

from keras.models       import Sequential, load_model
from keras.layers       import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers   import Adam
from keras.regularizers import l2
from keras.callbacks    import ModelCheckpoint

from sklearn.preprocessing      import StandardScaler
from sklearn.model_selection    import train_test_split
from sklearn.metrics            import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled  = scaler.fit_transform(X_train)
X_val_scaled    = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))


modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 3.7356 - accuracy: 0.4884
# Epoch 1: val_accuracy improved from -inf to 0.48250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 3s 124ms/step - loss: 3.7356 - accuracy: 0.4884 - val_loss: 1.9203 - val_accuracy: 0.4825
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.4555 - accuracy: 0.5697
# Epoch 2: val_accuracy improved from 0.48250 to 0.58000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4391 - accuracy: 0.5738 - val_loss: 1.0462 - val_accuracy: 0.5800
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: 0.9636 - accuracy: 0.6969
# Epoch 3: val_accuracy improved from 0.58000 to 0.71000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.9636 - accuracy: 0.6969 - val_loss: 0.9018 - val_accuracy: 0.7100
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8554 - accuracy: 0.7021
# Epoch 4: val_accuracy did not improve from 0.71000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.8534 - accuracy: 0.7019 - val_loss: 0.7924 - val_accuracy: 0.6775
# Epoch 5/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7328 - accuracy: 0.7366
# Epoch 5: val_accuracy improved from 0.71000 to 0.75500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 70ms/step - loss: 0.7328 - accuracy: 0.7366 - val_loss: 0.6773 - val_accuracy: 0.7550
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6464 - accuracy: 0.7604
# Epoch 6: val_accuracy did not improve from 0.75500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6471 - accuracy: 0.7606 - val_loss: 0.6913 - val_accuracy: 0.6388
# Epoch 7/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6357 - accuracy: 0.7328
# Epoch 7: val_accuracy did not improve from 0.75500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.6357 - accuracy: 0.7328 - val_loss: 0.6015 - val_accuracy: 0.7437
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5825 - accuracy: 0.7734
# Epoch 8: val_accuracy did not improve from 0.75500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5809 - accuracy: 0.7738 - val_loss: 0.5800 - val_accuracy: 0.7387
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5896 - accuracy: 0.7588
# Epoch 9: val_accuracy improved from 0.75500 to 0.77750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.5906 - accuracy: 0.7584 - val_loss: 0.5725 - val_accuracy: 0.7775
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5941 - accuracy: 0.7399
# Epoch 10: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5919 - accuracy: 0.7416 - val_loss: 0.5678 - val_accuracy: 0.7738
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5830 - accuracy: 0.7699
# Epoch 11: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5812 - accuracy: 0.7716 - val_loss: 0.5912 - val_accuracy: 0.7412
# Epoch 12/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5657 - accuracy: 0.7766
# Epoch 12: val_accuracy did not improve from 0.77750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5657 - accuracy: 0.7766 - val_loss: 0.5572 - val_accuracy: 0.7538
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5509 - accuracy: 0.7848
# Epoch 13: val_accuracy improved from 0.77750 to 0.78500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5510 - accuracy: 0.7847 - val_loss: 0.5270 - val_accuracy: 0.7850
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5270 - accuracy: 0.7941
# Epoch 14: val_accuracy improved from 0.78500 to 0.80125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5270 - accuracy: 0.7941 - val_loss: 0.5137 - val_accuracy: 0.8012
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7049 - accuracy: 0.6790
# Epoch 15: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7046 - accuracy: 0.6697 - val_loss: 0.6700 - val_accuracy: 0.5425
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6467 - accuracy: 0.6981
# Epoch 16: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 51ms/step - loss: 0.6467 - accuracy: 0.6981 - val_loss: 0.5940 - val_accuracy: 0.7850
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.7681
# Epoch 17: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 51ms/step - loss: 0.6152 - accuracy: 0.7681 - val_loss: 0.6422 - val_accuracy: 0.7487
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6100 - accuracy: 0.7663
# Epoch 18: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.6100 - accuracy: 0.7663 - val_loss: 0.5627 - val_accuracy: 0.7850
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.7828
# Epoch 19: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5697 - accuracy: 0.7828 - val_loss: 0.5560 - val_accuracy: 0.7700
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5505 - accuracy: 0.7812
# Epoch 20: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5540 - accuracy: 0.7791 - val_loss: 0.5277 - val_accuracy: 0.7837
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.7897
# Epoch 21: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5337 - accuracy: 0.7897 - val_loss: 0.5202 - val_accuracy: 0.7837
# Epoch 22/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5212 - accuracy: 0.7920
# Epoch 22: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5208 - accuracy: 0.7931 - val_loss: 0.5192 - val_accuracy: 0.7837
# Epoch 23/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5218 - accuracy: 0.7962
# Epoch 23: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5221 - accuracy: 0.7959 - val_loss: 0.5109 - val_accuracy: 0.7900
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5157 - accuracy: 0.7910
# Epoch 24: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5161 - accuracy: 0.7922 - val_loss: 0.5074 - val_accuracy: 0.7862
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.8056
# Epoch 25: val_accuracy did not improve from 0.80125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5125 - accuracy: 0.8056 - val_loss: 0.5433 - val_accuracy: 0.7812
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5143 - accuracy: 0.8009
# Epoch 26: val_accuracy improved from 0.80125 to 0.81125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5143 - accuracy: 0.8009 - val_loss: 0.4934 - val_accuracy: 0.8112
# Epoch 27/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.8313
# Epoch 27: val_accuracy improved from 0.81125 to 0.82375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4808 - accuracy: 0.8313 - val_loss: 0.4889 - val_accuracy: 0.8238
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.7947
# Epoch 28: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5401 - accuracy: 0.7947 - val_loss: 0.5266 - val_accuracy: 0.7837
# Epoch 29/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5572 - accuracy: 0.7734
# Epoch 29: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5572 - accuracy: 0.7734 - val_loss: 0.5446 - val_accuracy: 0.7675
# Epoch 30/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5472 - accuracy: 0.7778
# Epoch 30: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5472 - accuracy: 0.7778 - val_loss: 0.5294 - val_accuracy: 0.7850
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5441 - accuracy: 0.7844
# Epoch 31: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5441 - accuracy: 0.7844 - val_loss: 0.5195 - val_accuracy: 0.7887
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5307 - accuracy: 0.7866
# Epoch 32: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5307 - accuracy: 0.7866 - val_loss: 0.5367 - val_accuracy: 0.7713
# Epoch 33/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5233 - accuracy: 0.7881
# Epoch 33: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5233 - accuracy: 0.7881 - val_loss: 0.5159 - val_accuracy: 0.7775
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5201 - accuracy: 0.7872
# Epoch 34: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5201 - accuracy: 0.7872 - val_loss: 0.5025 - val_accuracy: 0.7887
# Epoch 35/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.7944
# Epoch 35: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5063 - accuracy: 0.7944 - val_loss: 0.4964 - val_accuracy: 0.7837
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4756 - accuracy: 0.8297
# Epoch 36: val_accuracy improved from 0.82375 to 0.82500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4756 - accuracy: 0.8297 - val_loss: 0.4872 - val_accuracy: 0.8250
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4595 - accuracy: 0.8405
# Epoch 37: val_accuracy improved from 0.82500 to 0.83375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4595 - accuracy: 0.8406 - val_loss: 0.4506 - val_accuracy: 0.8338
# Epoch 38/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4608 - accuracy: 0.8424
# Epoch 38: val_accuracy improved from 0.83375 to 0.84750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4610 - accuracy: 0.8431 - val_loss: 0.4442 - val_accuracy: 0.8475
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4582 - accuracy: 0.8459
# Epoch 39: val_accuracy improved from 0.84750 to 0.85375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4582 - accuracy: 0.8459 - val_loss: 0.4394 - val_accuracy: 0.8537
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5420 - accuracy: 0.7859
# Epoch 40: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5420 - accuracy: 0.7859 - val_loss: 0.6031 - val_accuracy: 0.7525
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5557 - accuracy: 0.7784
# Epoch 41: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5557 - accuracy: 0.7784 - val_loss: 0.5108 - val_accuracy: 0.7950
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5295 - accuracy: 0.7920
# Epoch 42: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5319 - accuracy: 0.7903 - val_loss: 0.5404 - val_accuracy: 0.7700
# Epoch 43/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5119 - accuracy: 0.8128
# Epoch 43: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5119 - accuracy: 0.8128 - val_loss: 0.4941 - val_accuracy: 0.8163
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.8331
# Epoch 44: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4753 - accuracy: 0.8331 - val_loss: 0.4560 - val_accuracy: 0.8350
# Epoch 45/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4504 - accuracy: 0.8537
# Epoch 45: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4504 - accuracy: 0.8537 - val_loss: 0.4535 - val_accuracy: 0.8462
# Epoch 46/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4574 - accuracy: 0.8408
# Epoch 46: val_accuracy improved from 0.85375 to 0.85750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4619 - accuracy: 0.8388 - val_loss: 0.4372 - val_accuracy: 0.8575
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4395 - accuracy: 0.8584
# Epoch 47: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4419 - accuracy: 0.8572 - val_loss: 0.4366 - val_accuracy: 0.8475
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4341 - accuracy: 0.8587
# Epoch 48: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4346 - accuracy: 0.8587 - val_loss: 0.4724 - val_accuracy: 0.8112
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4544 - accuracy: 0.8467
# Epoch 49: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4530 - accuracy: 0.8478 - val_loss: 0.4529 - val_accuracy: 0.8438
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4504 - accuracy: 0.8509
# Epoch 50: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4532 - accuracy: 0.8491 - val_loss: 0.4596 - val_accuracy: 0.8363
# Epoch 51/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4797 - accuracy: 0.8337
# Epoch 51: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4763 - accuracy: 0.8369 - val_loss: 0.4361 - val_accuracy: 0.8562
# Epoch 52/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4473 - accuracy: 0.8550
# Epoch 52: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4473 - accuracy: 0.8550 - val_loss: 0.4275 - val_accuracy: 0.8512
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4497 - accuracy: 0.8561
# Epoch 53: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4482 - accuracy: 0.8566 - val_loss: 0.5075 - val_accuracy: 0.8000
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4742 - accuracy: 0.8313
# Epoch 54: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4742 - accuracy: 0.8313 - val_loss: 0.4825 - val_accuracy: 0.8138
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4649 - accuracy: 0.8379
# Epoch 55: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4677 - accuracy: 0.8366 - val_loss: 0.4328 - val_accuracy: 0.8537
# Epoch 56/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4509 - accuracy: 0.8484
# Epoch 56: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4509 - accuracy: 0.8484 - val_loss: 0.4880 - val_accuracy: 0.8175
# Epoch 57/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4585 - accuracy: 0.8512
# Epoch 57: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4545 - accuracy: 0.8534 - val_loss: 0.4329 - val_accuracy: 0.8537
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4236 - accuracy: 0.8721
# Epoch 58: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4266 - accuracy: 0.8703 - val_loss: 0.4438 - val_accuracy: 0.8575
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4659 - accuracy: 0.8398
# Epoch 59: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4689 - accuracy: 0.8375 - val_loss: 0.4327 - val_accuracy: 0.8550
# Epoch 60/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4515 - accuracy: 0.8493
# Epoch 60: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4520 - accuracy: 0.8487 - val_loss: 0.4671 - val_accuracy: 0.8175
# Epoch 61/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8544
# Epoch 61: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4530 - accuracy: 0.8544 - val_loss: 0.4350 - val_accuracy: 0.8512
# Epoch 62/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4314 - accuracy: 0.8646
# Epoch 62: val_accuracy improved from 0.85750 to 0.86500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4317 - accuracy: 0.8647 - val_loss: 0.4322 - val_accuracy: 0.8650
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4134 - accuracy: 0.8711
# Epoch 63: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4167 - accuracy: 0.8700 - val_loss: 0.4263 - val_accuracy: 0.8575
# Epoch 64/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4133 - accuracy: 0.8753
# Epoch 64: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4126 - accuracy: 0.8756 - val_loss: 0.4080 - val_accuracy: 0.8650
# Epoch 65/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8681
# Epoch 65: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4237 - accuracy: 0.8681 - val_loss: 0.4342 - val_accuracy: 0.8562
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4288 - accuracy: 0.8619
# Epoch 66: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4288 - accuracy: 0.8619 - val_loss: 0.4310 - val_accuracy: 0.8600
# Epoch 67/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.8666
# Epoch 67: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4253 - accuracy: 0.8666 - val_loss: 0.4145 - val_accuracy: 0.8587
# Epoch 68/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4119 - accuracy: 0.8776
# Epoch 68: val_accuracy improved from 0.86500 to 0.86625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4121 - accuracy: 0.8769 - val_loss: 0.4147 - val_accuracy: 0.8662
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4231 - accuracy: 0.8665
# Epoch 69: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4241 - accuracy: 0.8659 - val_loss: 0.4800 - val_accuracy: 0.8288
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5040 - accuracy: 0.8236
# Epoch 70: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5055 - accuracy: 0.8222 - val_loss: 0.5130 - val_accuracy: 0.8213
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8328
# Epoch 71: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4894 - accuracy: 0.8328 - val_loss: 0.4720 - val_accuracy: 0.8313
# Epoch 72/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.8250
# Epoch 72: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5073 - accuracy: 0.8250 - val_loss: 0.4480 - val_accuracy: 0.8500
# Epoch 73/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4571 - accuracy: 0.8600
# Epoch 73: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4548 - accuracy: 0.8619 - val_loss: 0.4509 - val_accuracy: 0.8562
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4553 - accuracy: 0.8590
# Epoch 74: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4553 - accuracy: 0.8591 - val_loss: 0.4612 - val_accuracy: 0.8425
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4381 - accuracy: 0.8626
# Epoch 75: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4362 - accuracy: 0.8631 - val_loss: 0.4429 - val_accuracy: 0.8487
# Epoch 76/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4240 - accuracy: 0.8662
# Epoch 76: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4240 - accuracy: 0.8662 - val_loss: 0.4193 - val_accuracy: 0.8550
# Epoch 77/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8781
# Epoch 77: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4060 - accuracy: 0.8781 - val_loss: 0.4109 - val_accuracy: 0.8600
# Epoch 78/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4111 - accuracy: 0.8716
# Epoch 78: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4111 - accuracy: 0.8716 - val_loss: 0.4149 - val_accuracy: 0.8650
# Epoch 79/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8753
# Epoch 79: val_accuracy did not improve from 0.86625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4128 - accuracy: 0.8753 - val_loss: 0.4038 - val_accuracy: 0.8662
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4043 - accuracy: 0.8779
# Epoch 80: val_accuracy improved from 0.86625 to 0.86875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4016 - accuracy: 0.8797 - val_loss: 0.4055 - val_accuracy: 0.8687
# Epoch 81/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3952 - accuracy: 0.8816
# Epoch 81: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3952 - accuracy: 0.8816 - val_loss: 0.4403 - val_accuracy: 0.8413
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4014 - accuracy: 0.8773
# Epoch 82: val_accuracy improved from 0.86875 to 0.87250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4026 - accuracy: 0.8766 - val_loss: 0.4028 - val_accuracy: 0.8725
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4036 - accuracy: 0.8799
# Epoch 83: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4029 - accuracy: 0.8806 - val_loss: 0.4288 - val_accuracy: 0.8525
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4010 - accuracy: 0.8770
# Epoch 84: val_accuracy improved from 0.87250 to 0.87875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4023 - accuracy: 0.8769 - val_loss: 0.3949 - val_accuracy: 0.8788
# Epoch 85/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.8728
# Epoch 85: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4102 - accuracy: 0.8728 - val_loss: 0.4040 - val_accuracy: 0.8737
# Epoch 86/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8806
# Epoch 86: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4020 - accuracy: 0.8806 - val_loss: 0.4146 - val_accuracy: 0.8625
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4061 - accuracy: 0.8809
# Epoch 87: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4119 - accuracy: 0.8769 - val_loss: 0.3972 - val_accuracy: 0.8700
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4109 - accuracy: 0.8691
# Epoch 88: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4108 - accuracy: 0.8697 - val_loss: 0.4071 - val_accuracy: 0.8712
# Epoch 89/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.8784
# Epoch 89: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3987 - accuracy: 0.8784 - val_loss: 0.4208 - val_accuracy: 0.8612
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4227 - accuracy: 0.8688
# Epoch 90: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4219 - accuracy: 0.8694 - val_loss: 0.4126 - val_accuracy: 0.8625
# Epoch 91/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4285 - accuracy: 0.8662
# Epoch 91: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4285 - accuracy: 0.8662 - val_loss: 0.4340 - val_accuracy: 0.8487
# Epoch 92/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4228 - accuracy: 0.8603
# Epoch 92: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4228 - accuracy: 0.8603 - val_loss: 0.4094 - val_accuracy: 0.8612
# Epoch 93/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4007 - accuracy: 0.8813
# Epoch 93: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4007 - accuracy: 0.8813 - val_loss: 0.4132 - val_accuracy: 0.8587
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3947 - accuracy: 0.8822
# Epoch 94: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3953 - accuracy: 0.8822 - val_loss: 0.4080 - val_accuracy: 0.8700
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4071 - accuracy: 0.8750
# Epoch 95: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4078 - accuracy: 0.8747 - val_loss: 0.4156 - val_accuracy: 0.8562
# Epoch 96/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.8444
# Epoch 96: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4602 - accuracy: 0.8444 - val_loss: 0.4068 - val_accuracy: 0.8612
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4290 - accuracy: 0.8675
# Epoch 97: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4253 - accuracy: 0.8697 - val_loss: 0.4310 - val_accuracy: 0.8537
# Epoch 98/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.8719
# Epoch 98: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4245 - accuracy: 0.8719 - val_loss: 0.4018 - val_accuracy: 0.8750
# Epoch 99/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4211 - accuracy: 0.8722
# Epoch 99: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4211 - accuracy: 0.8722 - val_loss: 0.4068 - val_accuracy: 0.8687
# Epoch 100/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.8813
# Epoch 100: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4073 - accuracy: 0.8813 - val_loss: 0.3997 - val_accuracy: 0.8687
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3984 - accuracy: 0.8818
# Epoch 101: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4004 - accuracy: 0.8809 - val_loss: 0.4195 - val_accuracy: 0.8600
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4115 - accuracy: 0.8740
# Epoch 102: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4097 - accuracy: 0.8750 - val_loss: 0.4196 - val_accuracy: 0.8625
# Epoch 103/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4079 - accuracy: 0.8747
# Epoch 103: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4079 - accuracy: 0.8747 - val_loss: 0.4024 - val_accuracy: 0.8737
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3929 - accuracy: 0.8848
# Epoch 104: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3924 - accuracy: 0.8838 - val_loss: 0.4230 - val_accuracy: 0.8462
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4090 - accuracy: 0.8760
# Epoch 105: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4074 - accuracy: 0.8772 - val_loss: 0.3999 - val_accuracy: 0.8725
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3931 - accuracy: 0.8815
# Epoch 106: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3906 - accuracy: 0.8825 - val_loss: 0.3910 - val_accuracy: 0.8725
# Epoch 107/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3889 - accuracy: 0.8841
# Epoch 107: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3878 - accuracy: 0.8847 - val_loss: 0.3968 - val_accuracy: 0.8687
# Epoch 108/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.8900
# Epoch 108: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3795 - accuracy: 0.8900 - val_loss: 0.3994 - val_accuracy: 0.8775
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4045 - accuracy: 0.8763
# Epoch 109: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4081 - accuracy: 0.8744 - val_loss: 0.4045 - val_accuracy: 0.8687
# Epoch 110/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.8672
# Epoch 110: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4241 - accuracy: 0.8672 - val_loss: 0.4039 - val_accuracy: 0.8675
# Epoch 111/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.8059
# Epoch 111: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5118 - accuracy: 0.8059 - val_loss: 0.4862 - val_accuracy: 0.8087
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5053 - accuracy: 0.8118
# Epoch 112: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5025 - accuracy: 0.8128 - val_loss: 0.4706 - val_accuracy: 0.8363
# Epoch 113/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8591
# Epoch 113: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4479 - accuracy: 0.8591 - val_loss: 0.4272 - val_accuracy: 0.8625
# Epoch 114/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8709
# Epoch 114: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4251 - accuracy: 0.8709 - val_loss: 0.4057 - val_accuracy: 0.8725
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4002 - accuracy: 0.8831
# Epoch 115: val_accuracy improved from 0.87875 to 0.88000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3975 - accuracy: 0.8844 - val_loss: 0.3905 - val_accuracy: 0.8800
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3889 - accuracy: 0.8844
# Epoch 116: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3874 - accuracy: 0.8859 - val_loss: 0.3999 - val_accuracy: 0.8725
# Epoch 117/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3841 - accuracy: 0.8884
# Epoch 117: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3841 - accuracy: 0.8884 - val_loss: 0.3886 - val_accuracy: 0.8788
# Epoch 118/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.8856
# Epoch 118: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3809 - accuracy: 0.8856 - val_loss: 0.3966 - val_accuracy: 0.8712
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3989 - accuracy: 0.8727
# Epoch 119: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3961 - accuracy: 0.8744 - val_loss: 0.3854 - val_accuracy: 0.8750
# Epoch 120/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3849 - accuracy: 0.8844
# Epoch 120: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3834 - accuracy: 0.8856 - val_loss: 0.4155 - val_accuracy: 0.8637
# Epoch 121/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3953 - accuracy: 0.8794
# Epoch 121: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3953 - accuracy: 0.8794 - val_loss: 0.3853 - val_accuracy: 0.8775
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3816 - accuracy: 0.8835
# Epoch 122: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3794 - accuracy: 0.8853 - val_loss: 0.3950 - val_accuracy: 0.8725
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3794 - accuracy: 0.8851
# Epoch 123: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3800 - accuracy: 0.8847 - val_loss: 0.5043 - val_accuracy: 0.8138
# Epoch 124/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4264 - accuracy: 0.8636
# Epoch 124: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4278 - accuracy: 0.8631 - val_loss: 0.3982 - val_accuracy: 0.8700
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3882 - accuracy: 0.8841
# Epoch 125: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3878 - accuracy: 0.8844 - val_loss: 0.3995 - val_accuracy: 0.8750
# Epoch 126/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.8825
# Epoch 126: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3903 - accuracy: 0.8825 - val_loss: 0.4293 - val_accuracy: 0.8587
# Epoch 127/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4048 - accuracy: 0.8759
# Epoch 127: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4048 - accuracy: 0.8759 - val_loss: 0.3825 - val_accuracy: 0.8788
# Epoch 128/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3746 - accuracy: 0.8939
# Epoch 128: val_accuracy improved from 0.88000 to 0.88625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3731 - accuracy: 0.8947 - val_loss: 0.3779 - val_accuracy: 0.8863
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3711 - accuracy: 0.8916
# Epoch 129: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3689 - accuracy: 0.8931 - val_loss: 0.4241 - val_accuracy: 0.8537
# Epoch 130/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8856
# Epoch 130: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3907 - accuracy: 0.8856 - val_loss: 0.4008 - val_accuracy: 0.8737
# Epoch 131/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3970 - accuracy: 0.8797
# Epoch 131: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3970 - accuracy: 0.8797 - val_loss: 0.4142 - val_accuracy: 0.8562
# Epoch 132/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3928 - accuracy: 0.8841
# Epoch 132: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3928 - accuracy: 0.8841 - val_loss: 0.5048 - val_accuracy: 0.8263
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4495 - accuracy: 0.8512
# Epoch 133: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4465 - accuracy: 0.8528 - val_loss: 0.3863 - val_accuracy: 0.8788
# Epoch 134/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3875 - accuracy: 0.8877
# Epoch 134: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3889 - accuracy: 0.8869 - val_loss: 0.4027 - val_accuracy: 0.8737
# Epoch 135/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3886 - accuracy: 0.8867
# Epoch 135: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3878 - accuracy: 0.8872 - val_loss: 0.4193 - val_accuracy: 0.8625
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3971 - accuracy: 0.8809
# Epoch 136: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3947 - accuracy: 0.8822 - val_loss: 0.4051 - val_accuracy: 0.8763
# Epoch 137/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3712 - accuracy: 0.8925
# Epoch 137: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3712 - accuracy: 0.8925 - val_loss: 0.3855 - val_accuracy: 0.8763
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3716 - accuracy: 0.8949
# Epoch 138: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3697 - accuracy: 0.8963 - val_loss: 0.3769 - val_accuracy: 0.8750
# Epoch 139/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3660 - accuracy: 0.8929
# Epoch 139: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3661 - accuracy: 0.8922 - val_loss: 0.3798 - val_accuracy: 0.8800
# Epoch 140/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8906
# Epoch 140: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3756 - accuracy: 0.8906 - val_loss: 0.4203 - val_accuracy: 0.8587
# Epoch 141/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3794 - accuracy: 0.8853
# Epoch 141: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3794 - accuracy: 0.8853 - val_loss: 0.4316 - val_accuracy: 0.8500
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4213 - accuracy: 0.8646
# Epoch 142: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4208 - accuracy: 0.8647 - val_loss: 0.4805 - val_accuracy: 0.8438
# Epoch 143/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4063 - accuracy: 0.8794
# Epoch 143: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4063 - accuracy: 0.8794 - val_loss: 0.3824 - val_accuracy: 0.8788
# Epoch 144/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.8844
# Epoch 144: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3876 - accuracy: 0.8844 - val_loss: 0.3946 - val_accuracy: 0.8712
# Epoch 145/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3855 - accuracy: 0.8856
# Epoch 145: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3855 - accuracy: 0.8856 - val_loss: 0.3781 - val_accuracy: 0.8813
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8956
# Epoch 146: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3705 - accuracy: 0.8956 - val_loss: 0.3892 - val_accuracy: 0.8775
# Epoch 147/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8925
# Epoch 147: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3705 - accuracy: 0.8925 - val_loss: 0.4012 - val_accuracy: 0.8700
# Epoch 148/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3881 - accuracy: 0.8856
# Epoch 148: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3881 - accuracy: 0.8856 - val_loss: 0.3796 - val_accuracy: 0.8800
# Epoch 149/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8847
# Epoch 149: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3819 - accuracy: 0.8847 - val_loss: 0.4736 - val_accuracy: 0.8450
# Epoch 150/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8725
# Epoch 150: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3971 - accuracy: 0.8725 - val_loss: 0.3708 - val_accuracy: 0.8813
# Epoch 151/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8941
# Epoch 151: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3692 - accuracy: 0.8941 - val_loss: 0.4040 - val_accuracy: 0.8687
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3744 - accuracy: 0.8893
# Epoch 152: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3733 - accuracy: 0.8897 - val_loss: 0.3808 - val_accuracy: 0.8737
# Epoch 153/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3656 - accuracy: 0.8909
# Epoch 153: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3656 - accuracy: 0.8909 - val_loss: 0.3784 - val_accuracy: 0.8813
# Epoch 154/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3702 - accuracy: 0.8913
# Epoch 154: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3702 - accuracy: 0.8913 - val_loss: 0.3730 - val_accuracy: 0.8838
# Epoch 155/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3575 - accuracy: 0.8955
# Epoch 155: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3591 - accuracy: 0.8950 - val_loss: 0.3765 - val_accuracy: 0.8813
# Epoch 156/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.8959
# Epoch 156: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3570 - accuracy: 0.8959 - val_loss: 0.3783 - val_accuracy: 0.8737
# Epoch 157/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8906
# Epoch 157: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3696 - accuracy: 0.8906 - val_loss: 0.4261 - val_accuracy: 0.8625
# Epoch 158/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8803
# Epoch 158: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3884 - accuracy: 0.8803 - val_loss: 0.4039 - val_accuracy: 0.8700
# Epoch 159/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3853 - accuracy: 0.8828
# Epoch 159: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3853 - accuracy: 0.8828 - val_loss: 0.3778 - val_accuracy: 0.8813
# Epoch 160/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3587 - accuracy: 0.9009
# Epoch 160: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3587 - accuracy: 0.9009 - val_loss: 0.3766 - val_accuracy: 0.8813
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3497 - accuracy: 0.9033
# Epoch 161: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3517 - accuracy: 0.9022 - val_loss: 0.3788 - val_accuracy: 0.8800
# Epoch 162/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4229 - accuracy: 0.8691
# Epoch 162: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4231 - accuracy: 0.8703 - val_loss: 0.3956 - val_accuracy: 0.8700
# Epoch 163/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3868 - accuracy: 0.8772
# Epoch 163: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3868 - accuracy: 0.8772 - val_loss: 0.3978 - val_accuracy: 0.8750
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3822 - accuracy: 0.8900
# Epoch 164: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3807 - accuracy: 0.8903 - val_loss: 0.4288 - val_accuracy: 0.8625
# Epoch 165/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8863
# Epoch 165: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3791 - accuracy: 0.8863 - val_loss: 0.3780 - val_accuracy: 0.8775
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3542 - accuracy: 0.8988
# Epoch 166: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3567 - accuracy: 0.8975 - val_loss: 0.3781 - val_accuracy: 0.8788
# Epoch 167/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3579 - accuracy: 0.8945
# Epoch 167: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3545 - accuracy: 0.8959 - val_loss: 0.4205 - val_accuracy: 0.8637
# Epoch 168/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.8966
# Epoch 168: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3512 - accuracy: 0.8966 - val_loss: 0.4132 - val_accuracy: 0.8637
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3907 - accuracy: 0.8743
# Epoch 169: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3950 - accuracy: 0.8728 - val_loss: 0.3868 - val_accuracy: 0.8775
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3587 - accuracy: 0.8971
# Epoch 170: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3657 - accuracy: 0.8950 - val_loss: 0.4421 - val_accuracy: 0.8537
# Epoch 171/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.8644
# Epoch 171: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4338 - accuracy: 0.8644 - val_loss: 0.4438 - val_accuracy: 0.8375
# Epoch 172/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8659
# Epoch 172: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4219 - accuracy: 0.8659 - val_loss: 0.3946 - val_accuracy: 0.8763
# Epoch 173/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4037 - accuracy: 0.8802
# Epoch 173: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4027 - accuracy: 0.8813 - val_loss: 0.4235 - val_accuracy: 0.8687
# Epoch 174/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3883 - accuracy: 0.8841
# Epoch 174: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3883 - accuracy: 0.8841 - val_loss: 0.3862 - val_accuracy: 0.8763
# Epoch 175/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3599 - accuracy: 0.8958
# Epoch 175: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3615 - accuracy: 0.8947 - val_loss: 0.3753 - val_accuracy: 0.8775
# Epoch 176/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.8950
# Epoch 176: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3516 - accuracy: 0.8950 - val_loss: 0.3721 - val_accuracy: 0.8775
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3519 - accuracy: 0.8936
# Epoch 177: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3548 - accuracy: 0.8928 - val_loss: 0.3688 - val_accuracy: 0.8775
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3510 - accuracy: 0.8910
# Epoch 178: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3541 - accuracy: 0.8900 - val_loss: 0.3567 - val_accuracy: 0.8788
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3510 - accuracy: 0.8958
# Epoch 179: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3504 - accuracy: 0.8963 - val_loss: 0.3648 - val_accuracy: 0.8863
# Epoch 180/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8966
# Epoch 180: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3421 - accuracy: 0.8966 - val_loss: 0.3568 - val_accuracy: 0.8775
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3382 - accuracy: 0.8968
# Epoch 181: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3393 - accuracy: 0.8963 - val_loss: 0.4128 - val_accuracy: 0.8712
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3743 - accuracy: 0.8874
# Epoch 182: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3737 - accuracy: 0.8878 - val_loss: 0.4252 - val_accuracy: 0.8600
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3834 - accuracy: 0.8799
# Epoch 183: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3847 - accuracy: 0.8791 - val_loss: 0.3691 - val_accuracy: 0.8763
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3679 - accuracy: 0.8880
# Epoch 184: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3657 - accuracy: 0.8891 - val_loss: 0.3612 - val_accuracy: 0.8863
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3364 - accuracy: 0.9046
# Epoch 185: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3357 - accuracy: 0.9050 - val_loss: 0.3516 - val_accuracy: 0.8788
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3551 - accuracy: 0.8942
# Epoch 186: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3539 - accuracy: 0.8950 - val_loss: 0.3675 - val_accuracy: 0.8775
# Epoch 187/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3571 - accuracy: 0.8950
# Epoch 187: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3571 - accuracy: 0.8950 - val_loss: 0.3950 - val_accuracy: 0.8763
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3511 - accuracy: 0.8906
# Epoch 188: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3488 - accuracy: 0.8931 - val_loss: 0.3543 - val_accuracy: 0.8813
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3339 - accuracy: 0.9027
# Epoch 189: val_accuracy improved from 0.88625 to 0.88875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3330 - accuracy: 0.9028 - val_loss: 0.3426 - val_accuracy: 0.8888
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3325 - accuracy: 0.8984
# Epoch 190: val_accuracy improved from 0.88875 to 0.89875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3322 - accuracy: 0.8975 - val_loss: 0.3624 - val_accuracy: 0.8988
# Epoch 191/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3617 - accuracy: 0.8900
# Epoch 191: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3617 - accuracy: 0.8900 - val_loss: 0.3826 - val_accuracy: 0.8838
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3429 - accuracy: 0.9033
# Epoch 192: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3455 - accuracy: 0.9013 - val_loss: 0.3597 - val_accuracy: 0.8800
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3883 - accuracy: 0.8753
# Epoch 193: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3883 - accuracy: 0.8753 - val_loss: 0.5164 - val_accuracy: 0.8388
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4003 - accuracy: 0.8750
# Epoch 194: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4047 - accuracy: 0.8741 - val_loss: 0.3625 - val_accuracy: 0.8763
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3874 - accuracy: 0.8776
# Epoch 195: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3878 - accuracy: 0.8784 - val_loss: 0.4106 - val_accuracy: 0.8763
# Epoch 196/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3841 - accuracy: 0.8891
# Epoch 196: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3841 - accuracy: 0.8891 - val_loss: 0.3815 - val_accuracy: 0.8775
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3803 - accuracy: 0.8936
# Epoch 197: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3806 - accuracy: 0.8934 - val_loss: 0.3902 - val_accuracy: 0.8737
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3696 - accuracy: 0.8949
# Epoch 198: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3686 - accuracy: 0.8959 - val_loss: 0.3673 - val_accuracy: 0.8763
# Epoch 199/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.8969
# Epoch 199: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3472 - accuracy: 0.8969 - val_loss: 0.3568 - val_accuracy: 0.8788
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3396 - accuracy: 0.8994
# Epoch 200: val_accuracy did not improve from 0.89875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3422 - accuracy: 0.8984 - val_loss: 0.3580 - val_accuracy: 0.8788

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 96, 64)            12352
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 16, 64)            12352
#
#  max_pooling1d_3 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 70,465
# Trainable params: 70,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo    = load_model("modelo_generado/mejor_modelo.keras")
resul_eva       = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida     = resul_eva[0]
accuracy    = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))
# Out:
# Loss: 0.3624
# Accuracy: 89.8750%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy    = accuracy_score(y_val, y_pred)
precision   = precision_score(y_val, y_pred)
recall      = recall_score(y_val, y_pred)
f1          = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	89.88%
# Sensitivity:	96.89%
# Specificity:	83.33%
# Precision:	84.42%
# F1-score:	90.23%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.95

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
