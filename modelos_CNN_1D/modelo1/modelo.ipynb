# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado//modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, epochs=200, 
    batch_size=512, 
    callbacks=[checkpoint_callback],
    validation_data= (X_val_reshaped, y_val)
)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 4.5701 - accuracy: 0.5113
# Epoch 1: val_accuracy improved from -inf to 0.51875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 3s 108ms/step - loss: 4.5701 - accuracy: 0.5113 - val_loss: 2.6392 - val_accuracy: 0.5188
# Epoch 2/200
# 7/7 [==============================] - ETA: 0s - loss: 2.4865 - accuracy: 0.5406
# Epoch 2: val_accuracy improved from 0.51875 to 0.66625, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 2.4865 - accuracy: 0.5406 - val_loss: 2.2793 - val_accuracy: 0.6662
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 2.1231 - accuracy: 0.6523
# Epoch 3: val_accuracy improved from 0.66625 to 0.74750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 2.1133 - accuracy: 0.6544 - val_loss: 1.7999 - val_accuracy: 0.7475
# Epoch 4/200
# 7/7 [==============================] - ETA: 0s - loss: 1.6459 - accuracy: 0.7256
# Epoch 4: val_accuracy did not improve from 0.74750
# 7/7 [==============================] - 0s 53ms/step - loss: 1.6459 - accuracy: 0.7256 - val_loss: 1.4310 - val_accuracy: 0.6913
# Epoch 5/200
# 7/7 [==============================] - ETA: 0s - loss: 1.3477 - accuracy: 0.7022
# Epoch 5: val_accuracy did not improve from 0.74750
# 7/7 [==============================] - 0s 52ms/step - loss: 1.3477 - accuracy: 0.7022 - val_loss: 1.2050 - val_accuracy: 0.7275
# Epoch 6/200
# 7/7 [==============================] - ETA: 0s - loss: 1.1153 - accuracy: 0.7331
# Epoch 6: val_accuracy improved from 0.74750 to 0.79500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 1.1153 - accuracy: 0.7331 - val_loss: 0.9804 - val_accuracy: 0.7950
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.9422 - accuracy: 0.7650
# Epoch 7: val_accuracy improved from 0.79500 to 0.84250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.9407 - accuracy: 0.7650 - val_loss: 0.8220 - val_accuracy: 0.8425
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: 0.8150 - accuracy: 0.7869
# Epoch 8: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8150 - accuracy: 0.7869 - val_loss: 0.7381 - val_accuracy: 0.8275
# Epoch 9/200
# 7/7 [==============================] - ETA: 0s - loss: 0.8016 - accuracy: 0.7622
# Epoch 9: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.8016 - accuracy: 0.7622 - val_loss: 0.7428 - val_accuracy: 0.7462
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7523 - accuracy: 0.7622
# Epoch 10: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.7523 - accuracy: 0.7622 - val_loss: 0.6863 - val_accuracy: 0.7987
# Epoch 11/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6966 - accuracy: 0.7844
# Epoch 11: val_accuracy improved from 0.84250 to 0.84625, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.6966 - accuracy: 0.7844 - val_loss: 0.6396 - val_accuracy: 0.8462
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6475 - accuracy: 0.7923
# Epoch 12: val_accuracy improved from 0.84625 to 0.84875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.6463 - accuracy: 0.7934 - val_loss: 0.5772 - val_accuracy: 0.8487
# Epoch 13/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7253 - accuracy: 0.7581
# Epoch 13: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.7253 - accuracy: 0.7581 - val_loss: 0.6774 - val_accuracy: 0.7575
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.7619
# Epoch 14: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 52ms/step - loss: 0.7022 - accuracy: 0.7619 - val_loss: 0.6547 - val_accuracy: 0.7513
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6606 - accuracy: 0.7936
# Epoch 15: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6608 - accuracy: 0.7934 - val_loss: 0.6202 - val_accuracy: 0.7625
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6145 - accuracy: 0.7900
# Epoch 16: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6145 - accuracy: 0.7900 - val_loss: 0.5440 - val_accuracy: 0.8462
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5617 - accuracy: 0.8076
# Epoch 17: val_accuracy improved from 0.84875 to 0.85250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 1s 76ms/step - loss: 0.5604 - accuracy: 0.8078 - val_loss: 0.5015 - val_accuracy: 0.8525
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5230 - accuracy: 0.8303
# Epoch 18: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5230 - accuracy: 0.8303 - val_loss: 0.5270 - val_accuracy: 0.7650
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5159 - accuracy: 0.8306
# Epoch 19: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5159 - accuracy: 0.8306 - val_loss: 0.4963 - val_accuracy: 0.8475
# Epoch 20/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5084 - accuracy: 0.8272
# Epoch 20: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5084 - accuracy: 0.8272 - val_loss: 0.5011 - val_accuracy: 0.8288
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.8250
# Epoch 21: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4947 - accuracy: 0.8250 - val_loss: 0.4578 - val_accuracy: 0.8200
# Epoch 22/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4708 - accuracy: 0.8451
# Epoch 22: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4694 - accuracy: 0.8456 - val_loss: 0.4448 - val_accuracy: 0.8462
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8572
# Epoch 23: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4537 - accuracy: 0.8572 - val_loss: 0.4597 - val_accuracy: 0.8213
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4929 - accuracy: 0.8200
# Epoch 24: val_accuracy did not improve from 0.85250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4923 - accuracy: 0.8222 - val_loss: 0.4729 - val_accuracy: 0.8100
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4827 - accuracy: 0.8369
# Epoch 25: val_accuracy improved from 0.85250 to 0.86250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4827 - accuracy: 0.8369 - val_loss: 0.4295 - val_accuracy: 0.8625
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.8619
# Epoch 26: val_accuracy improved from 0.86250 to 0.86375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4491 - accuracy: 0.8619 - val_loss: 0.4083 - val_accuracy: 0.8637
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4281 - accuracy: 0.8532
# Epoch 27: val_accuracy improved from 0.86375 to 0.86875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4296 - accuracy: 0.8525 - val_loss: 0.4040 - val_accuracy: 0.8687
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4189 - accuracy: 0.8669
# Epoch 28: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4189 - accuracy: 0.8669 - val_loss: 0.4092 - val_accuracy: 0.8675
# Epoch 29/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.8188
# Epoch 29: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4856 - accuracy: 0.8188 - val_loss: 0.4728 - val_accuracy: 0.8512
# Epoch 30/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.8344
# Epoch 30: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4877 - accuracy: 0.8344 - val_loss: 0.4293 - val_accuracy: 0.8475
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.8484
# Epoch 31: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4545 - accuracy: 0.8484 - val_loss: 0.4149 - val_accuracy: 0.8675
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4437 - accuracy: 0.8525
# Epoch 32: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4437 - accuracy: 0.8525 - val_loss: 0.4628 - val_accuracy: 0.8037
# Epoch 33/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.8316
# Epoch 33: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4641 - accuracy: 0.8316 - val_loss: 0.4604 - val_accuracy: 0.8275
# Epoch 34/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4467 - accuracy: 0.8470
# Epoch 34: val_accuracy improved from 0.86875 to 0.87500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4446 - accuracy: 0.8484 - val_loss: 0.4139 - val_accuracy: 0.8750
# Epoch 35/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.8575
# Epoch 35: val_accuracy did not improve from 0.87500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4383 - accuracy: 0.8575 - val_loss: 0.4736 - val_accuracy: 0.8462
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.8541
# Epoch 36: val_accuracy did not improve from 0.87500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4454 - accuracy: 0.8541 - val_loss: 0.4963 - val_accuracy: 0.7900
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4570 - accuracy: 0.8398
# Epoch 37: val_accuracy did not improve from 0.87500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4575 - accuracy: 0.8397 - val_loss: 0.4091 - val_accuracy: 0.8712
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4257 - accuracy: 0.8566
# Epoch 38: val_accuracy improved from 0.87500 to 0.87750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4257 - accuracy: 0.8566 - val_loss: 0.3941 - val_accuracy: 0.8775
# Epoch 39/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3982 - accuracy: 0.8701
# Epoch 39: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3994 - accuracy: 0.8697 - val_loss: 0.3902 - val_accuracy: 0.8737
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3947 - accuracy: 0.8706
# Epoch 40: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3947 - accuracy: 0.8706 - val_loss: 0.3801 - val_accuracy: 0.8763
# Epoch 41/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3869 - accuracy: 0.8773
# Epoch 41: val_accuracy improved from 0.87750 to 0.88000, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3871 - accuracy: 0.8778 - val_loss: 0.3752 - val_accuracy: 0.8800
# Epoch 42/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.8813
# Epoch 42: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3776 - accuracy: 0.8813 - val_loss: 0.4104 - val_accuracy: 0.8587
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4147 - accuracy: 0.8509
# Epoch 43: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4128 - accuracy: 0.8525 - val_loss: 0.3949 - val_accuracy: 0.8675
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8559
# Epoch 44: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4237 - accuracy: 0.8559 - val_loss: 0.3871 - val_accuracy: 0.8750
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4288 - accuracy: 0.8620
# Epoch 45: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4275 - accuracy: 0.8628 - val_loss: 0.4093 - val_accuracy: 0.8763
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4224 - accuracy: 0.8641
# Epoch 46: val_accuracy improved from 0.88000 to 0.88750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 70ms/step - loss: 0.4224 - accuracy: 0.8641 - val_loss: 0.3932 - val_accuracy: 0.8875
# Epoch 47/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4002 - accuracy: 0.8772
# Epoch 47: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4002 - accuracy: 0.8772 - val_loss: 0.3718 - val_accuracy: 0.8850
# Epoch 48/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3984 - accuracy: 0.8703
# Epoch 48: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3984 - accuracy: 0.8703 - val_loss: 0.4386 - val_accuracy: 0.8200
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3852 - accuracy: 0.8783
# Epoch 49: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3891 - accuracy: 0.8756 - val_loss: 0.4057 - val_accuracy: 0.8575
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4114 - accuracy: 0.8519
# Epoch 50: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4117 - accuracy: 0.8519 - val_loss: 0.4005 - val_accuracy: 0.8737
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.8697
# Epoch 51: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3914 - accuracy: 0.8697 - val_loss: 0.3810 - val_accuracy: 0.8788
# Epoch 52/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8631
# Epoch 52: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4015 - accuracy: 0.8631 - val_loss: 0.4014 - val_accuracy: 0.8687
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4159 - accuracy: 0.8571
# Epoch 53: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4131 - accuracy: 0.8584 - val_loss: 0.4467 - val_accuracy: 0.8138
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4173 - accuracy: 0.8519
# Epoch 54: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4173 - accuracy: 0.8519 - val_loss: 0.3716 - val_accuracy: 0.8775
# Epoch 55/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.8700
# Epoch 55: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3837 - accuracy: 0.8700 - val_loss: 0.3767 - val_accuracy: 0.8788
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3678 - accuracy: 0.8809
# Epoch 56: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3719 - accuracy: 0.8784 - val_loss: 0.3631 - val_accuracy: 0.8875
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8803
# Epoch 57: val_accuracy improved from 0.88750 to 0.89250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3649 - accuracy: 0.8803 - val_loss: 0.3582 - val_accuracy: 0.8925
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3615 - accuracy: 0.8815
# Epoch 58: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3626 - accuracy: 0.8813 - val_loss: 0.3619 - val_accuracy: 0.8913
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3770 - accuracy: 0.8757
# Epoch 59: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3767 - accuracy: 0.8756 - val_loss: 0.3598 - val_accuracy: 0.8913
# Epoch 60/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3743 - accuracy: 0.8786
# Epoch 60: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3738 - accuracy: 0.8781 - val_loss: 0.3696 - val_accuracy: 0.8875
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3777 - accuracy: 0.8763
# Epoch 61: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3772 - accuracy: 0.8753 - val_loss: 0.3792 - val_accuracy: 0.8763
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8697
# Epoch 62: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3917 - accuracy: 0.8697 - val_loss: 0.3654 - val_accuracy: 0.8925
# Epoch 63/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.8816
# Epoch 63: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3767 - accuracy: 0.8816 - val_loss: 0.3562 - val_accuracy: 0.8888
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3613 - accuracy: 0.8859
# Epoch 64: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3613 - accuracy: 0.8859 - val_loss: 0.3573 - val_accuracy: 0.8913
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3655 - accuracy: 0.8857
# Epoch 65: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3719 - accuracy: 0.8828 - val_loss: 0.3885 - val_accuracy: 0.8800
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3910 - accuracy: 0.8778
# Epoch 66: val_accuracy improved from 0.89250 to 0.89500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3910 - accuracy: 0.8778 - val_loss: 0.3507 - val_accuracy: 0.8950
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3715 - accuracy: 0.8818
# Epoch 67: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3713 - accuracy: 0.8822 - val_loss: 0.3753 - val_accuracy: 0.8775
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.8531
# Epoch 68: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4073 - accuracy: 0.8531 - val_loss: 0.3608 - val_accuracy: 0.8850
# Epoch 69/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3952 - accuracy: 0.8650
# Epoch 69: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3952 - accuracy: 0.8650 - val_loss: 0.3730 - val_accuracy: 0.8813
# Epoch 70/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3835 - accuracy: 0.8756
# Epoch 70: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3835 - accuracy: 0.8756 - val_loss: 0.4439 - val_accuracy: 0.8338
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3925 - accuracy: 0.8625
# Epoch 71: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 51ms/step - loss: 0.3925 - accuracy: 0.8625 - val_loss: 0.4071 - val_accuracy: 0.8662
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4034 - accuracy: 0.8555
# Epoch 72: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4039 - accuracy: 0.8556 - val_loss: 0.4093 - val_accuracy: 0.8750
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.8447
# Epoch 73: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4481 - accuracy: 0.8447 - val_loss: 0.4282 - val_accuracy: 0.8813
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4152 - accuracy: 0.8698
# Epoch 74: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4148 - accuracy: 0.8703 - val_loss: 0.4685 - val_accuracy: 0.8413
# Epoch 75/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.8303
# Epoch 75: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4895 - accuracy: 0.8303 - val_loss: 0.4206 - val_accuracy: 0.8800
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4368 - accuracy: 0.8626
# Epoch 76: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4381 - accuracy: 0.8616 - val_loss: 0.4091 - val_accuracy: 0.8775
# Epoch 77/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4135 - accuracy: 0.8681
# Epoch 77: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4135 - accuracy: 0.8681 - val_loss: 0.3787 - val_accuracy: 0.8838
# Epoch 78/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3771 - accuracy: 0.8838
# Epoch 78: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3771 - accuracy: 0.8838 - val_loss: 0.3668 - val_accuracy: 0.8888
# Epoch 79/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3724 - accuracy: 0.8844
# Epoch 79: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3724 - accuracy: 0.8844 - val_loss: 0.3562 - val_accuracy: 0.8925
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3514 - accuracy: 0.8929
# Epoch 80: val_accuracy improved from 0.89500 to 0.89625, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3503 - accuracy: 0.8944 - val_loss: 0.3472 - val_accuracy: 0.8963
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3428 - accuracy: 0.8916
# Epoch 81: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3430 - accuracy: 0.8906 - val_loss: 0.3515 - val_accuracy: 0.8875
# Epoch 82/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3394 - accuracy: 0.8903
# Epoch 82: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3394 - accuracy: 0.8903 - val_loss: 0.3399 - val_accuracy: 0.8950
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3506 - accuracy: 0.8844
# Epoch 83: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3480 - accuracy: 0.8869 - val_loss: 0.3479 - val_accuracy: 0.8925
# Epoch 84/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8766
# Epoch 84: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3714 - accuracy: 0.8766 - val_loss: 0.3485 - val_accuracy: 0.8913
# Epoch 85/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8781
# Epoch 85: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3661 - accuracy: 0.8781 - val_loss: 0.3526 - val_accuracy: 0.8963
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3734 - accuracy: 0.8786
# Epoch 86: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3746 - accuracy: 0.8778 - val_loss: 0.3930 - val_accuracy: 0.8675
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3829 - accuracy: 0.8783
# Epoch 87: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3845 - accuracy: 0.8772 - val_loss: 0.3648 - val_accuracy: 0.8888
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3811 - accuracy: 0.8848
# Epoch 88: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3807 - accuracy: 0.8847 - val_loss: 0.3549 - val_accuracy: 0.8900
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3717 - accuracy: 0.8831
# Epoch 89: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3750 - accuracy: 0.8806 - val_loss: 0.3907 - val_accuracy: 0.8775
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3911 - accuracy: 0.8717
# Epoch 90: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3901 - accuracy: 0.8725 - val_loss: 0.3676 - val_accuracy: 0.8863
# Epoch 91/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.8700
# Epoch 91: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3933 - accuracy: 0.8700 - val_loss: 0.3630 - val_accuracy: 0.8938
# Epoch 92/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8834
# Epoch 92: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3884 - accuracy: 0.8834 - val_loss: 0.3874 - val_accuracy: 0.8900
# Epoch 93/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.8803
# Epoch 93: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3963 - accuracy: 0.8803 - val_loss: 0.3939 - val_accuracy: 0.8800
# Epoch 94/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8697
# Epoch 94: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4128 - accuracy: 0.8697 - val_loss: 0.3755 - val_accuracy: 0.8938
# Epoch 95/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.8331
# Epoch 95: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4615 - accuracy: 0.8331 - val_loss: 0.4397 - val_accuracy: 0.8712
# Epoch 96/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4573 - accuracy: 0.8416
# Epoch 96: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4573 - accuracy: 0.8416 - val_loss: 0.3991 - val_accuracy: 0.8875
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4313 - accuracy: 0.8704
# Epoch 97: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4303 - accuracy: 0.8716 - val_loss: 0.3919 - val_accuracy: 0.8938
# Epoch 98/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8769
# Epoch 98: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4090 - accuracy: 0.8769 - val_loss: 0.3740 - val_accuracy: 0.8925
# Epoch 99/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3860 - accuracy: 0.8759
# Epoch 99: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3860 - accuracy: 0.8759 - val_loss: 0.3487 - val_accuracy: 0.8950
# Epoch 100/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3766 - accuracy: 0.8770
# Epoch 100: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3762 - accuracy: 0.8769 - val_loss: 0.3846 - val_accuracy: 0.8737
# Epoch 101/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4115 - accuracy: 0.8612
# Epoch 101: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4115 - accuracy: 0.8612 - val_loss: 0.3911 - val_accuracy: 0.8763
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3967 - accuracy: 0.8708
# Epoch 102: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3972 - accuracy: 0.8709 - val_loss: 0.3711 - val_accuracy: 0.8850
# Epoch 103/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8791
# Epoch 103: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3791 - accuracy: 0.8791 - val_loss: 0.3634 - val_accuracy: 0.8900
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3690 - accuracy: 0.8822
# Epoch 104: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3715 - accuracy: 0.8794 - val_loss: 0.3464 - val_accuracy: 0.8938
# Epoch 105/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3598 - accuracy: 0.8791
# Epoch 105: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3598 - accuracy: 0.8791 - val_loss: 0.3412 - val_accuracy: 0.8950
# Epoch 106/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.8756
# Epoch 106: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3650 - accuracy: 0.8756 - val_loss: 0.3459 - val_accuracy: 0.8925
# Epoch 107/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3597 - accuracy: 0.8816
# Epoch 107: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3597 - accuracy: 0.8816 - val_loss: 0.3414 - val_accuracy: 0.8963
# Epoch 108/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.8841
# Epoch 108: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3609 - accuracy: 0.8841 - val_loss: 0.4240 - val_accuracy: 0.8462
# Epoch 109/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8231
# Epoch 109: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4759 - accuracy: 0.8231 - val_loss: 0.3975 - val_accuracy: 0.8875
# Epoch 110/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4210 - accuracy: 0.8756
# Epoch 110: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4210 - accuracy: 0.8756 - val_loss: 0.4149 - val_accuracy: 0.8875
# Epoch 111/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4190 - accuracy: 0.8775
# Epoch 111: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4190 - accuracy: 0.8775 - val_loss: 0.3890 - val_accuracy: 0.8913
# Epoch 112/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8775
# Epoch 112: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4082 - accuracy: 0.8775 - val_loss: 0.3754 - val_accuracy: 0.8938
# Epoch 113/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8681
# Epoch 113: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4146 - accuracy: 0.8681 - val_loss: 0.3731 - val_accuracy: 0.8925
# Epoch 114/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.8700
# Epoch 114: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4042 - accuracy: 0.8700 - val_loss: 0.3854 - val_accuracy: 0.8838
# Epoch 115/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8684
# Epoch 115: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4132 - accuracy: 0.8684 - val_loss: 0.3894 - val_accuracy: 0.8900
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4452 - accuracy: 0.8607
# Epoch 116: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4453 - accuracy: 0.8616 - val_loss: 0.3946 - val_accuracy: 0.8913
# Epoch 117/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4261 - accuracy: 0.8794
# Epoch 117: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4261 - accuracy: 0.8794 - val_loss: 0.3960 - val_accuracy: 0.8888
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4217 - accuracy: 0.8734
# Epoch 118: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4212 - accuracy: 0.8728 - val_loss: 0.3917 - val_accuracy: 0.8913
# Epoch 119/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.8778
# Epoch 119: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4050 - accuracy: 0.8778 - val_loss: 0.3839 - val_accuracy: 0.8875
# Epoch 120/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3934 - accuracy: 0.8851
# Epoch 120: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3932 - accuracy: 0.8847 - val_loss: 0.3759 - val_accuracy: 0.8925
# Epoch 121/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.8863
# Epoch 121: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3807 - accuracy: 0.8863 - val_loss: 0.5085 - val_accuracy: 0.8112
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5386 - accuracy: 0.7783
# Epoch 122: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5398 - accuracy: 0.7772 - val_loss: 0.5261 - val_accuracy: 0.7775
# Epoch 123/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5537 - accuracy: 0.7663
# Epoch 123: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5537 - accuracy: 0.7663 - val_loss: 0.5202 - val_accuracy: 0.7788
# Epoch 124/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5735 - accuracy: 0.7575
# Epoch 124: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5735 - accuracy: 0.7575 - val_loss: 0.5330 - val_accuracy: 0.7763
# Epoch 125/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5815 - accuracy: 0.7478
# Epoch 125: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5815 - accuracy: 0.7478 - val_loss: 0.5564 - val_accuracy: 0.7538
# Epoch 126/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5765 - accuracy: 0.7581
# Epoch 126: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5740 - accuracy: 0.7606 - val_loss: 0.5442 - val_accuracy: 0.7750
# Epoch 127/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5699 - accuracy: 0.7628
# Epoch 127: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5699 - accuracy: 0.7628 - val_loss: 0.5355 - val_accuracy: 0.7788
# Epoch 128/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5525 - accuracy: 0.7681
# Epoch 128: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5525 - accuracy: 0.7681 - val_loss: 0.5171 - val_accuracy: 0.7775
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5405 - accuracy: 0.7640
# Epoch 129: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5369 - accuracy: 0.7659 - val_loss: 0.5015 - val_accuracy: 0.7763
# Epoch 130/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.7681
# Epoch 130: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5186 - accuracy: 0.7681 - val_loss: 0.4872 - val_accuracy: 0.7750
# Epoch 131/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5011 - accuracy: 0.7715
# Epoch 131: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5014 - accuracy: 0.7700 - val_loss: 0.4758 - val_accuracy: 0.7725
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4874 - accuracy: 0.7812
# Epoch 132: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4899 - accuracy: 0.7788 - val_loss: 0.4592 - val_accuracy: 0.7788
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4839 - accuracy: 0.7904
# Epoch 133: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4854 - accuracy: 0.7903 - val_loss: 0.4612 - val_accuracy: 0.7837
# Epoch 134/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7744
# Epoch 134: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4936 - accuracy: 0.7744 - val_loss: 0.4597 - val_accuracy: 0.8175
# Epoch 135/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7722
# Epoch 135: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4947 - accuracy: 0.7722 - val_loss: 0.4559 - val_accuracy: 0.7775
# Epoch 136/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4830 - accuracy: 0.7803
# Epoch 136: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4830 - accuracy: 0.7803 - val_loss: 0.4825 - val_accuracy: 0.7550
# Epoch 137/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.7669
# Epoch 137: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4906 - accuracy: 0.7669 - val_loss: 0.4567 - val_accuracy: 0.7775
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4692 - accuracy: 0.7826
# Epoch 138: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4708 - accuracy: 0.7809 - val_loss: 0.4503 - val_accuracy: 0.7775
# Epoch 139/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7862
# Epoch 139: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4675 - accuracy: 0.7862 - val_loss: 0.4418 - val_accuracy: 0.7788
# Epoch 140/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.7769
# Epoch 140: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4709 - accuracy: 0.7769 - val_loss: 0.4389 - val_accuracy: 0.8087
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4638 - accuracy: 0.7839
# Epoch 141: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4644 - accuracy: 0.7819 - val_loss: 0.4501 - val_accuracy: 0.7975
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4698 - accuracy: 0.7829
# Epoch 142: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4729 - accuracy: 0.7803 - val_loss: 0.4362 - val_accuracy: 0.8400
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4684 - accuracy: 0.7705
# Epoch 143: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4674 - accuracy: 0.7728 - val_loss: 0.4603 - val_accuracy: 0.7700
# Epoch 144/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4644 - accuracy: 0.7712
# Epoch 144: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4645 - accuracy: 0.7716 - val_loss: 0.4475 - val_accuracy: 0.7738
# Epoch 145/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4732 - accuracy: 0.7684
# Epoch 145: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4732 - accuracy: 0.7684 - val_loss: 0.4728 - val_accuracy: 0.7675
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.7763
# Epoch 146: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4760 - accuracy: 0.7763 - val_loss: 0.4824 - val_accuracy: 0.7538
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4802 - accuracy: 0.7777
# Epoch 147: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4803 - accuracy: 0.7769 - val_loss: 0.4390 - val_accuracy: 0.8325
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4848 - accuracy: 0.7712
# Epoch 148: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4857 - accuracy: 0.7706 - val_loss: 0.4789 - val_accuracy: 0.7675
# Epoch 149/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.7631
# Epoch 149: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5089 - accuracy: 0.7631 - val_loss: 0.6282 - val_accuracy: 0.6562
# Epoch 150/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5700 - accuracy: 0.7259
# Epoch 150: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5700 - accuracy: 0.7259 - val_loss: 0.5281 - val_accuracy: 0.7738
# Epoch 151/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5625 - accuracy: 0.7594
# Epoch 151: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5625 - accuracy: 0.7594 - val_loss: 0.5412 - val_accuracy: 0.7775
# Epoch 152/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5629 - accuracy: 0.7644
# Epoch 152: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5629 - accuracy: 0.7644 - val_loss: 0.5352 - val_accuracy: 0.7775
# Epoch 153/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5473 - accuracy: 0.7691
# Epoch 153: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5473 - accuracy: 0.7691 - val_loss: 0.5185 - val_accuracy: 0.7763
# Epoch 154/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5279 - accuracy: 0.7722
# Epoch 154: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5279 - accuracy: 0.7722 - val_loss: 0.5009 - val_accuracy: 0.7775
# Epoch 155/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5097 - accuracy: 0.7703
# Epoch 155: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5097 - accuracy: 0.7703 - val_loss: 0.4822 - val_accuracy: 0.7775
# Epoch 156/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.7719
# Epoch 156: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4939 - accuracy: 0.7719 - val_loss: 0.4729 - val_accuracy: 0.7750
# Epoch 157/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4780 - accuracy: 0.7722
# Epoch 157: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4780 - accuracy: 0.7722 - val_loss: 0.4561 - val_accuracy: 0.7775
# Epoch 158/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4701 - accuracy: 0.7706
# Epoch 158: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4701 - accuracy: 0.7706 - val_loss: 0.4497 - val_accuracy: 0.7775
# Epoch 159/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7684
# Epoch 159: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4662 - accuracy: 0.7684 - val_loss: 0.4477 - val_accuracy: 0.7775
# Epoch 160/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4706 - accuracy: 0.7675
# Epoch 160: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4706 - accuracy: 0.7675 - val_loss: 0.4583 - val_accuracy: 0.7763
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4697 - accuracy: 0.7702
# Epoch 161: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4677 - accuracy: 0.7716 - val_loss: 0.4513 - val_accuracy: 0.7763
# Epoch 162/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7675
# Epoch 162: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4675 - accuracy: 0.7675 - val_loss: 0.4473 - val_accuracy: 0.7763
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4573 - accuracy: 0.7676
# Epoch 163: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4579 - accuracy: 0.7675 - val_loss: 0.4512 - val_accuracy: 0.7775
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4648 - accuracy: 0.7666
# Epoch 164: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4617 - accuracy: 0.7684 - val_loss: 0.4391 - val_accuracy: 0.7775
# Epoch 165/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.7678
# Epoch 165: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4545 - accuracy: 0.7678 - val_loss: 0.4451 - val_accuracy: 0.7738
# Epoch 166/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.7669
# Epoch 166: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4612 - accuracy: 0.7669 - val_loss: 0.4362 - val_accuracy: 0.7763
# Epoch 167/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4582 - accuracy: 0.7688
# Epoch 167: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4582 - accuracy: 0.7688 - val_loss: 0.4417 - val_accuracy: 0.7775
# Epoch 168/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4664 - accuracy: 0.7692
# Epoch 168: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4683 - accuracy: 0.7669 - val_loss: 0.4417 - val_accuracy: 0.7775
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4603 - accuracy: 0.7692
# Epoch 169: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4601 - accuracy: 0.7700 - val_loss: 0.4486 - val_accuracy: 0.7775
# Epoch 170/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4576 - accuracy: 0.7703
# Epoch 170: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4576 - accuracy: 0.7703 - val_loss: 0.4375 - val_accuracy: 0.7738
# Epoch 171/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4580 - accuracy: 0.7682
# Epoch 171: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4567 - accuracy: 0.7681 - val_loss: 0.4374 - val_accuracy: 0.7738
# Epoch 172/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4504 - accuracy: 0.7699
# Epoch 172: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4519 - accuracy: 0.7681 - val_loss: 0.4489 - val_accuracy: 0.7725
# Epoch 173/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4573 - accuracy: 0.7691
# Epoch 173: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4573 - accuracy: 0.7691 - val_loss: 0.4351 - val_accuracy: 0.7750
# Epoch 174/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4713 - accuracy: 0.7656
# Epoch 174: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4713 - accuracy: 0.7656 - val_loss: 0.4482 - val_accuracy: 0.7763
# Epoch 175/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4551 - accuracy: 0.7688
# Epoch 175: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4551 - accuracy: 0.7688 - val_loss: 0.4493 - val_accuracy: 0.7775
# Epoch 176/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.7669
# Epoch 176: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4652 - accuracy: 0.7669 - val_loss: 0.4396 - val_accuracy: 0.7775
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4572 - accuracy: 0.7673
# Epoch 177: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4567 - accuracy: 0.7684 - val_loss: 0.4447 - val_accuracy: 0.7763
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4660 - accuracy: 0.7676
# Epoch 178: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4670 - accuracy: 0.7675 - val_loss: 0.4362 - val_accuracy: 0.7775
# Epoch 179/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.7663
# Epoch 179: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4656 - accuracy: 0.7663 - val_loss: 0.4377 - val_accuracy: 0.7775
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4504 - accuracy: 0.7692
# Epoch 180: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4488 - accuracy: 0.7709 - val_loss: 0.4396 - val_accuracy: 0.7763
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4518 - accuracy: 0.7666
# Epoch 181: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4518 - accuracy: 0.7666 - val_loss: 0.4369 - val_accuracy: 0.7725
# Epoch 182/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.7688
# Epoch 182: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4522 - accuracy: 0.7688 - val_loss: 0.4282 - val_accuracy: 0.7763
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4439 - accuracy: 0.7699
# Epoch 183: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4417 - accuracy: 0.7706 - val_loss: 0.4246 - val_accuracy: 0.7775
# Epoch 184/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4418 - accuracy: 0.7672
# Epoch 184: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4418 - accuracy: 0.7672 - val_loss: 0.5015 - val_accuracy: 0.7550
# Epoch 185/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.7531
# Epoch 185: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4998 - accuracy: 0.7531 - val_loss: 0.4970 - val_accuracy: 0.7738
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5289 - accuracy: 0.7656
# Epoch 186: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5310 - accuracy: 0.7628 - val_loss: 0.5064 - val_accuracy: 0.7738
# Epoch 187/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.7725
# Epoch 187: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5193 - accuracy: 0.7725 - val_loss: 0.4961 - val_accuracy: 0.7775
# Epoch 188/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4981 - accuracy: 0.7719
# Epoch 188: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4981 - accuracy: 0.7719 - val_loss: 0.4613 - val_accuracy: 0.7775
# Epoch 189/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.7700
# Epoch 189: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4765 - accuracy: 0.7700 - val_loss: 0.4576 - val_accuracy: 0.7725
# Epoch 190/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4692 - accuracy: 0.7675
# Epoch 190: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4692 - accuracy: 0.7675 - val_loss: 0.4418 - val_accuracy: 0.7763
# Epoch 191/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.7691
# Epoch 191: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4515 - accuracy: 0.7691 - val_loss: 0.4369 - val_accuracy: 0.7725
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4671 - accuracy: 0.7627
# Epoch 192: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4693 - accuracy: 0.7613 - val_loss: 0.4551 - val_accuracy: 0.7763
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.7675
# Epoch 193: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4759 - accuracy: 0.7675 - val_loss: 0.4496 - val_accuracy: 0.7763
# Epoch 194/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.7625
# Epoch 194: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4777 - accuracy: 0.7625 - val_loss: 0.4653 - val_accuracy: 0.7763
# Epoch 195/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4745 - accuracy: 0.7703
# Epoch 195: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4745 - accuracy: 0.7703 - val_loss: 0.4443 - val_accuracy: 0.7775
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4654 - accuracy: 0.7669
# Epoch 196: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4635 - accuracy: 0.7678 - val_loss: 0.4416 - val_accuracy: 0.7763
# Epoch 197/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4553 - accuracy: 0.7700
# Epoch 197: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4553 - accuracy: 0.7700 - val_loss: 0.4377 - val_accuracy: 0.7763
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.7697
# Epoch 198: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4519 - accuracy: 0.7697 - val_loss: 0.4398 - val_accuracy: 0.7738
# Epoch 199/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.7678
# Epoch 199: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4544 - accuracy: 0.7678 - val_loss: 0.4551 - val_accuracy: 0.7650
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4628 - accuracy: 0.7585
# Epoch 200: val_accuracy did not improve from 0.89625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4635 - accuracy: 0.7594 - val_loss: 0.4388 - val_accuracy: 0.7725

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 815,681
# Trainable params: 815,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.35
# Accuracy: 89.63%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("\nAccuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	89.62%
# Sensitivity:	98.44%
# Specificity:	81.45%
# Precision:	83.11%
# F1-score:	90.13%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.93

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
