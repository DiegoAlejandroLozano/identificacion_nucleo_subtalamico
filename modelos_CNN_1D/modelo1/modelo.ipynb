# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import os

import tensorflow           as tf
import pandas               as pd
import seaborn              as sns
import matplotlib.pyplot    as plt

from keras.models       import Sequential, load_model
from keras.layers       import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers   import Adam
from keras.regularizers import l2
from keras.callbacks    import ModelCheckpoint

from sklearn.preprocessing      import StandardScaler
from sklearn.model_selection    import train_test_split
from sklearn.metrics            import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler         = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath        = "modelo_generado//modelo.keras",
    monitor         = "val_accuracy",
    save_best_only  = True,
    mode            = "max",
    verbose         = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs          = 200, 
    batch_size      = 512, 
    callbacks       = [checkpoint_callback],
    validation_data = (X_val_reshaped, y_val)
)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 7.3960 - accuracy: 0.5116
# Epoch 1: val_accuracy improved from -inf to 0.51875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 6s 120ms/step - loss: 7.3960 - accuracy: 0.5116 - val_loss: 3.6412 - val_accuracy: 0.5188
# Epoch 2/200
# 7/7 [==============================] - ETA: 0s - loss: 3.6875 - accuracy: 0.5328
# Epoch 2: val_accuracy did not improve from 0.51875
# 7/7 [==============================] - 0s 53ms/step - loss: 3.6875 - accuracy: 0.5328 - val_loss: 3.6109 - val_accuracy: 0.5038
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: 3.4132 - accuracy: 0.6363
# Epoch 3: val_accuracy improved from 0.51875 to 0.63500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 3.4132 - accuracy: 0.6363 - val_loss: 3.0407 - val_accuracy: 0.6350
# Epoch 4/200
# 7/7 [==============================] - ETA: 0s - loss: 2.7947 - accuracy: 0.6806
# Epoch 4: val_accuracy improved from 0.63500 to 0.74375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 2.7947 - accuracy: 0.6806 - val_loss: 2.4004 - val_accuracy: 0.7437
# Epoch 5/200
# 7/7 [==============================] - ETA: 0s - loss: 2.1728 - accuracy: 0.7209
# Epoch 5: val_accuracy did not improve from 0.74375
# 7/7 [==============================] - 0s 51ms/step - loss: 2.1728 - accuracy: 0.7209 - val_loss: 1.8789 - val_accuracy: 0.7437
# Epoch 6/200
# 7/7 [==============================] - ETA: 0s - loss: 1.7116 - accuracy: 0.7434
# Epoch 6: val_accuracy did not improve from 0.74375
# 7/7 [==============================] - 0s 51ms/step - loss: 1.7116 - accuracy: 0.7434 - val_loss: 1.4697 - val_accuracy: 0.7250
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.3643 - accuracy: 0.7585
# Epoch 7: val_accuracy did not improve from 0.74375
# 7/7 [==============================] - 0s 54ms/step - loss: 1.3613 - accuracy: 0.7569 - val_loss: 1.1942 - val_accuracy: 0.7387
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: 1.1277 - accuracy: 0.7638
# Epoch 8: val_accuracy did not improve from 0.74375
# 7/7 [==============================] - 0s 53ms/step - loss: 1.1277 - accuracy: 0.7638 - val_loss: 1.0111 - val_accuracy: 0.7212
# Epoch 9/200
# 7/7 [==============================] - ETA: 0s - loss: 1.0083 - accuracy: 0.7594
# Epoch 9: val_accuracy did not improve from 0.74375
# 7/7 [==============================] - 0s 51ms/step - loss: 1.0083 - accuracy: 0.7594 - val_loss: 0.9569 - val_accuracy: 0.7088
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: 0.9236 - accuracy: 0.7713
# Epoch 10: val_accuracy improved from 0.74375 to 0.74875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.9236 - accuracy: 0.7713 - val_loss: 0.8881 - val_accuracy: 0.7487
# Epoch 11/200
# 7/7 [==============================] - ETA: 0s - loss: 0.8499 - accuracy: 0.7703
# Epoch 11: val_accuracy improved from 0.74875 to 0.75000, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.8499 - accuracy: 0.7703 - val_loss: 0.8086 - val_accuracy: 0.7500
# Epoch 12/200
# 7/7 [==============================] - ETA: 0s - loss: 0.8299 - accuracy: 0.7594
# Epoch 12: val_accuracy did not improve from 0.75000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.8299 - accuracy: 0.7594 - val_loss: 0.7851 - val_accuracy: 0.7500
# Epoch 13/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7643 - accuracy: 0.7753
# Epoch 13: val_accuracy did not improve from 0.75000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.7643 - accuracy: 0.7753 - val_loss: 0.7307 - val_accuracy: 0.7300
# Epoch 14/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7289 - accuracy: 0.7734
# Epoch 14: val_accuracy improved from 0.75000 to 0.77375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.7304 - accuracy: 0.7709 - val_loss: 0.7023 - val_accuracy: 0.7738
# Epoch 15/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.7909
# Epoch 15: val_accuracy did not improve from 0.77375
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6922 - accuracy: 0.7909 - val_loss: 0.6807 - val_accuracy: 0.7588
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.7897
# Epoch 16: val_accuracy improved from 0.77375 to 0.79875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.6699 - accuracy: 0.7897 - val_loss: 0.6679 - val_accuracy: 0.7987
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.7912
# Epoch 17: val_accuracy did not improve from 0.79875
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6659 - accuracy: 0.7912 - val_loss: 0.6517 - val_accuracy: 0.7700
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.8019
# Epoch 18: val_accuracy did not improve from 0.79875
# 7/7 [==============================] - 0s 51ms/step - loss: 0.6389 - accuracy: 0.8019 - val_loss: 0.6669 - val_accuracy: 0.7525
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7286 - accuracy: 0.7478
# Epoch 19: val_accuracy did not improve from 0.79875
# 7/7 [==============================] - 0s 50ms/step - loss: 0.7286 - accuracy: 0.7478 - val_loss: 0.7617 - val_accuracy: 0.7350
# Epoch 20/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.7697
# Epoch 20: val_accuracy did not improve from 0.79875
# 7/7 [==============================] - 0s 51ms/step - loss: 0.6868 - accuracy: 0.7697 - val_loss: 0.6404 - val_accuracy: 0.7550
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6429 - accuracy: 0.7881
# Epoch 21: val_accuracy improved from 0.79875 to 0.80750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.6429 - accuracy: 0.7881 - val_loss: 0.6077 - val_accuracy: 0.8075
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.8041
# Epoch 22: val_accuracy improved from 0.80750 to 0.81375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.6055 - accuracy: 0.8041 - val_loss: 0.5714 - val_accuracy: 0.8138
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5797 - accuracy: 0.8019
# Epoch 23: val_accuracy did not improve from 0.81375
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5797 - accuracy: 0.8019 - val_loss: 0.5533 - val_accuracy: 0.7900
# Epoch 24/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5571 - accuracy: 0.8275
# Epoch 24: val_accuracy improved from 0.81375 to 0.82875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5571 - accuracy: 0.8275 - val_loss: 0.5476 - val_accuracy: 0.8288
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.8209
# Epoch 25: val_accuracy did not improve from 0.82875
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5447 - accuracy: 0.8209 - val_loss: 0.5766 - val_accuracy: 0.7825
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.8250
# Epoch 26: val_accuracy improved from 0.82875 to 0.85750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5475 - accuracy: 0.8250 - val_loss: 0.5095 - val_accuracy: 0.8575
# Epoch 27/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8441
# Epoch 27: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 51ms/step - loss: 0.5157 - accuracy: 0.8441 - val_loss: 0.5049 - val_accuracy: 0.8000
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.8319
# Epoch 28: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5189 - accuracy: 0.8319 - val_loss: 0.5211 - val_accuracy: 0.8363
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5115 - accuracy: 0.8382
# Epoch 29: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5093 - accuracy: 0.8409 - val_loss: 0.4909 - val_accuracy: 0.8413
# Epoch 30/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.8438
# Epoch 30: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4936 - accuracy: 0.8438 - val_loss: 0.5292 - val_accuracy: 0.7775
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.8219
# Epoch 31: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5369 - accuracy: 0.8219 - val_loss: 0.5388 - val_accuracy: 0.7975
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4944 - accuracy: 0.8384
# Epoch 32: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4944 - accuracy: 0.8384 - val_loss: 0.4939 - val_accuracy: 0.8413
# Epoch 33/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.8447
# Epoch 33: val_accuracy improved from 0.85750 to 0.85875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4901 - accuracy: 0.8447 - val_loss: 0.4720 - val_accuracy: 0.8587
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.8528
# Epoch 34: val_accuracy did not improve from 0.85875
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4851 - accuracy: 0.8528 - val_loss: 0.5066 - val_accuracy: 0.8150
# Epoch 35/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5205 - accuracy: 0.8363
# Epoch 35: val_accuracy did not improve from 0.85875
# 7/7 [==============================] - 0s 50ms/step - loss: 0.5205 - accuracy: 0.8363 - val_loss: 0.4873 - val_accuracy: 0.8562
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.8484
# Epoch 36: val_accuracy improved from 0.85875 to 0.86000, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4733 - accuracy: 0.8484 - val_loss: 0.4525 - val_accuracy: 0.8600
# Epoch 37/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4442 - accuracy: 0.8609
# Epoch 37: val_accuracy improved from 0.86000 to 0.86750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4442 - accuracy: 0.8609 - val_loss: 0.4380 - val_accuracy: 0.8675
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8694
# Epoch 38: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4378 - accuracy: 0.8694 - val_loss: 0.4484 - val_accuracy: 0.8600
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8662
# Epoch 39: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4508 - accuracy: 0.8662 - val_loss: 0.5180 - val_accuracy: 0.8163
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.8569
# Epoch 40: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4721 - accuracy: 0.8569 - val_loss: 0.4636 - val_accuracy: 0.8313
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.8578
# Epoch 41: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4673 - accuracy: 0.8578 - val_loss: 0.4912 - val_accuracy: 0.8350
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4505 - accuracy: 0.8669
# Epoch 42: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4511 - accuracy: 0.8666 - val_loss: 0.4515 - val_accuracy: 0.8612
# Epoch 43/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5030 - accuracy: 0.8347
# Epoch 43: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5030 - accuracy: 0.8347 - val_loss: 0.6291 - val_accuracy: 0.7738
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.8322
# Epoch 44: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5115 - accuracy: 0.8322 - val_loss: 0.5075 - val_accuracy: 0.8363
# Epoch 45/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.8556
# Epoch 45: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4633 - accuracy: 0.8556 - val_loss: 0.5152 - val_accuracy: 0.7975
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8363
# Epoch 46: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4894 - accuracy: 0.8363 - val_loss: 0.4513 - val_accuracy: 0.8562
# Epoch 47/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4335 - accuracy: 0.8703
# Epoch 47: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4335 - accuracy: 0.8703 - val_loss: 0.4266 - val_accuracy: 0.8550
# Epoch 48/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8659
# Epoch 48: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4391 - accuracy: 0.8659 - val_loss: 0.4387 - val_accuracy: 0.8550
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4369 - accuracy: 0.8698
# Epoch 49: val_accuracy improved from 0.86750 to 0.87250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4351 - accuracy: 0.8694 - val_loss: 0.4409 - val_accuracy: 0.8725
# Epoch 50/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.8703
# Epoch 50: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4299 - accuracy: 0.8703 - val_loss: 0.4529 - val_accuracy: 0.8413
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4301 - accuracy: 0.8659
# Epoch 51: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4301 - accuracy: 0.8659 - val_loss: 0.4383 - val_accuracy: 0.8662
# Epoch 52/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4276 - accuracy: 0.8672
# Epoch 52: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4276 - accuracy: 0.8672 - val_loss: 0.4066 - val_accuracy: 0.8662
# Epoch 53/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4111 - accuracy: 0.8778
# Epoch 53: val_accuracy improved from 0.87250 to 0.87375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 70ms/step - loss: 0.4111 - accuracy: 0.8778 - val_loss: 0.4054 - val_accuracy: 0.8737
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4080 - accuracy: 0.8822
# Epoch 54: val_accuracy improved from 0.87375 to 0.87500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4080 - accuracy: 0.8822 - val_loss: 0.4151 - val_accuracy: 0.8750
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4077 - accuracy: 0.8822
# Epoch 55: val_accuracy did not improve from 0.87500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4080 - accuracy: 0.8819 - val_loss: 0.6026 - val_accuracy: 0.7613
# Epoch 56/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.8272
# Epoch 56: val_accuracy did not improve from 0.87500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5127 - accuracy: 0.8272 - val_loss: 0.4727 - val_accuracy: 0.8363
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4560 - accuracy: 0.8603
# Epoch 57: val_accuracy did not improve from 0.87500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4560 - accuracy: 0.8603 - val_loss: 0.4569 - val_accuracy: 0.8450
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4249 - accuracy: 0.8724
# Epoch 58: val_accuracy improved from 0.87500 to 0.87875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4238 - accuracy: 0.8725 - val_loss: 0.4087 - val_accuracy: 0.8788
# Epoch 59/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4086 - accuracy: 0.8778
# Epoch 59: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4086 - accuracy: 0.8778 - val_loss: 0.4052 - val_accuracy: 0.8788
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4041 - accuracy: 0.8747
# Epoch 60: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4041 - accuracy: 0.8747 - val_loss: 0.4259 - val_accuracy: 0.8487
# Epoch 61/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8894
# Epoch 61: val_accuracy improved from 0.87875 to 0.88000, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3831 - accuracy: 0.8894 - val_loss: 0.3866 - val_accuracy: 0.8800
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.8716
# Epoch 62: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4073 - accuracy: 0.8716 - val_loss: 0.4615 - val_accuracy: 0.8562
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4368 - accuracy: 0.8594
# Epoch 63: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4363 - accuracy: 0.8600 - val_loss: 0.4011 - val_accuracy: 0.8650
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4384 - accuracy: 0.8606
# Epoch 64: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4384 - accuracy: 0.8606 - val_loss: 0.4629 - val_accuracy: 0.8338
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4376 - accuracy: 0.8636
# Epoch 65: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4355 - accuracy: 0.8662 - val_loss: 0.4957 - val_accuracy: 0.8263
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.8691
# Epoch 66: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4379 - accuracy: 0.8691 - val_loss: 0.5042 - val_accuracy: 0.8263
# Epoch 67/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4442 - accuracy: 0.8597
# Epoch 67: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4442 - accuracy: 0.8597 - val_loss: 0.4206 - val_accuracy: 0.8662
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8847
# Epoch 68: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3968 - accuracy: 0.8847 - val_loss: 0.4065 - val_accuracy: 0.8600
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3860 - accuracy: 0.8831
# Epoch 69: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3891 - accuracy: 0.8816 - val_loss: 0.3943 - val_accuracy: 0.8737
# Epoch 70/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3698 - accuracy: 0.8959
# Epoch 70: val_accuracy did not improve from 0.88000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3698 - accuracy: 0.8959 - val_loss: 0.3790 - val_accuracy: 0.8788
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3690 - accuracy: 0.8878
# Epoch 71: val_accuracy improved from 0.88000 to 0.88500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3690 - accuracy: 0.8878 - val_loss: 0.3825 - val_accuracy: 0.8850
# Epoch 72/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3861 - accuracy: 0.8903
# Epoch 72: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3861 - accuracy: 0.8903 - val_loss: 0.4344 - val_accuracy: 0.8512
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8694
# Epoch 73: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4138 - accuracy: 0.8694 - val_loss: 0.4047 - val_accuracy: 0.8763
# Epoch 74/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8884
# Epoch 74: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4028 - accuracy: 0.8884 - val_loss: 0.4049 - val_accuracy: 0.8750
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3946 - accuracy: 0.8822
# Epoch 75: val_accuracy improved from 0.88500 to 0.88625, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3934 - accuracy: 0.8831 - val_loss: 0.3906 - val_accuracy: 0.8863
# Epoch 76/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3785 - accuracy: 0.8878
# Epoch 76: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3785 - accuracy: 0.8878 - val_loss: 0.3767 - val_accuracy: 0.8850
# Epoch 77/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3724 - accuracy: 0.8909
# Epoch 77: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3724 - accuracy: 0.8909 - val_loss: 0.3918 - val_accuracy: 0.8788
# Epoch 78/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8863
# Epoch 78: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3748 - accuracy: 0.8863 - val_loss: 0.3888 - val_accuracy: 0.8675
# Epoch 79/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8781
# Epoch 79: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4045 - accuracy: 0.8781 - val_loss: 0.4169 - val_accuracy: 0.8712
# Epoch 80/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8744
# Epoch 80: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4105 - accuracy: 0.8744 - val_loss: 0.4865 - val_accuracy: 0.8562
# Epoch 81/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.8447
# Epoch 81: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4866 - accuracy: 0.8447 - val_loss: 0.4621 - val_accuracy: 0.8525
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4447 - accuracy: 0.8656
# Epoch 82: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4433 - accuracy: 0.8669 - val_loss: 0.4164 - val_accuracy: 0.8750
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4221 - accuracy: 0.8779
# Epoch 83: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4186 - accuracy: 0.8781 - val_loss: 0.5025 - val_accuracy: 0.8238
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4070 - accuracy: 0.8776
# Epoch 84: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4052 - accuracy: 0.8788 - val_loss: 0.4059 - val_accuracy: 0.8625
# Epoch 85/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.8847
# Epoch 85: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3823 - accuracy: 0.8847 - val_loss: 0.4118 - val_accuracy: 0.8537
# Epoch 86/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8888
# Epoch 86: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3833 - accuracy: 0.8888 - val_loss: 0.3854 - val_accuracy: 0.8700
# Epoch 87/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.8938
# Epoch 87: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3621 - accuracy: 0.8938 - val_loss: 0.4147 - val_accuracy: 0.8700
# Epoch 88/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4449 - accuracy: 0.8587
# Epoch 88: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4449 - accuracy: 0.8587 - val_loss: 0.4008 - val_accuracy: 0.8675
# Epoch 89/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8716
# Epoch 89: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4148 - accuracy: 0.8716 - val_loss: 0.4708 - val_accuracy: 0.8413
# Epoch 90/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4135 - accuracy: 0.8719
# Epoch 90: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 51ms/step - loss: 0.4135 - accuracy: 0.8719 - val_loss: 0.4217 - val_accuracy: 0.8650
# Epoch 91/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8944
# Epoch 91: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3806 - accuracy: 0.8944 - val_loss: 0.4208 - val_accuracy: 0.8700
# Epoch 92/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.8856
# Epoch 92: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3916 - accuracy: 0.8856 - val_loss: 0.4214 - val_accuracy: 0.8575
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3782 - accuracy: 0.8835
# Epoch 93: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3740 - accuracy: 0.8850 - val_loss: 0.4010 - val_accuracy: 0.8763
# Epoch 94/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.8906
# Epoch 94: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3676 - accuracy: 0.8906 - val_loss: 0.3793 - val_accuracy: 0.8788
# Epoch 95/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3523 - accuracy: 0.9006
# Epoch 95: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3523 - accuracy: 0.9006 - val_loss: 0.3756 - val_accuracy: 0.8863
# Epoch 96/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.9003
# Epoch 96: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3491 - accuracy: 0.9003 - val_loss: 0.3692 - val_accuracy: 0.8863
# Epoch 97/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8972
# Epoch 97: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3547 - accuracy: 0.8972 - val_loss: 0.4258 - val_accuracy: 0.8575
# Epoch 98/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8878
# Epoch 98: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3760 - accuracy: 0.8878 - val_loss: 0.3899 - val_accuracy: 0.8763
# Epoch 99/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.8963
# Epoch 99: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3609 - accuracy: 0.8963 - val_loss: 0.4204 - val_accuracy: 0.8750
# Epoch 100/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4289 - accuracy: 0.8626
# Epoch 100: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4299 - accuracy: 0.8628 - val_loss: 0.3973 - val_accuracy: 0.8763
# Epoch 101/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4006 - accuracy: 0.8866
# Epoch 101: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4006 - accuracy: 0.8866 - val_loss: 0.4280 - val_accuracy: 0.8562
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3799 - accuracy: 0.8926
# Epoch 102: val_accuracy improved from 0.88625 to 0.88750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3813 - accuracy: 0.8909 - val_loss: 0.3846 - val_accuracy: 0.8875
# Epoch 103/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.8972
# Epoch 103: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3737 - accuracy: 0.8972 - val_loss: 0.3899 - val_accuracy: 0.8813
# Epoch 104/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3736 - accuracy: 0.8941
# Epoch 104: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3736 - accuracy: 0.8941 - val_loss: 0.4001 - val_accuracy: 0.8650
# Epoch 105/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8953
# Epoch 105: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3684 - accuracy: 0.8953 - val_loss: 0.4200 - val_accuracy: 0.8700
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3803 - accuracy: 0.8893
# Epoch 106: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3817 - accuracy: 0.8884 - val_loss: 0.4365 - val_accuracy: 0.8250
# Epoch 107/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8800
# Epoch 107: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3854 - accuracy: 0.8800 - val_loss: 0.4360 - val_accuracy: 0.8550
# Epoch 108/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8897
# Epoch 108: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3804 - accuracy: 0.8897 - val_loss: 0.3931 - val_accuracy: 0.8813
# Epoch 109/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3646 - accuracy: 0.8994
# Epoch 109: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3646 - accuracy: 0.8994 - val_loss: 0.3920 - val_accuracy: 0.8850
# Epoch 110/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3783 - accuracy: 0.8925
# Epoch 110: val_accuracy improved from 0.88750 to 0.89500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3783 - accuracy: 0.8925 - val_loss: 0.3649 - val_accuracy: 0.8950
# Epoch 111/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3524 - accuracy: 0.9003
# Epoch 111: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3524 - accuracy: 0.9003 - val_loss: 0.3818 - val_accuracy: 0.8788
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3588 - accuracy: 0.8962
# Epoch 112: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3555 - accuracy: 0.8978 - val_loss: 0.3732 - val_accuracy: 0.8850
# Epoch 113/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.9087
# Epoch 113: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3404 - accuracy: 0.9087 - val_loss: 0.4693 - val_accuracy: 0.8200
# Epoch 114/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3764 - accuracy: 0.8828
# Epoch 114: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3779 - accuracy: 0.8831 - val_loss: 0.4144 - val_accuracy: 0.8500
# Epoch 115/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.8791
# Epoch 115: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4100 - accuracy: 0.8791 - val_loss: 0.4288 - val_accuracy: 0.8662
# Epoch 116/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3967 - accuracy: 0.8847
# Epoch 116: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3967 - accuracy: 0.8847 - val_loss: 0.4876 - val_accuracy: 0.8325
# Epoch 117/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4011 - accuracy: 0.8841
# Epoch 117: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4011 - accuracy: 0.8841 - val_loss: 0.3823 - val_accuracy: 0.8863
# Epoch 118/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.8978
# Epoch 118: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3665 - accuracy: 0.8978 - val_loss: 0.4368 - val_accuracy: 0.8612
# Epoch 119/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4021 - accuracy: 0.8750
# Epoch 119: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4021 - accuracy: 0.8750 - val_loss: 0.3917 - val_accuracy: 0.8800
# Epoch 120/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8909
# Epoch 120: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3856 - accuracy: 0.8909 - val_loss: 0.3904 - val_accuracy: 0.8788
# Epoch 121/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8950
# Epoch 121: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3678 - accuracy: 0.8950 - val_loss: 0.3795 - val_accuracy: 0.8850
# Epoch 122/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.8950
# Epoch 122: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3634 - accuracy: 0.8950 - val_loss: 0.3697 - val_accuracy: 0.8888
# Epoch 123/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8966
# Epoch 123: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3553 - accuracy: 0.8966 - val_loss: 0.3789 - val_accuracy: 0.8763
# Epoch 124/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8919
# Epoch 124: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3588 - accuracy: 0.8919 - val_loss: 0.3861 - val_accuracy: 0.8725
# Epoch 125/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3997 - accuracy: 0.8756
# Epoch 125: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3997 - accuracy: 0.8756 - val_loss: 0.4460 - val_accuracy: 0.8537
# Epoch 126/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4295 - accuracy: 0.8669
# Epoch 126: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4295 - accuracy: 0.8669 - val_loss: 0.4497 - val_accuracy: 0.8487
# Epoch 127/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4152 - accuracy: 0.8825
# Epoch 127: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4152 - accuracy: 0.8825 - val_loss: 0.4217 - val_accuracy: 0.8662
# Epoch 128/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8891
# Epoch 128: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3880 - accuracy: 0.8891 - val_loss: 0.3882 - val_accuracy: 0.8813
# Epoch 129/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.8963
# Epoch 129: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3618 - accuracy: 0.8963 - val_loss: 0.3706 - val_accuracy: 0.8888
# Epoch 130/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.9013
# Epoch 130: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3508 - accuracy: 0.9013 - val_loss: 0.3832 - val_accuracy: 0.8687
# Epoch 131/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3580 - accuracy: 0.8981
# Epoch 131: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3580 - accuracy: 0.8981 - val_loss: 0.3659 - val_accuracy: 0.8825
# Epoch 132/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.8969
# Epoch 132: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3479 - accuracy: 0.8969 - val_loss: 0.4156 - val_accuracy: 0.8500
# Epoch 133/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3683 - accuracy: 0.8891
# Epoch 133: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3683 - accuracy: 0.8891 - val_loss: 0.3916 - val_accuracy: 0.8725
# Epoch 134/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3626 - accuracy: 0.8966
# Epoch 134: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3626 - accuracy: 0.8966 - val_loss: 0.3774 - val_accuracy: 0.8775
# Epoch 135/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.8975
# Epoch 135: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3563 - accuracy: 0.8975 - val_loss: 0.3951 - val_accuracy: 0.8813
# Epoch 136/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.8891
# Epoch 136: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3666 - accuracy: 0.8891 - val_loss: 0.3695 - val_accuracy: 0.8825
# Epoch 137/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3604 - accuracy: 0.8906
# Epoch 137: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3604 - accuracy: 0.8906 - val_loss: 0.3639 - val_accuracy: 0.8775
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3476 - accuracy: 0.8971
# Epoch 138: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3511 - accuracy: 0.8953 - val_loss: 0.3542 - val_accuracy: 0.8838
# Epoch 139/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8813
# Epoch 139: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3864 - accuracy: 0.8813 - val_loss: 0.3909 - val_accuracy: 0.8813
# Epoch 140/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8900
# Epoch 140: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3752 - accuracy: 0.8900 - val_loss: 0.3778 - val_accuracy: 0.8712
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3409 - accuracy: 0.9033
# Epoch 141: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3441 - accuracy: 0.9022 - val_loss: 0.4531 - val_accuracy: 0.8388
# Epoch 142/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3920 - accuracy: 0.8831
# Epoch 142: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3920 - accuracy: 0.8831 - val_loss: 0.4413 - val_accuracy: 0.8600
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4073 - accuracy: 0.8737
# Epoch 143: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4075 - accuracy: 0.8731 - val_loss: 0.4265 - val_accuracy: 0.8612
# Epoch 144/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.8553
# Epoch 144: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4383 - accuracy: 0.8553 - val_loss: 0.3894 - val_accuracy: 0.8763
# Epoch 145/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8744
# Epoch 145: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4105 - accuracy: 0.8744 - val_loss: 0.4239 - val_accuracy: 0.8750
# Epoch 146/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4051 - accuracy: 0.8838
# Epoch 146: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4025 - accuracy: 0.8850 - val_loss: 0.4124 - val_accuracy: 0.8712
# Epoch 147/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.8959
# Epoch 147: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3743 - accuracy: 0.8959 - val_loss: 0.3844 - val_accuracy: 0.8788
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3599 - accuracy: 0.8965
# Epoch 148: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3586 - accuracy: 0.8972 - val_loss: 0.3792 - val_accuracy: 0.8788
# Epoch 149/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8969
# Epoch 149: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3468 - accuracy: 0.8969 - val_loss: 0.3544 - val_accuracy: 0.8825
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3499 - accuracy: 0.8949
# Epoch 150: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3520 - accuracy: 0.8941 - val_loss: 0.3800 - val_accuracy: 0.8737
# Epoch 151/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8994
# Epoch 151: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3572 - accuracy: 0.8994 - val_loss: 0.4092 - val_accuracy: 0.8763
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3664 - accuracy: 0.8971
# Epoch 152: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3640 - accuracy: 0.8984 - val_loss: 0.3896 - val_accuracy: 0.8700
# Epoch 153/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3634 - accuracy: 0.8942
# Epoch 153: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3635 - accuracy: 0.8934 - val_loss: 0.3699 - val_accuracy: 0.8750
# Epoch 154/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.9047
# Epoch 154: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3438 - accuracy: 0.9047 - val_loss: 0.3615 - val_accuracy: 0.8913
# Epoch 155/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8944
# Epoch 155: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3537 - accuracy: 0.8944 - val_loss: 0.3993 - val_accuracy: 0.8825
# Epoch 156/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3821 - accuracy: 0.8883
# Epoch 156: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3805 - accuracy: 0.8894 - val_loss: 0.3918 - val_accuracy: 0.8788
# Epoch 157/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8944
# Epoch 157: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3687 - accuracy: 0.8944 - val_loss: 0.3650 - val_accuracy: 0.8838
# Epoch 158/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3743 - accuracy: 0.8981
# Epoch 158: val_accuracy improved from 0.89500 to 0.90000, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3726 - accuracy: 0.8988 - val_loss: 0.3829 - val_accuracy: 0.9000
# Epoch 159/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3627 - accuracy: 0.8965
# Epoch 159: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3618 - accuracy: 0.8966 - val_loss: 0.4124 - val_accuracy: 0.8788
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3769 - accuracy: 0.8880
# Epoch 160: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3763 - accuracy: 0.8878 - val_loss: 0.3604 - val_accuracy: 0.8800
# Epoch 161/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.9053
# Epoch 161: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3314 - accuracy: 0.9053 - val_loss: 0.3451 - val_accuracy: 0.8950
# Epoch 162/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.9034
# Epoch 162: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3420 - accuracy: 0.9034 - val_loss: 0.3578 - val_accuracy: 0.8938
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3365 - accuracy: 0.9108
# Epoch 163: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3372 - accuracy: 0.9100 - val_loss: 0.4175 - val_accuracy: 0.8662
# Epoch 164/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3818 - accuracy: 0.8916
# Epoch 164: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3818 - accuracy: 0.8916 - val_loss: 0.3856 - val_accuracy: 0.8863
# Epoch 165/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.9000
# Epoch 165: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3588 - accuracy: 0.9000 - val_loss: 0.3754 - val_accuracy: 0.8775
# Epoch 166/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3558 - accuracy: 0.8922
# Epoch 166: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3558 - accuracy: 0.8922 - val_loss: 0.3639 - val_accuracy: 0.8825
# Epoch 167/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3400 - accuracy: 0.8988
# Epoch 167: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3400 - accuracy: 0.8988 - val_loss: 0.3569 - val_accuracy: 0.8825
# Epoch 168/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8953
# Epoch 168: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3421 - accuracy: 0.8953 - val_loss: 0.3525 - val_accuracy: 0.8850
# Epoch 169/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.8944
# Epoch 169: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3420 - accuracy: 0.8944 - val_loss: 0.3605 - val_accuracy: 0.8813
# Epoch 170/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.8925
# Epoch 170: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3405 - accuracy: 0.8925 - val_loss: 0.3440 - val_accuracy: 0.8838
# Epoch 171/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.9087
# Epoch 171: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3054 - accuracy: 0.9087 - val_loss: 0.3611 - val_accuracy: 0.8725
# Epoch 172/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.9053
# Epoch 172: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3153 - accuracy: 0.9053 - val_loss: 0.3778 - val_accuracy: 0.8637
# Epoch 173/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.9038
# Epoch 173: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3295 - accuracy: 0.9038 - val_loss: 0.8639 - val_accuracy: 0.7237
# Epoch 174/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6159 - accuracy: 0.7744
# Epoch 174: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6159 - accuracy: 0.7744 - val_loss: 0.4829 - val_accuracy: 0.8375
# Epoch 175/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.8297
# Epoch 175: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5144 - accuracy: 0.8297 - val_loss: 0.4920 - val_accuracy: 0.8350
# Epoch 176/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4703 - accuracy: 0.8478
# Epoch 176: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4703 - accuracy: 0.8478 - val_loss: 0.4376 - val_accuracy: 0.8550
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4308 - accuracy: 0.8584
# Epoch 177: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4298 - accuracy: 0.8587 - val_loss: 0.4210 - val_accuracy: 0.8550
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4185 - accuracy: 0.8568
# Epoch 178: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4169 - accuracy: 0.8575 - val_loss: 0.3878 - val_accuracy: 0.8700
# Epoch 179/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3716 - accuracy: 0.8788
# Epoch 179: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3716 - accuracy: 0.8788 - val_loss: 0.3795 - val_accuracy: 0.8712
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3570 - accuracy: 0.8896
# Epoch 180: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3567 - accuracy: 0.8897 - val_loss: 0.3731 - val_accuracy: 0.8775
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3438 - accuracy: 0.8988
# Epoch 181: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3428 - accuracy: 0.8988 - val_loss: 0.3681 - val_accuracy: 0.8813
# Epoch 182/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8959
# Epoch 182: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3392 - accuracy: 0.8959 - val_loss: 0.3662 - val_accuracy: 0.8775
# Epoch 183/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.8975
# Epoch 183: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3330 - accuracy: 0.8975 - val_loss: 0.3548 - val_accuracy: 0.8825
# Epoch 184/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3213 - accuracy: 0.9009
# Epoch 184: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3213 - accuracy: 0.9009 - val_loss: 0.3490 - val_accuracy: 0.8838
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3126 - accuracy: 0.9017
# Epoch 185: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3110 - accuracy: 0.9028 - val_loss: 0.3499 - val_accuracy: 0.8788
# Epoch 186/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.9006
# Epoch 186: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3181 - accuracy: 0.9006 - val_loss: 0.4234 - val_accuracy: 0.8512
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3447 - accuracy: 0.8913
# Epoch 187: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3422 - accuracy: 0.8928 - val_loss: 0.3805 - val_accuracy: 0.8637
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3540 - accuracy: 0.8815
# Epoch 188: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3541 - accuracy: 0.8819 - val_loss: 0.3725 - val_accuracy: 0.8763
# Epoch 189/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8844
# Epoch 189: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3732 - accuracy: 0.8844 - val_loss: 0.3836 - val_accuracy: 0.8687
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3595 - accuracy: 0.8874
# Epoch 190: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3574 - accuracy: 0.8884 - val_loss: 0.3696 - val_accuracy: 0.8800
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3389 - accuracy: 0.9033
# Epoch 191: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3399 - accuracy: 0.9025 - val_loss: 0.4993 - val_accuracy: 0.8300
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3562 - accuracy: 0.8919
# Epoch 192: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3556 - accuracy: 0.8928 - val_loss: 0.3966 - val_accuracy: 0.8700
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3589 - accuracy: 0.8835
# Epoch 193: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3567 - accuracy: 0.8841 - val_loss: 0.3709 - val_accuracy: 0.8712
# Epoch 194/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8988
# Epoch 194: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3324 - accuracy: 0.8988 - val_loss: 0.3646 - val_accuracy: 0.8775
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3327 - accuracy: 0.9007
# Epoch 195: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3352 - accuracy: 0.8994 - val_loss: 0.4033 - val_accuracy: 0.8650
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3268 - accuracy: 0.9040
# Epoch 196: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3280 - accuracy: 0.9028 - val_loss: 0.3513 - val_accuracy: 0.8763
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3175 - accuracy: 0.9033
# Epoch 197: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3202 - accuracy: 0.9025 - val_loss: 0.3620 - val_accuracy: 0.8750
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.9038
# Epoch 198: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3199 - accuracy: 0.9038 - val_loss: 0.3499 - val_accuracy: 0.8825
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3255 - accuracy: 0.9017
# Epoch 199: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3242 - accuracy: 0.9022 - val_loss: 0.4105 - val_accuracy: 0.8562
# Epoch 200/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3487 - accuracy: 0.8953
# Epoch 200: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3487 - accuracy: 0.8953 - val_loss: 0.3495 - val_accuracy: 0.8838

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 815,681
# Trainable params: 815,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))
# Out:
# Loss: 0.38
# Accuracy: 90.00%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy    = accuracy_score(y_val, y_pred)
precision   = precision_score(y_val, y_pred)
recall      = recall_score(y_val, y_pred)
f1          = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("\nAccuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	90.00%
# Sensitivity:	88.05%
# Specificity:	91.81%
# Precision:	90.88%
# F1-score:	89.45%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.96

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
