# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado//modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, epochs=200, 
    batch_size=512, 
    callbacks=[checkpoint_callback],
    validation_data= (X_val_reshaped, y_val)
)
# Out:
# Epoch 1/200
# 6/7 [========================>.....] - ETA: 0s - loss: 7.6628 - accuracy: 0.4850
# Epoch 1: val_accuracy improved from -inf to 0.46875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 1s 89ms/step - loss: 7.5280 - accuracy: 0.4856 - val_loss: 4.3721 - val_accuracy: 0.4688
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 4.2968 - accuracy: 0.5033
# Epoch 2: val_accuracy did not improve from 0.46875
# 7/7 [==============================] - 0s 61ms/step - loss: 4.2872 - accuracy: 0.5038 - val_loss: 3.9610 - val_accuracy: 0.4688
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 3.6363 - accuracy: 0.5846
# Epoch 3: val_accuracy improved from 0.46875 to 0.53250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 3.6197 - accuracy: 0.5866 - val_loss: 3.0818 - val_accuracy: 0.5325
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 2.8089 - accuracy: 0.6354
# Epoch 4: val_accuracy improved from 0.53250 to 0.62375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 2.7945 - accuracy: 0.6316 - val_loss: 2.3420 - val_accuracy: 0.6237
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 2.1179 - accuracy: 0.7054
# Epoch 5: val_accuracy did not improve from 0.62375
# 7/7 [==============================] - 0s 58ms/step - loss: 2.1061 - accuracy: 0.7072 - val_loss: 1.8576 - val_accuracy: 0.6112
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.6317 - accuracy: 0.6927
# Epoch 6: val_accuracy improved from 0.62375 to 0.72500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 1.6252 - accuracy: 0.6925 - val_loss: 1.3849 - val_accuracy: 0.7250
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.3037 - accuracy: 0.7572
# Epoch 7: val_accuracy improved from 0.72500 to 0.77000, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 1.2968 - accuracy: 0.7584 - val_loss: 1.0924 - val_accuracy: 0.7700
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.0556 - accuracy: 0.7845
# Epoch 8: val_accuracy improved from 0.77000 to 0.78375, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 1.0549 - accuracy: 0.7834 - val_loss: 0.9441 - val_accuracy: 0.7837
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.9169 - accuracy: 0.8044
# Epoch 9: val_accuracy improved from 0.78375 to 0.84125, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.9140 - accuracy: 0.8047 - val_loss: 0.8516 - val_accuracy: 0.8413
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: 0.9159 - accuracy: 0.7603
# Epoch 10: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.9159 - accuracy: 0.7603 - val_loss: 0.9577 - val_accuracy: 0.7563
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8734 - accuracy: 0.7826
# Epoch 11: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.8722 - accuracy: 0.7847 - val_loss: 0.8028 - val_accuracy: 0.8138
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7978 - accuracy: 0.7835
# Epoch 12: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.7925 - accuracy: 0.7862 - val_loss: 0.7161 - val_accuracy: 0.7750
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7287 - accuracy: 0.7917
# Epoch 13: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7278 - accuracy: 0.7909 - val_loss: 0.6701 - val_accuracy: 0.8112
# Epoch 14/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6783 - accuracy: 0.8050
# Epoch 14: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.6756 - accuracy: 0.8062 - val_loss: 0.6927 - val_accuracy: 0.7188
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6936 - accuracy: 0.7904
# Epoch 15: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.6873 - accuracy: 0.7953 - val_loss: 0.6684 - val_accuracy: 0.7912
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6450 - accuracy: 0.8103
# Epoch 16: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.6450 - accuracy: 0.8103 - val_loss: 0.6069 - val_accuracy: 0.7875
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6051 - accuracy: 0.8200
# Epoch 17: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.6051 - accuracy: 0.8200 - val_loss: 0.6241 - val_accuracy: 0.7350
# Epoch 18/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6237 - accuracy: 0.8092
# Epoch 18: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.6242 - accuracy: 0.8094 - val_loss: 0.5881 - val_accuracy: 0.7862
# Epoch 19/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5904 - accuracy: 0.8122
# Epoch 19: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5891 - accuracy: 0.8122 - val_loss: 0.5516 - val_accuracy: 0.7850
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5702 - accuracy: 0.8184
# Epoch 20: val_accuracy did not improve from 0.84125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5702 - accuracy: 0.8188 - val_loss: 0.5389 - val_accuracy: 0.8225
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5457 - accuracy: 0.8327
# Epoch 21: val_accuracy improved from 0.84125 to 0.85500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.5479 - accuracy: 0.8322 - val_loss: 0.5449 - val_accuracy: 0.8550
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5464 - accuracy: 0.8328
# Epoch 22: val_accuracy improved from 0.85500 to 0.85875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 0.5464 - accuracy: 0.8328 - val_loss: 0.5121 - val_accuracy: 0.8587
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5170 - accuracy: 0.8450
# Epoch 23: val_accuracy did not improve from 0.85875
# 7/7 [==============================] - 0s 63ms/step - loss: 0.5170 - accuracy: 0.8450 - val_loss: 0.5062 - val_accuracy: 0.8062
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5189 - accuracy: 0.8402
# Epoch 24: val_accuracy improved from 0.85875 to 0.86250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5174 - accuracy: 0.8416 - val_loss: 0.5018 - val_accuracy: 0.8625
# Epoch 25/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4998 - accuracy: 0.8366
# Epoch 25: val_accuracy did not improve from 0.86250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5000 - accuracy: 0.8366 - val_loss: 0.4854 - val_accuracy: 0.8413
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4861 - accuracy: 0.8529
# Epoch 26: val_accuracy did not improve from 0.86250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4850 - accuracy: 0.8534 - val_loss: 0.5406 - val_accuracy: 0.8225
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5022 - accuracy: 0.8359
# Epoch 27: val_accuracy improved from 0.86250 to 0.87875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5014 - accuracy: 0.8366 - val_loss: 0.4448 - val_accuracy: 0.8788
# Epoch 28/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4580 - accuracy: 0.8516
# Epoch 28: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4581 - accuracy: 0.8522 - val_loss: 0.4617 - val_accuracy: 0.8637
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4880 - accuracy: 0.8415
# Epoch 29: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4950 - accuracy: 0.8375 - val_loss: 0.5109 - val_accuracy: 0.7950
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5212 - accuracy: 0.8171
# Epoch 30: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5197 - accuracy: 0.8191 - val_loss: 0.5161 - val_accuracy: 0.8450
# Epoch 31/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5041 - accuracy: 0.8421
# Epoch 31: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5009 - accuracy: 0.8438 - val_loss: 0.4305 - val_accuracy: 0.8775
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.8453
# Epoch 32: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4591 - accuracy: 0.8453 - val_loss: 0.4487 - val_accuracy: 0.8188
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4606 - accuracy: 0.8441
# Epoch 33: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4599 - accuracy: 0.8453 - val_loss: 0.4928 - val_accuracy: 0.8525
# Epoch 34/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4731 - accuracy: 0.8431
# Epoch 34: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4741 - accuracy: 0.8409 - val_loss: 0.4249 - val_accuracy: 0.8687
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4597 - accuracy: 0.8490
# Epoch 35: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4605 - accuracy: 0.8472 - val_loss: 0.5896 - val_accuracy: 0.7337
# Epoch 36/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5492 - accuracy: 0.7943
# Epoch 36: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5455 - accuracy: 0.7959 - val_loss: 0.4873 - val_accuracy: 0.8388
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5085 - accuracy: 0.8229
# Epoch 37: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5096 - accuracy: 0.8225 - val_loss: 0.4447 - val_accuracy: 0.8662
# Epoch 38/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4869 - accuracy: 0.8187
# Epoch 38: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4874 - accuracy: 0.8175 - val_loss: 0.4596 - val_accuracy: 0.8525
# Epoch 39/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4590 - accuracy: 0.8356
# Epoch 39: val_accuracy did not improve from 0.87875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4566 - accuracy: 0.8375 - val_loss: 0.4176 - val_accuracy: 0.8763
# Epoch 40/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4442 - accuracy: 0.8418
# Epoch 40: val_accuracy improved from 0.87875 to 0.88875, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4418 - accuracy: 0.8450 - val_loss: 0.3983 - val_accuracy: 0.8888
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.8487
# Epoch 41: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4456 - accuracy: 0.8487 - val_loss: 0.4104 - val_accuracy: 0.8788
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4230 - accuracy: 0.8597
# Epoch 42: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4223 - accuracy: 0.8600 - val_loss: 0.3865 - val_accuracy: 0.8712
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4095 - accuracy: 0.8643
# Epoch 43: val_accuracy improved from 0.88875 to 0.89500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4064 - accuracy: 0.8659 - val_loss: 0.3704 - val_accuracy: 0.8950
# Epoch 44/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3968 - accuracy: 0.8633
# Epoch 44: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3948 - accuracy: 0.8653 - val_loss: 0.3943 - val_accuracy: 0.8888
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4154 - accuracy: 0.8633
# Epoch 45: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4186 - accuracy: 0.8616 - val_loss: 0.3726 - val_accuracy: 0.8925
# Epoch 46/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4139 - accuracy: 0.8711
# Epoch 46: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4130 - accuracy: 0.8716 - val_loss: 0.3816 - val_accuracy: 0.8550
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4152 - accuracy: 0.8590
# Epoch 47: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4140 - accuracy: 0.8606 - val_loss: 0.3929 - val_accuracy: 0.8775
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5041 - accuracy: 0.8089
# Epoch 48: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5025 - accuracy: 0.8125 - val_loss: 0.4730 - val_accuracy: 0.7975
# Epoch 49/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.8213
# Epoch 49: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4806 - accuracy: 0.8213 - val_loss: 0.4614 - val_accuracy: 0.8500
# Epoch 50/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4595 - accuracy: 0.8481
# Epoch 50: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4595 - accuracy: 0.8481 - val_loss: 0.4146 - val_accuracy: 0.8788
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.8556
# Epoch 51: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4282 - accuracy: 0.8556 - val_loss: 0.3867 - val_accuracy: 0.8800
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4118 - accuracy: 0.8633
# Epoch 52: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4079 - accuracy: 0.8662 - val_loss: 0.3766 - val_accuracy: 0.8825
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3926 - accuracy: 0.8727
# Epoch 53: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3943 - accuracy: 0.8703 - val_loss: 0.4042 - val_accuracy: 0.8662
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.8625
# Epoch 54: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4062 - accuracy: 0.8625 - val_loss: 0.4419 - val_accuracy: 0.8263
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4863 - accuracy: 0.8174
# Epoch 55: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4828 - accuracy: 0.8197 - val_loss: 0.5113 - val_accuracy: 0.8225
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4509 - accuracy: 0.8385
# Epoch 56: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4512 - accuracy: 0.8388 - val_loss: 0.4413 - val_accuracy: 0.8462
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8547
# Epoch 57: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4217 - accuracy: 0.8547 - val_loss: 0.3796 - val_accuracy: 0.8537
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3991 - accuracy: 0.8597
# Epoch 58: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4035 - accuracy: 0.8575 - val_loss: 0.4209 - val_accuracy: 0.8550
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4308 - accuracy: 0.8535
# Epoch 59: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4295 - accuracy: 0.8544 - val_loss: 0.4687 - val_accuracy: 0.8512
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4188 - accuracy: 0.8569
# Epoch 60: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4188 - accuracy: 0.8569 - val_loss: 0.3626 - val_accuracy: 0.8888
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3790 - accuracy: 0.8773
# Epoch 61: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3782 - accuracy: 0.8778 - val_loss: 0.3703 - val_accuracy: 0.8462
# Epoch 62/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3938 - accuracy: 0.8672
# Epoch 62: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3924 - accuracy: 0.8684 - val_loss: 0.3508 - val_accuracy: 0.8925
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3759 - accuracy: 0.8789
# Epoch 63: val_accuracy did not improve from 0.89500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3783 - accuracy: 0.8775 - val_loss: 0.3758 - val_accuracy: 0.8850
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8737
# Epoch 64: val_accuracy improved from 0.89500 to 0.89750, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3826 - accuracy: 0.8737 - val_loss: 0.3535 - val_accuracy: 0.8975
# Epoch 65/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.8697
# Epoch 65: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3915 - accuracy: 0.8697 - val_loss: 0.3631 - val_accuracy: 0.8825
# Epoch 66/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3945 - accuracy: 0.8721
# Epoch 66: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3938 - accuracy: 0.8731 - val_loss: 0.4131 - val_accuracy: 0.8363
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3968 - accuracy: 0.8757
# Epoch 67: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3965 - accuracy: 0.8753 - val_loss: 0.3518 - val_accuracy: 0.8963
# Epoch 68/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3941 - accuracy: 0.8724
# Epoch 68: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3915 - accuracy: 0.8734 - val_loss: 0.3725 - val_accuracy: 0.8925
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3907 - accuracy: 0.8776
# Epoch 69: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3947 - accuracy: 0.8753 - val_loss: 0.5291 - val_accuracy: 0.7975
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5090 - accuracy: 0.8122
# Epoch 70: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5019 - accuracy: 0.8175 - val_loss: 0.5125 - val_accuracy: 0.8238
# Epoch 71/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4840 - accuracy: 0.8232
# Epoch 71: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4818 - accuracy: 0.8241 - val_loss: 0.5036 - val_accuracy: 0.7925
# Epoch 72/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4529 - accuracy: 0.8422
# Epoch 72: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4529 - accuracy: 0.8422 - val_loss: 0.4626 - val_accuracy: 0.8450
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8566
# Epoch 73: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4391 - accuracy: 0.8566 - val_loss: 0.3920 - val_accuracy: 0.8525
# Epoch 74/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.8722
# Epoch 74: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3857 - accuracy: 0.8722 - val_loss: 0.3565 - val_accuracy: 0.8913
# Epoch 75/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.8834
# Epoch 75: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3767 - accuracy: 0.8834 - val_loss: 0.3543 - val_accuracy: 0.8788
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3858 - accuracy: 0.8714
# Epoch 76: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3906 - accuracy: 0.8681 - val_loss: 0.4171 - val_accuracy: 0.8288
# Epoch 77/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8516
# Epoch 77: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4146 - accuracy: 0.8516 - val_loss: 0.3849 - val_accuracy: 0.8850
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4132 - accuracy: 0.8652
# Epoch 78: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4101 - accuracy: 0.8675 - val_loss: 0.3759 - val_accuracy: 0.8900
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4017 - accuracy: 0.8760
# Epoch 79: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4020 - accuracy: 0.8763 - val_loss: 0.4168 - val_accuracy: 0.8625
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3785 - accuracy: 0.8893
# Epoch 80: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3764 - accuracy: 0.8894 - val_loss: 0.3875 - val_accuracy: 0.8725
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4033 - accuracy: 0.8678
# Epoch 81: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4022 - accuracy: 0.8687 - val_loss: 0.3696 - val_accuracy: 0.8838
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3670 - accuracy: 0.8844
# Epoch 82: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3664 - accuracy: 0.8850 - val_loss: 0.3560 - val_accuracy: 0.8850
# Epoch 83/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8794
# Epoch 83: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3744 - accuracy: 0.8794 - val_loss: 0.3424 - val_accuracy: 0.8963
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3788 - accuracy: 0.8750
# Epoch 84: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3805 - accuracy: 0.8734 - val_loss: 0.4607 - val_accuracy: 0.8375
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4203 - accuracy: 0.8525
# Epoch 85: val_accuracy improved from 0.89750 to 0.90250, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4223 - accuracy: 0.8509 - val_loss: 0.3497 - val_accuracy: 0.9025
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3831 - accuracy: 0.8792
# Epoch 86: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3855 - accuracy: 0.8775 - val_loss: 0.3661 - val_accuracy: 0.8925
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3828 - accuracy: 0.8809
# Epoch 87: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3837 - accuracy: 0.8806 - val_loss: 0.3546 - val_accuracy: 0.9025
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3707 - accuracy: 0.8880
# Epoch 88: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3747 - accuracy: 0.8844 - val_loss: 0.3387 - val_accuracy: 0.8963
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3719 - accuracy: 0.8743
# Epoch 89: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3682 - accuracy: 0.8769 - val_loss: 0.3793 - val_accuracy: 0.8775
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3687 - accuracy: 0.8805
# Epoch 90: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3702 - accuracy: 0.8813 - val_loss: 0.3669 - val_accuracy: 0.8875
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3751 - accuracy: 0.8773
# Epoch 91: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3735 - accuracy: 0.8781 - val_loss: 0.3559 - val_accuracy: 0.8838
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3646 - accuracy: 0.8838
# Epoch 92: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3663 - accuracy: 0.8828 - val_loss: 0.3717 - val_accuracy: 0.8875
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3918 - accuracy: 0.8734
# Epoch 93: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4009 - accuracy: 0.8678 - val_loss: 0.4147 - val_accuracy: 0.8537
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4710 - accuracy: 0.8245
# Epoch 94: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4746 - accuracy: 0.8228 - val_loss: 0.4222 - val_accuracy: 0.8813
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4451 - accuracy: 0.8532
# Epoch 95: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4429 - accuracy: 0.8547 - val_loss: 0.4333 - val_accuracy: 0.8487
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4354 - accuracy: 0.8652
# Epoch 96: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4354 - accuracy: 0.8653 - val_loss: 0.3887 - val_accuracy: 0.8863
# Epoch 97/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8794
# Epoch 97: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3998 - accuracy: 0.8794 - val_loss: 0.3721 - val_accuracy: 0.8875
# Epoch 98/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3697 - accuracy: 0.8869
# Epoch 98: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3697 - accuracy: 0.8869 - val_loss: 0.3718 - val_accuracy: 0.8775
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4091 - accuracy: 0.8685
# Epoch 99: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4063 - accuracy: 0.8700 - val_loss: 0.5004 - val_accuracy: 0.8375
# Epoch 100/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4067 - accuracy: 0.8669
# Epoch 100: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4058 - accuracy: 0.8675 - val_loss: 0.3499 - val_accuracy: 0.8913
# Epoch 101/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3981 - accuracy: 0.8722
# Epoch 101: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3981 - accuracy: 0.8722 - val_loss: 0.3479 - val_accuracy: 0.8925
# Epoch 102/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3697 - accuracy: 0.8816
# Epoch 102: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3697 - accuracy: 0.8816 - val_loss: 0.3899 - val_accuracy: 0.8687
# Epoch 103/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3665 - accuracy: 0.8802
# Epoch 103: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3655 - accuracy: 0.8806 - val_loss: 0.4235 - val_accuracy: 0.8413
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4216 - accuracy: 0.8551
# Epoch 104: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4219 - accuracy: 0.8544 - val_loss: 0.3595 - val_accuracy: 0.8813
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3821 - accuracy: 0.8730
# Epoch 105: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3815 - accuracy: 0.8731 - val_loss: 0.3435 - val_accuracy: 0.9000
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3689 - accuracy: 0.8874
# Epoch 106: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3685 - accuracy: 0.8872 - val_loss: 0.3350 - val_accuracy: 0.9013
# Epoch 107/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3510 - accuracy: 0.8890
# Epoch 107: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3499 - accuracy: 0.8891 - val_loss: 0.3292 - val_accuracy: 0.8950
# Epoch 108/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3362 - accuracy: 0.8926
# Epoch 108: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3381 - accuracy: 0.8919 - val_loss: 0.3399 - val_accuracy: 0.8838
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3426 - accuracy: 0.8906
# Epoch 109: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3422 - accuracy: 0.8906 - val_loss: 0.3858 - val_accuracy: 0.8487
# Epoch 110/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3657 - accuracy: 0.8828
# Epoch 110: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3652 - accuracy: 0.8828 - val_loss: 0.3409 - val_accuracy: 0.9000
# Epoch 111/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3451 - accuracy: 0.8890
# Epoch 111: val_accuracy improved from 0.90250 to 0.90500, saving model to modelo_generado\modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3431 - accuracy: 0.8909 - val_loss: 0.3294 - val_accuracy: 0.9050
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3371 - accuracy: 0.8984
# Epoch 112: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3356 - accuracy: 0.8984 - val_loss: 0.3259 - val_accuracy: 0.9038
# Epoch 113/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3350 - accuracy: 0.8936
# Epoch 113: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3348 - accuracy: 0.8931 - val_loss: 0.3512 - val_accuracy: 0.8813
# Epoch 114/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3590 - accuracy: 0.8786
# Epoch 114: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3616 - accuracy: 0.8769 - val_loss: 0.5649 - val_accuracy: 0.7750
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6751 - accuracy: 0.7220
# Epoch 115: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.6722 - accuracy: 0.7244 - val_loss: 0.5918 - val_accuracy: 0.7650
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6189 - accuracy: 0.7715
# Epoch 116: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.6203 - accuracy: 0.7706 - val_loss: 0.6514 - val_accuracy: 0.7425
# Epoch 117/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.7731
# Epoch 117: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.6286 - accuracy: 0.7731 - val_loss: 0.6052 - val_accuracy: 0.7487
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5901 - accuracy: 0.7663
# Epoch 118: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5908 - accuracy: 0.7650 - val_loss: 0.5630 - val_accuracy: 0.7575
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5483 - accuracy: 0.7822
# Epoch 119: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5471 - accuracy: 0.7825 - val_loss: 0.5283 - val_accuracy: 0.7650
# Epoch 120/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.7909
# Epoch 120: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5073 - accuracy: 0.7909 - val_loss: 0.4910 - val_accuracy: 0.7850
# Epoch 121/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4784 - accuracy: 0.8011
# Epoch 121: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4800 - accuracy: 0.8000 - val_loss: 0.4875 - val_accuracy: 0.7763
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4702 - accuracy: 0.8040
# Epoch 122: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4689 - accuracy: 0.8047 - val_loss: 0.4717 - val_accuracy: 0.7875
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4555 - accuracy: 0.8109
# Epoch 123: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4535 - accuracy: 0.8119 - val_loss: 0.4381 - val_accuracy: 0.8087
# Epoch 124/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4306 - accuracy: 0.8180
# Epoch 124: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4288 - accuracy: 0.8194 - val_loss: 0.4268 - val_accuracy: 0.8125
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4257 - accuracy: 0.8190
# Epoch 125: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4271 - accuracy: 0.8169 - val_loss: 0.4232 - val_accuracy: 0.8075
# Epoch 126/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4339 - accuracy: 0.8109
# Epoch 126: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4311 - accuracy: 0.8131 - val_loss: 0.4238 - val_accuracy: 0.8087
# Epoch 127/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4214 - accuracy: 0.8190
# Epoch 127: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4206 - accuracy: 0.8191 - val_loss: 0.4577 - val_accuracy: 0.7962
# Epoch 128/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4339 - accuracy: 0.8150
# Epoch 128: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4339 - accuracy: 0.8150 - val_loss: 0.4775 - val_accuracy: 0.7837
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4257 - accuracy: 0.8193
# Epoch 129: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4276 - accuracy: 0.8191 - val_loss: 0.4188 - val_accuracy: 0.8138
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4227 - accuracy: 0.8219
# Epoch 130: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4233 - accuracy: 0.8216 - val_loss: 0.4222 - val_accuracy: 0.8075
# Epoch 131/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4094 - accuracy: 0.8298
# Epoch 131: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4101 - accuracy: 0.8291 - val_loss: 0.4171 - val_accuracy: 0.8175
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4086 - accuracy: 0.8262
# Epoch 132: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4081 - accuracy: 0.8266 - val_loss: 0.4245 - val_accuracy: 0.8100
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4005 - accuracy: 0.8281
# Epoch 133: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3988 - accuracy: 0.8294 - val_loss: 0.4100 - val_accuracy: 0.8238
# Epoch 134/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4144 - accuracy: 0.8252
# Epoch 134: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4119 - accuracy: 0.8269 - val_loss: 0.4108 - val_accuracy: 0.8163
# Epoch 135/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4089 - accuracy: 0.8271
# Epoch 135: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4084 - accuracy: 0.8284 - val_loss: 0.4558 - val_accuracy: 0.8037
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4132 - accuracy: 0.8268
# Epoch 136: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4125 - accuracy: 0.8266 - val_loss: 0.4048 - val_accuracy: 0.8225
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3997 - accuracy: 0.8298
# Epoch 137: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4005 - accuracy: 0.8300 - val_loss: 0.4629 - val_accuracy: 0.7900
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4304 - accuracy: 0.8135
# Epoch 138: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4277 - accuracy: 0.8156 - val_loss: 0.4060 - val_accuracy: 0.8200
# Epoch 139/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4067 - accuracy: 0.8275
# Epoch 139: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4057 - accuracy: 0.8278 - val_loss: 0.4203 - val_accuracy: 0.8125
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4091 - accuracy: 0.8278
# Epoch 140: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4116 - accuracy: 0.8259 - val_loss: 0.4497 - val_accuracy: 0.7975
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4110 - accuracy: 0.8255
# Epoch 141: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4108 - accuracy: 0.8269 - val_loss: 0.4167 - val_accuracy: 0.8263
# Epoch 142/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4156 - accuracy: 0.8256
# Epoch 142: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4156 - accuracy: 0.8256 - val_loss: 0.4293 - val_accuracy: 0.8087
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4126 - accuracy: 0.8258
# Epoch 143: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4128 - accuracy: 0.8263 - val_loss: 0.4033 - val_accuracy: 0.8275
# Epoch 144/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8322
# Epoch 144: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3931 - accuracy: 0.8322 - val_loss: 0.3954 - val_accuracy: 0.8213
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3892 - accuracy: 0.8320
# Epoch 145: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3891 - accuracy: 0.8322 - val_loss: 0.3981 - val_accuracy: 0.8263
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3929 - accuracy: 0.8338
# Epoch 146: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3929 - accuracy: 0.8338 - val_loss: 0.3945 - val_accuracy: 0.8275
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3930 - accuracy: 0.8363
# Epoch 147: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3933 - accuracy: 0.8356 - val_loss: 0.3977 - val_accuracy: 0.8238
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3888 - accuracy: 0.8333
# Epoch 148: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3883 - accuracy: 0.8331 - val_loss: 0.3946 - val_accuracy: 0.8238
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3823 - accuracy: 0.8337
# Epoch 149: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3815 - accuracy: 0.8341 - val_loss: 0.3972 - val_accuracy: 0.8300
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3993 - accuracy: 0.8294
# Epoch 150: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3949 - accuracy: 0.8328 - val_loss: 0.4435 - val_accuracy: 0.8188
# Epoch 151/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8303
# Epoch 151: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4146 - accuracy: 0.8303 - val_loss: 0.5293 - val_accuracy: 0.7763
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5059 - accuracy: 0.7809
# Epoch 152: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5058 - accuracy: 0.7803 - val_loss: 0.4072 - val_accuracy: 0.8213
# Epoch 153/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4676 - accuracy: 0.8005
# Epoch 153: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4670 - accuracy: 0.8009 - val_loss: 0.4282 - val_accuracy: 0.8075
# Epoch 154/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4372 - accuracy: 0.8118
# Epoch 154: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4361 - accuracy: 0.8116 - val_loss: 0.4130 - val_accuracy: 0.8138
# Epoch 155/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4097 - accuracy: 0.8239
# Epoch 155: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4079 - accuracy: 0.8253 - val_loss: 0.3937 - val_accuracy: 0.8238
# Epoch 156/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3822 - accuracy: 0.8343
# Epoch 156: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3805 - accuracy: 0.8359 - val_loss: 0.3892 - val_accuracy: 0.8225
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3794 - accuracy: 0.8291
# Epoch 157: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3786 - accuracy: 0.8297 - val_loss: 0.3757 - val_accuracy: 0.8238
# Epoch 158/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3649 - accuracy: 0.8385
# Epoch 158: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3680 - accuracy: 0.8372 - val_loss: 0.3988 - val_accuracy: 0.8163
# Epoch 159/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3825 - accuracy: 0.8359
# Epoch 159: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3830 - accuracy: 0.8353 - val_loss: 0.4180 - val_accuracy: 0.8100
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4130 - accuracy: 0.8291
# Epoch 160: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4137 - accuracy: 0.8284 - val_loss: 0.3980 - val_accuracy: 0.8250
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3926 - accuracy: 0.8340
# Epoch 161: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3910 - accuracy: 0.8356 - val_loss: 0.3956 - val_accuracy: 0.8225
# Epoch 162/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8319
# Epoch 162: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3834 - accuracy: 0.8319 - val_loss: 0.3928 - val_accuracy: 0.8225
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3808 - accuracy: 0.8346
# Epoch 163: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3782 - accuracy: 0.8372 - val_loss: 0.4174 - val_accuracy: 0.8200
# Epoch 164/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3926 - accuracy: 0.8319
# Epoch 164: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3926 - accuracy: 0.8319 - val_loss: 0.4861 - val_accuracy: 0.7837
# Epoch 165/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.8169
# Epoch 165: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4424 - accuracy: 0.8169 - val_loss: 0.4131 - val_accuracy: 0.8163
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4096 - accuracy: 0.8324
# Epoch 166: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4079 - accuracy: 0.8331 - val_loss: 0.4053 - val_accuracy: 0.8213
# Epoch 167/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3957 - accuracy: 0.8320
# Epoch 167: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3945 - accuracy: 0.8331 - val_loss: 0.3899 - val_accuracy: 0.8225
# Epoch 168/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3914 - accuracy: 0.8324
# Epoch 168: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3927 - accuracy: 0.8306 - val_loss: 0.4021 - val_accuracy: 0.8087
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3949 - accuracy: 0.8304
# Epoch 169: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3953 - accuracy: 0.8297 - val_loss: 0.3800 - val_accuracy: 0.8288
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3997 - accuracy: 0.8268
# Epoch 170: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3974 - accuracy: 0.8281 - val_loss: 0.4314 - val_accuracy: 0.8062
# Epoch 171/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4014 - accuracy: 0.8307
# Epoch 171: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4058 - accuracy: 0.8275 - val_loss: 0.3894 - val_accuracy: 0.8263
# Epoch 172/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8219
# Epoch 172: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4215 - accuracy: 0.8219 - val_loss: 0.4332 - val_accuracy: 0.7975
# Epoch 173/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4031 - accuracy: 0.8232
# Epoch 173: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4023 - accuracy: 0.8241 - val_loss: 0.3875 - val_accuracy: 0.8150
# Epoch 174/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.8359
# Epoch 174: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3775 - accuracy: 0.8359 - val_loss: 0.3743 - val_accuracy: 0.8275
# Epoch 175/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3777 - accuracy: 0.8350
# Epoch 175: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3753 - accuracy: 0.8369 - val_loss: 0.3712 - val_accuracy: 0.8313
# Epoch 176/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.8319
# Epoch 176: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3772 - accuracy: 0.8319 - val_loss: 0.3940 - val_accuracy: 0.8188
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3794 - accuracy: 0.8346
# Epoch 177: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3778 - accuracy: 0.8363 - val_loss: 0.3852 - val_accuracy: 0.8225
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3789 - accuracy: 0.8486
# Epoch 178: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3812 - accuracy: 0.8462 - val_loss: 0.3911 - val_accuracy: 0.8537
# Epoch 179/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.8556
# Epoch 179: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3815 - accuracy: 0.8556 - val_loss: 0.3522 - val_accuracy: 0.8788
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3965 - accuracy: 0.8496
# Epoch 180: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3947 - accuracy: 0.8503 - val_loss: 0.4444 - val_accuracy: 0.7875
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4716 - accuracy: 0.8047
# Epoch 181: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4686 - accuracy: 0.8066 - val_loss: 0.5006 - val_accuracy: 0.7825
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4331 - accuracy: 0.8174
# Epoch 182: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4322 - accuracy: 0.8184 - val_loss: 0.3805 - val_accuracy: 0.8250
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4060 - accuracy: 0.8268
# Epoch 183: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4048 - accuracy: 0.8272 - val_loss: 0.3828 - val_accuracy: 0.8238
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3889 - accuracy: 0.8320
# Epoch 184: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3880 - accuracy: 0.8331 - val_loss: 0.3989 - val_accuracy: 0.8288
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3847 - accuracy: 0.8415
# Epoch 185: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3840 - accuracy: 0.8422 - val_loss: 0.3661 - val_accuracy: 0.8650
# Epoch 186/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8525
# Epoch 186: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3833 - accuracy: 0.8525 - val_loss: 0.3400 - val_accuracy: 0.8863
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3397 - accuracy: 0.8844
# Epoch 187: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3394 - accuracy: 0.8856 - val_loss: 0.4318 - val_accuracy: 0.8250
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3905 - accuracy: 0.8597
# Epoch 188: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3890 - accuracy: 0.8606 - val_loss: 0.5173 - val_accuracy: 0.7688
# Epoch 189/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.7822
# Epoch 189: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 66ms/step - loss: 0.5633 - accuracy: 0.7822 - val_loss: 0.4551 - val_accuracy: 0.8138
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5080 - accuracy: 0.7926
# Epoch 190: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5060 - accuracy: 0.7950 - val_loss: 0.4713 - val_accuracy: 0.8025
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4929 - accuracy: 0.8073
# Epoch 191: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4899 - accuracy: 0.8091 - val_loss: 0.4843 - val_accuracy: 0.8000
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4746 - accuracy: 0.8128
# Epoch 192: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4743 - accuracy: 0.8134 - val_loss: 0.4149 - val_accuracy: 0.8238
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4273 - accuracy: 0.8294
# Epoch 193: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4275 - accuracy: 0.8284 - val_loss: 0.4019 - val_accuracy: 0.8188
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4028 - accuracy: 0.8356
# Epoch 194: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4022 - accuracy: 0.8359 - val_loss: 0.3893 - val_accuracy: 0.8363
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3984 - accuracy: 0.8408
# Epoch 195: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3962 - accuracy: 0.8428 - val_loss: 0.3763 - val_accuracy: 0.8225
# Epoch 196/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.8453
# Epoch 196: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3909 - accuracy: 0.8453 - val_loss: 0.3669 - val_accuracy: 0.8275
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3606 - accuracy: 0.8499
# Epoch 197: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3589 - accuracy: 0.8525 - val_loss: 0.3547 - val_accuracy: 0.8313
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3550 - accuracy: 0.8623
# Epoch 198: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3567 - accuracy: 0.8616 - val_loss: 0.3515 - val_accuracy: 0.8675
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3623 - accuracy: 0.8564
# Epoch 199: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3611 - accuracy: 0.8575 - val_loss: 0.3174 - val_accuracy: 0.8938
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3509 - accuracy: 0.8708
# Epoch 200: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3526 - accuracy: 0.8700 - val_loss: 0.3458 - val_accuracy: 0.8687

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.33
# Accuracy: 90.50%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("\nAccuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	90.50%
# Sensitivity:	97.87%
# Specificity:	84.00%
# Precision:	84.37%
# F1-score:	90.62%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.94
