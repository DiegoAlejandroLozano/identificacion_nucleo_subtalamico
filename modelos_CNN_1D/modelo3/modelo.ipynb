# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import os

import tensorflow           as tf
import pandas               as pd
import seaborn              as sns
import matplotlib.pyplot    as plt

from keras.models       import Sequential, load_model
from keras.layers       import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers   import Adam
from keras.regularizers import l2
from keras.callbacks    import ModelCheckpoint

from sklearn.preprocessing      import StandardScaler
from sklearn.model_selection    import train_test_split
from sklearn.metrics            import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled  = scaler.fit_transform(X_train)
X_val_scaled    = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped    = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped      = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))


modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs          = 200, 
    batch_size      = 512, 
    validation_data = (X_val_reshaped, y_val), 
    callbacks       = [checkpoint_callback]
)
# Out:
# Epoch 1/200
# 6/7 [========================>.....] - ETA: 0s - loss: 2.7114 - accuracy: 0.5365
# Epoch 1: val_accuracy improved from -inf to 0.68125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 2s 96ms/step - loss: 2.6635 - accuracy: 0.5353 - val_loss: 1.3186 - val_accuracy: 0.6812
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.0496 - accuracy: 0.6003
# Epoch 2: val_accuracy improved from 0.68125 to 0.76500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 74ms/step - loss: 1.0413 - accuracy: 0.6041 - val_loss: 0.8141 - val_accuracy: 0.7650
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8148 - accuracy: 0.6963
# Epoch 3: val_accuracy did not improve from 0.76500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.8134 - accuracy: 0.6981 - val_loss: 0.8242 - val_accuracy: 0.5750
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7659 - accuracy: 0.6777
# Epoch 4: val_accuracy did not improve from 0.76500
# 7/7 [==============================] - 0s 63ms/step - loss: 0.7663 - accuracy: 0.6747 - val_loss: 0.6844 - val_accuracy: 0.7350
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6461 - accuracy: 0.7568
# Epoch 5: val_accuracy did not improve from 0.76500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.6451 - accuracy: 0.7547 - val_loss: 0.5806 - val_accuracy: 0.7575
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6012 - accuracy: 0.7578
# Epoch 6: val_accuracy improved from 0.76500 to 0.79250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.6004 - accuracy: 0.7591 - val_loss: 0.5538 - val_accuracy: 0.7925
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5592 - accuracy: 0.7760
# Epoch 7: val_accuracy improved from 0.79250 to 0.79500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 74ms/step - loss: 0.5560 - accuracy: 0.7784 - val_loss: 0.5275 - val_accuracy: 0.7950
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5398 - accuracy: 0.7799
# Epoch 8: val_accuracy did not improve from 0.79500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5404 - accuracy: 0.7800 - val_loss: 0.5314 - val_accuracy: 0.7675
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5190 - accuracy: 0.7839
# Epoch 9: val_accuracy improved from 0.79500 to 0.80500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.5183 - accuracy: 0.7828 - val_loss: 0.4885 - val_accuracy: 0.8050
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5013 - accuracy: 0.7920
# Epoch 10: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5019 - accuracy: 0.7894 - val_loss: 0.5396 - val_accuracy: 0.7775
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5087 - accuracy: 0.7780
# Epoch 11: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5083 - accuracy: 0.7778 - val_loss: 0.4810 - val_accuracy: 0.7812
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4870 - accuracy: 0.7887
# Epoch 12: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4876 - accuracy: 0.7909 - val_loss: 0.4495 - val_accuracy: 0.8000
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4829 - accuracy: 0.7917
# Epoch 13: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4870 - accuracy: 0.7875 - val_loss: 0.5164 - val_accuracy: 0.7638
# Epoch 14/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5079 - accuracy: 0.7812
# Epoch 14: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5068 - accuracy: 0.7819 - val_loss: 0.5206 - val_accuracy: 0.7700
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5120 - accuracy: 0.7764
# Epoch 15: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5131 - accuracy: 0.7756 - val_loss: 0.5059 - val_accuracy: 0.7775
# Epoch 16/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4945 - accuracy: 0.7822
# Epoch 16: val_accuracy improved from 0.80500 to 0.82250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 73ms/step - loss: 0.4945 - accuracy: 0.7809 - val_loss: 0.4598 - val_accuracy: 0.8225
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4752 - accuracy: 0.7926
# Epoch 17: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4781 - accuracy: 0.7906 - val_loss: 0.4704 - val_accuracy: 0.7825
# Epoch 18/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4876 - accuracy: 0.7881
# Epoch 18: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4858 - accuracy: 0.7887 - val_loss: 0.4722 - val_accuracy: 0.7912
# Epoch 19/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4687 - accuracy: 0.7881
# Epoch 19: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4692 - accuracy: 0.7884 - val_loss: 0.4551 - val_accuracy: 0.7887
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4632 - accuracy: 0.7959
# Epoch 20: val_accuracy improved from 0.82250 to 0.82875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4665 - accuracy: 0.7941 - val_loss: 0.4376 - val_accuracy: 0.8288
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4652 - accuracy: 0.8005
# Epoch 21: val_accuracy improved from 0.82875 to 0.84625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4650 - accuracy: 0.8009 - val_loss: 0.4457 - val_accuracy: 0.8462
# Epoch 22/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4664 - accuracy: 0.7982
# Epoch 22: val_accuracy did not improve from 0.84625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4630 - accuracy: 0.8012 - val_loss: 0.4725 - val_accuracy: 0.7788
# Epoch 23/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4637 - accuracy: 0.8128
# Epoch 23: val_accuracy improved from 0.84625 to 0.85125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 73ms/step - loss: 0.4640 - accuracy: 0.8128 - val_loss: 0.4195 - val_accuracy: 0.8512
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4753 - accuracy: 0.7995
# Epoch 24: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4785 - accuracy: 0.7962 - val_loss: 0.5459 - val_accuracy: 0.7513
# Epoch 25/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5184 - accuracy: 0.7669
# Epoch 25: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5177 - accuracy: 0.7678 - val_loss: 0.4936 - val_accuracy: 0.7763
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4995 - accuracy: 0.7839
# Epoch 26: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4998 - accuracy: 0.7837 - val_loss: 0.4465 - val_accuracy: 0.8037
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4752 - accuracy: 0.7842
# Epoch 27: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4725 - accuracy: 0.7853 - val_loss: 0.4401 - val_accuracy: 0.8012
# Epoch 28/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4507 - accuracy: 0.7975
# Epoch 28: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4490 - accuracy: 0.7972 - val_loss: 0.4364 - val_accuracy: 0.7987
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4429 - accuracy: 0.8151
# Epoch 29: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4439 - accuracy: 0.8141 - val_loss: 0.4233 - val_accuracy: 0.8388
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4393 - accuracy: 0.8083
# Epoch 30: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4416 - accuracy: 0.8062 - val_loss: 0.4478 - val_accuracy: 0.7975
# Epoch 31/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4564 - accuracy: 0.8040
# Epoch 31: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4570 - accuracy: 0.8034 - val_loss: 0.4521 - val_accuracy: 0.7887
# Epoch 32/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4581 - accuracy: 0.8001
# Epoch 32: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4595 - accuracy: 0.7981 - val_loss: 0.4324 - val_accuracy: 0.8075
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4451 - accuracy: 0.8014
# Epoch 33: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4454 - accuracy: 0.8012 - val_loss: 0.4369 - val_accuracy: 0.8363
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4430 - accuracy: 0.8022
# Epoch 34: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4430 - accuracy: 0.8022 - val_loss: 0.4222 - val_accuracy: 0.8475
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4366 - accuracy: 0.8092
# Epoch 35: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4394 - accuracy: 0.8069 - val_loss: 0.4429 - val_accuracy: 0.8012
# Epoch 36/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4639 - accuracy: 0.8005
# Epoch 36: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4652 - accuracy: 0.8000 - val_loss: 0.4188 - val_accuracy: 0.8112
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4534 - accuracy: 0.8089
# Epoch 37: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4541 - accuracy: 0.8069 - val_loss: 0.4293 - val_accuracy: 0.8313
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.8019
# Epoch 38: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4401 - accuracy: 0.8019 - val_loss: 0.4341 - val_accuracy: 0.8037
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4677 - accuracy: 0.7934
# Epoch 39: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4677 - accuracy: 0.7934 - val_loss: 0.4370 - val_accuracy: 0.8188
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4392 - accuracy: 0.8153
# Epoch 40: val_accuracy improved from 0.85125 to 0.86500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4392 - accuracy: 0.8153 - val_loss: 0.4200 - val_accuracy: 0.8650
# Epoch 41/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4233 - accuracy: 0.8236
# Epoch 41: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4231 - accuracy: 0.8238 - val_loss: 0.4204 - val_accuracy: 0.8388
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4285 - accuracy: 0.8343
# Epoch 42: val_accuracy improved from 0.86500 to 0.88375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4309 - accuracy: 0.8328 - val_loss: 0.3917 - val_accuracy: 0.8838
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4367 - accuracy: 0.8223
# Epoch 43: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4433 - accuracy: 0.8184 - val_loss: 0.4543 - val_accuracy: 0.7900
# Epoch 44/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5011 - accuracy: 0.7874
# Epoch 44: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4999 - accuracy: 0.7869 - val_loss: 0.4846 - val_accuracy: 0.7925
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4696 - accuracy: 0.8034
# Epoch 45: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4684 - accuracy: 0.8034 - val_loss: 0.4221 - val_accuracy: 0.8175
# Epoch 46/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4422 - accuracy: 0.8112
# Epoch 46: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4409 - accuracy: 0.8109 - val_loss: 0.4070 - val_accuracy: 0.8500
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4275 - accuracy: 0.8278
# Epoch 47: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4250 - accuracy: 0.8291 - val_loss: 0.4123 - val_accuracy: 0.8238
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4148 - accuracy: 0.8512
# Epoch 48: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4168 - accuracy: 0.8484 - val_loss: 0.5097 - val_accuracy: 0.7825
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4746 - accuracy: 0.8018
# Epoch 49: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4741 - accuracy: 0.8006 - val_loss: 0.4339 - val_accuracy: 0.8087
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4376 - accuracy: 0.8226
# Epoch 50: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4358 - accuracy: 0.8241 - val_loss: 0.5501 - val_accuracy: 0.8238
# Epoch 51/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5161 - accuracy: 0.7907
# Epoch 51: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5159 - accuracy: 0.7897 - val_loss: 0.5325 - val_accuracy: 0.7788
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5149 - accuracy: 0.7676
# Epoch 52: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5099 - accuracy: 0.7719 - val_loss: 0.4361 - val_accuracy: 0.8112
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4441 - accuracy: 0.8112
# Epoch 53: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4419 - accuracy: 0.8109 - val_loss: 0.4044 - val_accuracy: 0.8188
# Epoch 54/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4260 - accuracy: 0.8385
# Epoch 54: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4264 - accuracy: 0.8381 - val_loss: 0.3964 - val_accuracy: 0.8725
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4161 - accuracy: 0.8444
# Epoch 55: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4172 - accuracy: 0.8444 - val_loss: 0.4027 - val_accuracy: 0.8775
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4215 - accuracy: 0.8376
# Epoch 56: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4199 - accuracy: 0.8378 - val_loss: 0.4201 - val_accuracy: 0.8138
# Epoch 57/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4530 - accuracy: 0.8187
# Epoch 57: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4522 - accuracy: 0.8191 - val_loss: 0.4241 - val_accuracy: 0.8200
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4520 - accuracy: 0.8102
# Epoch 58: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4522 - accuracy: 0.8119 - val_loss: 0.4138 - val_accuracy: 0.8400
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4303 - accuracy: 0.8359
# Epoch 59: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4301 - accuracy: 0.8366 - val_loss: 0.3872 - val_accuracy: 0.8675
# Epoch 60/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4429 - accuracy: 0.8415
# Epoch 60: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4411 - accuracy: 0.8413 - val_loss: 0.3955 - val_accuracy: 0.8712
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4115 - accuracy: 0.8496
# Epoch 61: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4102 - accuracy: 0.8497 - val_loss: 0.4108 - val_accuracy: 0.8438
# Epoch 62/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4064 - accuracy: 0.8636
# Epoch 62: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4061 - accuracy: 0.8653 - val_loss: 0.3643 - val_accuracy: 0.8775
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4106 - accuracy: 0.8545
# Epoch 63: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4082 - accuracy: 0.8566 - val_loss: 0.4213 - val_accuracy: 0.8438
# Epoch 64/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3989 - accuracy: 0.8551
# Epoch 64: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4005 - accuracy: 0.8541 - val_loss: 0.4227 - val_accuracy: 0.8388
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4019 - accuracy: 0.8529
# Epoch 65: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3994 - accuracy: 0.8553 - val_loss: 0.3611 - val_accuracy: 0.8763
# Epoch 66/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3754 - accuracy: 0.8844
# Epoch 66: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3785 - accuracy: 0.8828 - val_loss: 0.3769 - val_accuracy: 0.8750
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3746 - accuracy: 0.8789
# Epoch 67: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3774 - accuracy: 0.8756 - val_loss: 0.3575 - val_accuracy: 0.8800
# Epoch 68/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3734 - accuracy: 0.8743
# Epoch 68: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3720 - accuracy: 0.8759 - val_loss: 0.3592 - val_accuracy: 0.8650
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3599 - accuracy: 0.8818
# Epoch 69: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3601 - accuracy: 0.8822 - val_loss: 0.3639 - val_accuracy: 0.8737
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3512 - accuracy: 0.8864
# Epoch 70: val_accuracy improved from 0.88375 to 0.89250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3502 - accuracy: 0.8863 - val_loss: 0.3423 - val_accuracy: 0.8925
# Epoch 71/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3523 - accuracy: 0.8848
# Epoch 71: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3534 - accuracy: 0.8844 - val_loss: 0.4284 - val_accuracy: 0.8475
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4662 - accuracy: 0.8193
# Epoch 72: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4689 - accuracy: 0.8188 - val_loss: 0.5022 - val_accuracy: 0.7975
# Epoch 73/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5426 - accuracy: 0.7660
# Epoch 73: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5436 - accuracy: 0.7659 - val_loss: 0.5239 - val_accuracy: 0.8000
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5100 - accuracy: 0.7959
# Epoch 74: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5067 - accuracy: 0.7978 - val_loss: 0.4674 - val_accuracy: 0.8025
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4578 - accuracy: 0.8086
# Epoch 75: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4558 - accuracy: 0.8087 - val_loss: 0.4255 - val_accuracy: 0.8175
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4360 - accuracy: 0.8092
# Epoch 76: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4359 - accuracy: 0.8109 - val_loss: 0.4008 - val_accuracy: 0.8250
# Epoch 77/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4074 - accuracy: 0.8477
# Epoch 77: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4065 - accuracy: 0.8497 - val_loss: 0.3499 - val_accuracy: 0.8888
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3790 - accuracy: 0.8734
# Epoch 78: val_accuracy did not improve from 0.89250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3799 - accuracy: 0.8734 - val_loss: 0.3597 - val_accuracy: 0.8775
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3782 - accuracy: 0.8743
# Epoch 79: val_accuracy improved from 0.89250 to 0.90000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3763 - accuracy: 0.8759 - val_loss: 0.3497 - val_accuracy: 0.9000
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3744 - accuracy: 0.8792
# Epoch 80: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3722 - accuracy: 0.8800 - val_loss: 0.3578 - val_accuracy: 0.8825
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3717 - accuracy: 0.8750
# Epoch 81: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3714 - accuracy: 0.8753 - val_loss: 0.3771 - val_accuracy: 0.8637
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3791 - accuracy: 0.8727
# Epoch 82: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3815 - accuracy: 0.8716 - val_loss: 0.3503 - val_accuracy: 0.8913
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3869 - accuracy: 0.8724
# Epoch 83: val_accuracy improved from 0.90000 to 0.90250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3833 - accuracy: 0.8737 - val_loss: 0.3432 - val_accuracy: 0.9025
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3423 - accuracy: 0.8916
# Epoch 84: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3439 - accuracy: 0.8916 - val_loss: 0.3325 - val_accuracy: 0.8900
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3368 - accuracy: 0.8942
# Epoch 85: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3384 - accuracy: 0.8928 - val_loss: 0.3301 - val_accuracy: 0.8888
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3376 - accuracy: 0.8939
# Epoch 86: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3364 - accuracy: 0.8950 - val_loss: 0.3314 - val_accuracy: 0.9025
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3691 - accuracy: 0.8730
# Epoch 87: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3686 - accuracy: 0.8725 - val_loss: 0.3933 - val_accuracy: 0.8587
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3574 - accuracy: 0.8812
# Epoch 88: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3541 - accuracy: 0.8834 - val_loss: 0.3681 - val_accuracy: 0.8700
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3549 - accuracy: 0.8844
# Epoch 89: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3587 - accuracy: 0.8838 - val_loss: 0.4420 - val_accuracy: 0.8263
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4175 - accuracy: 0.8444
# Epoch 90: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4270 - accuracy: 0.8434 - val_loss: 0.5527 - val_accuracy: 0.7625
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5269 - accuracy: 0.7744
# Epoch 91: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5299 - accuracy: 0.7722 - val_loss: 0.6152 - val_accuracy: 0.7275
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5709 - accuracy: 0.7578
# Epoch 92: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5704 - accuracy: 0.7572 - val_loss: 0.5651 - val_accuracy: 0.7763
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5457 - accuracy: 0.7721
# Epoch 93: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5459 - accuracy: 0.7709 - val_loss: 0.5321 - val_accuracy: 0.7663
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5308 - accuracy: 0.7712
# Epoch 94: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.5293 - accuracy: 0.7728 - val_loss: 0.5267 - val_accuracy: 0.7663
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5121 - accuracy: 0.7816
# Epoch 95: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5170 - accuracy: 0.7772 - val_loss: 0.5009 - val_accuracy: 0.7937
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4976 - accuracy: 0.7868
# Epoch 96: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4970 - accuracy: 0.7878 - val_loss: 0.4640 - val_accuracy: 0.8037
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4772 - accuracy: 0.7926
# Epoch 97: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4781 - accuracy: 0.7925 - val_loss: 0.4539 - val_accuracy: 0.7975
# Epoch 98/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4638 - accuracy: 0.7956
# Epoch 98: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4628 - accuracy: 0.7959 - val_loss: 0.4447 - val_accuracy: 0.8075
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4587 - accuracy: 0.7972
# Epoch 99: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4604 - accuracy: 0.7956 - val_loss: 0.4357 - val_accuracy: 0.8138
# Epoch 100/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4568 - accuracy: 0.7966
# Epoch 100: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4568 - accuracy: 0.7966 - val_loss: 0.4261 - val_accuracy: 0.8125
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4494 - accuracy: 0.7962
# Epoch 101: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4459 - accuracy: 0.7991 - val_loss: 0.4239 - val_accuracy: 0.8062
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4396 - accuracy: 0.8073
# Epoch 102: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4386 - accuracy: 0.8072 - val_loss: 0.4186 - val_accuracy: 0.8150
# Epoch 103/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4329 - accuracy: 0.8047
# Epoch 103: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4329 - accuracy: 0.8047 - val_loss: 0.4054 - val_accuracy: 0.8213
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4249 - accuracy: 0.8135
# Epoch 104: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4240 - accuracy: 0.8147 - val_loss: 0.3965 - val_accuracy: 0.8163
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4156 - accuracy: 0.8213
# Epoch 105: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4149 - accuracy: 0.8209 - val_loss: 0.4025 - val_accuracy: 0.8300
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4273 - accuracy: 0.8001
# Epoch 106: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4242 - accuracy: 0.8031 - val_loss: 0.4195 - val_accuracy: 0.8138
# Epoch 107/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4331 - accuracy: 0.8105
# Epoch 107: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4346 - accuracy: 0.8100 - val_loss: 0.4110 - val_accuracy: 0.8188
# Epoch 108/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4266 - accuracy: 0.8138
# Epoch 108: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4266 - accuracy: 0.8138 - val_loss: 0.3877 - val_accuracy: 0.8300
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4054 - accuracy: 0.8187
# Epoch 109: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4042 - accuracy: 0.8194 - val_loss: 0.3807 - val_accuracy: 0.8288
# Epoch 110/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3899 - accuracy: 0.8262
# Epoch 110: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3921 - accuracy: 0.8244 - val_loss: 0.3787 - val_accuracy: 0.8375
# Epoch 111/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3927 - accuracy: 0.8109
# Epoch 111: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3946 - accuracy: 0.8109 - val_loss: 0.3865 - val_accuracy: 0.8350
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4051 - accuracy: 0.8206
# Epoch 112: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4055 - accuracy: 0.8203 - val_loss: 0.3954 - val_accuracy: 0.8213
# Epoch 113/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4134 - accuracy: 0.8128
# Epoch 113: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4106 - accuracy: 0.8163 - val_loss: 0.3964 - val_accuracy: 0.8300
# Epoch 114/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3939 - accuracy: 0.8284
# Epoch 114: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3939 - accuracy: 0.8284 - val_loss: 0.3762 - val_accuracy: 0.8300
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3906 - accuracy: 0.8298
# Epoch 115: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3909 - accuracy: 0.8291 - val_loss: 0.3760 - val_accuracy: 0.8288
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3871 - accuracy: 0.8239
# Epoch 116: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3881 - accuracy: 0.8222 - val_loss: 0.3854 - val_accuracy: 0.8338
# Epoch 117/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8338
# Epoch 117: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3852 - accuracy: 0.8338 - val_loss: 0.3771 - val_accuracy: 0.8363
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3909 - accuracy: 0.8268
# Epoch 118: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3910 - accuracy: 0.8259 - val_loss: 0.3711 - val_accuracy: 0.8350
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3832 - accuracy: 0.8288
# Epoch 119: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3823 - accuracy: 0.8303 - val_loss: 0.3908 - val_accuracy: 0.8263
# Epoch 120/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3824 - accuracy: 0.8353
# Epoch 120: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3812 - accuracy: 0.8369 - val_loss: 0.3640 - val_accuracy: 0.8400
# Epoch 121/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4129 - accuracy: 0.8222
# Epoch 121: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4129 - accuracy: 0.8222 - val_loss: 0.4493 - val_accuracy: 0.8138
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4103 - accuracy: 0.8255
# Epoch 122: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4116 - accuracy: 0.8244 - val_loss: 0.3822 - val_accuracy: 0.8263
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3916 - accuracy: 0.8314
# Epoch 123: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3926 - accuracy: 0.8306 - val_loss: 0.3672 - val_accuracy: 0.8338
# Epoch 124/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3814 - accuracy: 0.8343
# Epoch 124: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3800 - accuracy: 0.8356 - val_loss: 0.3653 - val_accuracy: 0.8363
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3734 - accuracy: 0.8317
# Epoch 125: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3725 - accuracy: 0.8319 - val_loss: 0.3611 - val_accuracy: 0.8400
# Epoch 126/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3801 - accuracy: 0.8327
# Epoch 126: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3803 - accuracy: 0.8322 - val_loss: 0.3705 - val_accuracy: 0.8375
# Epoch 127/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.8319
# Epoch 127: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3901 - accuracy: 0.8319 - val_loss: 0.3633 - val_accuracy: 0.8375
# Epoch 128/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.8356
# Epoch 128: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3772 - accuracy: 0.8356 - val_loss: 0.3637 - val_accuracy: 0.8363
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3965 - accuracy: 0.8239
# Epoch 129: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3975 - accuracy: 0.8238 - val_loss: 0.3726 - val_accuracy: 0.8363
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3839 - accuracy: 0.8311
# Epoch 130: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3862 - accuracy: 0.8306 - val_loss: 0.3640 - val_accuracy: 0.8413
# Epoch 131/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3688 - accuracy: 0.8389
# Epoch 131: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3695 - accuracy: 0.8384 - val_loss: 0.4329 - val_accuracy: 0.8062
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4047 - accuracy: 0.8275
# Epoch 132: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4059 - accuracy: 0.8247 - val_loss: 0.3927 - val_accuracy: 0.8288
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3907 - accuracy: 0.8307
# Epoch 133: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3905 - accuracy: 0.8303 - val_loss: 0.4169 - val_accuracy: 0.8188
# Epoch 134/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3900 - accuracy: 0.8281
# Epoch 134: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3900 - accuracy: 0.8281 - val_loss: 0.3589 - val_accuracy: 0.8413
# Epoch 135/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3656 - accuracy: 0.8337
# Epoch 135: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3636 - accuracy: 0.8359 - val_loss: 0.3596 - val_accuracy: 0.8413
# Epoch 136/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8394
# Epoch 136: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3675 - accuracy: 0.8394 - val_loss: 0.3653 - val_accuracy: 0.8338
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3800 - accuracy: 0.8382
# Epoch 137: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3785 - accuracy: 0.8388 - val_loss: 0.3725 - val_accuracy: 0.8325
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3688 - accuracy: 0.8418
# Epoch 138: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3699 - accuracy: 0.8397 - val_loss: 0.3566 - val_accuracy: 0.8425
# Epoch 139/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.8416
# Epoch 139: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3731 - accuracy: 0.8416 - val_loss: 0.3519 - val_accuracy: 0.8438
# Epoch 140/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3740 - accuracy: 0.8375
# Epoch 140: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3740 - accuracy: 0.8375 - val_loss: 0.3647 - val_accuracy: 0.8363
# Epoch 141/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8347
# Epoch 141: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3848 - accuracy: 0.8347 - val_loss: 0.4159 - val_accuracy: 0.8188
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4000 - accuracy: 0.8320
# Epoch 142: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3981 - accuracy: 0.8322 - val_loss: 0.4083 - val_accuracy: 0.8238
# Epoch 143/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8253
# Epoch 143: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4083 - accuracy: 0.8253 - val_loss: 0.3791 - val_accuracy: 0.8388
# Epoch 144/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8462
# Epoch 144: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3864 - accuracy: 0.8462 - val_loss: 0.4128 - val_accuracy: 0.8537
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3776 - accuracy: 0.8535
# Epoch 145: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3766 - accuracy: 0.8547 - val_loss: 0.4310 - val_accuracy: 0.8213
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4156 - accuracy: 0.8238
# Epoch 146: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4156 - accuracy: 0.8238 - val_loss: 0.3853 - val_accuracy: 0.8388
# Epoch 147/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.8316
# Epoch 147: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4062 - accuracy: 0.8316 - val_loss: 0.3846 - val_accuracy: 0.8325
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3820 - accuracy: 0.8438
# Epoch 148: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3823 - accuracy: 0.8441 - val_loss: 0.3636 - val_accuracy: 0.8400
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3797 - accuracy: 0.8402
# Epoch 149: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3767 - accuracy: 0.8416 - val_loss: 0.3886 - val_accuracy: 0.8325
# Epoch 150/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.8469
# Epoch 150: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3796 - accuracy: 0.8469 - val_loss: 0.3564 - val_accuracy: 0.8637
# Epoch 151/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3626 - accuracy: 0.8561
# Epoch 151: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3608 - accuracy: 0.8562 - val_loss: 0.3376 - val_accuracy: 0.8637
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4243 - accuracy: 0.8398
# Epoch 152: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4301 - accuracy: 0.8381 - val_loss: 0.3984 - val_accuracy: 0.8325
# Epoch 153/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5309 - accuracy: 0.7834
# Epoch 153: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5309 - accuracy: 0.7834 - val_loss: 0.6213 - val_accuracy: 0.7138
# Epoch 154/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5538 - accuracy: 0.7614
# Epoch 154: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5547 - accuracy: 0.7625 - val_loss: 0.5663 - val_accuracy: 0.7713
# Epoch 155/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.7819
# Epoch 155: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5180 - accuracy: 0.7819 - val_loss: 0.4850 - val_accuracy: 0.7912
# Epoch 156/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4927 - accuracy: 0.7881
# Epoch 156: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4904 - accuracy: 0.7891 - val_loss: 0.4601 - val_accuracy: 0.8025
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4655 - accuracy: 0.8040
# Epoch 157: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4651 - accuracy: 0.8037 - val_loss: 0.4413 - val_accuracy: 0.8112
# Epoch 158/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4419 - accuracy: 0.8096
# Epoch 158: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4433 - accuracy: 0.8091 - val_loss: 0.4166 - val_accuracy: 0.8225
# Epoch 159/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8191
# Epoch 159: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4136 - accuracy: 0.8191 - val_loss: 0.3979 - val_accuracy: 0.8250
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4057 - accuracy: 0.8197
# Epoch 160: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4047 - accuracy: 0.8222 - val_loss: 0.4057 - val_accuracy: 0.8025
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4094 - accuracy: 0.8285
# Epoch 161: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4097 - accuracy: 0.8284 - val_loss: 0.4246 - val_accuracy: 0.8263
# Epoch 162/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4146 - accuracy: 0.8307
# Epoch 162: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4163 - accuracy: 0.8291 - val_loss: 0.3674 - val_accuracy: 0.8375
# Epoch 163/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4017 - accuracy: 0.8300
# Epoch 163: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4017 - accuracy: 0.8300 - val_loss: 0.3791 - val_accuracy: 0.8325
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3870 - accuracy: 0.8382
# Epoch 164: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3842 - accuracy: 0.8397 - val_loss: 0.3807 - val_accuracy: 0.8338
# Epoch 165/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3786 - accuracy: 0.8467
# Epoch 165: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3807 - accuracy: 0.8444 - val_loss: 0.3609 - val_accuracy: 0.8438
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3891 - accuracy: 0.8447
# Epoch 166: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3886 - accuracy: 0.8444 - val_loss: 0.4444 - val_accuracy: 0.8587
# Epoch 167/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4046 - accuracy: 0.8416
# Epoch 167: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4046 - accuracy: 0.8416 - val_loss: 0.3762 - val_accuracy: 0.8338
# Epoch 168/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3601 - accuracy: 0.8734
# Epoch 168: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3588 - accuracy: 0.8731 - val_loss: 0.3389 - val_accuracy: 0.8825
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3511 - accuracy: 0.8848
# Epoch 169: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3507 - accuracy: 0.8863 - val_loss: 0.3238 - val_accuracy: 0.8950
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3407 - accuracy: 0.8877
# Epoch 170: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3411 - accuracy: 0.8869 - val_loss: 0.3313 - val_accuracy: 0.8938
# Epoch 171/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3349 - accuracy: 0.8896
# Epoch 171: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3337 - accuracy: 0.8900 - val_loss: 0.3160 - val_accuracy: 0.8975
# Epoch 172/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3244 - accuracy: 0.8975
# Epoch 172: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3231 - accuracy: 0.8978 - val_loss: 0.3195 - val_accuracy: 0.8888
# Epoch 173/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3171 - accuracy: 0.8981
# Epoch 173: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3192 - accuracy: 0.8969 - val_loss: 0.3324 - val_accuracy: 0.8938
# Epoch 174/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3196 - accuracy: 0.9004
# Epoch 174: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3190 - accuracy: 0.8997 - val_loss: 0.3098 - val_accuracy: 0.8988
# Epoch 175/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.9003
# Epoch 175: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3142 - accuracy: 0.9003 - val_loss: 0.3320 - val_accuracy: 0.8925
# Epoch 176/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3295 - accuracy: 0.8903
# Epoch 176: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3304 - accuracy: 0.8900 - val_loss: 0.3141 - val_accuracy: 0.8975
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3264 - accuracy: 0.8945
# Epoch 177: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3280 - accuracy: 0.8941 - val_loss: 0.3149 - val_accuracy: 0.8988
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3119 - accuracy: 0.9033
# Epoch 178: val_accuracy did not improve from 0.90250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3130 - accuracy: 0.9031 - val_loss: 0.3092 - val_accuracy: 0.9000
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3197 - accuracy: 0.8952
# Epoch 179: val_accuracy improved from 0.90250 to 0.90500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3169 - accuracy: 0.8963 - val_loss: 0.3013 - val_accuracy: 0.9050
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3058 - accuracy: 0.9033
# Epoch 180: val_accuracy did not improve from 0.90500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3073 - accuracy: 0.9022 - val_loss: 0.3075 - val_accuracy: 0.8963
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3092 - accuracy: 0.9007
# Epoch 181: val_accuracy improved from 0.90500 to 0.90625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3077 - accuracy: 0.9019 - val_loss: 0.3092 - val_accuracy: 0.9062
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3314 - accuracy: 0.8880
# Epoch 182: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3307 - accuracy: 0.8884 - val_loss: 0.3738 - val_accuracy: 0.8587
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3868 - accuracy: 0.8568
# Epoch 183: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3860 - accuracy: 0.8562 - val_loss: 0.3181 - val_accuracy: 0.8988
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3309 - accuracy: 0.8903
# Epoch 184: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3289 - accuracy: 0.8913 - val_loss: 0.3227 - val_accuracy: 0.9000
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3264 - accuracy: 0.8955
# Epoch 185: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3249 - accuracy: 0.8969 - val_loss: 0.3172 - val_accuracy: 0.8963
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3110 - accuracy: 0.8978
# Epoch 186: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3096 - accuracy: 0.8984 - val_loss: 0.3079 - val_accuracy: 0.9050
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3110 - accuracy: 0.9027
# Epoch 187: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3084 - accuracy: 0.9041 - val_loss: 0.3118 - val_accuracy: 0.9025
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3187 - accuracy: 0.8939
# Epoch 188: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3158 - accuracy: 0.8966 - val_loss: 0.3297 - val_accuracy: 0.8938
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3122 - accuracy: 0.8991
# Epoch 189: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3094 - accuracy: 0.9006 - val_loss: 0.3184 - val_accuracy: 0.8863
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3378 - accuracy: 0.8851
# Epoch 190: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3354 - accuracy: 0.8866 - val_loss: 0.4349 - val_accuracy: 0.8400
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4377 - accuracy: 0.8392
# Epoch 191: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4381 - accuracy: 0.8381 - val_loss: 0.4081 - val_accuracy: 0.8625
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3969 - accuracy: 0.8571
# Epoch 192: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3946 - accuracy: 0.8584 - val_loss: 0.3467 - val_accuracy: 0.8913
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3426 - accuracy: 0.8913
# Epoch 193: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3403 - accuracy: 0.8922 - val_loss: 0.3419 - val_accuracy: 0.8913
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3432 - accuracy: 0.8896
# Epoch 194: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3408 - accuracy: 0.8913 - val_loss: 0.3172 - val_accuracy: 0.9038
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3232 - accuracy: 0.8936
# Epoch 195: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3250 - accuracy: 0.8931 - val_loss: 0.3153 - val_accuracy: 0.9025
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3272 - accuracy: 0.8910
# Epoch 196: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3242 - accuracy: 0.8925 - val_loss: 0.3712 - val_accuracy: 0.8775
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3351 - accuracy: 0.8854
# Epoch 197: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3333 - accuracy: 0.8866 - val_loss: 0.3110 - val_accuracy: 0.9025
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3128 - accuracy: 0.9001
# Epoch 198: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3164 - accuracy: 0.8984 - val_loss: 0.3069 - val_accuracy: 0.8963
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3081 - accuracy: 0.9020
# Epoch 199: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3083 - accuracy: 0.9019 - val_loss: 0.3008 - val_accuracy: 0.9050
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3064 - accuracy: 0.9007
# Epoch 200: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3077 - accuracy: 0.9006 - val_loss: 0.3205 - val_accuracy: 0.8975

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 2498, 64)          256
#
#  max_pooling1d_4 (MaxPooling  (None, 499, 64)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_5 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 96, 64)            12352
#
#  max_pooling1d_6 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 16, 64)            12352
#
#  max_pooling1d_7 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 53,953
# Trainable params: 53,953
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))
# Out:
# Loss: 0.3092
# Accuracy: 90.6250%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp  = conf_matrix.ravel()
sensitivity     = tp / (tp + fn)
specificity     = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	90.62%
# Sensitivity:	98.76%
# Specificity:	82.37%
# Precision:	85.04%
# F1-score:	91.39%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.96

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
