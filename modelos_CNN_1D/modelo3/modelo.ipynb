# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))


modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 2.7314 - accuracy: 0.5359
# Epoch 1: val_accuracy improved from -inf to 0.48250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 4s 141ms/step - loss: 2.7314 - accuracy: 0.5359 - val_loss: 1.4049 - val_accuracy: 0.4825
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.1125 - accuracy: 0.6081
# Epoch 2: val_accuracy improved from 0.48250 to 0.58125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 83ms/step - loss: 1.1036 - accuracy: 0.6103 - val_loss: 0.8865 - val_accuracy: 0.5813
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8290 - accuracy: 0.6989
# Epoch 3: val_accuracy improved from 0.58125 to 0.74125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 83ms/step - loss: 0.8277 - accuracy: 0.6991 - val_loss: 0.8092 - val_accuracy: 0.7412
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7553 - accuracy: 0.7266
# Epoch 4: val_accuracy did not improve from 0.74125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.7510 - accuracy: 0.7284 - val_loss: 0.6824 - val_accuracy: 0.7225
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6377 - accuracy: 0.7510
# Epoch 5: val_accuracy improved from 0.74125 to 0.77625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 76ms/step - loss: 0.6360 - accuracy: 0.7528 - val_loss: 0.6182 - val_accuracy: 0.7763
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5805 - accuracy: 0.7692
# Epoch 6: val_accuracy improved from 0.77625 to 0.78750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 83ms/step - loss: 0.5829 - accuracy: 0.7669 - val_loss: 0.5665 - val_accuracy: 0.7875
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5594 - accuracy: 0.7783
# Epoch 7: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.5583 - accuracy: 0.7797 - val_loss: 0.5590 - val_accuracy: 0.7850
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5373 - accuracy: 0.7852
# Epoch 8: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5368 - accuracy: 0.7853 - val_loss: 0.5290 - val_accuracy: 0.7850
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5207 - accuracy: 0.7874
# Epoch 9: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5205 - accuracy: 0.7875 - val_loss: 0.5069 - val_accuracy: 0.7812
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5062 - accuracy: 0.7923
# Epoch 10: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5066 - accuracy: 0.7931 - val_loss: 0.5087 - val_accuracy: 0.7862
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4888 - accuracy: 0.7962
# Epoch 11: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4877 - accuracy: 0.7969 - val_loss: 0.5156 - val_accuracy: 0.7750
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4783 - accuracy: 0.7972
# Epoch 12: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4800 - accuracy: 0.7966 - val_loss: 0.4901 - val_accuracy: 0.7837
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4848 - accuracy: 0.7952
# Epoch 13: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4848 - accuracy: 0.7962 - val_loss: 0.4932 - val_accuracy: 0.7725
# Epoch 14/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5012 - accuracy: 0.7894
# Epoch 14: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4978 - accuracy: 0.7909 - val_loss: 0.5695 - val_accuracy: 0.7700
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5082 - accuracy: 0.7904
# Epoch 15: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.5089 - accuracy: 0.7900 - val_loss: 0.4992 - val_accuracy: 0.7750
# Epoch 16/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4963 - accuracy: 0.7852
# Epoch 16: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4988 - accuracy: 0.7831 - val_loss: 0.4663 - val_accuracy: 0.7837
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4744 - accuracy: 0.7995
# Epoch 17: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4743 - accuracy: 0.7984 - val_loss: 0.4926 - val_accuracy: 0.7700
# Epoch 18/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4725 - accuracy: 0.7995
# Epoch 18: val_accuracy did not improve from 0.78750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4713 - accuracy: 0.7994 - val_loss: 0.4849 - val_accuracy: 0.7837
# Epoch 19/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4623 - accuracy: 0.8118
# Epoch 19: val_accuracy improved from 0.78750 to 0.79000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 79ms/step - loss: 0.4620 - accuracy: 0.8112 - val_loss: 0.5146 - val_accuracy: 0.7900
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4895 - accuracy: 0.7985
# Epoch 20: val_accuracy did not improve from 0.79000
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4867 - accuracy: 0.7997 - val_loss: 0.5193 - val_accuracy: 0.7675
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4728 - accuracy: 0.8024
# Epoch 21: val_accuracy did not improve from 0.79000
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4738 - accuracy: 0.8006 - val_loss: 0.5177 - val_accuracy: 0.7775
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.8119
# Epoch 22: val_accuracy improved from 0.79000 to 0.80500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 85ms/step - loss: 0.4602 - accuracy: 0.8119 - val_loss: 0.4509 - val_accuracy: 0.8050
# Epoch 23/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4415 - accuracy: 0.8232
# Epoch 23: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4400 - accuracy: 0.8253 - val_loss: 0.4883 - val_accuracy: 0.7875
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4327 - accuracy: 0.8421
# Epoch 24: val_accuracy improved from 0.80500 to 0.81750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 76ms/step - loss: 0.4315 - accuracy: 0.8431 - val_loss: 0.4551 - val_accuracy: 0.8175
# Epoch 25/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4291 - accuracy: 0.8496
# Epoch 25: val_accuracy did not improve from 0.81750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4291 - accuracy: 0.8494 - val_loss: 0.4521 - val_accuracy: 0.8138
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5055 - accuracy: 0.8053
# Epoch 26: val_accuracy did not improve from 0.81750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.5059 - accuracy: 0.8037 - val_loss: 0.5371 - val_accuracy: 0.7525
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4982 - accuracy: 0.7871
# Epoch 27: val_accuracy did not improve from 0.81750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4981 - accuracy: 0.7881 - val_loss: 0.5182 - val_accuracy: 0.7525
# Epoch 28/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4746 - accuracy: 0.8092
# Epoch 28: val_accuracy did not improve from 0.81750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4755 - accuracy: 0.8078 - val_loss: 0.4816 - val_accuracy: 0.7788
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4547 - accuracy: 0.8223
# Epoch 29: val_accuracy improved from 0.81750 to 0.82625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 86ms/step - loss: 0.4554 - accuracy: 0.8209 - val_loss: 0.4509 - val_accuracy: 0.8263
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4504 - accuracy: 0.8285
# Epoch 30: val_accuracy improved from 0.82625 to 0.82750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 77ms/step - loss: 0.4524 - accuracy: 0.8269 - val_loss: 0.4460 - val_accuracy: 0.8275
# Epoch 31/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4332 - accuracy: 0.8418
# Epoch 31: val_accuracy did not improve from 0.82750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4314 - accuracy: 0.8422 - val_loss: 0.4434 - val_accuracy: 0.8275
# Epoch 32/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4203 - accuracy: 0.8529
# Epoch 32: val_accuracy did not improve from 0.82750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4257 - accuracy: 0.8484 - val_loss: 0.5747 - val_accuracy: 0.7625
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5175 - accuracy: 0.7884
# Epoch 33: val_accuracy did not improve from 0.82750
# 7/7 [==============================] - 0s 70ms/step - loss: 0.5174 - accuracy: 0.7869 - val_loss: 0.5298 - val_accuracy: 0.7513
# Epoch 34/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4953 - accuracy: 0.7923
# Epoch 34: val_accuracy did not improve from 0.82750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4939 - accuracy: 0.7919 - val_loss: 0.4820 - val_accuracy: 0.7837
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4450 - accuracy: 0.8197
# Epoch 35: val_accuracy did not improve from 0.82750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4442 - accuracy: 0.8194 - val_loss: 0.4565 - val_accuracy: 0.7887
# Epoch 36/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4377 - accuracy: 0.8340
# Epoch 36: val_accuracy did not improve from 0.82750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4361 - accuracy: 0.8359 - val_loss: 0.4643 - val_accuracy: 0.8150
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4265 - accuracy: 0.8460
# Epoch 37: val_accuracy improved from 0.82750 to 0.83875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 91ms/step - loss: 0.4254 - accuracy: 0.8478 - val_loss: 0.4333 - val_accuracy: 0.8388
# Epoch 38/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4221 - accuracy: 0.8587
# Epoch 38: val_accuracy improved from 0.83875 to 0.84625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 75ms/step - loss: 0.4241 - accuracy: 0.8578 - val_loss: 0.4330 - val_accuracy: 0.8462
# Epoch 39/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4039 - accuracy: 0.8682
# Epoch 39: val_accuracy did not improve from 0.84625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4051 - accuracy: 0.8669 - val_loss: 0.5029 - val_accuracy: 0.8200
# Epoch 40/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4352 - accuracy: 0.8363
# Epoch 40: val_accuracy did not improve from 0.84625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4380 - accuracy: 0.8359 - val_loss: 0.4300 - val_accuracy: 0.8450
# Epoch 41/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4140 - accuracy: 0.8454
# Epoch 41: val_accuracy did not improve from 0.84625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4157 - accuracy: 0.8450 - val_loss: 0.4151 - val_accuracy: 0.8275
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3998 - accuracy: 0.8587
# Epoch 42: val_accuracy improved from 0.84625 to 0.85000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 76ms/step - loss: 0.4041 - accuracy: 0.8566 - val_loss: 0.4128 - val_accuracy: 0.8500
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4039 - accuracy: 0.8555
# Epoch 43: val_accuracy did not improve from 0.85000
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4098 - accuracy: 0.8512 - val_loss: 0.4719 - val_accuracy: 0.8100
# Epoch 44/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4715 - accuracy: 0.8177
# Epoch 44: val_accuracy did not improve from 0.85000
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4722 - accuracy: 0.8175 - val_loss: 0.4604 - val_accuracy: 0.8000
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4392 - accuracy: 0.8408
# Epoch 45: val_accuracy did not improve from 0.85000
# 7/7 [==============================] - 0s 70ms/step - loss: 0.4384 - accuracy: 0.8416 - val_loss: 0.4326 - val_accuracy: 0.8175
# Epoch 46/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4205 - accuracy: 0.8499
# Epoch 46: val_accuracy did not improve from 0.85000
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4194 - accuracy: 0.8497 - val_loss: 0.4296 - val_accuracy: 0.8225
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3925 - accuracy: 0.8665
# Epoch 47: val_accuracy improved from 0.85000 to 0.85125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 76ms/step - loss: 0.3921 - accuracy: 0.8662 - val_loss: 0.4108 - val_accuracy: 0.8512
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3781 - accuracy: 0.8747
# Epoch 48: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3790 - accuracy: 0.8737 - val_loss: 0.4037 - val_accuracy: 0.8487
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3829 - accuracy: 0.8747
# Epoch 49: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3795 - accuracy: 0.8769 - val_loss: 0.3994 - val_accuracy: 0.8462
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3712 - accuracy: 0.8766
# Epoch 50: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3701 - accuracy: 0.8778 - val_loss: 0.4361 - val_accuracy: 0.8512
# Epoch 51/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4382 - accuracy: 0.8454
# Epoch 51: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4375 - accuracy: 0.8447 - val_loss: 0.4721 - val_accuracy: 0.8037
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4444 - accuracy: 0.8385
# Epoch 52: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4440 - accuracy: 0.8378 - val_loss: 0.4770 - val_accuracy: 0.7862
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4123 - accuracy: 0.8438
# Epoch 53: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4131 - accuracy: 0.8434 - val_loss: 0.4185 - val_accuracy: 0.8413
# Epoch 54/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3830 - accuracy: 0.8656
# Epoch 54: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3804 - accuracy: 0.8675 - val_loss: 0.3920 - val_accuracy: 0.8500
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3771 - accuracy: 0.8701
# Epoch 55: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3770 - accuracy: 0.8703 - val_loss: 0.4235 - val_accuracy: 0.8462
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4360 - accuracy: 0.8317
# Epoch 56: val_accuracy did not improve from 0.85125
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4392 - accuracy: 0.8313 - val_loss: 0.4131 - val_accuracy: 0.8363
# Epoch 57/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4016 - accuracy: 0.8662
# Epoch 57: val_accuracy improved from 0.85125 to 0.86250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 77ms/step - loss: 0.3998 - accuracy: 0.8666 - val_loss: 0.4398 - val_accuracy: 0.8625
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3790 - accuracy: 0.8757
# Epoch 58: val_accuracy did not improve from 0.86250
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3804 - accuracy: 0.8753 - val_loss: 0.3913 - val_accuracy: 0.8612
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3827 - accuracy: 0.8737
# Epoch 59: val_accuracy improved from 0.86250 to 0.86375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 82ms/step - loss: 0.3828 - accuracy: 0.8719 - val_loss: 0.3825 - val_accuracy: 0.8637
# Epoch 60/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3710 - accuracy: 0.8776
# Epoch 60: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3738 - accuracy: 0.8772 - val_loss: 0.3916 - val_accuracy: 0.8600
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3772 - accuracy: 0.8789
# Epoch 61: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3785 - accuracy: 0.8778 - val_loss: 0.3969 - val_accuracy: 0.8562
# Epoch 62/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3716 - accuracy: 0.8838
# Epoch 62: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3717 - accuracy: 0.8828 - val_loss: 0.3857 - val_accuracy: 0.8450
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3681 - accuracy: 0.8773
# Epoch 63: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3722 - accuracy: 0.8759 - val_loss: 0.4132 - val_accuracy: 0.8375
# Epoch 64/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3798 - accuracy: 0.8766
# Epoch 64: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3832 - accuracy: 0.8753 - val_loss: 0.3910 - val_accuracy: 0.8587
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3844 - accuracy: 0.8734
# Epoch 65: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3856 - accuracy: 0.8709 - val_loss: 0.3818 - val_accuracy: 0.8525
# Epoch 66/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3627 - accuracy: 0.8802
# Epoch 66: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3610 - accuracy: 0.8806 - val_loss: 0.3815 - val_accuracy: 0.8612
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3551 - accuracy: 0.8848
# Epoch 67: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3537 - accuracy: 0.8859 - val_loss: 0.3707 - val_accuracy: 0.8600
# Epoch 68/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3603 - accuracy: 0.8815
# Epoch 68: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3604 - accuracy: 0.8828 - val_loss: 0.3855 - val_accuracy: 0.8600
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3518 - accuracy: 0.8877
# Epoch 69: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3492 - accuracy: 0.8894 - val_loss: 0.3908 - val_accuracy: 0.8525
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3508 - accuracy: 0.8890
# Epoch 70: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3505 - accuracy: 0.8894 - val_loss: 0.3882 - val_accuracy: 0.8537
# Epoch 71/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3633 - accuracy: 0.8844
# Epoch 71: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3639 - accuracy: 0.8844 - val_loss: 0.3777 - val_accuracy: 0.8525
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3477 - accuracy: 0.8903
# Epoch 72: val_accuracy improved from 0.86375 to 0.86750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 77ms/step - loss: 0.3463 - accuracy: 0.8916 - val_loss: 0.3653 - val_accuracy: 0.8675
# Epoch 73/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3382 - accuracy: 0.8936
# Epoch 73: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3367 - accuracy: 0.8941 - val_loss: 0.3651 - val_accuracy: 0.8662
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3529 - accuracy: 0.8822
# Epoch 74: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3550 - accuracy: 0.8822 - val_loss: 0.3842 - val_accuracy: 0.8562
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4272 - accuracy: 0.8467
# Epoch 75: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4254 - accuracy: 0.8475 - val_loss: 0.4472 - val_accuracy: 0.8037
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3930 - accuracy: 0.8665
# Epoch 76: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3924 - accuracy: 0.8662 - val_loss: 0.4082 - val_accuracy: 0.8462
# Epoch 77/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3716 - accuracy: 0.8880
# Epoch 77: val_accuracy improved from 0.86750 to 0.86875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3707 - accuracy: 0.8888 - val_loss: 0.3778 - val_accuracy: 0.8687
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3546 - accuracy: 0.8890
# Epoch 78: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3569 - accuracy: 0.8875 - val_loss: 0.3738 - val_accuracy: 0.8687
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3614 - accuracy: 0.8818
# Epoch 79: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3586 - accuracy: 0.8841 - val_loss: 0.3774 - val_accuracy: 0.8650
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3472 - accuracy: 0.8900
# Epoch 80: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3485 - accuracy: 0.8897 - val_loss: 0.3608 - val_accuracy: 0.8675
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3399 - accuracy: 0.8887
# Epoch 81: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3411 - accuracy: 0.8884 - val_loss: 0.3618 - val_accuracy: 0.8662
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3522 - accuracy: 0.8864
# Epoch 82: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3547 - accuracy: 0.8866 - val_loss: 0.3914 - val_accuracy: 0.8562
# Epoch 83/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3842 - accuracy: 0.8750
# Epoch 83: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3846 - accuracy: 0.8747 - val_loss: 0.4898 - val_accuracy: 0.8087
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4215 - accuracy: 0.8395
# Epoch 84: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4219 - accuracy: 0.8388 - val_loss: 0.4520 - val_accuracy: 0.8163
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4078 - accuracy: 0.8581
# Epoch 85: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4052 - accuracy: 0.8603 - val_loss: 0.3825 - val_accuracy: 0.8662
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3996 - accuracy: 0.8711
# Epoch 86: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3995 - accuracy: 0.8712 - val_loss: 0.3747 - val_accuracy: 0.8637
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4122 - accuracy: 0.8532
# Epoch 87: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4114 - accuracy: 0.8519 - val_loss: 0.4433 - val_accuracy: 0.8338
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3968 - accuracy: 0.8646
# Epoch 88: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3949 - accuracy: 0.8662 - val_loss: 0.4223 - val_accuracy: 0.8500
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3712 - accuracy: 0.8838
# Epoch 89: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3732 - accuracy: 0.8841 - val_loss: 0.3837 - val_accuracy: 0.8675
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3541 - accuracy: 0.8919
# Epoch 90: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3542 - accuracy: 0.8916 - val_loss: 0.3850 - val_accuracy: 0.8662
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3467 - accuracy: 0.8942
# Epoch 91: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3467 - accuracy: 0.8944 - val_loss: 0.3606 - val_accuracy: 0.8675
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3435 - accuracy: 0.8923
# Epoch 92: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3427 - accuracy: 0.8928 - val_loss: 0.3815 - val_accuracy: 0.8675
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3459 - accuracy: 0.8910
# Epoch 93: val_accuracy did not improve from 0.86875
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3456 - accuracy: 0.8906 - val_loss: 0.3788 - val_accuracy: 0.8612
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3404 - accuracy: 0.8916
# Epoch 94: val_accuracy improved from 0.86875 to 0.87625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 76ms/step - loss: 0.3411 - accuracy: 0.8913 - val_loss: 0.3617 - val_accuracy: 0.8763
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3440 - accuracy: 0.8919
# Epoch 95: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3454 - accuracy: 0.8916 - val_loss: 0.3742 - val_accuracy: 0.8575
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3312 - accuracy: 0.8952
# Epoch 96: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3298 - accuracy: 0.8969 - val_loss: 0.3578 - val_accuracy: 0.8662
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3213 - accuracy: 0.8991
# Epoch 97: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3230 - accuracy: 0.8991 - val_loss: 0.3642 - val_accuracy: 0.8662
# Epoch 98/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3308 - accuracy: 0.8936
# Epoch 98: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3324 - accuracy: 0.8931 - val_loss: 0.3611 - val_accuracy: 0.8700
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3395 - accuracy: 0.8887
# Epoch 99: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3416 - accuracy: 0.8884 - val_loss: 0.3569 - val_accuracy: 0.8725
# Epoch 100/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3223 - accuracy: 0.9001
# Epoch 100: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3212 - accuracy: 0.9003 - val_loss: 0.3542 - val_accuracy: 0.8725
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3218 - accuracy: 0.8981
# Epoch 101: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3231 - accuracy: 0.8972 - val_loss: 0.3485 - val_accuracy: 0.8700
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3208 - accuracy: 0.8975
# Epoch 102: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3221 - accuracy: 0.8972 - val_loss: 0.3508 - val_accuracy: 0.8687
# Epoch 103/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3195 - accuracy: 0.8981
# Epoch 103: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 71ms/step - loss: 0.3190 - accuracy: 0.8978 - val_loss: 0.3461 - val_accuracy: 0.8687
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3198 - accuracy: 0.8984
# Epoch 104: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3212 - accuracy: 0.8988 - val_loss: 0.3531 - val_accuracy: 0.8725
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3189 - accuracy: 0.8994
# Epoch 105: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3185 - accuracy: 0.9000 - val_loss: 0.3478 - val_accuracy: 0.8687
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3136 - accuracy: 0.9033
# Epoch 106: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3163 - accuracy: 0.9022 - val_loss: 0.4186 - val_accuracy: 0.8388
# Epoch 107/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3535 - accuracy: 0.8854
# Epoch 107: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3600 - accuracy: 0.8806 - val_loss: 0.5022 - val_accuracy: 0.8125
# Epoch 108/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4729 - accuracy: 0.8265
# Epoch 108: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4740 - accuracy: 0.8269 - val_loss: 0.3954 - val_accuracy: 0.8550
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4240 - accuracy: 0.8441
# Epoch 109: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4210 - accuracy: 0.8456 - val_loss: 0.4265 - val_accuracy: 0.8537
# Epoch 110/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4018 - accuracy: 0.8740
# Epoch 110: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4001 - accuracy: 0.8747 - val_loss: 0.4180 - val_accuracy: 0.8475
# Epoch 111/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3707 - accuracy: 0.8854
# Epoch 111: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3716 - accuracy: 0.8844 - val_loss: 0.3818 - val_accuracy: 0.8587
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3502 - accuracy: 0.8955
# Epoch 112: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3482 - accuracy: 0.8959 - val_loss: 0.3844 - val_accuracy: 0.8550
# Epoch 113/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3398 - accuracy: 0.8936
# Epoch 113: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3383 - accuracy: 0.8941 - val_loss: 0.3817 - val_accuracy: 0.8562
# Epoch 114/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3262 - accuracy: 0.8978
# Epoch 114: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3301 - accuracy: 0.8950 - val_loss: 0.3835 - val_accuracy: 0.8600
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3548 - accuracy: 0.8799
# Epoch 115: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3577 - accuracy: 0.8794 - val_loss: 0.3630 - val_accuracy: 0.8637
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3493 - accuracy: 0.8864
# Epoch 116: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3481 - accuracy: 0.8869 - val_loss: 0.3924 - val_accuracy: 0.8500
# Epoch 117/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3498 - accuracy: 0.8815
# Epoch 117: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3470 - accuracy: 0.8841 - val_loss: 0.3804 - val_accuracy: 0.8637
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3404 - accuracy: 0.8916
# Epoch 118: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3410 - accuracy: 0.8913 - val_loss: 0.3662 - val_accuracy: 0.8662
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3368 - accuracy: 0.8965
# Epoch 119: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3366 - accuracy: 0.8956 - val_loss: 0.3534 - val_accuracy: 0.8687
# Epoch 120/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3196 - accuracy: 0.9004
# Epoch 120: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3196 - accuracy: 0.9000 - val_loss: 0.3544 - val_accuracy: 0.8725
# Epoch 121/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3143 - accuracy: 0.9040
# Epoch 121: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3154 - accuracy: 0.9028 - val_loss: 0.3745 - val_accuracy: 0.8612
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3202 - accuracy: 0.8997
# Epoch 122: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3216 - accuracy: 0.8991 - val_loss: 0.3533 - val_accuracy: 0.8687
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3139 - accuracy: 0.9027
# Epoch 123: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3120 - accuracy: 0.9038 - val_loss: 0.3505 - val_accuracy: 0.8712
# Epoch 124/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3116 - accuracy: 0.9076
# Epoch 124: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3132 - accuracy: 0.9056 - val_loss: 0.4207 - val_accuracy: 0.8363
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3361 - accuracy: 0.8913
# Epoch 125: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3324 - accuracy: 0.8934 - val_loss: 0.3977 - val_accuracy: 0.8625
# Epoch 126/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3302 - accuracy: 0.8929
# Epoch 126: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3297 - accuracy: 0.8931 - val_loss: 0.3595 - val_accuracy: 0.8687
# Epoch 127/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3166 - accuracy: 0.9053
# Epoch 127: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3171 - accuracy: 0.9047 - val_loss: 0.3526 - val_accuracy: 0.8725
# Epoch 128/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3075 - accuracy: 0.9059
# Epoch 128: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3078 - accuracy: 0.9062 - val_loss: 0.3705 - val_accuracy: 0.8650
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3227 - accuracy: 0.8939
# Epoch 129: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3195 - accuracy: 0.8959 - val_loss: 0.3558 - val_accuracy: 0.8637
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3119 - accuracy: 0.9020
# Epoch 130: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 76ms/step - loss: 0.3137 - accuracy: 0.9016 - val_loss: 0.3504 - val_accuracy: 0.8675
# Epoch 131/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3198 - accuracy: 0.8981
# Epoch 131: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3168 - accuracy: 0.9000 - val_loss: 0.4051 - val_accuracy: 0.8550
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3386 - accuracy: 0.8913
# Epoch 132: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 70ms/step - loss: 0.3396 - accuracy: 0.8891 - val_loss: 0.3549 - val_accuracy: 0.8737
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3381 - accuracy: 0.8864
# Epoch 133: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3404 - accuracy: 0.8863 - val_loss: 0.3483 - val_accuracy: 0.8737
# Epoch 134/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3408 - accuracy: 0.8848
# Epoch 134: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3376 - accuracy: 0.8863 - val_loss: 0.3458 - val_accuracy: 0.8725
# Epoch 135/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3167 - accuracy: 0.9027
# Epoch 135: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3153 - accuracy: 0.9034 - val_loss: 0.3620 - val_accuracy: 0.8712
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3110 - accuracy: 0.9001
# Epoch 136: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3119 - accuracy: 0.8988 - val_loss: 0.3385 - val_accuracy: 0.8750
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3102 - accuracy: 0.9033
# Epoch 137: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 1s 75ms/step - loss: 0.3093 - accuracy: 0.9041 - val_loss: 0.3806 - val_accuracy: 0.8625
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3236 - accuracy: 0.8958
# Epoch 138: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3252 - accuracy: 0.8959 - val_loss: 0.3620 - val_accuracy: 0.8650
# Epoch 139/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3076 - accuracy: 0.9056
# Epoch 139: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3070 - accuracy: 0.9066 - val_loss: 0.3841 - val_accuracy: 0.8600
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3143 - accuracy: 0.9017
# Epoch 140: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3146 - accuracy: 0.9013 - val_loss: 0.3640 - val_accuracy: 0.8662
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3069 - accuracy: 0.9069
# Epoch 141: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3101 - accuracy: 0.9053 - val_loss: 0.3399 - val_accuracy: 0.8700
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3118 - accuracy: 0.9033
# Epoch 142: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 70ms/step - loss: 0.3116 - accuracy: 0.9034 - val_loss: 0.3500 - val_accuracy: 0.8712
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3335 - accuracy: 0.8887
# Epoch 143: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 70ms/step - loss: 0.3343 - accuracy: 0.8891 - val_loss: 0.3377 - val_accuracy: 0.8737
# Epoch 144/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3206 - accuracy: 0.8965
# Epoch 144: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3217 - accuracy: 0.8963 - val_loss: 0.3438 - val_accuracy: 0.8737
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3259 - accuracy: 0.8988
# Epoch 145: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3262 - accuracy: 0.8984 - val_loss: 0.3919 - val_accuracy: 0.8675
# Epoch 146/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3704 - accuracy: 0.8669
# Epoch 146: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3708 - accuracy: 0.8669 - val_loss: 0.3590 - val_accuracy: 0.8700
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3338 - accuracy: 0.8949
# Epoch 147: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3337 - accuracy: 0.8938 - val_loss: 0.3566 - val_accuracy: 0.8750
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3156 - accuracy: 0.9030
# Epoch 148: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3180 - accuracy: 0.9013 - val_loss: 0.3909 - val_accuracy: 0.8625
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3412 - accuracy: 0.8880
# Epoch 149: val_accuracy did not improve from 0.87625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3409 - accuracy: 0.8888 - val_loss: 0.3403 - val_accuracy: 0.8712
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3193 - accuracy: 0.9001
# Epoch 150: val_accuracy improved from 0.87625 to 0.87750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 77ms/step - loss: 0.3218 - accuracy: 0.8994 - val_loss: 0.3508 - val_accuracy: 0.8775
# Epoch 151/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3350 - accuracy: 0.8936
# Epoch 151: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3399 - accuracy: 0.8900 - val_loss: 0.3571 - val_accuracy: 0.8662
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3533 - accuracy: 0.8818
# Epoch 152: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3496 - accuracy: 0.8838 - val_loss: 0.5513 - val_accuracy: 0.7875
# Epoch 153/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3919 - accuracy: 0.8678
# Epoch 153: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3935 - accuracy: 0.8659 - val_loss: 0.3593 - val_accuracy: 0.8662
# Epoch 154/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3387 - accuracy: 0.8877
# Epoch 154: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3388 - accuracy: 0.8881 - val_loss: 0.3567 - val_accuracy: 0.8675
# Epoch 155/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3333 - accuracy: 0.8984
# Epoch 155: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 71ms/step - loss: 0.3329 - accuracy: 0.8981 - val_loss: 0.3582 - val_accuracy: 0.8625
# Epoch 156/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3176 - accuracy: 0.9043
# Epoch 156: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3187 - accuracy: 0.9034 - val_loss: 0.3504 - val_accuracy: 0.8750
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3146 - accuracy: 0.8975
# Epoch 157: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 1s 75ms/step - loss: 0.3120 - accuracy: 0.8994 - val_loss: 0.3539 - val_accuracy: 0.8750
# Epoch 158/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3094 - accuracy: 0.9043
# Epoch 158: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3090 - accuracy: 0.9047 - val_loss: 0.3399 - val_accuracy: 0.8775
# Epoch 159/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2975 - accuracy: 0.9092
# Epoch 159: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2989 - accuracy: 0.9084 - val_loss: 0.3823 - val_accuracy: 0.8537
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3574 - accuracy: 0.8753
# Epoch 160: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3550 - accuracy: 0.8781 - val_loss: 0.3511 - val_accuracy: 0.8650
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3287 - accuracy: 0.8932
# Epoch 161: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3298 - accuracy: 0.8922 - val_loss: 0.3477 - val_accuracy: 0.8725
# Epoch 162/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3078 - accuracy: 0.8994
# Epoch 162: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3074 - accuracy: 0.9006 - val_loss: 0.3400 - val_accuracy: 0.8700
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3077 - accuracy: 0.8997
# Epoch 163: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3086 - accuracy: 0.8997 - val_loss: 0.3329 - val_accuracy: 0.8712
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3083 - accuracy: 0.8978
# Epoch 164: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 71ms/step - loss: 0.3102 - accuracy: 0.8969 - val_loss: 0.3359 - val_accuracy: 0.8675
# Epoch 165/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2918 - accuracy: 0.9079
# Epoch 165: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.2931 - accuracy: 0.9072 - val_loss: 0.3293 - val_accuracy: 0.8737
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2981 - accuracy: 0.9040
# Epoch 166: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 68ms/step - loss: 0.2974 - accuracy: 0.9050 - val_loss: 0.3613 - val_accuracy: 0.8675
# Epoch 167/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3052 - accuracy: 0.9040
# Epoch 167: val_accuracy did not improve from 0.87750
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3050 - accuracy: 0.9038 - val_loss: 0.3298 - val_accuracy: 0.8725
# Epoch 168/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2908 - accuracy: 0.9092
# Epoch 168: val_accuracy improved from 0.87750 to 0.88125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 79ms/step - loss: 0.2931 - accuracy: 0.9087 - val_loss: 0.3424 - val_accuracy: 0.8813
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2890 - accuracy: 0.9066
# Epoch 169: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2917 - accuracy: 0.9053 - val_loss: 0.3459 - val_accuracy: 0.8687
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3164 - accuracy: 0.8958
# Epoch 170: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3128 - accuracy: 0.8975 - val_loss: 0.4969 - val_accuracy: 0.7850
# Epoch 171/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3933 - accuracy: 0.8604
# Epoch 171: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3941 - accuracy: 0.8609 - val_loss: 0.3896 - val_accuracy: 0.8700
# Epoch 172/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3636 - accuracy: 0.8809
# Epoch 172: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3636 - accuracy: 0.8813 - val_loss: 0.3699 - val_accuracy: 0.8725
# Epoch 173/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3386 - accuracy: 0.8932
# Epoch 173: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.3380 - accuracy: 0.8941 - val_loss: 0.3624 - val_accuracy: 0.8637
# Epoch 174/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3199 - accuracy: 0.9040
# Epoch 174: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 71ms/step - loss: 0.3207 - accuracy: 0.9034 - val_loss: 0.3428 - val_accuracy: 0.8800
# Epoch 175/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3021 - accuracy: 0.9043
# Epoch 175: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3079 - accuracy: 0.9019 - val_loss: 0.3441 - val_accuracy: 0.8737
# Epoch 176/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3061 - accuracy: 0.9040
# Epoch 176: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 72ms/step - loss: 0.3052 - accuracy: 0.9041 - val_loss: 0.3374 - val_accuracy: 0.8788
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3121 - accuracy: 0.9010
# Epoch 177: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3146 - accuracy: 0.8994 - val_loss: 0.3466 - val_accuracy: 0.8712
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3022 - accuracy: 0.9072
# Epoch 178: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3030 - accuracy: 0.9072 - val_loss: 0.3551 - val_accuracy: 0.8687
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3355 - accuracy: 0.8864
# Epoch 179: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3371 - accuracy: 0.8856 - val_loss: 0.3691 - val_accuracy: 0.8587
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3097 - accuracy: 0.8991
# Epoch 180: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3088 - accuracy: 0.8994 - val_loss: 0.3345 - val_accuracy: 0.8750
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2919 - accuracy: 0.9098
# Epoch 181: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.2912 - accuracy: 0.9094 - val_loss: 0.3278 - val_accuracy: 0.8712
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2926 - accuracy: 0.9095
# Epoch 182: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 1s 76ms/step - loss: 0.2905 - accuracy: 0.9097 - val_loss: 0.3331 - val_accuracy: 0.8725
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2904 - accuracy: 0.9095
# Epoch 183: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 71ms/step - loss: 0.2896 - accuracy: 0.9091 - val_loss: 0.3186 - val_accuracy: 0.8750
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2880 - accuracy: 0.9072
# Epoch 184: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 72ms/step - loss: 0.2852 - accuracy: 0.9087 - val_loss: 0.3360 - val_accuracy: 0.8687
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3041 - accuracy: 0.9014
# Epoch 185: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 70ms/step - loss: 0.3047 - accuracy: 0.9003 - val_loss: 0.3350 - val_accuracy: 0.8700
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3064 - accuracy: 0.9001
# Epoch 186: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 71ms/step - loss: 0.3056 - accuracy: 0.9003 - val_loss: 0.3594 - val_accuracy: 0.8462
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3075 - accuracy: 0.8971
# Epoch 187: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3104 - accuracy: 0.8956 - val_loss: 0.3286 - val_accuracy: 0.8813
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2922 - accuracy: 0.9089
# Epoch 188: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 70ms/step - loss: 0.2913 - accuracy: 0.9094 - val_loss: 0.3328 - val_accuracy: 0.8675
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2866 - accuracy: 0.9105
# Epoch 189: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2872 - accuracy: 0.9100 - val_loss: 0.3384 - val_accuracy: 0.8637
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2947 - accuracy: 0.9082
# Epoch 190: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2931 - accuracy: 0.9094 - val_loss: 0.3243 - val_accuracy: 0.8775
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2869 - accuracy: 0.9066
# Epoch 191: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.2864 - accuracy: 0.9081 - val_loss: 0.3189 - val_accuracy: 0.8800
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2837 - accuracy: 0.9108
# Epoch 192: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2805 - accuracy: 0.9125 - val_loss: 0.3417 - val_accuracy: 0.8700
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2920 - accuracy: 0.9062
# Epoch 193: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.2909 - accuracy: 0.9062 - val_loss: 0.3520 - val_accuracy: 0.8675
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2961 - accuracy: 0.9043
# Epoch 194: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.2948 - accuracy: 0.9056 - val_loss: 0.3405 - val_accuracy: 0.8575
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2863 - accuracy: 0.9049
# Epoch 195: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.2846 - accuracy: 0.9062 - val_loss: 0.3605 - val_accuracy: 0.8625
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4160 - accuracy: 0.8405
# Epoch 196: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4322 - accuracy: 0.8350 - val_loss: 0.5080 - val_accuracy: 0.7875
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5560 - accuracy: 0.7744
# Epoch 197: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 67ms/step - loss: 0.5557 - accuracy: 0.7744 - val_loss: 0.5481 - val_accuracy: 0.7738
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5264 - accuracy: 0.7910
# Epoch 198: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 69ms/step - loss: 0.5285 - accuracy: 0.7884 - val_loss: 0.5358 - val_accuracy: 0.7775
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5105 - accuracy: 0.8044
# Epoch 199: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 66ms/step - loss: 0.5102 - accuracy: 0.8044 - val_loss: 0.5153 - val_accuracy: 0.7875
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4825 - accuracy: 0.8239
# Epoch 200: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 72ms/step - loss: 0.4815 - accuracy: 0.8238 - val_loss: 0.4851 - val_accuracy: 0.8000

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 96, 64)            12352
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 16, 64)            12352
#
#  max_pooling1d_3 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 53,953
# Trainable params: 53,953
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.3424
# Accuracy: 88.1250%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	88.12%
# Sensitivity:	95.34%
# Specificity:	81.40%
# Precision:	82.70%
# F1-score:	88.57%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.95

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
