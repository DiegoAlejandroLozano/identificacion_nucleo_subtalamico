# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))

modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback])
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 3.4251 - accuracy: 0.5253
# Epoch 1: val_accuracy improved from -inf to 0.51250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 3s 126ms/step - loss: 3.4251 - accuracy: 0.5253 - val_loss: 1.8350 - val_accuracy: 0.5125
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.7737 - accuracy: 0.5687
# Epoch 2: val_accuracy improved from 0.51250 to 0.53000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 1.7692 - accuracy: 0.5663 - val_loss: 1.6179 - val_accuracy: 0.5300
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: 1.5073 - accuracy: 0.6866
# Epoch 3: val_accuracy improved from 0.53000 to 0.61375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 1.5073 - accuracy: 0.6866 - val_loss: 1.3549 - val_accuracy: 0.6137
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.2679 - accuracy: 0.6885
# Epoch 4: val_accuracy improved from 0.61375 to 0.79500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 1.2647 - accuracy: 0.6884 - val_loss: 1.0954 - val_accuracy: 0.7950
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.0265 - accuracy: 0.7575
# Epoch 5: val_accuracy did not improve from 0.79500
# 7/7 [==============================] - 0s 58ms/step - loss: 1.0218 - accuracy: 0.7578 - val_loss: 1.0380 - val_accuracy: 0.6712
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.9571 - accuracy: 0.6901
# Epoch 6: val_accuracy did not improve from 0.79500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.9564 - accuracy: 0.6903 - val_loss: 0.9066 - val_accuracy: 0.7412
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8374 - accuracy: 0.7604
# Epoch 7: val_accuracy did not improve from 0.79500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.8320 - accuracy: 0.7631 - val_loss: 0.7022 - val_accuracy: 0.7950
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6976 - accuracy: 0.7874
# Epoch 8: val_accuracy improved from 0.79500 to 0.82250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.6960 - accuracy: 0.7894 - val_loss: 0.6121 - val_accuracy: 0.8225
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6249 - accuracy: 0.8024
# Epoch 9: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.6281 - accuracy: 0.7994 - val_loss: 0.5509 - val_accuracy: 0.8200
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5697 - accuracy: 0.8112
# Epoch 10: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5696 - accuracy: 0.8100 - val_loss: 0.5277 - val_accuracy: 0.8163
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5500 - accuracy: 0.8122
# Epoch 11: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5512 - accuracy: 0.8131 - val_loss: 0.5686 - val_accuracy: 0.7675
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5749 - accuracy: 0.7861
# Epoch 12: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5817 - accuracy: 0.7816 - val_loss: 0.5446 - val_accuracy: 0.7887
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5739 - accuracy: 0.7770
# Epoch 13: val_accuracy did not improve from 0.82250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5773 - accuracy: 0.7759 - val_loss: 0.5019 - val_accuracy: 0.8012
# Epoch 14/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5479 - accuracy: 0.7822
# Epoch 14: val_accuracy improved from 0.82250 to 0.84875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.5461 - accuracy: 0.7841 - val_loss: 0.4928 - val_accuracy: 0.8487
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5196 - accuracy: 0.8187
# Epoch 15: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5194 - accuracy: 0.8166 - val_loss: 0.4867 - val_accuracy: 0.7900
# Epoch 16/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5141 - accuracy: 0.7995
# Epoch 16: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5155 - accuracy: 0.7987 - val_loss: 0.4767 - val_accuracy: 0.8188
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.8266
# Epoch 17: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4826 - accuracy: 0.8266 - val_loss: 0.4469 - val_accuracy: 0.8338
# Epoch 18/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4790 - accuracy: 0.8262
# Epoch 18: val_accuracy did not improve from 0.84875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4790 - accuracy: 0.8269 - val_loss: 0.4427 - val_accuracy: 0.8313
# Epoch 19/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4604 - accuracy: 0.8324
# Epoch 19: val_accuracy improved from 0.84875 to 0.87000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4593 - accuracy: 0.8334 - val_loss: 0.4325 - val_accuracy: 0.8700
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4527 - accuracy: 0.8434
# Epoch 20: val_accuracy improved from 0.87000 to 0.87250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4534 - accuracy: 0.8431 - val_loss: 0.4198 - val_accuracy: 0.8725
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4497 - accuracy: 0.8472
# Epoch 21: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4497 - accuracy: 0.8472 - val_loss: 0.4252 - val_accuracy: 0.8325
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.8269
# Epoch 22: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4578 - accuracy: 0.8269 - val_loss: 0.4039 - val_accuracy: 0.8612
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8519
# Epoch 23: val_accuracy improved from 0.87250 to 0.87625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4369 - accuracy: 0.8519 - val_loss: 0.3910 - val_accuracy: 0.8763
# Epoch 24/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8506
# Epoch 24: val_accuracy improved from 0.87625 to 0.88125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 0.4221 - accuracy: 0.8506 - val_loss: 0.3977 - val_accuracy: 0.8813
# Epoch 25/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5053 - accuracy: 0.8154
# Epoch 25: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5053 - accuracy: 0.8169 - val_loss: 0.4937 - val_accuracy: 0.8462
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4698 - accuracy: 0.8413
# Epoch 26: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4698 - accuracy: 0.8413 - val_loss: 0.4094 - val_accuracy: 0.8750
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4607 - accuracy: 0.8392
# Epoch 27: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4583 - accuracy: 0.8413 - val_loss: 0.4456 - val_accuracy: 0.8313
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8441
# Epoch 28: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4378 - accuracy: 0.8441 - val_loss: 0.4079 - val_accuracy: 0.8750
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4259 - accuracy: 0.8574
# Epoch 29: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4226 - accuracy: 0.8591 - val_loss: 0.3894 - val_accuracy: 0.8687
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4028 - accuracy: 0.8656
# Epoch 30: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4052 - accuracy: 0.8644 - val_loss: 0.4387 - val_accuracy: 0.8175
# Epoch 31/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4425 - accuracy: 0.8337
# Epoch 31: val_accuracy improved from 0.88125 to 0.88250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4458 - accuracy: 0.8316 - val_loss: 0.3903 - val_accuracy: 0.8825
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4476 - accuracy: 0.8322
# Epoch 32: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4476 - accuracy: 0.8322 - val_loss: 0.4105 - val_accuracy: 0.8500
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4277 - accuracy: 0.8490
# Epoch 33: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4280 - accuracy: 0.8500 - val_loss: 0.3887 - val_accuracy: 0.8712
# Epoch 34/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4165 - accuracy: 0.8633
# Epoch 34: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4163 - accuracy: 0.8634 - val_loss: 0.3798 - val_accuracy: 0.8813
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4050 - accuracy: 0.8672
# Epoch 35: val_accuracy did not improve from 0.88250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4015 - accuracy: 0.8694 - val_loss: 0.3669 - val_accuracy: 0.8813
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3956 - accuracy: 0.8650
# Epoch 36: val_accuracy improved from 0.88250 to 0.88375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3956 - accuracy: 0.8650 - val_loss: 0.3679 - val_accuracy: 0.8838
# Epoch 37/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3924 - accuracy: 0.8698
# Epoch 37: val_accuracy did not improve from 0.88375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3909 - accuracy: 0.8700 - val_loss: 0.3943 - val_accuracy: 0.8525
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.8438
# Epoch 38: val_accuracy improved from 0.88375 to 0.88750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4279 - accuracy: 0.8438 - val_loss: 0.3852 - val_accuracy: 0.8875
# Epoch 39/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4756 - accuracy: 0.7998
# Epoch 39: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4774 - accuracy: 0.7997 - val_loss: 0.4475 - val_accuracy: 0.8163
# Epoch 40/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4518 - accuracy: 0.8141
# Epoch 40: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4558 - accuracy: 0.8128 - val_loss: 0.4319 - val_accuracy: 0.8475
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.8003
# Epoch 41: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4647 - accuracy: 0.8003 - val_loss: 0.4089 - val_accuracy: 0.8350
# Epoch 42/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4447 - accuracy: 0.8266
# Epoch 42: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4447 - accuracy: 0.8266 - val_loss: 0.3999 - val_accuracy: 0.8600
# Epoch 43/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8484
# Epoch 43: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4160 - accuracy: 0.8484 - val_loss: 0.3786 - val_accuracy: 0.8750
# Epoch 44/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3996 - accuracy: 0.8678
# Epoch 44: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3994 - accuracy: 0.8684 - val_loss: 0.3699 - val_accuracy: 0.8813
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3972 - accuracy: 0.8708
# Epoch 45: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3984 - accuracy: 0.8700 - val_loss: 0.4098 - val_accuracy: 0.8737
# Epoch 46/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4827 - accuracy: 0.8171
# Epoch 46: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4786 - accuracy: 0.8197 - val_loss: 0.3776 - val_accuracy: 0.8737
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4268 - accuracy: 0.8564
# Epoch 47: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4219 - accuracy: 0.8587 - val_loss: 0.3726 - val_accuracy: 0.8825
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4001 - accuracy: 0.8691
# Epoch 48: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3974 - accuracy: 0.8703 - val_loss: 0.3735 - val_accuracy: 0.8612
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3897 - accuracy: 0.8652
# Epoch 49: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3884 - accuracy: 0.8672 - val_loss: 0.3965 - val_accuracy: 0.8475
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3918 - accuracy: 0.8636
# Epoch 50: val_accuracy did not improve from 0.88750
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3921 - accuracy: 0.8641 - val_loss: 0.3551 - val_accuracy: 0.8788
# Epoch 51/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4358 - accuracy: 0.8320
# Epoch 51: val_accuracy improved from 0.88750 to 0.88875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4349 - accuracy: 0.8328 - val_loss: 0.3796 - val_accuracy: 0.8888
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3977 - accuracy: 0.8717
# Epoch 52: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3937 - accuracy: 0.8734 - val_loss: 0.3715 - val_accuracy: 0.8763
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3760 - accuracy: 0.8740
# Epoch 53: val_accuracy did not improve from 0.88875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3790 - accuracy: 0.8719 - val_loss: 0.4110 - val_accuracy: 0.8650
# Epoch 54/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4158 - accuracy: 0.8506
# Epoch 54: val_accuracy improved from 0.88875 to 0.89750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4157 - accuracy: 0.8503 - val_loss: 0.3443 - val_accuracy: 0.8975
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3758 - accuracy: 0.8737
# Epoch 55: val_accuracy did not improve from 0.89750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3743 - accuracy: 0.8747 - val_loss: 0.3507 - val_accuracy: 0.8875
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3668 - accuracy: 0.8796
# Epoch 56: val_accuracy improved from 0.89750 to 0.90125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3661 - accuracy: 0.8806 - val_loss: 0.3420 - val_accuracy: 0.9013
# Epoch 57/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3646 - accuracy: 0.8822
# Epoch 57: val_accuracy did not improve from 0.90125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3628 - accuracy: 0.8822 - val_loss: 0.3509 - val_accuracy: 0.8900
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3687 - accuracy: 0.8753
# Epoch 58: val_accuracy did not improve from 0.90125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3699 - accuracy: 0.8744 - val_loss: 0.3670 - val_accuracy: 0.8875
# Epoch 59/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3738 - accuracy: 0.8769
# Epoch 59: val_accuracy improved from 0.90125 to 0.90625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.3738 - accuracy: 0.8769 - val_loss: 0.3269 - val_accuracy: 0.9062
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3597 - accuracy: 0.8825
# Epoch 60: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3597 - accuracy: 0.8825 - val_loss: 0.3894 - val_accuracy: 0.8600
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3842 - accuracy: 0.8620
# Epoch 61: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3867 - accuracy: 0.8616 - val_loss: 0.3736 - val_accuracy: 0.8712
# Epoch 62/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3815 - accuracy: 0.8730
# Epoch 62: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3861 - accuracy: 0.8697 - val_loss: 0.3385 - val_accuracy: 0.8988
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3569 - accuracy: 0.8867
# Epoch 63: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3545 - accuracy: 0.8878 - val_loss: 0.3385 - val_accuracy: 0.8900
# Epoch 64/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3469 - accuracy: 0.8835
# Epoch 64: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3451 - accuracy: 0.8850 - val_loss: 0.3318 - val_accuracy: 0.8975
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3536 - accuracy: 0.8763
# Epoch 65: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3525 - accuracy: 0.8766 - val_loss: 0.3229 - val_accuracy: 0.8988
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.8884
# Epoch 66: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3414 - accuracy: 0.8884 - val_loss: 0.3168 - val_accuracy: 0.9050
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3284 - accuracy: 0.8913
# Epoch 67: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3279 - accuracy: 0.8906 - val_loss: 0.3234 - val_accuracy: 0.8900
# Epoch 68/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3408 - accuracy: 0.8809
# Epoch 68: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3421 - accuracy: 0.8800 - val_loss: 0.3439 - val_accuracy: 0.8775
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3702 - accuracy: 0.8704
# Epoch 69: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3689 - accuracy: 0.8716 - val_loss: 0.3456 - val_accuracy: 0.8838
# Epoch 70/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3613 - accuracy: 0.8800
# Epoch 70: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3613 - accuracy: 0.8800 - val_loss: 0.3217 - val_accuracy: 0.9062
# Epoch 71/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3495 - accuracy: 0.8818
# Epoch 71: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3475 - accuracy: 0.8834 - val_loss: 0.3393 - val_accuracy: 0.8975
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3498 - accuracy: 0.8825
# Epoch 72: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3488 - accuracy: 0.8838 - val_loss: 0.3217 - val_accuracy: 0.8975
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.8872
# Epoch 73: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3405 - accuracy: 0.8872 - val_loss: 0.3498 - val_accuracy: 0.8813
# Epoch 74/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3530 - accuracy: 0.8838
# Epoch 74: val_accuracy did not improve from 0.90625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3493 - accuracy: 0.8856 - val_loss: 0.3165 - val_accuracy: 0.9062
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3204 - accuracy: 0.8958
# Epoch 75: val_accuracy improved from 0.90625 to 0.91000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3212 - accuracy: 0.8947 - val_loss: 0.3022 - val_accuracy: 0.9100
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3269 - accuracy: 0.8906
# Epoch 76: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3295 - accuracy: 0.8897 - val_loss: 0.3134 - val_accuracy: 0.9013
# Epoch 77/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3403 - accuracy: 0.8854
# Epoch 77: val_accuracy improved from 0.91000 to 0.91125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3384 - accuracy: 0.8866 - val_loss: 0.3041 - val_accuracy: 0.9112
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3183 - accuracy: 0.8945
# Epoch 78: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3193 - accuracy: 0.8934 - val_loss: 0.3253 - val_accuracy: 0.8788
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4189 - accuracy: 0.8415
# Epoch 79: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4205 - accuracy: 0.8400 - val_loss: 0.4074 - val_accuracy: 0.8550
# Epoch 80/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4043 - accuracy: 0.8594
# Epoch 80: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4043 - accuracy: 0.8594 - val_loss: 0.4698 - val_accuracy: 0.8338
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4546 - accuracy: 0.8428
# Epoch 81: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4557 - accuracy: 0.8409 - val_loss: 0.3694 - val_accuracy: 0.9013
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4345 - accuracy: 0.8646
# Epoch 82: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4367 - accuracy: 0.8628 - val_loss: 0.4073 - val_accuracy: 0.8662
# Epoch 83/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4213 - accuracy: 0.8562
# Epoch 83: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4213 - accuracy: 0.8562 - val_loss: 0.3620 - val_accuracy: 0.8913
# Epoch 84/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3918 - accuracy: 0.8737
# Epoch 84: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3918 - accuracy: 0.8737 - val_loss: 0.3562 - val_accuracy: 0.8838
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3833 - accuracy: 0.8747
# Epoch 85: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3807 - accuracy: 0.8756 - val_loss: 0.3238 - val_accuracy: 0.9087
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3511 - accuracy: 0.8831
# Epoch 86: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3524 - accuracy: 0.8831 - val_loss: 0.3415 - val_accuracy: 0.8938
# Epoch 87/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.8775
# Epoch 87: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3561 - accuracy: 0.8775 - val_loss: 0.3249 - val_accuracy: 0.8988
# Epoch 88/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8878
# Epoch 88: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3460 - accuracy: 0.8878 - val_loss: 0.3199 - val_accuracy: 0.8938
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3581 - accuracy: 0.8812
# Epoch 89: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3547 - accuracy: 0.8834 - val_loss: 0.3008 - val_accuracy: 0.9112
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3415 - accuracy: 0.8887
# Epoch 90: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3402 - accuracy: 0.8903 - val_loss: 0.3270 - val_accuracy: 0.9075
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3447 - accuracy: 0.8870
# Epoch 91: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3407 - accuracy: 0.8888 - val_loss: 0.3081 - val_accuracy: 0.9013
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3256 - accuracy: 0.8949
# Epoch 92: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3246 - accuracy: 0.8953 - val_loss: 0.2974 - val_accuracy: 0.9100
# Epoch 93/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3357 - accuracy: 0.8854
# Epoch 93: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3354 - accuracy: 0.8856 - val_loss: 0.3409 - val_accuracy: 0.8900
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3824 - accuracy: 0.8610
# Epoch 94: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3863 - accuracy: 0.8594 - val_loss: 0.3355 - val_accuracy: 0.8938
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3849 - accuracy: 0.8652
# Epoch 95: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3851 - accuracy: 0.8666 - val_loss: 0.3544 - val_accuracy: 0.8838
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3710 - accuracy: 0.8802
# Epoch 96: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3712 - accuracy: 0.8794 - val_loss: 0.3304 - val_accuracy: 0.9100
# Epoch 97/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.8878
# Epoch 97: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3459 - accuracy: 0.8878 - val_loss: 0.3132 - val_accuracy: 0.9062
# Epoch 98/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3321 - accuracy: 0.8932
# Epoch 98: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3342 - accuracy: 0.8931 - val_loss: 0.3472 - val_accuracy: 0.8750
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3524 - accuracy: 0.8770
# Epoch 99: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3501 - accuracy: 0.8778 - val_loss: 0.3145 - val_accuracy: 0.9013
# Epoch 100/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.8903
# Epoch 100: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3294 - accuracy: 0.8903 - val_loss: 0.3877 - val_accuracy: 0.8500
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3541 - accuracy: 0.8786
# Epoch 101: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3512 - accuracy: 0.8797 - val_loss: 0.3366 - val_accuracy: 0.8888
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3320 - accuracy: 0.8910
# Epoch 102: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3312 - accuracy: 0.8922 - val_loss: 0.3231 - val_accuracy: 0.9038
# Epoch 103/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3326 - accuracy: 0.8857
# Epoch 103: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3308 - accuracy: 0.8872 - val_loss: 0.3461 - val_accuracy: 0.8800
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3494 - accuracy: 0.8796
# Epoch 104: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3486 - accuracy: 0.8791 - val_loss: 0.3926 - val_accuracy: 0.8612
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3541 - accuracy: 0.8822
# Epoch 105: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3548 - accuracy: 0.8806 - val_loss: 0.3211 - val_accuracy: 0.9000
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3513 - accuracy: 0.8809
# Epoch 106: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3524 - accuracy: 0.8806 - val_loss: 0.2954 - val_accuracy: 0.9112
# Epoch 107/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3257 - accuracy: 0.8926
# Epoch 107: val_accuracy improved from 0.91125 to 0.91250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3259 - accuracy: 0.8922 - val_loss: 0.3048 - val_accuracy: 0.9125
# Epoch 108/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3208 - accuracy: 0.8950
# Epoch 108: val_accuracy improved from 0.91250 to 0.91500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3208 - accuracy: 0.8950 - val_loss: 0.2898 - val_accuracy: 0.9150
# Epoch 109/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8947
# Epoch 109: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3128 - accuracy: 0.8947 - val_loss: 0.3152 - val_accuracy: 0.8950
# Epoch 110/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3312 - accuracy: 0.8900
# Epoch 110: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3305 - accuracy: 0.8903 - val_loss: 0.2934 - val_accuracy: 0.9025
# Epoch 111/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3162 - accuracy: 0.8945
# Epoch 111: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3161 - accuracy: 0.8947 - val_loss: 0.3048 - val_accuracy: 0.9137
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3230 - accuracy: 0.8923
# Epoch 112: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3219 - accuracy: 0.8925 - val_loss: 0.3152 - val_accuracy: 0.8925
# Epoch 113/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3286 - accuracy: 0.8864
# Epoch 113: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3268 - accuracy: 0.8884 - val_loss: 0.3067 - val_accuracy: 0.9075
# Epoch 114/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3147 - accuracy: 0.8936
# Epoch 114: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3136 - accuracy: 0.8944 - val_loss: 0.2956 - val_accuracy: 0.9125
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3069 - accuracy: 0.8988
# Epoch 115: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3081 - accuracy: 0.8975 - val_loss: 0.2845 - val_accuracy: 0.9100
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3057 - accuracy: 0.8952
# Epoch 116: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3062 - accuracy: 0.8956 - val_loss: 0.2922 - val_accuracy: 0.9137
# Epoch 117/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3011 - accuracy: 0.8968
# Epoch 117: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3016 - accuracy: 0.8963 - val_loss: 0.2777 - val_accuracy: 0.9125
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2964 - accuracy: 0.8975
# Epoch 118: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2947 - accuracy: 0.8988 - val_loss: 0.2750 - val_accuracy: 0.9125
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2935 - accuracy: 0.8975
# Epoch 119: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2948 - accuracy: 0.8972 - val_loss: 0.2740 - val_accuracy: 0.9112
# Epoch 120/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2964 - accuracy: 0.9004
# Epoch 120: val_accuracy did not improve from 0.91500
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2983 - accuracy: 0.8994 - val_loss: 0.3154 - val_accuracy: 0.8988
# Epoch 121/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3193 - accuracy: 0.8848
# Epoch 121: val_accuracy improved from 0.91500 to 0.91625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3214 - accuracy: 0.8841 - val_loss: 0.2830 - val_accuracy: 0.9162
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3489 - accuracy: 0.8711
# Epoch 122: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3463 - accuracy: 0.8731 - val_loss: 0.3556 - val_accuracy: 0.8950
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3763 - accuracy: 0.8883
# Epoch 123: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3761 - accuracy: 0.8878 - val_loss: 0.3363 - val_accuracy: 0.9025
# Epoch 124/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3644 - accuracy: 0.8887
# Epoch 124: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3625 - accuracy: 0.8906 - val_loss: 0.3502 - val_accuracy: 0.8925
# Epoch 125/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.8897
# Epoch 125: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3540 - accuracy: 0.8897 - val_loss: 0.3000 - val_accuracy: 0.9150
# Epoch 126/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3301 - accuracy: 0.8916
# Epoch 126: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3290 - accuracy: 0.8928 - val_loss: 0.3134 - val_accuracy: 0.9075
# Epoch 127/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3261 - accuracy: 0.8890
# Epoch 127: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3267 - accuracy: 0.8888 - val_loss: 0.2913 - val_accuracy: 0.9150
# Epoch 128/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.8966
# Epoch 128: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3106 - accuracy: 0.8966 - val_loss: 0.2843 - val_accuracy: 0.9137
# Epoch 129/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3013 - accuracy: 0.8981
# Epoch 129: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3013 - accuracy: 0.8981 - val_loss: 0.2919 - val_accuracy: 0.9087
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3043 - accuracy: 0.8991
# Epoch 130: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3048 - accuracy: 0.8988 - val_loss: 0.2792 - val_accuracy: 0.9125
# Epoch 131/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.8994
# Epoch 131: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.2996 - accuracy: 0.8994 - val_loss: 0.2849 - val_accuracy: 0.9062
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3040 - accuracy: 0.8971
# Epoch 132: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3062 - accuracy: 0.8950 - val_loss: 0.2782 - val_accuracy: 0.9125
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2918 - accuracy: 0.9033
# Epoch 133: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2933 - accuracy: 0.9031 - val_loss: 0.2806 - val_accuracy: 0.9150
# Epoch 134/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2952 - accuracy: 0.8962
# Epoch 134: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2926 - accuracy: 0.8978 - val_loss: 0.2748 - val_accuracy: 0.9075
# Epoch 135/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8966
# Epoch 135: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2955 - accuracy: 0.8966 - val_loss: 0.3637 - val_accuracy: 0.8600
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3456 - accuracy: 0.8682
# Epoch 136: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3436 - accuracy: 0.8687 - val_loss: 0.2995 - val_accuracy: 0.9062
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3056 - accuracy: 0.8978
# Epoch 137: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3063 - accuracy: 0.8963 - val_loss: 0.2851 - val_accuracy: 0.9137
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2952 - accuracy: 0.8991
# Epoch 138: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2940 - accuracy: 0.9000 - val_loss: 0.2728 - val_accuracy: 0.9125
# Epoch 139/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2883 - accuracy: 0.9027
# Epoch 139: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2866 - accuracy: 0.9034 - val_loss: 0.2727 - val_accuracy: 0.9150
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2976 - accuracy: 0.8975
# Epoch 140: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.2989 - accuracy: 0.8969 - val_loss: 0.2742 - val_accuracy: 0.9137
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2924 - accuracy: 0.9040
# Epoch 141: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2961 - accuracy: 0.9016 - val_loss: 0.2776 - val_accuracy: 0.9162
# Epoch 142/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2859 - accuracy: 0.8991
# Epoch 142: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2860 - accuracy: 0.8997 - val_loss: 0.3275 - val_accuracy: 0.8863
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3224 - accuracy: 0.8825
# Epoch 143: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3214 - accuracy: 0.8841 - val_loss: 0.2658 - val_accuracy: 0.9137
# Epoch 144/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2934 - accuracy: 0.9017
# Epoch 144: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2953 - accuracy: 0.8994 - val_loss: 0.2816 - val_accuracy: 0.9100
# Epoch 145/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8969
# Epoch 145: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3139 - accuracy: 0.8969 - val_loss: 0.3229 - val_accuracy: 0.8963
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8931
# Epoch 146: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3136 - accuracy: 0.8931 - val_loss: 0.2740 - val_accuracy: 0.9112
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2924 - accuracy: 0.9010
# Epoch 147: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2921 - accuracy: 0.9009 - val_loss: 0.2833 - val_accuracy: 0.9112
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3007 - accuracy: 0.8981
# Epoch 148: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3003 - accuracy: 0.8984 - val_loss: 0.2786 - val_accuracy: 0.9125
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2902 - accuracy: 0.9001
# Epoch 149: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.2911 - accuracy: 0.8997 - val_loss: 0.2879 - val_accuracy: 0.8988
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3230 - accuracy: 0.8818
# Epoch 150: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3235 - accuracy: 0.8816 - val_loss: 0.3460 - val_accuracy: 0.8788
# Epoch 151/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3789 - accuracy: 0.8590
# Epoch 151: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3761 - accuracy: 0.8612 - val_loss: 0.3279 - val_accuracy: 0.8975
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3212 - accuracy: 0.9004
# Epoch 152: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3247 - accuracy: 0.8984 - val_loss: 0.2909 - val_accuracy: 0.9125
# Epoch 153/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8950
# Epoch 153: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3200 - accuracy: 0.8950 - val_loss: 0.3348 - val_accuracy: 0.8838
# Epoch 154/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3416 - accuracy: 0.8819
# Epoch 154: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3416 - accuracy: 0.8819 - val_loss: 0.3732 - val_accuracy: 0.8775
# Epoch 155/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3314 - accuracy: 0.8887
# Epoch 155: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3292 - accuracy: 0.8897 - val_loss: 0.2954 - val_accuracy: 0.9087
# Epoch 156/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.9028
# Epoch 156: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2972 - accuracy: 0.9028 - val_loss: 0.2796 - val_accuracy: 0.9087
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2958 - accuracy: 0.9004
# Epoch 157: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2962 - accuracy: 0.9000 - val_loss: 0.2636 - val_accuracy: 0.9112
# Epoch 158/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.8956
# Epoch 158: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2970 - accuracy: 0.8956 - val_loss: 0.2692 - val_accuracy: 0.9112
# Epoch 159/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2821 - accuracy: 0.9066
# Epoch 159: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2829 - accuracy: 0.9056 - val_loss: 0.2779 - val_accuracy: 0.9137
# Epoch 160/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.9025
# Epoch 160: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2897 - accuracy: 0.9025 - val_loss: 0.2673 - val_accuracy: 0.9162
# Epoch 161/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2872 - accuracy: 0.9030
# Epoch 161: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2880 - accuracy: 0.9022 - val_loss: 0.2720 - val_accuracy: 0.9137
# Epoch 162/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2717 - accuracy: 0.9089
# Epoch 162: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2713 - accuracy: 0.9091 - val_loss: 0.2584 - val_accuracy: 0.9137
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2668 - accuracy: 0.9069
# Epoch 163: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2658 - accuracy: 0.9078 - val_loss: 0.3414 - val_accuracy: 0.8813
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4150 - accuracy: 0.8258
# Epoch 164: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4141 - accuracy: 0.8250 - val_loss: 0.4351 - val_accuracy: 0.8350
# Epoch 165/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4830 - accuracy: 0.8219
# Epoch 165: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4817 - accuracy: 0.8247 - val_loss: 0.4063 - val_accuracy: 0.8988
# Epoch 166/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5201 - accuracy: 0.8272
# Epoch 166: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5201 - accuracy: 0.8272 - val_loss: 0.5819 - val_accuracy: 0.7800
# Epoch 167/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6339 - accuracy: 0.7399
# Epoch 167: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.6324 - accuracy: 0.7431 - val_loss: 0.5929 - val_accuracy: 0.7912
# Epoch 168/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6105 - accuracy: 0.7650
# Epoch 168: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.6105 - accuracy: 0.7650 - val_loss: 0.5743 - val_accuracy: 0.7950
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5807 - accuracy: 0.7812
# Epoch 169: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5794 - accuracy: 0.7822 - val_loss: 0.5046 - val_accuracy: 0.8350
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5208 - accuracy: 0.8145
# Epoch 170: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5201 - accuracy: 0.8147 - val_loss: 0.4623 - val_accuracy: 0.8413
# Epoch 171/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4945 - accuracy: 0.8200
# Epoch 171: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4915 - accuracy: 0.8203 - val_loss: 0.4250 - val_accuracy: 0.8475
# Epoch 172/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4615 - accuracy: 0.8219
# Epoch 172: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4602 - accuracy: 0.8238 - val_loss: 0.4090 - val_accuracy: 0.8575
# Epoch 173/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4433 - accuracy: 0.8252
# Epoch 173: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4421 - accuracy: 0.8256 - val_loss: 0.3977 - val_accuracy: 0.8525
# Epoch 174/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4289 - accuracy: 0.8275
# Epoch 174: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4289 - accuracy: 0.8275 - val_loss: 0.3769 - val_accuracy: 0.8575
# Epoch 175/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4071 - accuracy: 0.8353
# Epoch 175: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4074 - accuracy: 0.8350 - val_loss: 0.3618 - val_accuracy: 0.8612
# Epoch 176/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3967 - accuracy: 0.8356
# Epoch 176: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3959 - accuracy: 0.8350 - val_loss: 0.3656 - val_accuracy: 0.8525
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3926 - accuracy: 0.8294
# Epoch 177: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3918 - accuracy: 0.8288 - val_loss: 0.3711 - val_accuracy: 0.8462
# Epoch 178/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3861 - accuracy: 0.8313
# Epoch 178: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3861 - accuracy: 0.8313 - val_loss: 0.3545 - val_accuracy: 0.8537
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3777 - accuracy: 0.8320
# Epoch 179: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3767 - accuracy: 0.8331 - val_loss: 0.3410 - val_accuracy: 0.8612
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3646 - accuracy: 0.8389
# Epoch 180: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3625 - accuracy: 0.8403 - val_loss: 0.3529 - val_accuracy: 0.8525
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3713 - accuracy: 0.8330
# Epoch 181: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3685 - accuracy: 0.8353 - val_loss: 0.3361 - val_accuracy: 0.8600
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3793 - accuracy: 0.8311
# Epoch 182: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3767 - accuracy: 0.8331 - val_loss: 0.3610 - val_accuracy: 0.8400
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3861 - accuracy: 0.8249
# Epoch 183: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3871 - accuracy: 0.8256 - val_loss: 0.3345 - val_accuracy: 0.8587
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3791 - accuracy: 0.8288
# Epoch 184: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3793 - accuracy: 0.8291 - val_loss: 0.3563 - val_accuracy: 0.8550
# Epoch 185/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3905 - accuracy: 0.8262
# Epoch 185: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3920 - accuracy: 0.8247 - val_loss: 0.3458 - val_accuracy: 0.8537
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3702 - accuracy: 0.8298
# Epoch 186: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3693 - accuracy: 0.8294 - val_loss: 0.3278 - val_accuracy: 0.8587
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3576 - accuracy: 0.8379
# Epoch 187: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3559 - accuracy: 0.8397 - val_loss: 0.3275 - val_accuracy: 0.8625
# Epoch 188/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8338
# Epoch 188: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3643 - accuracy: 0.8338 - val_loss: 0.3235 - val_accuracy: 0.8575
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3478 - accuracy: 0.8424
# Epoch 189: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3461 - accuracy: 0.8428 - val_loss: 0.3202 - val_accuracy: 0.8600
# Epoch 190/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3519 - accuracy: 0.8406
# Epoch 190: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3519 - accuracy: 0.8406 - val_loss: 0.3150 - val_accuracy: 0.8587
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3488 - accuracy: 0.8415
# Epoch 191: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3458 - accuracy: 0.8431 - val_loss: 0.3137 - val_accuracy: 0.8625
# Epoch 192/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8425
# Epoch 192: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3412 - accuracy: 0.8425 - val_loss: 0.3155 - val_accuracy: 0.8612
# Epoch 193/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3362 - accuracy: 0.8444
# Epoch 193: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3389 - accuracy: 0.8422 - val_loss: 0.3151 - val_accuracy: 0.8600
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3587 - accuracy: 0.8359
# Epoch 194: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 63ms/step - loss: 0.3559 - accuracy: 0.8388 - val_loss: 0.3278 - val_accuracy: 0.8525
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3566 - accuracy: 0.8392
# Epoch 195: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3574 - accuracy: 0.8381 - val_loss: 0.3177 - val_accuracy: 0.8650
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3543 - accuracy: 0.8346
# Epoch 196: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3544 - accuracy: 0.8353 - val_loss: 0.3183 - val_accuracy: 0.8600
# Epoch 197/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3549 - accuracy: 0.8350
# Epoch 197: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3564 - accuracy: 0.8353 - val_loss: 0.3243 - val_accuracy: 0.8600
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3453 - accuracy: 0.8421
# Epoch 198: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3455 - accuracy: 0.8419 - val_loss: 0.3265 - val_accuracy: 0.8587
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3555 - accuracy: 0.8356
# Epoch 199: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3536 - accuracy: 0.8369 - val_loss: 0.3910 - val_accuracy: 0.8275
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4010 - accuracy: 0.8265
# Epoch 200: val_accuracy did not improve from 0.91625
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3993 - accuracy: 0.8275 - val_loss: 0.3540 - val_accuracy: 0.8550

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 96, 64)            12352
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 172,673
# Trainable params: 172,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.2830
# Accuracy: 91.6250%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	91.62%
# Sensitivity:	100.00%
# Specificity:	82.82%
# Precision:	85.95%
# F1-score:	92.45%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.97

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
