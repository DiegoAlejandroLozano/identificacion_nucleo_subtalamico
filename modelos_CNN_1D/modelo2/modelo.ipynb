# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import os

import tensorflow           as tf
import pandas               as pd
import seaborn              as sns
import matplotlib.pyplot    as plt

from keras.models       import Sequential, load_model
from keras.layers       import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers   import Adam
from keras.regularizers import l2
from keras.callbacks    import ModelCheckpoint

from sklearn.preprocessing      import StandardScaler
from sklearn.model_selection    import train_test_split
from sklearn.metrics            import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))

modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback])
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 3.2452 - accuracy: 0.5113
# Epoch 1: val_accuracy improved from -inf to 0.50375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 5s 128ms/step - loss: 3.2452 - accuracy: 0.5113 - val_loss: 1.8439 - val_accuracy: 0.5038
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.7687 - accuracy: 0.5186
# Epoch 2: val_accuracy improved from 0.50375 to 0.72875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 1.7641 - accuracy: 0.5166 - val_loss: 1.5829 - val_accuracy: 0.7287
# Epoch 3/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.4696 - accuracy: 0.6755
# Epoch 3: val_accuracy did not improve from 0.72875
# 7/7 [==============================] - 0s 56ms/step - loss: 1.4635 - accuracy: 0.6778 - val_loss: 1.2615 - val_accuracy: 0.7150
# Epoch 4/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.2101 - accuracy: 0.7087
# Epoch 4: val_accuracy improved from 0.72875 to 0.80500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 1.2051 - accuracy: 0.7094 - val_loss: 1.0452 - val_accuracy: 0.8050
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.0107 - accuracy: 0.7441
# Epoch 5: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 55ms/step - loss: 1.0073 - accuracy: 0.7437 - val_loss: 0.8672 - val_accuracy: 0.7738
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.8574 - accuracy: 0.7581
# Epoch 6: val_accuracy did not improve from 0.80500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.8550 - accuracy: 0.7578 - val_loss: 0.7440 - val_accuracy: 0.7550
# Epoch 7/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7531 - accuracy: 0.7760
# Epoch 7: val_accuracy improved from 0.80500 to 0.82625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.7511 - accuracy: 0.7772 - val_loss: 0.6483 - val_accuracy: 0.8263
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: 0.6858 - accuracy: 0.7847
# Epoch 8: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6858 - accuracy: 0.7847 - val_loss: 0.5944 - val_accuracy: 0.8213
# Epoch 9/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6405 - accuracy: 0.7799
# Epoch 9: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.6394 - accuracy: 0.7803 - val_loss: 0.5784 - val_accuracy: 0.8075
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5969 - accuracy: 0.7897
# Epoch 10: val_accuracy did not improve from 0.82625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5960 - accuracy: 0.7900 - val_loss: 0.5082 - val_accuracy: 0.8062
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5549 - accuracy: 0.8031
# Epoch 11: val_accuracy improved from 0.82625 to 0.84250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.5553 - accuracy: 0.8009 - val_loss: 0.4830 - val_accuracy: 0.8425
# Epoch 12/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5343 - accuracy: 0.8070
# Epoch 12: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5339 - accuracy: 0.8069 - val_loss: 0.5208 - val_accuracy: 0.7937
# Epoch 13/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5345 - accuracy: 0.7903
# Epoch 13: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5345 - accuracy: 0.7903 - val_loss: 0.5257 - val_accuracy: 0.7912
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5241 - accuracy: 0.7975
# Epoch 14: val_accuracy did not improve from 0.84250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5241 - accuracy: 0.7975 - val_loss: 0.4883 - val_accuracy: 0.8062
# Epoch 15/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5138 - accuracy: 0.8062
# Epoch 15: val_accuracy improved from 0.84250 to 0.85500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5138 - accuracy: 0.8062 - val_loss: 0.4397 - val_accuracy: 0.8550
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8194
# Epoch 16: val_accuracy did not improve from 0.85500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4931 - accuracy: 0.8194 - val_loss: 0.4458 - val_accuracy: 0.8225
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4855 - accuracy: 0.8092
# Epoch 17: val_accuracy did not improve from 0.85500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4868 - accuracy: 0.8091 - val_loss: 0.4205 - val_accuracy: 0.8363
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4718 - accuracy: 0.8281
# Epoch 18: val_accuracy improved from 0.85500 to 0.85750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4718 - accuracy: 0.8281 - val_loss: 0.4076 - val_accuracy: 0.8575
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8316
# Epoch 19: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4457 - accuracy: 0.8316 - val_loss: 0.4544 - val_accuracy: 0.8175
# Epoch 20/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5315 - accuracy: 0.7756
# Epoch 20: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.5315 - accuracy: 0.7756 - val_loss: 0.4994 - val_accuracy: 0.8062
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5076 - accuracy: 0.8021
# Epoch 21: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.5056 - accuracy: 0.8012 - val_loss: 0.4691 - val_accuracy: 0.7987
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8037
# Epoch 22: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4876 - accuracy: 0.8037 - val_loss: 0.4384 - val_accuracy: 0.8425
# Epoch 23/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4839 - accuracy: 0.8105
# Epoch 23: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4873 - accuracy: 0.8081 - val_loss: 0.4304 - val_accuracy: 0.8550
# Epoch 24/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.7994
# Epoch 24: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4929 - accuracy: 0.7994 - val_loss: 0.4935 - val_accuracy: 0.7825
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4834 - accuracy: 0.8097
# Epoch 25: val_accuracy did not improve from 0.85750
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4834 - accuracy: 0.8097 - val_loss: 0.4108 - val_accuracy: 0.8575
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4404 - accuracy: 0.8229
# Epoch 26: val_accuracy improved from 0.85750 to 0.86500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4417 - accuracy: 0.8197 - val_loss: 0.3947 - val_accuracy: 0.8650
# Epoch 27/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.8291
# Epoch 27: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4318 - accuracy: 0.8291 - val_loss: 0.4900 - val_accuracy: 0.7588
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.8253
# Epoch 28: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4470 - accuracy: 0.8253 - val_loss: 0.4502 - val_accuracy: 0.8087
# Epoch 29/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4762 - accuracy: 0.8078
# Epoch 29: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4762 - accuracy: 0.8078 - val_loss: 0.4704 - val_accuracy: 0.8062
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4464 - accuracy: 0.8249
# Epoch 30: val_accuracy did not improve from 0.86500
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4475 - accuracy: 0.8238 - val_loss: 0.4260 - val_accuracy: 0.8225
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8306
# Epoch 31: val_accuracy improved from 0.86500 to 0.87125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4326 - accuracy: 0.8306 - val_loss: 0.3898 - val_accuracy: 0.8712
# Epoch 32/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4194 - accuracy: 0.8382
# Epoch 32: val_accuracy did not improve from 0.87125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4179 - accuracy: 0.8391 - val_loss: 0.3907 - val_accuracy: 0.8375
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3998 - accuracy: 0.8398
# Epoch 33: val_accuracy improved from 0.87125 to 0.88125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4020 - accuracy: 0.8388 - val_loss: 0.3721 - val_accuracy: 0.8813
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4054 - accuracy: 0.8459
# Epoch 34: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4054 - accuracy: 0.8459 - val_loss: 0.4781 - val_accuracy: 0.8188
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4275 - accuracy: 0.8369
# Epoch 35: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4299 - accuracy: 0.8381 - val_loss: 0.3953 - val_accuracy: 0.8537
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8381
# Epoch 36: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4136 - accuracy: 0.8381 - val_loss: 0.4425 - val_accuracy: 0.7912
# Epoch 37/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8434
# Epoch 37: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4148 - accuracy: 0.8434 - val_loss: 0.4117 - val_accuracy: 0.8313
# Epoch 38/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4607 - accuracy: 0.8298
# Epoch 38: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4581 - accuracy: 0.8316 - val_loss: 0.3934 - val_accuracy: 0.8363
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.8188
# Epoch 39: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4347 - accuracy: 0.8188 - val_loss: 0.4127 - val_accuracy: 0.8213
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4173 - accuracy: 0.8253
# Epoch 40: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4173 - accuracy: 0.8253 - val_loss: 0.3827 - val_accuracy: 0.8288
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4071 - accuracy: 0.8231
# Epoch 41: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4071 - accuracy: 0.8231 - val_loss: 0.4815 - val_accuracy: 0.7738
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4390 - accuracy: 0.8167
# Epoch 42: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4397 - accuracy: 0.8172 - val_loss: 0.3962 - val_accuracy: 0.8213
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3997 - accuracy: 0.8281
# Epoch 43: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3990 - accuracy: 0.8275 - val_loss: 0.3711 - val_accuracy: 0.8188
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.8278
# Epoch 44: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3808 - accuracy: 0.8278 - val_loss: 0.3686 - val_accuracy: 0.8250
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3837 - accuracy: 0.8304
# Epoch 45: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3825 - accuracy: 0.8300 - val_loss: 0.4605 - val_accuracy: 0.7912
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4176 - accuracy: 0.8156
# Epoch 46: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4176 - accuracy: 0.8156 - val_loss: 0.3713 - val_accuracy: 0.8388
# Epoch 47/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3783 - accuracy: 0.8272
# Epoch 47: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3783 - accuracy: 0.8272 - val_loss: 0.3773 - val_accuracy: 0.8375
# Epoch 48/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3787 - accuracy: 0.8285
# Epoch 48: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3783 - accuracy: 0.8294 - val_loss: 0.3575 - val_accuracy: 0.8537
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3601 - accuracy: 0.8324
# Epoch 49: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3641 - accuracy: 0.8306 - val_loss: 0.4000 - val_accuracy: 0.8275
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3723 - accuracy: 0.8301
# Epoch 50: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3721 - accuracy: 0.8319 - val_loss: 0.3581 - val_accuracy: 0.8400
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8256
# Epoch 51: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3852 - accuracy: 0.8256 - val_loss: 0.3808 - val_accuracy: 0.8350
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3741 - accuracy: 0.8298
# Epoch 52: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3754 - accuracy: 0.8278 - val_loss: 0.3548 - val_accuracy: 0.8425
# Epoch 53/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3910 - accuracy: 0.8244
# Epoch 53: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3910 - accuracy: 0.8244 - val_loss: 0.3830 - val_accuracy: 0.8413
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.8247
# Epoch 54: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3808 - accuracy: 0.8247 - val_loss: 0.3880 - val_accuracy: 0.8300
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3936 - accuracy: 0.8249
# Epoch 55: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3959 - accuracy: 0.8241 - val_loss: 0.6018 - val_accuracy: 0.6988
# Epoch 56/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4473 - accuracy: 0.7912
# Epoch 56: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4473 - accuracy: 0.7912 - val_loss: 0.4108 - val_accuracy: 0.8288
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3843 - accuracy: 0.8269
# Epoch 57: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3843 - accuracy: 0.8269 - val_loss: 0.3693 - val_accuracy: 0.8275
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3864 - accuracy: 0.8141
# Epoch 58: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3847 - accuracy: 0.8166 - val_loss: 0.3779 - val_accuracy: 0.8175
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3704 - accuracy: 0.8304
# Epoch 59: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3698 - accuracy: 0.8309 - val_loss: 0.3635 - val_accuracy: 0.8325
# Epoch 60/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3663 - accuracy: 0.8278
# Epoch 60: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3653 - accuracy: 0.8291 - val_loss: 0.3522 - val_accuracy: 0.8338
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3651 - accuracy: 0.8327
# Epoch 61: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3645 - accuracy: 0.8331 - val_loss: 0.3460 - val_accuracy: 0.8350
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8347
# Epoch 62: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3502 - accuracy: 0.8347 - val_loss: 0.3414 - val_accuracy: 0.8338
# Epoch 63/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3455 - accuracy: 0.8356
# Epoch 63: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3455 - accuracy: 0.8356 - val_loss: 0.3357 - val_accuracy: 0.8288
# Epoch 64/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3428 - accuracy: 0.8346
# Epoch 64: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3442 - accuracy: 0.8341 - val_loss: 0.3669 - val_accuracy: 0.8425
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3715 - accuracy: 0.8236
# Epoch 65: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3684 - accuracy: 0.8269 - val_loss: 0.3507 - val_accuracy: 0.8313
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8300
# Epoch 66: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3475 - accuracy: 0.8300 - val_loss: 0.3390 - val_accuracy: 0.8213
# Epoch 67/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.8378
# Epoch 67: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3422 - accuracy: 0.8378 - val_loss: 0.3301 - val_accuracy: 0.8275
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3415 - accuracy: 0.8363
# Epoch 68: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3415 - accuracy: 0.8363 - val_loss: 0.3543 - val_accuracy: 0.8213
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3447 - accuracy: 0.8395
# Epoch 69: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3445 - accuracy: 0.8406 - val_loss: 0.3814 - val_accuracy: 0.8125
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3607 - accuracy: 0.8262
# Epoch 70: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3626 - accuracy: 0.8256 - val_loss: 0.4509 - val_accuracy: 0.7862
# Epoch 71/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4006 - accuracy: 0.8128
# Epoch 71: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4016 - accuracy: 0.8138 - val_loss: 0.3517 - val_accuracy: 0.8100
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3608 - accuracy: 0.8294
# Epoch 72: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3583 - accuracy: 0.8309 - val_loss: 0.3398 - val_accuracy: 0.8350
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8438
# Epoch 73: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3475 - accuracy: 0.8438 - val_loss: 0.3307 - val_accuracy: 0.8313
# Epoch 74/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8381
# Epoch 74: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3355 - accuracy: 0.8381 - val_loss: 0.3328 - val_accuracy: 0.8338
# Epoch 75/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3408 - accuracy: 0.8391
# Epoch 75: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3408 - accuracy: 0.8391 - val_loss: 0.3255 - val_accuracy: 0.8275
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3295 - accuracy: 0.8470
# Epoch 76: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3287 - accuracy: 0.8475 - val_loss: 0.3378 - val_accuracy: 0.8413
# Epoch 77/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3503 - accuracy: 0.8319
# Epoch 77: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3503 - accuracy: 0.8319 - val_loss: 0.3380 - val_accuracy: 0.8338
# Epoch 78/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3426 - accuracy: 0.8406
# Epoch 78: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3426 - accuracy: 0.8406 - val_loss: 0.3352 - val_accuracy: 0.8100
# Epoch 79/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.8363
# Epoch 79: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3309 - accuracy: 0.8363 - val_loss: 0.3250 - val_accuracy: 0.8325
# Epoch 80/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3369 - accuracy: 0.8363
# Epoch 80: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3361 - accuracy: 0.8372 - val_loss: 0.3447 - val_accuracy: 0.8050
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3439 - accuracy: 0.8372
# Epoch 81: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3461 - accuracy: 0.8359 - val_loss: 0.4271 - val_accuracy: 0.7962
# Epoch 82/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3827 - accuracy: 0.8135
# Epoch 82: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3806 - accuracy: 0.8156 - val_loss: 0.4013 - val_accuracy: 0.7937
# Epoch 83/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8153
# Epoch 83: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3923 - accuracy: 0.8153 - val_loss: 0.3415 - val_accuracy: 0.8325
# Epoch 84/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3515 - accuracy: 0.8409
# Epoch 84: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3515 - accuracy: 0.8409 - val_loss: 0.3344 - val_accuracy: 0.8250
# Epoch 85/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.8334
# Epoch 85: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3531 - accuracy: 0.8334 - val_loss: 0.3366 - val_accuracy: 0.8275
# Epoch 86/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3465 - accuracy: 0.8278
# Epoch 86: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3448 - accuracy: 0.8297 - val_loss: 0.3616 - val_accuracy: 0.8213
# Epoch 87/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3406 - accuracy: 0.8337
# Epoch 87: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3412 - accuracy: 0.8338 - val_loss: 0.3352 - val_accuracy: 0.8150
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3542 - accuracy: 0.8346
# Epoch 88: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3510 - accuracy: 0.8338 - val_loss: 0.3584 - val_accuracy: 0.8163
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3474 - accuracy: 0.8389
# Epoch 89: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3506 - accuracy: 0.8366 - val_loss: 0.3573 - val_accuracy: 0.8388
# Epoch 90/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3471 - accuracy: 0.8389
# Epoch 90: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3480 - accuracy: 0.8372 - val_loss: 0.3251 - val_accuracy: 0.8425
# Epoch 91/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3436 - accuracy: 0.8330
# Epoch 91: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3459 - accuracy: 0.8325 - val_loss: 0.5383 - val_accuracy: 0.7487
# Epoch 92/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.8028
# Epoch 92: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4282 - accuracy: 0.8028 - val_loss: 0.3865 - val_accuracy: 0.8200
# Epoch 93/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4022 - accuracy: 0.8175
# Epoch 93: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 54ms/step - loss: 0.4022 - accuracy: 0.8175 - val_loss: 0.3888 - val_accuracy: 0.8275
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3684 - accuracy: 0.8385
# Epoch 94: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3699 - accuracy: 0.8375 - val_loss: 0.3859 - val_accuracy: 0.8525
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3614 - accuracy: 0.8438
# Epoch 95: val_accuracy did not improve from 0.88125
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3609 - accuracy: 0.8462 - val_loss: 0.3353 - val_accuracy: 0.8388
# Epoch 96/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8484
# Epoch 96: val_accuracy improved from 0.88125 to 0.89750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3446 - accuracy: 0.8484 - val_loss: 0.3283 - val_accuracy: 0.8975
# Epoch 97/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3282 - accuracy: 0.8606
# Epoch 97: val_accuracy improved from 0.89750 to 0.92250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3282 - accuracy: 0.8606 - val_loss: 0.2963 - val_accuracy: 0.9225
# Epoch 98/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8822
# Epoch 98: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3217 - accuracy: 0.8822 - val_loss: 0.2862 - val_accuracy: 0.8950
# Epoch 99/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.8900
# Epoch 99: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3124 - accuracy: 0.8900 - val_loss: 0.2969 - val_accuracy: 0.9100
# Epoch 100/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8503
# Epoch 100: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3388 - accuracy: 0.8503 - val_loss: 0.3385 - val_accuracy: 0.8487
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3372 - accuracy: 0.8483
# Epoch 101: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3386 - accuracy: 0.8466 - val_loss: 0.3529 - val_accuracy: 0.8263
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3433 - accuracy: 0.8509
# Epoch 102: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3418 - accuracy: 0.8522 - val_loss: 0.3304 - val_accuracy: 0.8500
# Epoch 103/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8594
# Epoch 103: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3289 - accuracy: 0.8594 - val_loss: 0.3146 - val_accuracy: 0.8913
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3266 - accuracy: 0.8630
# Epoch 104: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3252 - accuracy: 0.8631 - val_loss: 0.2815 - val_accuracy: 0.8800
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2948 - accuracy: 0.8841
# Epoch 105: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2942 - accuracy: 0.8831 - val_loss: 0.3583 - val_accuracy: 0.8650
# Epoch 106/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8737
# Epoch 106: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3470 - accuracy: 0.8737 - val_loss: 0.4108 - val_accuracy: 0.8700
# Epoch 107/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4736 - accuracy: 0.8265
# Epoch 107: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4724 - accuracy: 0.8263 - val_loss: 0.4893 - val_accuracy: 0.8325
# Epoch 108/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4323 - accuracy: 0.8616
# Epoch 108: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4323 - accuracy: 0.8616 - val_loss: 0.3779 - val_accuracy: 0.8950
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4265 - accuracy: 0.8320
# Epoch 109: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4246 - accuracy: 0.8341 - val_loss: 0.4030 - val_accuracy: 0.8313
# Epoch 110/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4086 - accuracy: 0.8300
# Epoch 110: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.4086 - accuracy: 0.8300 - val_loss: 0.3729 - val_accuracy: 0.8512
# Epoch 111/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.8381
# Epoch 111: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3827 - accuracy: 0.8381 - val_loss: 0.3568 - val_accuracy: 0.8462
# Epoch 112/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8391
# Epoch 112: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3641 - accuracy: 0.8391 - val_loss: 0.3434 - val_accuracy: 0.8562
# Epoch 113/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3587 - accuracy: 0.8363
# Epoch 113: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3587 - accuracy: 0.8363 - val_loss: 0.3351 - val_accuracy: 0.8537
# Epoch 114/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.8422
# Epoch 114: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3467 - accuracy: 0.8422 - val_loss: 0.3444 - val_accuracy: 0.8413
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3563 - accuracy: 0.8363
# Epoch 115: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3568 - accuracy: 0.8353 - val_loss: 0.3308 - val_accuracy: 0.8725
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3549 - accuracy: 0.8460
# Epoch 116: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3549 - accuracy: 0.8447 - val_loss: 0.3624 - val_accuracy: 0.8375
# Epoch 117/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3605 - accuracy: 0.8384
# Epoch 117: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3605 - accuracy: 0.8384 - val_loss: 0.3555 - val_accuracy: 0.8250
# Epoch 118/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3578 - accuracy: 0.8444
# Epoch 118: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3578 - accuracy: 0.8444 - val_loss: 0.3522 - val_accuracy: 0.8413
# Epoch 119/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3498 - accuracy: 0.8555
# Epoch 119: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3479 - accuracy: 0.8566 - val_loss: 0.3085 - val_accuracy: 0.8988
# Epoch 120/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3509 - accuracy: 0.8641
# Epoch 120: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3509 - accuracy: 0.8641 - val_loss: 0.2965 - val_accuracy: 0.8888
# Epoch 121/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3194 - accuracy: 0.8841
# Epoch 121: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3194 - accuracy: 0.8841 - val_loss: 0.3116 - val_accuracy: 0.8950
# Epoch 122/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3112 - accuracy: 0.8923
# Epoch 122: val_accuracy did not improve from 0.92250
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3095 - accuracy: 0.8928 - val_loss: 0.2782 - val_accuracy: 0.9175
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2965 - accuracy: 0.9059
# Epoch 123: val_accuracy improved from 0.92250 to 0.92625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2964 - accuracy: 0.9056 - val_loss: 0.2685 - val_accuracy: 0.9262
# Epoch 124/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.9038
# Epoch 124: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2890 - accuracy: 0.9038 - val_loss: 0.2780 - val_accuracy: 0.9150
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3010 - accuracy: 0.8991
# Epoch 125: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2993 - accuracy: 0.8991 - val_loss: 0.3050 - val_accuracy: 0.9137
# Epoch 126/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.8916
# Epoch 126: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3251 - accuracy: 0.8916 - val_loss: 0.2883 - val_accuracy: 0.9150
# Epoch 127/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3222 - accuracy: 0.8926
# Epoch 127: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3224 - accuracy: 0.8928 - val_loss: 0.3012 - val_accuracy: 0.8813
# Epoch 128/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3700 - accuracy: 0.8509
# Epoch 128: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3685 - accuracy: 0.8506 - val_loss: 0.3442 - val_accuracy: 0.8500
# Epoch 129/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8384
# Epoch 129: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3559 - accuracy: 0.8384 - val_loss: 0.3403 - val_accuracy: 0.8525
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3470 - accuracy: 0.8512
# Epoch 130: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3465 - accuracy: 0.8516 - val_loss: 0.3313 - val_accuracy: 0.8450
# Epoch 131/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8566
# Epoch 131: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3367 - accuracy: 0.8566 - val_loss: 0.2962 - val_accuracy: 0.9200
# Epoch 132/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3166 - accuracy: 0.8859
# Epoch 132: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3166 - accuracy: 0.8859 - val_loss: 0.2932 - val_accuracy: 0.9212
# Epoch 133/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.8747
# Epoch 133: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3029 - accuracy: 0.8747 - val_loss: 0.2737 - val_accuracy: 0.9187
# Epoch 134/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.9000
# Epoch 134: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2995 - accuracy: 0.9000 - val_loss: 0.2648 - val_accuracy: 0.9250
# Epoch 135/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2985 - accuracy: 0.9004
# Epoch 135: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2965 - accuracy: 0.9016 - val_loss: 0.2946 - val_accuracy: 0.9062
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2910 - accuracy: 0.9036
# Epoch 136: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2930 - accuracy: 0.9016 - val_loss: 0.2668 - val_accuracy: 0.9175
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2939 - accuracy: 0.9017
# Epoch 137: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2921 - accuracy: 0.9022 - val_loss: 0.2878 - val_accuracy: 0.9087
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2898 - accuracy: 0.9014
# Epoch 138: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2875 - accuracy: 0.9025 - val_loss: 0.3105 - val_accuracy: 0.8975
# Epoch 139/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8916
# Epoch 139: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3022 - accuracy: 0.8916 - val_loss: 0.2805 - val_accuracy: 0.9100
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2871 - accuracy: 0.9036
# Epoch 140: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2864 - accuracy: 0.9038 - val_loss: 0.2659 - val_accuracy: 0.9212
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2910 - accuracy: 0.9001
# Epoch 141: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2917 - accuracy: 0.8994 - val_loss: 0.2620 - val_accuracy: 0.9212
# Epoch 142/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.9062
# Epoch 142: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2768 - accuracy: 0.9062 - val_loss: 0.2647 - val_accuracy: 0.9175
# Epoch 143/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2732 - accuracy: 0.9069
# Epoch 143: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2737 - accuracy: 0.9066 - val_loss: 0.2489 - val_accuracy: 0.9250
# Epoch 144/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9069
# Epoch 144: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2745 - accuracy: 0.9069 - val_loss: 0.2532 - val_accuracy: 0.9187
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2874 - accuracy: 0.8981
# Epoch 145: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2846 - accuracy: 0.8991 - val_loss: 0.2506 - val_accuracy: 0.9250
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.9084
# Epoch 146: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2705 - accuracy: 0.9084 - val_loss: 0.2785 - val_accuracy: 0.9075
# Epoch 147/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2667 - accuracy: 0.9115
# Epoch 147: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2668 - accuracy: 0.9109 - val_loss: 0.2606 - val_accuracy: 0.9187
# Epoch 148/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2737 - accuracy: 0.9040
# Epoch 148: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2719 - accuracy: 0.9044 - val_loss: 0.2755 - val_accuracy: 0.9062
# Epoch 149/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2898 - accuracy: 0.9010
# Epoch 149: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2933 - accuracy: 0.8988 - val_loss: 0.2617 - val_accuracy: 0.9175
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2896 - accuracy: 0.8984
# Epoch 150: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2908 - accuracy: 0.8981 - val_loss: 0.4138 - val_accuracy: 0.8562
# Epoch 151/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8703
# Epoch 151: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3744 - accuracy: 0.8703 - val_loss: 0.3334 - val_accuracy: 0.9025
# Epoch 152/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.8556
# Epoch 152: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3514 - accuracy: 0.8556 - val_loss: 0.3686 - val_accuracy: 0.8375
# Epoch 153/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8300
# Epoch 153: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3826 - accuracy: 0.8300 - val_loss: 0.4074 - val_accuracy: 0.8325
# Epoch 154/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4008 - accuracy: 0.8294
# Epoch 154: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4008 - accuracy: 0.8294 - val_loss: 0.3423 - val_accuracy: 0.8487
# Epoch 155/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8534
# Epoch 155: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3575 - accuracy: 0.8534 - val_loss: 0.3633 - val_accuracy: 0.8363
# Epoch 156/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8438
# Epoch 156: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3465 - accuracy: 0.8438 - val_loss: 0.3153 - val_accuracy: 0.8863
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3028 - accuracy: 0.8887
# Epoch 157: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3036 - accuracy: 0.8891 - val_loss: 0.2678 - val_accuracy: 0.9237
# Epoch 158/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.9050
# Epoch 158: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2899 - accuracy: 0.9050 - val_loss: 0.2682 - val_accuracy: 0.9212
# Epoch 159/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9069
# Epoch 159: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2842 - accuracy: 0.9069 - val_loss: 0.2598 - val_accuracy: 0.9187
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2873 - accuracy: 0.9043
# Epoch 160: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2873 - accuracy: 0.9044 - val_loss: 0.2808 - val_accuracy: 0.9175
# Epoch 161/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.9075
# Epoch 161: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2757 - accuracy: 0.9075 - val_loss: 0.3019 - val_accuracy: 0.9000
# Epoch 162/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2978 - accuracy: 0.8978
# Epoch 162: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2953 - accuracy: 0.8988 - val_loss: 0.3353 - val_accuracy: 0.8825
# Epoch 163/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3045 - accuracy: 0.8945
# Epoch 163: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3025 - accuracy: 0.8950 - val_loss: 0.2905 - val_accuracy: 0.9100
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2932 - accuracy: 0.8978
# Epoch 164: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2924 - accuracy: 0.8984 - val_loss: 0.2698 - val_accuracy: 0.9125
# Epoch 165/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8972
# Epoch 165: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2944 - accuracy: 0.8972 - val_loss: 0.2769 - val_accuracy: 0.9150
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2746 - accuracy: 0.9066
# Epoch 166: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2753 - accuracy: 0.9056 - val_loss: 0.2562 - val_accuracy: 0.9162
# Epoch 167/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.9075
# Epoch 167: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2696 - accuracy: 0.9075 - val_loss: 0.2635 - val_accuracy: 0.9187
# Epoch 168/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2759 - accuracy: 0.9066
# Epoch 168: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2759 - accuracy: 0.9066 - val_loss: 0.2466 - val_accuracy: 0.9225
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2739 - accuracy: 0.9036
# Epoch 169: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2740 - accuracy: 0.9038 - val_loss: 0.2786 - val_accuracy: 0.9112
# Epoch 170/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2813 - accuracy: 0.9020
# Epoch 170: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2810 - accuracy: 0.9016 - val_loss: 0.2558 - val_accuracy: 0.9225
# Epoch 171/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9041
# Epoch 171: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2745 - accuracy: 0.9041 - val_loss: 0.2490 - val_accuracy: 0.9200
# Epoch 172/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.9053
# Epoch 172: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2659 - accuracy: 0.9053 - val_loss: 0.2439 - val_accuracy: 0.9225
# Epoch 173/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.9103
# Epoch 173: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2604 - accuracy: 0.9103 - val_loss: 0.2510 - val_accuracy: 0.9225
# Epoch 174/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2576 - accuracy: 0.9092
# Epoch 174: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2613 - accuracy: 0.9075 - val_loss: 0.2495 - val_accuracy: 0.9212
# Epoch 175/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.9091
# Epoch 175: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2653 - accuracy: 0.9091 - val_loss: 0.2529 - val_accuracy: 0.9175
# Epoch 176/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2671 - accuracy: 0.9053
# Epoch 176: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2675 - accuracy: 0.9047 - val_loss: 0.2568 - val_accuracy: 0.9212
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2647 - accuracy: 0.9085
# Epoch 177: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2636 - accuracy: 0.9094 - val_loss: 0.2446 - val_accuracy: 0.9225
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2622 - accuracy: 0.9095
# Epoch 178: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2616 - accuracy: 0.9091 - val_loss: 0.2578 - val_accuracy: 0.9175
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2579 - accuracy: 0.9115
# Epoch 179: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2570 - accuracy: 0.9119 - val_loss: 0.2406 - val_accuracy: 0.9250
# Epoch 180/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9091
# Epoch 180: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2585 - accuracy: 0.9091 - val_loss: 0.2486 - val_accuracy: 0.9200
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2648 - accuracy: 0.9059
# Epoch 181: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2665 - accuracy: 0.9050 - val_loss: 0.2422 - val_accuracy: 0.9250
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2566 - accuracy: 0.9076
# Epoch 182: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2569 - accuracy: 0.9075 - val_loss: 0.2364 - val_accuracy: 0.9225
# Epoch 183/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2674 - accuracy: 0.9027
# Epoch 183: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2681 - accuracy: 0.9013 - val_loss: 0.2395 - val_accuracy: 0.9237
# Epoch 184/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2576 - accuracy: 0.9102
# Epoch 184: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2571 - accuracy: 0.9112 - val_loss: 0.2424 - val_accuracy: 0.9225
# Epoch 185/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.9062
# Epoch 185: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2696 - accuracy: 0.9062 - val_loss: 0.2387 - val_accuracy: 0.9237
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2553 - accuracy: 0.9092
# Epoch 186: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2540 - accuracy: 0.9103 - val_loss: 0.2507 - val_accuracy: 0.9212
# Epoch 187/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.9050
# Epoch 187: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2716 - accuracy: 0.9050 - val_loss: 0.2388 - val_accuracy: 0.9250
# Epoch 188/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9050
# Epoch 188: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2572 - accuracy: 0.9050 - val_loss: 0.2623 - val_accuracy: 0.9162
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2838 - accuracy: 0.8994
# Epoch 189: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2824 - accuracy: 0.9006 - val_loss: 0.3175 - val_accuracy: 0.8888
# Epoch 190/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2998 - accuracy: 0.8931
# Epoch 190: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2998 - accuracy: 0.8931 - val_loss: 0.2539 - val_accuracy: 0.9175
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2681 - accuracy: 0.9098
# Epoch 191: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2715 - accuracy: 0.9084 - val_loss: 0.2635 - val_accuracy: 0.9175
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3367 - accuracy: 0.8770
# Epoch 192: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3352 - accuracy: 0.8778 - val_loss: 0.2656 - val_accuracy: 0.9212
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.9000
# Epoch 193: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2951 - accuracy: 0.9000 - val_loss: 0.2803 - val_accuracy: 0.9087
# Epoch 194/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.9034
# Epoch 194: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2885 - accuracy: 0.9034 - val_loss: 0.2694 - val_accuracy: 0.9200
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3057 - accuracy: 0.8949
# Epoch 195: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.3050 - accuracy: 0.8950 - val_loss: 0.2938 - val_accuracy: 0.8950
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2858 - accuracy: 0.9049
# Epoch 196: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2836 - accuracy: 0.9056 - val_loss: 0.2646 - val_accuracy: 0.9200
# Epoch 197/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9047
# Epoch 197: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2852 - accuracy: 0.9047 - val_loss: 0.2542 - val_accuracy: 0.9187
# Epoch 198/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2595 - accuracy: 0.9092
# Epoch 198: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2606 - accuracy: 0.9081 - val_loss: 0.2489 - val_accuracy: 0.9212
# Epoch 199/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2640 - accuracy: 0.9102
# Epoch 199: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2628 - accuracy: 0.9097 - val_loss: 0.2438 - val_accuracy: 0.9237
# Epoch 200/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.9047
# Epoch 200: val_accuracy did not improve from 0.92625
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2782 - accuracy: 0.9047 - val_loss: 0.2553 - val_accuracy: 0.9200

# %% [markdown]
# Resumen del modelo

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2498, 64)          256
#
#  max_pooling1d (MaxPooling1D  (None, 499, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 497, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 98, 64)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 96, 64)            12352
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 172,673
# Trainable params: 172,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    # Obteniendo el nombre de la imagen para la gráfica de entrenamiento
    cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
    name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
    plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))
# Out:
# Loss: 0.2685
# Accuracy: 92.6250%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	92.62%
# Sensitivity:	98.26%
# Specificity:	86.90%
# Precision:	88.39%
# F1-score:	93.07%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.97

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
