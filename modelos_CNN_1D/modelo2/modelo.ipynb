# %% [markdown]
# ## **Parte 1:** Importanción de librerías

# %% [markdown]
# Importando las librerías necesarias

# %%
import tensorflow as tf
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from keras.models import Sequential, load_model
from keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# Configurar TensorFlow para usar la GPU
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## **Parte 2:** Cargando los datos

# %%
df = pd.read_csv("../../BD_procesada/BD_procesada.csv", sep=";")
df.head()
# Out:
#    muestra 1  muestra 2  muestra 3  muestra 4  muestra 5  muestra 6  \
# 0        -54        -14       -102       -286       -384       -379
# 1       -142       -242       -218       -144       -150       -214
# 2          2          7         15         27         47         45
# 3        135        -96         -6       -100         10        -68
# 4        -68        -91         67        119         83        128
#
#    muestra 7  muestra 8  muestra 9  muestra 10  ...  muestra 2492  \
# 0       -358       -340       -244        -144  ...            45
# 1       -145         33        226         315  ...            61
# 2         -9        -75        -94         -71  ...          -108
# 3       -138       -335       -373        -199  ...           116
# 4        -55         22       -139         -69  ...           -18
#
#    muestra 2493  muestra 2494  muestra 2495  muestra 2496  muestra 2497  \
# 0           100            58            31             1           -25
# 1           -59          -125           -86            70           162
# 2           -81           -86           -27           -24           -11
# 3           111           279           282           333           138
# 4            17           157           255           322           467
#
#    muestra 2498  muestra 2499  muestra 2500  estructura
# 0            15             0            -4           1
# 1           234           189           151           1
# 2            -2            47            38           0
# 3           -17           -14          -200           0
# 4           188           298           199           0
#
# [5 rows x 2501 columns]

# %% [markdown]
# ## **Parte 3:** transformando los datos

# %% [markdown]
# Diviendo el conjunto en entranimiento y prueba

# %%
X = df.drop(columns=['estructura'], axis=1)
y = df['estructura']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

print("Dimensiones X_train: {}".format(X_train.shape))
print("Dimensiones X_val: {}".format(X_val.shape))
print("Dimensiones y_train: {}".format(y_train.shape))
print("Dimensiones y_val: {}".format(y_val.shape))
# Out:
# Dimensiones X_train: (3200, 2500)
# Dimensiones X_val: (800, 2500)
# Dimensiones y_train: (3200,)
# Dimensiones y_val: (800,)

# %% [markdown]
# Estandarizar los datos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Forma X_train_scaled: {}".format(X_train_scaled.shape))
print("Forma X_val_scaled: {}".format(X_val_scaled.shape))
# Out:
# Forma X_train_scaled: (3200, 2500)
# Forma X_val_scaled: (800, 2500)

# %% [markdown]
# Reshape de los datos para que tengan la forma adecuada para la convolución (número de registros, longitud de los registros, número de características)

# %%
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_val_reshaped = X_val_scaled.reshape(X_val_scaled.shape[0], X_val_scaled.shape[1], 1)

print("Forma X_train_reshaped: {}".format(X_train_reshaped.shape))
print("Forma X_val_reshaped: {}".format(X_val_reshaped.shape))
# Out:
# Forma X_train_reshaped: (3200, 2500, 1)
# Forma X_val_reshaped: (800, 2500, 1)

# %% [markdown]
# ## **Parte 4:** Modelo

# %% [markdown]
# Creación del modelo

# %%
modelo = Sequential()

#Estructura del modelo
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))
modelo.add(Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(MaxPool1D(pool_size=8, strides=5))

modelo.add(Flatten())

modelo.add(Dense(128, activation='relu', kernel_regularizer=l2(l2=0.01)))
modelo.add(Dropout(0.5))
modelo.add(Dense(1, activation='sigmoid'))

#Compilación del modelo
modelo.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=["accuracy"])

#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

history = modelo.fit(
    X_train_reshaped, 
    y_train, 
    epochs=200, 
    batch_size=512, 
    validation_data=(X_val_reshaped, y_val), 
    callbacks=[checkpoint_callback])
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: 2.5157 - accuracy: 0.5294
# Epoch 1: val_accuracy improved from -inf to 0.47875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 4s 140ms/step - loss: 2.5157 - accuracy: 0.5294 - val_loss: 1.2708 - val_accuracy: 0.4787
# Epoch 2/200
# 6/7 [========================>.....] - ETA: 0s - loss: 1.1981 - accuracy: 0.6338
# Epoch 2: val_accuracy improved from 0.47875 to 0.68375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 68ms/step - loss: 1.1937 - accuracy: 0.6372 - val_loss: 1.0518 - val_accuracy: 0.6837
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: 0.9580 - accuracy: 0.7138
# Epoch 3: val_accuracy improved from 0.68375 to 0.72250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 63ms/step - loss: 0.9580 - accuracy: 0.7138 - val_loss: 0.8245 - val_accuracy: 0.7225
# Epoch 4/200
# 7/7 [==============================] - ETA: 0s - loss: 0.7813 - accuracy: 0.7387
# Epoch 4: val_accuracy improved from 0.72250 to 0.82375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7813 - accuracy: 0.7387 - val_loss: 0.6863 - val_accuracy: 0.8238
# Epoch 5/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6582 - accuracy: 0.7816
# Epoch 5: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 61ms/step - loss: 0.6633 - accuracy: 0.7788 - val_loss: 0.5980 - val_accuracy: 0.8163
# Epoch 6/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.6521 - accuracy: 0.7493
# Epoch 6: val_accuracy did not improve from 0.82375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.6506 - accuracy: 0.7506 - val_loss: 0.5835 - val_accuracy: 0.7638
# Epoch 7/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5894 - accuracy: 0.7837
# Epoch 7: val_accuracy improved from 0.82375 to 0.83000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.5894 - accuracy: 0.7837 - val_loss: 0.5199 - val_accuracy: 0.8300
# Epoch 8/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5425 - accuracy: 0.8076
# Epoch 8: val_accuracy did not improve from 0.83000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5426 - accuracy: 0.8066 - val_loss: 0.5152 - val_accuracy: 0.7987
# Epoch 9/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5200 - accuracy: 0.8134
# Epoch 9: val_accuracy did not improve from 0.83000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5200 - accuracy: 0.8134 - val_loss: 0.4875 - val_accuracy: 0.8263
# Epoch 10/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5119 - accuracy: 0.8200
# Epoch 10: val_accuracy improved from 0.83000 to 0.83875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 70ms/step - loss: 0.5135 - accuracy: 0.8188 - val_loss: 0.4706 - val_accuracy: 0.8388
# Epoch 11/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5175 - accuracy: 0.8125
# Epoch 11: val_accuracy improved from 0.83875 to 0.84500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.5210 - accuracy: 0.8106 - val_loss: 0.4680 - val_accuracy: 0.8450
# Epoch 12/200
# 7/7 [==============================] - ETA: 0s - loss: 0.5164 - accuracy: 0.8181
# Epoch 12: val_accuracy did not improve from 0.84500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5164 - accuracy: 0.8181 - val_loss: 0.4768 - val_accuracy: 0.8400
# Epoch 13/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5026 - accuracy: 0.8291
# Epoch 13: val_accuracy did not improve from 0.84500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5023 - accuracy: 0.8291 - val_loss: 0.4797 - val_accuracy: 0.8400
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.8313
# Epoch 14: val_accuracy improved from 0.84500 to 0.85375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 60ms/step - loss: 0.4905 - accuracy: 0.8313 - val_loss: 0.4409 - val_accuracy: 0.8537
# Epoch 15/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4576 - accuracy: 0.8496
# Epoch 15: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4592 - accuracy: 0.8478 - val_loss: 0.4664 - val_accuracy: 0.8462
# Epoch 16/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4683 - accuracy: 0.8369
# Epoch 16: val_accuracy did not improve from 0.85375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4687 - accuracy: 0.8363 - val_loss: 0.5342 - val_accuracy: 0.7900
# Epoch 17/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5139 - accuracy: 0.8125
# Epoch 17: val_accuracy improved from 0.85375 to 0.85500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.5112 - accuracy: 0.8134 - val_loss: 0.4288 - val_accuracy: 0.8550
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.8434
# Epoch 18: val_accuracy improved from 0.85500 to 0.86375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4600 - accuracy: 0.8434 - val_loss: 0.4378 - val_accuracy: 0.8637
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4550 - accuracy: 0.8394
# Epoch 19: val_accuracy did not improve from 0.86375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4550 - accuracy: 0.8394 - val_loss: 0.4878 - val_accuracy: 0.8138
# Epoch 20/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4800 - accuracy: 0.8262
# Epoch 20: val_accuracy improved from 0.86375 to 0.86750, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4810 - accuracy: 0.8269 - val_loss: 0.4077 - val_accuracy: 0.8675
# Epoch 21/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4578 - accuracy: 0.8483
# Epoch 21: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4581 - accuracy: 0.8472 - val_loss: 0.4104 - val_accuracy: 0.8637
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4589 - accuracy: 0.8438
# Epoch 22: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4589 - accuracy: 0.8438 - val_loss: 0.4335 - val_accuracy: 0.8612
# Epoch 23/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4594 - accuracy: 0.8470
# Epoch 23: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4599 - accuracy: 0.8466 - val_loss: 0.4226 - val_accuracy: 0.8462
# Epoch 24/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4435 - accuracy: 0.8460
# Epoch 24: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 57ms/step - loss: 0.4426 - accuracy: 0.8459 - val_loss: 0.4266 - val_accuracy: 0.8537
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8506
# Epoch 25: val_accuracy did not improve from 0.86750
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4334 - accuracy: 0.8506 - val_loss: 0.3934 - val_accuracy: 0.8612
# Epoch 26/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4128 - accuracy: 0.8691
# Epoch 26: val_accuracy improved from 0.86750 to 0.87250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4138 - accuracy: 0.8684 - val_loss: 0.3803 - val_accuracy: 0.8725
# Epoch 27/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3976 - accuracy: 0.8750
# Epoch 27: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3992 - accuracy: 0.8737 - val_loss: 0.5791 - val_accuracy: 0.7713
# Epoch 28/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.5002 - accuracy: 0.8047
# Epoch 28: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4960 - accuracy: 0.8069 - val_loss: 0.4381 - val_accuracy: 0.8637
# Epoch 29/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4471 - accuracy: 0.8532
# Epoch 29: val_accuracy did not improve from 0.87250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4431 - accuracy: 0.8537 - val_loss: 0.4155 - val_accuracy: 0.8675
# Epoch 30/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4320 - accuracy: 0.8587
# Epoch 30: val_accuracy improved from 0.87250 to 0.88125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4350 - accuracy: 0.8547 - val_loss: 0.3943 - val_accuracy: 0.8813
# Epoch 31/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4295 - accuracy: 0.8535
# Epoch 31: val_accuracy improved from 0.88125 to 0.88500, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4317 - accuracy: 0.8519 - val_loss: 0.3799 - val_accuracy: 0.8850
# Epoch 32/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4258 - accuracy: 0.8571
# Epoch 32: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4273 - accuracy: 0.8562 - val_loss: 0.5197 - val_accuracy: 0.7825
# Epoch 33/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4723 - accuracy: 0.8275
# Epoch 33: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4719 - accuracy: 0.8291 - val_loss: 0.3846 - val_accuracy: 0.8800
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4398 - accuracy: 0.8597
# Epoch 34: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4398 - accuracy: 0.8597 - val_loss: 0.3867 - val_accuracy: 0.8825
# Epoch 35/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4410 - accuracy: 0.8587
# Epoch 35: val_accuracy did not improve from 0.88500
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4397 - accuracy: 0.8597 - val_loss: 0.3864 - val_accuracy: 0.8612
# Epoch 36/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4037 - accuracy: 0.8630
# Epoch 36: val_accuracy improved from 0.88500 to 0.88625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4008 - accuracy: 0.8650 - val_loss: 0.3687 - val_accuracy: 0.8863
# Epoch 37/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8725
# Epoch 37: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3856 - accuracy: 0.8725 - val_loss: 0.3684 - val_accuracy: 0.8737
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3906 - accuracy: 0.8728
# Epoch 38: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 53ms/step - loss: 0.3906 - accuracy: 0.8728 - val_loss: 0.3688 - val_accuracy: 0.8750
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8725
# Epoch 39: val_accuracy did not improve from 0.88625
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3892 - accuracy: 0.8725 - val_loss: 0.3518 - val_accuracy: 0.8863
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8666
# Epoch 40: val_accuracy improved from 0.88625 to 0.89125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3905 - accuracy: 0.8666 - val_loss: 0.3571 - val_accuracy: 0.8913
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3709 - accuracy: 0.8766
# Epoch 41: val_accuracy improved from 0.89125 to 0.89250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3709 - accuracy: 0.8766 - val_loss: 0.3495 - val_accuracy: 0.8925
# Epoch 42/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3567 - accuracy: 0.8900
# Epoch 42: val_accuracy improved from 0.89250 to 0.89625, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3550 - accuracy: 0.8906 - val_loss: 0.3351 - val_accuracy: 0.8963
# Epoch 43/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3593 - accuracy: 0.8883
# Epoch 43: val_accuracy improved from 0.89625 to 0.90000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3575 - accuracy: 0.8891 - val_loss: 0.3260 - val_accuracy: 0.9000
# Epoch 44/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3978 - accuracy: 0.8604
# Epoch 44: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3996 - accuracy: 0.8591 - val_loss: 0.3413 - val_accuracy: 0.8938
# Epoch 45/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4113 - accuracy: 0.8516
# Epoch 45: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4114 - accuracy: 0.8531 - val_loss: 0.3544 - val_accuracy: 0.8913
# Epoch 46/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4020 - accuracy: 0.8636
# Epoch 46: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 53ms/step - loss: 0.4026 - accuracy: 0.8628 - val_loss: 0.3606 - val_accuracy: 0.8850
# Epoch 47/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3867 - accuracy: 0.8730
# Epoch 47: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3846 - accuracy: 0.8750 - val_loss: 0.3451 - val_accuracy: 0.8963
# Epoch 48/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3694 - accuracy: 0.8875
# Epoch 48: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3694 - accuracy: 0.8875 - val_loss: 0.3760 - val_accuracy: 0.8512
# Epoch 49/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3623 - accuracy: 0.8773
# Epoch 49: val_accuracy did not improve from 0.90000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3604 - accuracy: 0.8791 - val_loss: 0.3340 - val_accuracy: 0.9000
# Epoch 50/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3500 - accuracy: 0.8900
# Epoch 50: val_accuracy improved from 0.90000 to 0.90375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 1s 78ms/step - loss: 0.3490 - accuracy: 0.8903 - val_loss: 0.3170 - val_accuracy: 0.9038
# Epoch 51/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3334 - accuracy: 0.8962
# Epoch 51: val_accuracy did not improve from 0.90375
# 7/7 [==============================] - 1s 78ms/step - loss: 0.3326 - accuracy: 0.8966 - val_loss: 0.3203 - val_accuracy: 0.9000
# Epoch 52/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3367 - accuracy: 0.8916
# Epoch 52: val_accuracy did not improve from 0.90375
# 7/7 [==============================] - 0s 69ms/step - loss: 0.3380 - accuracy: 0.8909 - val_loss: 0.3939 - val_accuracy: 0.8650
# Epoch 53/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3577 - accuracy: 0.8851
# Epoch 53: val_accuracy did not improve from 0.90375
# 7/7 [==============================] - 0s 66ms/step - loss: 0.3550 - accuracy: 0.8869 - val_loss: 0.3273 - val_accuracy: 0.8988
# Epoch 54/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3555 - accuracy: 0.8841
# Epoch 54: val_accuracy did not improve from 0.90375
# 7/7 [==============================] - 0s 60ms/step - loss: 0.3534 - accuracy: 0.8841 - val_loss: 0.3076 - val_accuracy: 0.8988
# Epoch 55/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3250 - accuracy: 0.8962
# Epoch 55: val_accuracy did not improve from 0.90375
# 7/7 [==============================] - 0s 67ms/step - loss: 0.3243 - accuracy: 0.8959 - val_loss: 0.3334 - val_accuracy: 0.8850
# Epoch 56/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3261 - accuracy: 0.8978
# Epoch 56: val_accuracy improved from 0.90375 to 0.90875, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 71ms/step - loss: 0.3271 - accuracy: 0.8975 - val_loss: 0.3042 - val_accuracy: 0.9087
# Epoch 57/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3146 - accuracy: 0.9014
# Epoch 57: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3171 - accuracy: 0.9003 - val_loss: 0.3662 - val_accuracy: 0.8712
# Epoch 58/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3841 - accuracy: 0.8633
# Epoch 58: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3808 - accuracy: 0.8656 - val_loss: 0.4750 - val_accuracy: 0.8250
# Epoch 59/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4531 - accuracy: 0.8320
# Epoch 59: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4561 - accuracy: 0.8294 - val_loss: 0.4280 - val_accuracy: 0.8138
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.8150
# Epoch 60: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4495 - accuracy: 0.8150 - val_loss: 0.4245 - val_accuracy: 0.8350
# Epoch 61/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4220 - accuracy: 0.8444
# Epoch 61: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4239 - accuracy: 0.8447 - val_loss: 0.3571 - val_accuracy: 0.8875
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3562 - accuracy: 0.8956
# Epoch 62: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3562 - accuracy: 0.8956 - val_loss: 0.3255 - val_accuracy: 0.9050
# Epoch 63/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3478 - accuracy: 0.8952
# Epoch 63: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3457 - accuracy: 0.8969 - val_loss: 0.3188 - val_accuracy: 0.9025
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8969
# Epoch 64: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3295 - accuracy: 0.8969 - val_loss: 0.3563 - val_accuracy: 0.8900
# Epoch 65/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3421 - accuracy: 0.8945
# Epoch 65: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3454 - accuracy: 0.8947 - val_loss: 0.3443 - val_accuracy: 0.8850
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3276 - accuracy: 0.8872
# Epoch 66: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3276 - accuracy: 0.8872 - val_loss: 0.4058 - val_accuracy: 0.8525
# Epoch 67/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3853 - accuracy: 0.8737
# Epoch 67: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3896 - accuracy: 0.8706 - val_loss: 0.3201 - val_accuracy: 0.9025
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8906
# Epoch 68: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3488 - accuracy: 0.8906 - val_loss: 0.3145 - val_accuracy: 0.9000
# Epoch 69/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3155 - accuracy: 0.9027
# Epoch 69: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3151 - accuracy: 0.9028 - val_loss: 0.3061 - val_accuracy: 0.9025
# Epoch 70/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3094 - accuracy: 0.9049
# Epoch 70: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3072 - accuracy: 0.9062 - val_loss: 0.2977 - val_accuracy: 0.8988
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.9044
# Epoch 71: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3099 - accuracy: 0.9044 - val_loss: 0.3809 - val_accuracy: 0.8500
# Epoch 72/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3492 - accuracy: 0.8835
# Epoch 72: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3475 - accuracy: 0.8850 - val_loss: 0.3499 - val_accuracy: 0.8875
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.8944
# Epoch 73: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3333 - accuracy: 0.8944 - val_loss: 0.3165 - val_accuracy: 0.8763
# Epoch 74/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8913
# Epoch 74: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3386 - accuracy: 0.8913 - val_loss: 0.3003 - val_accuracy: 0.9038
# Epoch 75/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3220 - accuracy: 0.8932
# Epoch 75: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3239 - accuracy: 0.8931 - val_loss: 0.2958 - val_accuracy: 0.9050
# Epoch 76/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3205 - accuracy: 0.8962
# Epoch 76: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3202 - accuracy: 0.8963 - val_loss: 0.2932 - val_accuracy: 0.9038
# Epoch 77/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3005 - accuracy: 0.9040
# Epoch 77: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2999 - accuracy: 0.9044 - val_loss: 0.2974 - val_accuracy: 0.8988
# Epoch 78/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3082 - accuracy: 0.8997
# Epoch 78: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 62ms/step - loss: 0.3062 - accuracy: 0.9016 - val_loss: 0.2951 - val_accuracy: 0.9025
# Epoch 79/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3112 - accuracy: 0.8988
# Epoch 79: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3085 - accuracy: 0.9006 - val_loss: 0.2985 - val_accuracy: 0.9025
# Epoch 80/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.9006
# Epoch 80: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3102 - accuracy: 0.9006 - val_loss: 0.3126 - val_accuracy: 0.9000
# Epoch 81/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3038 - accuracy: 0.8991
# Epoch 81: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3033 - accuracy: 0.8991 - val_loss: 0.3353 - val_accuracy: 0.8800
# Epoch 82/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.9056
# Epoch 82: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2962 - accuracy: 0.9056 - val_loss: 0.2769 - val_accuracy: 0.9075
# Epoch 83/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.9044
# Epoch 83: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2885 - accuracy: 0.9044 - val_loss: 0.2803 - val_accuracy: 0.9013
# Epoch 84/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2907 - accuracy: 0.9023
# Epoch 84: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2917 - accuracy: 0.9025 - val_loss: 0.2945 - val_accuracy: 0.9013
# Epoch 85/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2901 - accuracy: 0.9056
# Epoch 85: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2910 - accuracy: 0.9047 - val_loss: 0.3207 - val_accuracy: 0.8938
# Epoch 86/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8956
# Epoch 86: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3156 - accuracy: 0.8956 - val_loss: 0.3322 - val_accuracy: 0.8913
# Epoch 87/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8981
# Epoch 87: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3099 - accuracy: 0.8981 - val_loss: 0.3022 - val_accuracy: 0.9038
# Epoch 88/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3020 - accuracy: 0.9036
# Epoch 88: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3019 - accuracy: 0.9041 - val_loss: 0.2984 - val_accuracy: 0.9025
# Epoch 89/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2966 - accuracy: 0.9014
# Epoch 89: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2979 - accuracy: 0.9003 - val_loss: 0.3203 - val_accuracy: 0.8963
# Epoch 90/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8841
# Epoch 90: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 57ms/step - loss: 0.3358 - accuracy: 0.8841 - val_loss: 0.3146 - val_accuracy: 0.9000
# Epoch 91/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.8947
# Epoch 91: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3224 - accuracy: 0.8947 - val_loss: 0.3073 - val_accuracy: 0.8988
# Epoch 92/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3055 - accuracy: 0.9010
# Epoch 92: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3038 - accuracy: 0.9009 - val_loss: 0.2928 - val_accuracy: 0.9025
# Epoch 93/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.9038
# Epoch 93: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2952 - accuracy: 0.9038 - val_loss: 0.2820 - val_accuracy: 0.9087
# Epoch 94/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2979 - accuracy: 0.9027
# Epoch 94: val_accuracy did not improve from 0.90875
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2974 - accuracy: 0.9031 - val_loss: 0.3007 - val_accuracy: 0.9025
# Epoch 95/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2953 - accuracy: 0.9023
# Epoch 95: val_accuracy improved from 0.90875 to 0.91000, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 67ms/step - loss: 0.2987 - accuracy: 0.9003 - val_loss: 0.2767 - val_accuracy: 0.9100
# Epoch 96/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2813 - accuracy: 0.9098
# Epoch 96: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2835 - accuracy: 0.9084 - val_loss: 0.3025 - val_accuracy: 0.8950
# Epoch 97/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2952 - accuracy: 0.8994
# Epoch 97: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2942 - accuracy: 0.9009 - val_loss: 0.2744 - val_accuracy: 0.9062
# Epoch 98/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.8994
# Epoch 98: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2995 - accuracy: 0.8994 - val_loss: 0.2886 - val_accuracy: 0.9062
# Epoch 99/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3154 - accuracy: 0.8906
# Epoch 99: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3174 - accuracy: 0.8894 - val_loss: 0.2901 - val_accuracy: 0.9025
# Epoch 100/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.9009
# Epoch 100: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2973 - accuracy: 0.9009 - val_loss: 0.2870 - val_accuracy: 0.9075
# Epoch 101/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2871 - accuracy: 0.9062
# Epoch 101: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2876 - accuracy: 0.9059 - val_loss: 0.2892 - val_accuracy: 0.9038
# Epoch 102/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2842 - accuracy: 0.9089
# Epoch 102: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2847 - accuracy: 0.9087 - val_loss: 0.2730 - val_accuracy: 0.9050
# Epoch 103/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2753 - accuracy: 0.9092
# Epoch 103: val_accuracy did not improve from 0.91000
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2772 - accuracy: 0.9084 - val_loss: 0.2654 - val_accuracy: 0.9062
# Epoch 104/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2778 - accuracy: 0.9036
# Epoch 104: val_accuracy improved from 0.91000 to 0.91125, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 62ms/step - loss: 0.2767 - accuracy: 0.9041 - val_loss: 0.2613 - val_accuracy: 0.9112
# Epoch 105/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2809 - accuracy: 0.9043
# Epoch 105: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2795 - accuracy: 0.9047 - val_loss: 0.2955 - val_accuracy: 0.8988
# Epoch 106/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2942 - accuracy: 0.9020
# Epoch 106: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2925 - accuracy: 0.9022 - val_loss: 0.2743 - val_accuracy: 0.9062
# Epoch 107/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.9075
# Epoch 107: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2814 - accuracy: 0.9075 - val_loss: 0.2773 - val_accuracy: 0.9112
# Epoch 108/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2736 - accuracy: 0.9040
# Epoch 108: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2757 - accuracy: 0.9038 - val_loss: 0.2611 - val_accuracy: 0.9100
# Epoch 109/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2793 - accuracy: 0.9059
# Epoch 109: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2794 - accuracy: 0.9062 - val_loss: 0.2811 - val_accuracy: 0.9025
# Epoch 110/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.9013
# Epoch 110: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2879 - accuracy: 0.9013 - val_loss: 0.2599 - val_accuracy: 0.9087
# Epoch 111/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2783 - accuracy: 0.9036
# Epoch 111: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2788 - accuracy: 0.9034 - val_loss: 0.3545 - val_accuracy: 0.8788
# Epoch 112/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3260 - accuracy: 0.8880
# Epoch 112: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3303 - accuracy: 0.8856 - val_loss: 0.3475 - val_accuracy: 0.8850
# Epoch 113/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3571 - accuracy: 0.8809
# Epoch 113: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3567 - accuracy: 0.8809 - val_loss: 0.3250 - val_accuracy: 0.8950
# Epoch 114/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.8984
# Epoch 114: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3120 - accuracy: 0.8984 - val_loss: 0.3089 - val_accuracy: 0.9000
# Epoch 115/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3228 - accuracy: 0.8919
# Epoch 115: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3228 - accuracy: 0.8922 - val_loss: 0.3121 - val_accuracy: 0.8888
# Epoch 116/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3158 - accuracy: 0.8939
# Epoch 116: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3182 - accuracy: 0.8944 - val_loss: 0.2940 - val_accuracy: 0.9087
# Epoch 117/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2988 - accuracy: 0.9033
# Epoch 117: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2976 - accuracy: 0.9034 - val_loss: 0.2709 - val_accuracy: 0.9062
# Epoch 118/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2844 - accuracy: 0.9056
# Epoch 118: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2824 - accuracy: 0.9069 - val_loss: 0.2881 - val_accuracy: 0.9025
# Epoch 119/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.9062
# Epoch 119: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2873 - accuracy: 0.9062 - val_loss: 0.3079 - val_accuracy: 0.8950
# Epoch 120/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.9059
# Epoch 120: val_accuracy did not improve from 0.91125
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2805 - accuracy: 0.9059 - val_loss: 0.2633 - val_accuracy: 0.9100
# Epoch 121/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2696 - accuracy: 0.9108
# Epoch 121: val_accuracy improved from 0.91125 to 0.91250, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 61ms/step - loss: 0.2702 - accuracy: 0.9100 - val_loss: 0.2594 - val_accuracy: 0.9125
# Epoch 122/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9119
# Epoch 122: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2663 - accuracy: 0.9119 - val_loss: 0.2548 - val_accuracy: 0.9100
# Epoch 123/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2636 - accuracy: 0.9082
# Epoch 123: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2675 - accuracy: 0.9062 - val_loss: 0.3079 - val_accuracy: 0.8913
# Epoch 124/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8900
# Epoch 124: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3189 - accuracy: 0.8900 - val_loss: 0.4238 - val_accuracy: 0.8087
# Epoch 125/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.4106 - accuracy: 0.8174
# Epoch 125: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4139 - accuracy: 0.8156 - val_loss: 0.3786 - val_accuracy: 0.8350
# Epoch 126/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4183 - accuracy: 0.8225
# Epoch 126: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4183 - accuracy: 0.8225 - val_loss: 0.4267 - val_accuracy: 0.8338
# Epoch 127/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4407 - accuracy: 0.8263
# Epoch 127: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4407 - accuracy: 0.8263 - val_loss: 0.4010 - val_accuracy: 0.8462
# Epoch 128/200
# 7/7 [==============================] - ETA: 0s - loss: 0.4071 - accuracy: 0.8381
# Epoch 128: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.4071 - accuracy: 0.8381 - val_loss: 0.3798 - val_accuracy: 0.8462
# Epoch 129/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3833 - accuracy: 0.8398
# Epoch 129: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3818 - accuracy: 0.8406 - val_loss: 0.3513 - val_accuracy: 0.8487
# Epoch 130/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3628 - accuracy: 0.8415
# Epoch 130: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3626 - accuracy: 0.8416 - val_loss: 0.3467 - val_accuracy: 0.8487
# Epoch 131/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3604 - accuracy: 0.8392
# Epoch 131: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3587 - accuracy: 0.8416 - val_loss: 0.3398 - val_accuracy: 0.8438
# Epoch 132/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3818 - accuracy: 0.8271
# Epoch 132: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 61ms/step - loss: 0.3826 - accuracy: 0.8272 - val_loss: 0.3645 - val_accuracy: 0.8462
# Epoch 133/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3603 - accuracy: 0.8372
# Epoch 133: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3603 - accuracy: 0.8378 - val_loss: 0.3217 - val_accuracy: 0.8625
# Epoch 134/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3412 - accuracy: 0.8438
# Epoch 134: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3398 - accuracy: 0.8456 - val_loss: 0.3379 - val_accuracy: 0.8462
# Epoch 135/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3344 - accuracy: 0.8478
# Epoch 135: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3344 - accuracy: 0.8478 - val_loss: 0.2937 - val_accuracy: 0.9050
# Epoch 136/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3072 - accuracy: 0.8874
# Epoch 136: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3050 - accuracy: 0.8897 - val_loss: 0.2727 - val_accuracy: 0.9125
# Epoch 137/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2903 - accuracy: 0.9098
# Epoch 137: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2927 - accuracy: 0.9081 - val_loss: 0.2838 - val_accuracy: 0.9100
# Epoch 138/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2970 - accuracy: 0.9062
# Epoch 138: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2972 - accuracy: 0.9062 - val_loss: 0.2923 - val_accuracy: 0.9038
# Epoch 139/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.9034
# Epoch 139: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3032 - accuracy: 0.9034 - val_loss: 0.2780 - val_accuracy: 0.9062
# Epoch 140/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3009 - accuracy: 0.9033
# Epoch 140: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2989 - accuracy: 0.9041 - val_loss: 0.3049 - val_accuracy: 0.9013
# Epoch 141/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2839 - accuracy: 0.9108
# Epoch 141: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2838 - accuracy: 0.9103 - val_loss: 0.2856 - val_accuracy: 0.9000
# Epoch 142/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9094
# Epoch 142: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2781 - accuracy: 0.9094 - val_loss: 0.2592 - val_accuracy: 0.9075
# Epoch 143/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.9075
# Epoch 143: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2684 - accuracy: 0.9075 - val_loss: 0.2647 - val_accuracy: 0.9100
# Epoch 144/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.9072
# Epoch 144: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2701 - accuracy: 0.9072 - val_loss: 0.2707 - val_accuracy: 0.9013
# Epoch 145/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2766 - accuracy: 0.9056
# Epoch 145: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2752 - accuracy: 0.9059 - val_loss: 0.2698 - val_accuracy: 0.9050
# Epoch 146/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9112
# Epoch 146: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2623 - accuracy: 0.9112 - val_loss: 0.3037 - val_accuracy: 0.8900
# Epoch 147/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.9072
# Epoch 147: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2799 - accuracy: 0.9072 - val_loss: 0.2604 - val_accuracy: 0.9038
# Epoch 148/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.9056
# Epoch 148: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2754 - accuracy: 0.9056 - val_loss: 0.2590 - val_accuracy: 0.9112
# Epoch 149/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.9003
# Epoch 149: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2921 - accuracy: 0.9003 - val_loss: 0.2596 - val_accuracy: 0.9100
# Epoch 150/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2609 - accuracy: 0.9128
# Epoch 150: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2608 - accuracy: 0.9131 - val_loss: 0.2812 - val_accuracy: 0.9000
# Epoch 151/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2802 - accuracy: 0.9023
# Epoch 151: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2834 - accuracy: 0.9013 - val_loss: 0.2644 - val_accuracy: 0.9100
# Epoch 152/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2610 - accuracy: 0.9128
# Epoch 152: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2597 - accuracy: 0.9128 - val_loss: 0.2582 - val_accuracy: 0.9100
# Epoch 153/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.9013
# Epoch 153: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2814 - accuracy: 0.9013 - val_loss: 0.3657 - val_accuracy: 0.8725
# Epoch 154/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3274 - accuracy: 0.8818
# Epoch 154: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.3268 - accuracy: 0.8828 - val_loss: 0.3045 - val_accuracy: 0.8913
# Epoch 155/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3027 - accuracy: 0.8991
# Epoch 155: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3016 - accuracy: 0.8997 - val_loss: 0.2690 - val_accuracy: 0.9075
# Epoch 156/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2815 - accuracy: 0.9069
# Epoch 156: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2821 - accuracy: 0.9069 - val_loss: 0.3043 - val_accuracy: 0.8963
# Epoch 157/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2953 - accuracy: 0.8955
# Epoch 157: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2922 - accuracy: 0.8972 - val_loss: 0.2841 - val_accuracy: 0.9038
# Epoch 158/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2847 - accuracy: 0.9017
# Epoch 158: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2832 - accuracy: 0.9025 - val_loss: 0.2678 - val_accuracy: 0.9038
# Epoch 159/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2703 - accuracy: 0.9092
# Epoch 159: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2706 - accuracy: 0.9094 - val_loss: 0.2659 - val_accuracy: 0.9087
# Epoch 160/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2661 - accuracy: 0.9092
# Epoch 160: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2676 - accuracy: 0.9091 - val_loss: 0.2580 - val_accuracy: 0.9025
# Epoch 161/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.9081
# Epoch 161: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2683 - accuracy: 0.9081 - val_loss: 0.2674 - val_accuracy: 0.8988
# Epoch 162/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9041
# Epoch 162: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2748 - accuracy: 0.9041 - val_loss: 0.3002 - val_accuracy: 0.8913
# Epoch 163/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9094
# Epoch 163: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2646 - accuracy: 0.9094 - val_loss: 0.2575 - val_accuracy: 0.9112
# Epoch 164/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2640 - accuracy: 0.9092
# Epoch 164: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2635 - accuracy: 0.9103 - val_loss: 0.2642 - val_accuracy: 0.9075
# Epoch 165/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2572 - accuracy: 0.9147
# Epoch 165: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2605 - accuracy: 0.9122 - val_loss: 0.2490 - val_accuracy: 0.9075
# Epoch 166/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2562 - accuracy: 0.9118
# Epoch 166: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2586 - accuracy: 0.9106 - val_loss: 0.2426 - val_accuracy: 0.9125
# Epoch 167/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2702 - accuracy: 0.9046
# Epoch 167: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2742 - accuracy: 0.9034 - val_loss: 0.4272 - val_accuracy: 0.8413
# Epoch 168/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3862 - accuracy: 0.8525
# Epoch 168: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3858 - accuracy: 0.8544 - val_loss: 0.3167 - val_accuracy: 0.8888
# Epoch 169/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.3362 - accuracy: 0.8773
# Epoch 169: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3360 - accuracy: 0.8775 - val_loss: 0.3087 - val_accuracy: 0.9000
# Epoch 170/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8944
# Epoch 170: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.3217 - accuracy: 0.8944 - val_loss: 0.3018 - val_accuracy: 0.9013
# Epoch 171/200
# 7/7 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9059
# Epoch 171: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3019 - accuracy: 0.9059 - val_loss: 0.2830 - val_accuracy: 0.9050
# Epoch 172/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2866 - accuracy: 0.9105
# Epoch 172: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 60ms/step - loss: 0.2866 - accuracy: 0.9100 - val_loss: 0.2757 - val_accuracy: 0.9100
# Epoch 173/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9078
# Epoch 173: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2762 - accuracy: 0.9078 - val_loss: 0.2581 - val_accuracy: 0.9075
# Epoch 174/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9097
# Epoch 174: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2666 - accuracy: 0.9097 - val_loss: 0.2791 - val_accuracy: 0.9038
# Epoch 175/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2683 - accuracy: 0.9092
# Epoch 175: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2665 - accuracy: 0.9100 - val_loss: 0.2581 - val_accuracy: 0.9050
# Epoch 176/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.9109
# Epoch 176: val_accuracy did not improve from 0.91250
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2626 - accuracy: 0.9109 - val_loss: 0.2554 - val_accuracy: 0.9112
# Epoch 177/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2530 - accuracy: 0.9150
# Epoch 177: val_accuracy improved from 0.91250 to 0.91375, saving model to modelo_generado\mejor_modelo.keras
# 7/7 [==============================] - 0s 64ms/step - loss: 0.2550 - accuracy: 0.9141 - val_loss: 0.2525 - val_accuracy: 0.9137
# Epoch 178/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2519 - accuracy: 0.9147
# Epoch 178: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2523 - accuracy: 0.9137 - val_loss: 0.2476 - val_accuracy: 0.9075
# Epoch 179/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2580 - accuracy: 0.9121
# Epoch 179: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2585 - accuracy: 0.9116 - val_loss: 0.2606 - val_accuracy: 0.9050
# Epoch 180/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2630 - accuracy: 0.9076
# Epoch 180: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2623 - accuracy: 0.9078 - val_loss: 0.2650 - val_accuracy: 0.9062
# Epoch 181/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2592 - accuracy: 0.9089
# Epoch 181: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2591 - accuracy: 0.9094 - val_loss: 0.2484 - val_accuracy: 0.9050
# Epoch 182/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2647 - accuracy: 0.9062
# Epoch 182: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2627 - accuracy: 0.9078 - val_loss: 0.2656 - val_accuracy: 0.9025
# Epoch 183/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.9075
# Epoch 183: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2637 - accuracy: 0.9075 - val_loss: 0.2490 - val_accuracy: 0.9100
# Epoch 184/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2560 - accuracy: 0.9125
# Epoch 184: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2560 - accuracy: 0.9125 - val_loss: 0.2478 - val_accuracy: 0.9100
# Epoch 185/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.9134
# Epoch 185: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 57ms/step - loss: 0.2486 - accuracy: 0.9134 - val_loss: 0.2503 - val_accuracy: 0.9112
# Epoch 186/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2505 - accuracy: 0.9105
# Epoch 186: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2516 - accuracy: 0.9116 - val_loss: 0.2571 - val_accuracy: 0.9075
# Epoch 187/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2502 - accuracy: 0.9167
# Epoch 187: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2504 - accuracy: 0.9159 - val_loss: 0.2511 - val_accuracy: 0.9112
# Epoch 188/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2504 - accuracy: 0.9108
# Epoch 188: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2502 - accuracy: 0.9116 - val_loss: 0.2474 - val_accuracy: 0.9125
# Epoch 189/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2397 - accuracy: 0.9170
# Epoch 189: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2419 - accuracy: 0.9166 - val_loss: 0.2454 - val_accuracy: 0.9125
# Epoch 190/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2454 - accuracy: 0.9157
# Epoch 190: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2464 - accuracy: 0.9153 - val_loss: 0.2638 - val_accuracy: 0.9000
# Epoch 191/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2888 - accuracy: 0.8965
# Epoch 191: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2913 - accuracy: 0.8950 - val_loss: 0.2554 - val_accuracy: 0.9050
# Epoch 192/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2887 - accuracy: 0.8991
# Epoch 192: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2913 - accuracy: 0.8972 - val_loss: 0.2610 - val_accuracy: 0.9100
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9022
# Epoch 193: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2832 - accuracy: 0.9022 - val_loss: 0.2726 - val_accuracy: 0.9087
# Epoch 194/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2729 - accuracy: 0.9049
# Epoch 194: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2698 - accuracy: 0.9069 - val_loss: 0.2524 - val_accuracy: 0.9062
# Epoch 195/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2572 - accuracy: 0.9108
# Epoch 195: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2567 - accuracy: 0.9116 - val_loss: 0.2551 - val_accuracy: 0.9137
# Epoch 196/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2448 - accuracy: 0.9160
# Epoch 196: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2458 - accuracy: 0.9144 - val_loss: 0.2492 - val_accuracy: 0.9050
# Epoch 197/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9100
# Epoch 197: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2520 - accuracy: 0.9100 - val_loss: 0.2493 - val_accuracy: 0.9125
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9137
# Epoch 198: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2512 - accuracy: 0.9137 - val_loss: 0.2733 - val_accuracy: 0.9038
# Epoch 199/200
# 7/7 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.9031
# Epoch 199: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 58ms/step - loss: 0.2655 - accuracy: 0.9031 - val_loss: 0.3174 - val_accuracy: 0.8850
# Epoch 200/200
# 6/7 [========================>.....] - ETA: 0s - loss: 0.2641 - accuracy: 0.9079
# Epoch 200: val_accuracy did not improve from 0.91375
# 7/7 [==============================] - 0s 56ms/step - loss: 0.2634 - accuracy: 0.9087 - val_loss: 0.3052 - val_accuracy: 0.8938

# %% [markdown]
# Registros del entrenamiento

# %%
# Mostrar la historia de entrenamiento en diagramas
def plot_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Accuracy
    axs[0].plot(history.history['accuracy'], label='train_accuracy')
    axs[0].plot(history.history['val_accuracy'], label='val_accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    axs[0].grid()
    axs[0].legend()

    # Pérdida
    axs[1].plot(history.history['loss'], label='train_loss')
    axs[1].plot(history.history['val_loss'], label='val_loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    axs[1].grid()
    axs[1].legend()

    plt.show()

plot_history(history)

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
resul_eva = mejor_modelo.evaluate(x=X_val_reshaped, y=y_val, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.4f}".format(perdida))
print("Accuracy: {:.4%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.2525
# Accuracy: 91.3750%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
y_pred_prob = mejor_modelo.predict(X_val_reshaped, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

#Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_val, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 3))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	91.38%
# Sensitivity:	96.34%
# Specificity:	86.81%
# Precision:	87.03%
# F1-score:	91.45%

# %%
# Calcular la curva ROC y el valor AUC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plotear la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (área = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

print("ROC-AUC:\t{:.2f}".format(roc_auc))
# Out:
# ROC-AUC:	0.98
