# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from pathlib import Path

import pandas as pd
import seaborn as sns
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import shutil
import splitfolders
import os

# %% [markdown]
# Configurar TensorFlow para usar la GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %% [markdown]
# Elimina y recrea directorio split_imagenes, divide imágenes en carpetas de entrenamiento y validación

# %%
transformada = "mexh"

#Ruta al directoria split_imagenes
ruta_imagenes = Path(f"../../../imagenes/{transformada}")
ruta_split_imagenes = Path(f"../../../split_imagenes/{transformada}")

#Si el directorio ya existe, eliminarlo junto con su contendio
if ruta_split_imagenes.exists():
    shutil.rmtree(ruta_split_imagenes)

#Crear el split de las imágenes de la transformada
splitfolders.ratio(input=ruta_imagenes, output=ruta_split_imagenes, ratio=(.8,.2))
# Out:
# Copying files: 4000 files [00:06, 633.28 files/s]

# %% [markdown]
# Se definen algunos parámetros

# %%
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)
epochs = 100
batch_size = 32

# %% [markdown]
# Se crean los generadores de datos de imágenes

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Cargar imágenes de entrenamiento
generador_entrenamiento = train_datagen.flow_from_directory(
    ruta_split_imagenes/"train",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Cargar imágenes de validación
generador_validacion = valid_datagen.flow_from_directory(
    ruta_split_imagenes/"val",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(128, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=128, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 1.1968 - accuracy: 0.6041
# Epoch 1: val_accuracy improved from -inf to 0.61500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 14s 106ms/step - loss: 1.1968 - accuracy: 0.6041 - val_loss: 0.7134 - val_accuracy: 0.6150
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.6450
# Epoch 2: val_accuracy did not improve from 0.61500
# 100/100 [==============================] - 10s 100ms/step - loss: 0.6917 - accuracy: 0.6450 - val_loss: 0.7369 - val_accuracy: 0.5550
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6665 - accuracy: 0.6562
# Epoch 3: val_accuracy improved from 0.61500 to 0.62875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 0.6665 - accuracy: 0.6562 - val_loss: 0.6727 - val_accuracy: 0.6288
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.6694
# Epoch 4: val_accuracy improved from 0.62875 to 0.65000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 0.6445 - accuracy: 0.6694 - val_loss: 0.6442 - val_accuracy: 0.6500
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6321 - accuracy: 0.6841
# Epoch 5: val_accuracy improved from 0.65000 to 0.66125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.6321 - accuracy: 0.6841 - val_loss: 0.6432 - val_accuracy: 0.6612
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6100 - accuracy: 0.6972
# Epoch 6: val_accuracy improved from 0.66125 to 0.69000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.6100 - accuracy: 0.6972 - val_loss: 0.6193 - val_accuracy: 0.6900
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5943 - accuracy: 0.6997
# Epoch 7: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5943 - accuracy: 0.6997 - val_loss: 0.6000 - val_accuracy: 0.6775
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.7231
# Epoch 8: val_accuracy improved from 0.69000 to 0.70000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5756 - accuracy: 0.7231 - val_loss: 0.5985 - val_accuracy: 0.7000
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5779 - accuracy: 0.7325
# Epoch 9: val_accuracy did not improve from 0.70000
# 100/100 [==============================] - 10s 102ms/step - loss: 0.5779 - accuracy: 0.7325 - val_loss: 0.6089 - val_accuracy: 0.6925
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5652 - accuracy: 0.7391
# Epoch 10: val_accuracy improved from 0.70000 to 0.73625, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5652 - accuracy: 0.7391 - val_loss: 0.5620 - val_accuracy: 0.7362
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5518 - accuracy: 0.7591
# Epoch 11: val_accuracy improved from 0.73625 to 0.76375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5518 - accuracy: 0.7591 - val_loss: 0.5631 - val_accuracy: 0.7638
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7663
# Epoch 12: val_accuracy did not improve from 0.76375
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5454 - accuracy: 0.7663 - val_loss: 0.5430 - val_accuracy: 0.7638
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5171 - accuracy: 0.7853
# Epoch 13: val_accuracy improved from 0.76375 to 0.77875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5171 - accuracy: 0.7853 - val_loss: 0.5398 - val_accuracy: 0.7788
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5195 - accuracy: 0.7869
# Epoch 14: val_accuracy did not improve from 0.77875
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5195 - accuracy: 0.7869 - val_loss: 0.5424 - val_accuracy: 0.7650
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.7850
# Epoch 15: val_accuracy improved from 0.77875 to 0.78125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5166 - accuracy: 0.7850 - val_loss: 0.5267 - val_accuracy: 0.7812
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4975 - accuracy: 0.8031
# Epoch 16: val_accuracy did not improve from 0.78125
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4975 - accuracy: 0.8031 - val_loss: 0.5319 - val_accuracy: 0.7750
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4916 - accuracy: 0.8012
# Epoch 17: val_accuracy did not improve from 0.78125
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4916 - accuracy: 0.8012 - val_loss: 0.5267 - val_accuracy: 0.7812
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.8097
# Epoch 18: val_accuracy improved from 0.78125 to 0.78750, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4884 - accuracy: 0.8097 - val_loss: 0.5215 - val_accuracy: 0.7875
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4725 - accuracy: 0.8203
# Epoch 19: val_accuracy did not improve from 0.78750
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4725 - accuracy: 0.8203 - val_loss: 0.5155 - val_accuracy: 0.7850
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4655 - accuracy: 0.8200
# Epoch 20: val_accuracy did not improve from 0.78750
# 100/100 [==============================] - 10s 102ms/step - loss: 0.4655 - accuracy: 0.8200 - val_loss: 0.5219 - val_accuracy: 0.7875
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4902 - accuracy: 0.8056
# Epoch 21: val_accuracy did not improve from 0.78750
# 100/100 [==============================] - 10s 102ms/step - loss: 0.4902 - accuracy: 0.8056 - val_loss: 0.5213 - val_accuracy: 0.7800
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4509 - accuracy: 0.8288
# Epoch 22: val_accuracy did not improve from 0.78750
# 100/100 [==============================] - 10s 102ms/step - loss: 0.4509 - accuracy: 0.8288 - val_loss: 0.5467 - val_accuracy: 0.7738
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4609 - accuracy: 0.8181
# Epoch 23: val_accuracy did not improve from 0.78750
# 100/100 [==============================] - 10s 102ms/step - loss: 0.4609 - accuracy: 0.8181 - val_loss: 0.5663 - val_accuracy: 0.7575
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8216
# Epoch 24: val_accuracy improved from 0.78750 to 0.79125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 104ms/step - loss: 0.4583 - accuracy: 0.8216 - val_loss: 0.5309 - val_accuracy: 0.7912
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8369
# Epoch 25: val_accuracy did not improve from 0.79125
# 100/100 [==============================] - 10s 104ms/step - loss: 0.4371 - accuracy: 0.8369 - val_loss: 0.5468 - val_accuracy: 0.7812
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4436 - accuracy: 0.8316
# Epoch 26: val_accuracy improved from 0.79125 to 0.80000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 104ms/step - loss: 0.4436 - accuracy: 0.8316 - val_loss: 0.5203 - val_accuracy: 0.8000
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8297
# Epoch 27: val_accuracy improved from 0.80000 to 0.80125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4537 - accuracy: 0.8297 - val_loss: 0.5090 - val_accuracy: 0.8012
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4333 - accuracy: 0.8394
# Epoch 28: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 10s 104ms/step - loss: 0.4333 - accuracy: 0.8394 - val_loss: 0.5024 - val_accuracy: 0.7950
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4307 - accuracy: 0.8475
# Epoch 29: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4307 - accuracy: 0.8475 - val_loss: 0.5146 - val_accuracy: 0.7912
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4144 - accuracy: 0.8484
# Epoch 30: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 10s 104ms/step - loss: 0.4144 - accuracy: 0.8484 - val_loss: 0.5526 - val_accuracy: 0.7837
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.8447
# Epoch 31: val_accuracy improved from 0.80125 to 0.81000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 105ms/step - loss: 0.4394 - accuracy: 0.8447 - val_loss: 0.5079 - val_accuracy: 0.8100
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4142 - accuracy: 0.8475
# Epoch 32: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.4142 - accuracy: 0.8475 - val_loss: 0.5373 - val_accuracy: 0.7950
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.8497
# Epoch 33: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.4180 - accuracy: 0.8497 - val_loss: 0.5208 - val_accuracy: 0.7825
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4232 - accuracy: 0.8438
# Epoch 34: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.4232 - accuracy: 0.8438 - val_loss: 0.5212 - val_accuracy: 0.7850
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8434
# Epoch 35: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 105ms/step - loss: 0.4212 - accuracy: 0.8434 - val_loss: 0.5095 - val_accuracy: 0.8000
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3997 - accuracy: 0.8537
# Epoch 36: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.3997 - accuracy: 0.8537 - val_loss: 0.5163 - val_accuracy: 0.7987
# Epoch 37/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.8606
# Epoch 37: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3933 - accuracy: 0.8606 - val_loss: 0.5099 - val_accuracy: 0.8062
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4125 - accuracy: 0.8516
# Epoch 38: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.4125 - accuracy: 0.8516 - val_loss: 0.5243 - val_accuracy: 0.8037
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.8603
# Epoch 39: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3959 - accuracy: 0.8603 - val_loss: 0.5159 - val_accuracy: 0.8100
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3938 - accuracy: 0.8650
# Epoch 40: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3938 - accuracy: 0.8650 - val_loss: 0.5625 - val_accuracy: 0.7638
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8616
# Epoch 41: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.3917 - accuracy: 0.8616 - val_loss: 0.5121 - val_accuracy: 0.8050
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3681 - accuracy: 0.8775
# Epoch 42: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3681 - accuracy: 0.8775 - val_loss: 0.5225 - val_accuracy: 0.7900
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8600
# Epoch 43: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3864 - accuracy: 0.8600 - val_loss: 0.5208 - val_accuracy: 0.7912
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.8759
# Epoch 44: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3628 - accuracy: 0.8759 - val_loss: 0.5295 - val_accuracy: 0.7887
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8681
# Epoch 45: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3814 - accuracy: 0.8681 - val_loss: 0.5392 - val_accuracy: 0.7900
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3961 - accuracy: 0.8684
# Epoch 46: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 106ms/step - loss: 0.3961 - accuracy: 0.8684 - val_loss: 0.5650 - val_accuracy: 0.7900
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8756
# Epoch 47: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3678 - accuracy: 0.8756 - val_loss: 0.5310 - val_accuracy: 0.8025
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3645 - accuracy: 0.8803
# Epoch 48: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3645 - accuracy: 0.8803 - val_loss: 0.5172 - val_accuracy: 0.8025
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.8813
# Epoch 49: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 107ms/step - loss: 0.3576 - accuracy: 0.8813 - val_loss: 0.5232 - val_accuracy: 0.8000
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.8794
# Epoch 50: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3651 - accuracy: 0.8794 - val_loss: 0.5448 - val_accuracy: 0.8012
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.8662
# Epoch 51: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3723 - accuracy: 0.8662 - val_loss: 0.5905 - val_accuracy: 0.7688
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8803
# Epoch 52: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3550 - accuracy: 0.8803 - val_loss: 0.5542 - val_accuracy: 0.7825
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3523 - accuracy: 0.8850
# Epoch 53: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3523 - accuracy: 0.8850 - val_loss: 0.5649 - val_accuracy: 0.7937
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8900
# Epoch 54: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3384 - accuracy: 0.8900 - val_loss: 0.5926 - val_accuracy: 0.7850
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8719
# Epoch 55: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3751 - accuracy: 0.8719 - val_loss: 0.5689 - val_accuracy: 0.7937
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.8853
# Epoch 56: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3570 - accuracy: 0.8853 - val_loss: 0.6127 - val_accuracy: 0.7738
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.8941
# Epoch 57: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3303 - accuracy: 0.8941 - val_loss: 0.5595 - val_accuracy: 0.7887
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3471 - accuracy: 0.8922
# Epoch 58: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3471 - accuracy: 0.8922 - val_loss: 0.6146 - val_accuracy: 0.7650
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8881
# Epoch 59: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3368 - accuracy: 0.8881 - val_loss: 0.5545 - val_accuracy: 0.7950
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8988
# Epoch 60: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3347 - accuracy: 0.8988 - val_loss: 0.5653 - val_accuracy: 0.7987
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8953
# Epoch 61: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3327 - accuracy: 0.8953 - val_loss: 0.6527 - val_accuracy: 0.7862
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3431 - accuracy: 0.8928
# Epoch 62: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.3431 - accuracy: 0.8928 - val_loss: 0.5787 - val_accuracy: 0.7887
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.9059
# Epoch 63: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3146 - accuracy: 0.9059 - val_loss: 0.6346 - val_accuracy: 0.7837
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.9047
# Epoch 64: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3169 - accuracy: 0.9047 - val_loss: 0.6194 - val_accuracy: 0.7700
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3209 - accuracy: 0.8994
# Epoch 65: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3209 - accuracy: 0.8994 - val_loss: 0.5955 - val_accuracy: 0.7713
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9116
# Epoch 66: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3083 - accuracy: 0.9116 - val_loss: 0.5842 - val_accuracy: 0.7912
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9166
# Epoch 67: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3029 - accuracy: 0.9166 - val_loss: 0.6086 - val_accuracy: 0.7812
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.9087
# Epoch 68: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3149 - accuracy: 0.9087 - val_loss: 0.5927 - val_accuracy: 0.8012
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.9056
# Epoch 69: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3135 - accuracy: 0.9056 - val_loss: 0.5935 - val_accuracy: 0.8000
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.9106
# Epoch 70: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3017 - accuracy: 0.9106 - val_loss: 0.6180 - val_accuracy: 0.7862
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.9175
# Epoch 71: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2903 - accuracy: 0.9175 - val_loss: 0.6155 - val_accuracy: 0.7812
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9206
# Epoch 72: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2871 - accuracy: 0.9206 - val_loss: 0.6636 - val_accuracy: 0.7912
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2991 - accuracy: 0.9131
# Epoch 73: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2991 - accuracy: 0.9131 - val_loss: 0.6276 - val_accuracy: 0.7975
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.9197
# Epoch 74: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2951 - accuracy: 0.9197 - val_loss: 0.6394 - val_accuracy: 0.8037
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.9181
# Epoch 75: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2922 - accuracy: 0.9181 - val_loss: 0.6632 - val_accuracy: 0.7887
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9216
# Epoch 76: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2844 - accuracy: 0.9216 - val_loss: 0.6526 - val_accuracy: 0.7812
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.9216
# Epoch 77: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2944 - accuracy: 0.9216 - val_loss: 0.8053 - val_accuracy: 0.7725
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2956 - accuracy: 0.9187
# Epoch 78: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2956 - accuracy: 0.9187 - val_loss: 0.6076 - val_accuracy: 0.8000
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.9141
# Epoch 79: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3106 - accuracy: 0.9141 - val_loss: 0.7135 - val_accuracy: 0.7425
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.9119
# Epoch 80: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3024 - accuracy: 0.9119 - val_loss: 0.6273 - val_accuracy: 0.7975
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.9300
# Epoch 81: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2816 - accuracy: 0.9300 - val_loss: 0.6668 - val_accuracy: 0.7788
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.9331
# Epoch 82: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2655 - accuracy: 0.9331 - val_loss: 0.7015 - val_accuracy: 0.7837
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.9253
# Epoch 83: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2704 - accuracy: 0.9253 - val_loss: 0.7206 - val_accuracy: 0.7925
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9237
# Epoch 84: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2826 - accuracy: 0.9237 - val_loss: 0.7167 - val_accuracy: 0.7900
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9309
# Epoch 85: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2667 - accuracy: 0.9309 - val_loss: 0.7674 - val_accuracy: 0.7912
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.9366
# Epoch 86: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2543 - accuracy: 0.9366 - val_loss: 0.7148 - val_accuracy: 0.7887
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.9331
# Epoch 87: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2692 - accuracy: 0.9331 - val_loss: 0.7098 - val_accuracy: 0.7800
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.9269
# Epoch 88: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2772 - accuracy: 0.9269 - val_loss: 0.7030 - val_accuracy: 0.7613
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2579 - accuracy: 0.9341
# Epoch 89: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2579 - accuracy: 0.9341 - val_loss: 0.8159 - val_accuracy: 0.7325
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2673 - accuracy: 0.9353
# Epoch 90: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2673 - accuracy: 0.9353 - val_loss: 0.7286 - val_accuracy: 0.7825
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 0.9463
# Epoch 91: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2410 - accuracy: 0.9463 - val_loss: 0.7146 - val_accuracy: 0.7937
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.9337
# Epoch 92: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2692 - accuracy: 0.9337 - val_loss: 0.7729 - val_accuracy: 0.7775
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9362
# Epoch 93: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2570 - accuracy: 0.9362 - val_loss: 0.7422 - val_accuracy: 0.7750
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2712 - accuracy: 0.9362
# Epoch 94: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2712 - accuracy: 0.9362 - val_loss: 0.7563 - val_accuracy: 0.7775
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.9400
# Epoch 95: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2499 - accuracy: 0.9400 - val_loss: 0.7956 - val_accuracy: 0.7837
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9406
# Epoch 96: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2531 - accuracy: 0.9406 - val_loss: 0.9118 - val_accuracy: 0.7588
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.9416
# Epoch 97: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2537 - accuracy: 0.9416 - val_loss: 0.8264 - val_accuracy: 0.7850
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.9234
# Epoch 98: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2895 - accuracy: 0.9234 - val_loss: 0.7242 - val_accuracy: 0.7750
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9413
# Epoch 99: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2474 - accuracy: 0.9413 - val_loss: 0.8705 - val_accuracy: 0.7638
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.9419
# Epoch 100: val_accuracy did not improve from 0.81000
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2516 - accuracy: 0.9419 - val_loss: 0.8764 - val_accuracy: 0.7563

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de Loss')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.51
# Accuracy: 81.00%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	49.00%
# Sensitivity:	49.50%
# Specificity:	48.50%
# Precision:	49.01%
# F1-score:	49.25%
