# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, auc

from pathlib import Path

import pandas as pd
import seaborn as sns
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import shutil
import splitfolders
import os

# %% [markdown]
# Configurar TensorFlow para usar la GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %% [markdown]
# Elimina y recrea directorio split_imagenes, divide imágenes en carpetas de entrenamiento y validación

# %%
transformada = "cmor"

#Ruta al directoria split_imagenes
ruta_imagenes = Path(f"../../../imagenes/{transformada}")
ruta_split_imagenes = Path(f"../../../split_imagenes/{transformada}")

#Si el directorio ya existe, eliminarlo junto con su contendio
if ruta_split_imagenes.exists():
    shutil.rmtree(ruta_split_imagenes)

#Crear el split de las imágenes de la transformada
splitfolders.ratio(input=ruta_imagenes, output=ruta_split_imagenes, ratio=(.8,.2))
# Out:
# Copying files: 4000 files [00:07, 515.36 files/s]

# %% [markdown]
# Se definen algunos parámetros

# %%
img_width, img_height = 250, 250
input_shape = (img_width, img_height, 3)
epochs = 100
batch_size = 32

# %% [markdown]
# Se crean los generadores de datos de imágenes

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Cargar imágenes de entrenamiento
generador_entrenamiento = train_datagen.flow_from_directory(
    ruta_split_imagenes/"train",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

# Cargar imágenes de validación
generador_validacion = valid_datagen.flow_from_directory(
    ruta_split_imagenes/"val",
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(128, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=128, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath = "modelo_generado/mejor_modelo.keras",
    monitor = "val_accuracy",
    save_best_only = True,
    mode = "max",
    verbose = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch=generador_entrenamiento.samples // batch_size,
    epochs=epochs,
    validation_data=generador_validacion,
    validation_steps=generador_validacion.samples // batch_size,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 1.2160 - accuracy: 0.6016
# Epoch 1: val_accuracy improved from -inf to 0.62250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 85s 807ms/step - loss: 1.2160 - accuracy: 0.6016 - val_loss: 0.7207 - val_accuracy: 0.6225
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.6459
# Epoch 2: val_accuracy improved from 0.62250 to 0.64500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 12s 116ms/step - loss: 0.6733 - accuracy: 0.6459 - val_loss: 0.6515 - val_accuracy: 0.6450
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.6787
# Epoch 3: val_accuracy improved from 0.64500 to 0.66250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 12s
val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 186ms/step - loss: 0.3980 - accuracy: 0.8659 - val_loss: 0.6007 - val_accuracy: 0.7937
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3702 - accuracy: 0.8856
# Epoch 39: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 171ms/step - loss: 0.3702 - accuracy: 0.8856 - val_loss: 0.5768 - val_accuracy: 0.7713
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3896 - accuracy: 0.8706
# Epoch 40: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3896 - accuracy: 0.8706 - val_loss: 0.6618 - val_accuracy: 0.7262
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3698 - accuracy: 0.8809
# Epoch 41: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 177ms/step - loss: 0.3698 - accuracy: 0.8809 - val_loss: 0.5853 - val_accuracy: 0.7925
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8884
# Epoch 42: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.3677 - accuracy: 0.8884 - val_loss: 0.5902 - val_accuracy: 0.7862
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3702 - accuracy: 0.8913
# Epoch 43: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 169ms/step - loss: 0.3702 - accuracy: 0.8913 - val_loss: 0.6104 - val_accuracy: 0.7850
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8894
# Epoch 44: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.3652 - accuracy: 0.8894 - val_loss: 0.6319 - val_accuracy: 0.7800
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3555 - accuracy: 0.8984
# Epoch 45: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.3555 - accuracy: 0.8984 - val_loss: 0.6063 - val_accuracy: 0.7725
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.9009
# Epoch 46: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3418 - accuracy: 0.9009 - val_loss: 0.6131 - val_accuracy: 0.7900
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3660 - accuracy: 0.8888
# Epoch 47: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 172ms/step - loss: 0.3660 - accuracy: 0.8888 - val_loss: 0.6200 - val_accuracy: 0.7800
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3538 - accuracy: 0.8959
# Epoch 48: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 168ms/step - loss: 0.3538 - accuracy: 0.8959 - val_loss: 0.6233 - val_accuracy: 0.7887
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.9200
# Epoch 49: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 167ms/step - loss: 0.3192 - accuracy: 0.9200 - val_loss: 0.6754 - val_accuracy: 0.7738
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.9097
# Epoch 50: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 171ms/step - loss: 0.3364 - accuracy: 0.9097 - val_loss: 0.6757 - val_accuracy: 0.7725
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.9203
# Epoch 51: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 169ms/step - loss: 0.3138 - accuracy: 0.9203 - val_loss: 0.6729 - val_accuracy: 0.7688
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3671 - accuracy: 0.8878
# Epoch 52: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.3671 - accuracy: 0.8878 - val_loss: 0.6537 - val_accuracy: 0.7713
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.9269
# Epoch 53: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 171ms/step - loss: 0.3124 - accuracy: 0.9269 - val_loss: 0.6993 - val_accuracy: 0.7713
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3148 - accuracy: 0.9184
# Epoch 54: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 172ms/step - loss: 0.3148 - accuracy: 0.9184 - val_loss: 0.6959 - val_accuracy: 0.7713
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.9212
# Epoch 55: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 170ms/step - loss: 0.3134 - accuracy: 0.9212 - val_loss: 0.9980 - val_accuracy: 0.7300
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3186 - accuracy: 0.9219
# Epoch 56: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 174ms/step - loss: 0.3186 - accuracy: 0.9219 - val_loss: 0.7242 - val_accuracy: 0.7725
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.9425
# Epoch 57: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 174ms/step - loss: 0.2777 - accuracy: 0.9425 - val_loss: 0.8373 - val_accuracy: 0.7550
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.9072
# Epoch 58: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 170ms/step - loss: 0.3311 - accuracy: 0.9072 - val_loss: 0.7207 - val_accuracy: 0.7525
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.9278
# Epoch 59: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2897 - accuracy: 0.9278 - val_loss: 0.7681 - val_accuracy: 0.7575
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.9375
# Epoch 60: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2793 - accuracy: 0.9375 - val_loss: 0.7843 - val_accuracy: 0.7650
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2928 - accuracy: 0.9297
# Epoch 61: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 170ms/step - loss: 0.2928 - accuracy: 0.9297 - val_loss: 0.8031 - val_accuracy: 0.7713
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9375
# Epoch 62: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 187ms/step - loss: 0.2842 - accuracy: 0.9375 - val_loss: 0.7586 - val_accuracy: 0.7800
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.9175
# Epoch 63: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 193ms/step - loss: 0.3117 - accuracy: 0.9175 - val_loss: 0.7734 - val_accuracy: 0.7663
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.9453
# Epoch 64: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 181ms/step - loss: 0.2783 - accuracy: 0.9453 - val_loss: 0.8551 - val_accuracy: 0.7500
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.9378
# Epoch 65: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 192ms/step - loss: 0.2864 - accuracy: 0.9378 - val_loss: 0.7924 - val_accuracy: 0.7638
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9613
# Epoch 66: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 187ms/step - loss: 0.2409 - accuracy: 0.9613 - val_loss: 1.0693 - val_accuracy: 0.7487
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9516
# Epoch 67: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 183ms/step - loss: 0.2570 - accuracy: 0.9516 - val_loss: 0.8620 - val_accuracy: 0.7638
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.9453
# Epoch 68: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.2702 - accuracy: 0.9453 - val_loss: 0.8630 - val_accuracy: 0.7425
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9663
# Epoch 69: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 188ms/step - loss: 0.2398 - accuracy: 0.9663 - val_loss: 0.8536 - val_accuracy: 0.7750
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9741
# Epoch 70: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.2114 - accuracy: 0.9741 - val_loss: 1.0545 - val_accuracy: 0.7475
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9603
# Epoch 71: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2409 - accuracy: 0.9603 - val_loss: 0.8744 - val_accuracy: 0.7425
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2431 - accuracy: 0.9575
# Epoch 72: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 173ms/step - loss: 0.2431 - accuracy: 0.9575 - val_loss: 0.9374 - val_accuracy: 0.7663
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.9509
# Epoch 73: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 186ms/step - loss: 0.2548 - accuracy: 0.9509 - val_loss: 0.9165 - val_accuracy: 0.7713
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9616
# Epoch 74: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.2334 - accuracy: 0.9616 - val_loss: 0.9828 - val_accuracy: 0.7700
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9563
# Epoch 75: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 174ms/step - loss: 0.2468 - accuracy: 0.9563 - val_loss: 0.9684 - val_accuracy: 0.7487
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.9513
# Epoch 76: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 174ms/step - loss: 0.2575 - accuracy: 0.9513 - val_loss: 0.9520 - val_accuracy: 0.7412
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9747
# Epoch 77: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2118 - accuracy: 0.9747 - val_loss: 1.0492 - val_accuracy: 0.7575
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9719
# Epoch 78: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 174ms/step - loss: 0.2110 - accuracy: 0.9719 - val_loss: 1.0054 - val_accuracy: 0.7625
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9703
# Epoch 79: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 177ms/step - loss: 0.2125 - accuracy: 0.9703 - val_loss: 0.9840 - val_accuracy: 0.7487
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2911 - accuracy: 0.9362
# Epoch 80: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 190ms/step - loss: 0.2911 - accuracy: 0.9362 - val_loss: 0.9127 - val_accuracy: 0.7713
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9725
# Epoch 81: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 186ms/step - loss: 0.2131 - accuracy: 0.9725 - val_loss: 1.0144 - val_accuracy: 0.7575
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9716
# Epoch 82: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 19s 186ms/step - loss: 0.2070 - accuracy: 0.9716 - val_loss: 0.9782 - val_accuracy: 0.7850
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9850
# Epoch 83: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 175ms/step - loss: 0.1809 - accuracy: 0.9850 - val_loss: 1.2658 - val_accuracy: 0.7475
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3116 - accuracy: 0.9287
# Epoch 84: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.3116 - accuracy: 0.9287 - val_loss: 0.7129 - val_accuracy: 0.7887
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.9722
# Epoch 85: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 175ms/step - loss: 0.2259 - accuracy: 0.9722 - val_loss: 0.8991 - val_accuracy: 0.7713
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9878
# Epoch 86: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 177ms/step - loss: 0.1783 - accuracy: 0.9878 - val_loss: 0.9736 - val_accuracy: 0.7713
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1836 - accuracy: 0.9837
# Epoch 87: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.1836 - accuracy: 0.9837 - val_loss: 1.1161 - val_accuracy: 0.7475
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9759
# Epoch 88: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 175ms/step - loss: 0.1952 - accuracy: 0.9759 - val_loss: 1.0609 - val_accuracy: 0.7500
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9638
# Epoch 89: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2334 - accuracy: 0.9638 - val_loss: 0.9152 - val_accuracy: 0.7663
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9716
# Epoch 90: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 176ms/step - loss: 0.2197 - accuracy: 0.9716 - val_loss: 0.9723 - val_accuracy: 0.7725
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9731
# Epoch 91: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2116 - accuracy: 0.9731 - val_loss: 1.0369 - val_accuracy: 0.7738
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9697
# Epoch 92: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 174ms/step - loss: 0.2064 - accuracy: 0.9697 - val_loss: 1.1430 - val_accuracy: 0.7650
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9737
# Epoch 93: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 177ms/step - loss: 0.2084 - accuracy: 0.9737 - val_loss: 1.2628 - val_accuracy: 0.7513
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9731
# Epoch 94: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 177ms/step - loss: 0.2088 - accuracy: 0.9731 - val_loss: 1.0602 - val_accuracy: 0.7725
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9613
# Epoch 95: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 171ms/step - loss: 0.2272 - accuracy: 0.9613 - val_loss: 1.0045 - val_accuracy: 0.7650
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9656
# Epoch 96: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 175ms/step - loss: 0.2176 - accuracy: 0.9656 - val_loss: 0.9654 - val_accuracy: 0.7638
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9731
# Epoch 97: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2080 - accuracy: 0.9731 - val_loss: 1.0148 - val_accuracy: 0.7775
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9691
# Epoch 98: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2155 - accuracy: 0.9691 - val_loss: 1.0791 - val_accuracy: 0.7713
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9600
# Epoch 99: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 175ms/step - loss: 0.2352 - accuracy: 0.9600 - val_loss: 1.0996 - val_accuracy: 0.7663
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2579 - accuracy: 0.9506
# Epoch 100: val_accuracy did not improve from 0.79500
# 100/100 [==============================] - 18s 181ms/step - loss: 0.2579 - accuracy: 0.9506 - val_loss: 1.0656 - val_accuracy: 0.7675

# %% [markdown]
# Resumen del modelo

# %%
clasificador.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 315,393
# Trainable params: 315,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de Loss')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()

# Obteniendo el nombre de la imagen para la gráfica de entrenamiento
cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))

#Crear un Dataframe con los nuevos resultados
new_data = pd.DataFrame({"Loss":[perdida], "Accuracy":[accuracy]})

#Especificar el nombre del archivo Excel
file_name = "resultados_iteraciones/resultados.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Resultados")
    #Concatenar los datos existentes con los nuevos datos
    df = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df = new_data

#Guardar el Dataframe en el archivo Excel
df.to_excel(file_name, sheet_name="Resultados", index=False)
# Out:
# Loss: 0.53
# Accuracy: 79.50%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	79.50%
# Sensitivity:	85.50%
# Specificity:	73.50%
# Precision:	76.34%
# F1-score:	80.66%

# %% [markdown]
# Curva roc y auc

# %%
# Calcular la curva ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Visualizar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid()

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

# Imprimir el AUC
print(f"Área Bajo la Curva (AUC): {roc_auc:.2f}")
# Out:
# Área Bajo la Curva (AUC): 0.86

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
