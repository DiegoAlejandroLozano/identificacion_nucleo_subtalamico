# %%
from tensorflow.keras.models                import Sequential, load_model
from tensorflow.keras.layers                import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers            import Adam
from tensorflow.keras.preprocessing.image   import ImageDataGenerator
from tensorflow.keras.callbacks             import ModelCheckpoint
from tensorflow.keras.regularizers          import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, auc

from pathlib import Path

import pandas               as pd
import seaborn              as sns
import tensorflow           as tf
import matplotlib.pyplot    as plt

import shutil, splitfolders, os

# %% [markdown]
# Configurar TensorFlow para usar la GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %% [markdown]
# Elimina y recrea directorio split_imagenes, divide imágenes en carpetas de entrenamiento y validación

# %%
transformada = "cgau1"

#Ruta al directoria split_imagenes
ruta_imagenes = Path(f"../../../imagenes/{transformada}")
ruta_split_imagenes = Path(f"../../../split_imagenes/{transformada}")

#Si el directorio ya existe, eliminarlo junto con su contendio
if ruta_split_imagenes.exists():
    shutil.rmtree(ruta_split_imagenes)

#Crear el split de las imágenes de la transformada
splitfolders.ratio(input=ruta_imagenes, output=ruta_split_imagenes, ratio=(.8,.2))
# Out:
# Copying files: 4000 files [00:09, 419.24 files/s]

# %% [markdown]
# Se definen algunos parámetros

# %%
img_width, img_height = 250, 250
input_shape           = (img_width, img_height, 3)
epochs                = 100
batch_size            = 32

# %% [markdown]
# Se crean los generadores de datos de imágenes

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Cargar imágenes de entrenamiento
generador_entrenamiento = train_datagen.flow_from_directory(
    ruta_split_imagenes/"train",
    target_size = (img_width, img_height),
    batch_size  = batch_size,
    class_mode  = 'binary',
    shuffle     = True
)

# Cargar imágenes de validación
generador_validacion = valid_datagen.flow_from_directory(
    ruta_split_imagenes/"val",
    target_size = (img_width, img_height),
    batch_size  = batch_size,
    class_mode  = 'binary',
    shuffle     = False
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
tamanio_ventana = (2,2)

# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(32, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))
clasificador.add(Conv2D(16, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))
clasificador.add(Conv2D(8, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=tamanio_ventana))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=32, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath       = "modelo_generado/mejor_modelo.keras",
    monitor        = "val_accuracy",
    save_best_only = True,
    mode           = "max",
    verbose        = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch  = generador_entrenamiento.samples // batch_size,
    epochs           = epochs,
    validation_data  = generador_validacion,
    validation_steps = generador_validacion.samples // batch_size,
    callbacks        = [checkpoint_callback]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8752 - accuracy: 0.6062
# Epoch 1: val_accuracy improved from -inf to 0.66875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 64s 585ms/step - loss: 0.8752 - accuracy: 0.6062 - val_loss: 0.7694 - val_accuracy: 0.6687
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.7206 - accuracy: 0.6503
# Epoch 2: val_accuracy improved from 0.66875 to 0.68125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 93ms/step - loss: 0.7206 - accuracy: 0.6503 - val_loss: 0.6681 - val_accuracy: 0.6812
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 0.6753
# Epoch 3: val_accuracy improved from 0.68125 to 0.68250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 93ms/step - loss: 0.6410 - accuracy: 0.6753 - val_loss: 0.6357 - val_accuracy: 0.6825
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5973 - accuracy: 0.6991
# Epoch 4: val_accuracy improved from 0.68250 to 0.74500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5973 - accuracy: 0.6991 - val_loss: 0.5868 - val_accuracy: 0.7450
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5745 - accuracy: 0.7041
# Epoch 5: val_accuracy did not improve from 0.74500
# 100/100 [==============================] - 10s 102ms/step - loss: 0.5745 - accuracy: 0.7041 - val_loss: 0.5727 - val_accuracy: 0.7262
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5532 - accuracy: 0.7328
# Epoch 6: val_accuracy improved from 0.74500 to 0.75500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5532 - accuracy: 0.7328 - val_loss: 0.5599 - val_accuracy: 0.7550
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5477 - accuracy: 0.7337
# Epoch 7: val_accuracy did not improve from 0.75500
# 100/100 [==============================] - 10s 97ms/step - loss: 0.5477 - accuracy: 0.7337 - val_loss: 0.5501 - val_accuracy: 0.7538
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5237 - accuracy: 0.7441
# Epoch 8: val_accuracy improved from 0.75500 to 0.76500, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 0.5237 - accuracy: 0.7441 - val_loss: 0.5687 - val_accuracy: 0.7650
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5349 - accuracy: 0.7359
# Epoch 9: val_accuracy did not improve from 0.76500
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5349 - accuracy: 0.7359 - val_loss: 0.5396 - val_accuracy: 0.7600
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5451 - accuracy: 0.7284
# Epoch 10: val_accuracy improved from 0.76500 to 0.79375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 0.5451 - accuracy: 0.7284 - val_loss: 0.5337 - val_accuracy: 0.7937
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.7513
# Epoch 11: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 9s 95ms/step - loss: 0.5224 - accuracy: 0.7513 - val_loss: 0.5789 - val_accuracy: 0.7475
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5198 - accuracy: 0.7481
# Epoch 12: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5198 - accuracy: 0.7481 - val_loss: 0.5555 - val_accuracy: 0.7575
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5124 - accuracy: 0.7553
# Epoch 13: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 9s 93ms/step - loss: 0.5124 - accuracy: 0.7553 - val_loss: 0.5344 - val_accuracy: 0.7663
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.7550
# Epoch 14: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 10s 96ms/step - loss: 0.5118 - accuracy: 0.7550 - val_loss: 0.5394 - val_accuracy: 0.7613
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5017 - accuracy: 0.7619
# Epoch 15: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 9s 94ms/step - loss: 0.5017 - accuracy: 0.7619 - val_loss: 0.5559 - val_accuracy: 0.7563
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7766
# Epoch 16: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 9s 94ms/step - loss: 0.4936 - accuracy: 0.7766 - val_loss: 0.5210 - val_accuracy: 0.7887
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.7613
# Epoch 17: val_accuracy did not improve from 0.79375
# 100/100 [==============================] - 9s 94ms/step - loss: 0.5045 - accuracy: 0.7613 - val_loss: 0.5419 - val_accuracy: 0.7763
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 143ms/step - loss: 0.4120 - accuracy: 0.8087 - val_loss: 0.6515 - val_accuracy: 0.7600
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8106
# Epoch 53: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 18s 184ms/step - loss: 0.4212 - accuracy: 0.8106 - val_loss: 0.6045 - val_accuracy: 0.7962
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4113 - accuracy: 0.8050
# Epoch 54: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 15s 151ms/step - loss: 0.4113 - accuracy: 0.8050 - val_loss: 0.6596 - val_accuracy: 0.7663
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4152 - accuracy: 0.8091
# Epoch 55: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 15s 149ms/step - loss: 0.4152 - accuracy: 0.8091 - val_loss: 0.6499 - val_accuracy: 0.7613
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.8159
# Epoch 56: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 139ms/step - loss: 0.4150 - accuracy: 0.8159 - val_loss: 0.6012 - val_accuracy: 0.7912
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8244
# Epoch 57: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 142ms/step - loss: 0.3854 - accuracy: 0.8244 - val_loss: 0.6546 - val_accuracy: 0.7525
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8225
# Epoch 58: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 142ms/step - loss: 0.3897 - accuracy: 0.8225 - val_loss: 0.7199 - val_accuracy: 0.7550
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8206
# Epoch 59: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 15s 146ms/step - loss: 0.3882 - accuracy: 0.8206 - val_loss: 0.6731 - val_accuracy: 0.7725
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3863 - accuracy: 0.8325
# Epoch 60: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 15s 149ms/step - loss: 0.3863 - accuracy: 0.8325 - val_loss: 0.6678 - val_accuracy: 0.7738
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8294
# Epoch 61: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 141ms/step - loss: 0.3848 - accuracy: 0.8294 - val_loss: 0.6830 - val_accuracy: 0.7875
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8325
# Epoch 62: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 144ms/step - loss: 0.3804 - accuracy: 0.8325 - val_loss: 0.6246 - val_accuracy: 0.7925
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.8297
# Epoch 63: val_accuracy did not improve from 0.80125
# 100/100 [==============================] - 14s 144ms/step - loss: 0.3914 - accuracy: 0.8297 - val_loss: 0.6931 - val_accuracy: 0.7700
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8263
# Epoch 64: val_accuracy improved from 0.80125 to 0.80250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 15s 146ms/step - loss: 0.3880 - accuracy: 0.8263 - val_loss: 0.6256 - val_accuracy: 0.8025
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8400
# Epoch 65: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 15s 148ms/step - loss: 0.3819 - accuracy: 0.8400 - val_loss: 0.6631 - val_accuracy: 0.7750
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.8322
# Epoch 66: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 15s 144ms/step - loss: 0.3839 - accuracy: 0.8322 - val_loss: 0.5891 - val_accuracy: 0.7850
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3888 - accuracy: 0.8384
# Epoch 67: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 15s 148ms/step - loss: 0.3888 - accuracy: 0.8384 - val_loss: 0.6737 - val_accuracy: 0.7775
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8434
# Epoch 68: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 15s 152ms/step - loss: 0.3714 - accuracy: 0.8434 - val_loss: 0.6616 - val_accuracy: 0.7862
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8347
# Epoch 69: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 14s 141ms/step - loss: 0.3714 - accuracy: 0.8347 - val_loss: 0.6068 - val_accuracy: 0.7925
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.8306
# Epoch 70: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 14s 140ms/step - loss: 0.3832 - accuracy: 0.8306 - val_loss: 0.6388 - val_accuracy: 0.7875
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3829 - accuracy: 0.8353
# Epoch 71: val_accuracy did not improve from 0.80250
# 100/100 [==============================] - 14s 140ms/step - loss: 0.3829 - accuracy: 0.8353 - val_loss: 0.6267 - val_accuracy: 0.7862
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3602 - accuracy: 0.8556
# Epoch 72: val_accuracy improved from 0.80250 to 0.80375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 14s 142ms/step - loss: 0.3602 - accuracy: 0.8556 - val_loss: 0.6052 - val_accuracy: 0.8037
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3664 - accuracy: 0.8572
# Epoch 73: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 17s 165ms/step - loss: 0.3664 - accuracy: 0.8572 - val_loss: 0.6535 - val_accuracy: 0.7887
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8453
# Epoch 74: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 17s 174ms/step - loss: 0.3874 - accuracy: 0.8453 - val_loss: 0.5920 - val_accuracy: 0.7912
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8484
# Epoch 75: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 14s 142ms/step - loss: 0.3746 - accuracy: 0.8484 - val_loss: 0.6096 - val_accuracy: 0.7950
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3569 - accuracy: 0.8609
# Epoch 76: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 14s 144ms/step - loss: 0.3569 - accuracy: 0.8609 - val_loss: 0.6204 - val_accuracy: 0.7975
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3552 - accuracy: 0.8597
# Epoch 77: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3552 - accuracy: 0.8597 - val_loss: 0.6286 - val_accuracy: 0.7887
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.8487
# Epoch 78: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 14s 143ms/step - loss: 0.3762 - accuracy: 0.8487 - val_loss: 0.6468 - val_accuracy: 0.7962
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8681
# Epoch 79: val_accuracy did not improve from 0.80375
# 100/100 [==============================] - 15s 145ms/step - loss: 0.3475 - accuracy: 0.8681 - val_loss: 0.6590 - val_accuracy: 0.7900
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.8591
# Epoch 80: val_accuracy improved from 0.80375 to 0.80875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 14s 143ms/step - loss: 0.3533 - accuracy: 0.8591 - val_loss: 0.6252 - val_accuracy: 0.8087
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.8566
# Epoch 81: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3618 - accuracy: 0.8566 - val_loss: 0.6720 - val_accuracy: 0.7912
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.8556
# Epoch 82: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 145ms/step - loss: 0.3650 - accuracy: 0.8556 - val_loss: 0.6625 - val_accuracy: 0.7862
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8584
# Epoch 83: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 14s 144ms/step - loss: 0.3573 - accuracy: 0.8584 - val_loss: 0.6396 - val_accuracy: 0.7788
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.8697
# Epoch 84: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3459 - accuracy: 0.8697 - val_loss: 0.6980 - val_accuracy: 0.7875
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8619
# Epoch 85: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3491 - accuracy: 0.8619 - val_loss: 0.7036 - val_accuracy: 0.7738
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.8750
# Epoch 86: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3466 - accuracy: 0.8750 - val_loss: 0.6310 - val_accuracy: 0.7937
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3423 - accuracy: 0.8672
# Epoch 87: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 146ms/step - loss: 0.3423 - accuracy: 0.8672 - val_loss: 0.7074 - val_accuracy: 0.7837
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3474 - accuracy: 0.8687
# Epoch 88: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 148ms/step - loss: 0.3474 - accuracy: 0.8687 - val_loss: 0.7006 - val_accuracy: 0.7775
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3717 - accuracy: 0.8519
# Epoch 89: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 16s 164ms/step - loss: 0.3717 - accuracy: 0.8519 - val_loss: 0.6211 - val_accuracy: 0.7812
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.8659
# Epoch 90: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 151ms/step - loss: 0.3492 - accuracy: 0.8659 - val_loss: 0.7537 - val_accuracy: 0.7563
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.8741
# Epoch 91: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3570 - accuracy: 0.8741 - val_loss: 0.6268 - val_accuracy: 0.7925
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3302 - accuracy: 0.8759
# Epoch 92: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 153ms/step - loss: 0.3302 - accuracy: 0.8759 - val_loss: 0.6668 - val_accuracy: 0.7950
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.8744
# Epoch 93: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 16s 157ms/step - loss: 0.3429 - accuracy: 0.8744 - val_loss: 0.7141 - val_accuracy: 0.7713
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8631
# Epoch 94: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 152ms/step - loss: 0.3464 - accuracy: 0.8631 - val_loss: 0.6686 - val_accuracy: 0.7763
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3530 - accuracy: 0.8728
# Epoch 95: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 154ms/step - loss: 0.3530 - accuracy: 0.8728 - val_loss: 0.6602 - val_accuracy: 0.7875
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3489 - accuracy: 0.8691
# Epoch 96: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 14s 142ms/step - loss: 0.3489 - accuracy: 0.8691 - val_loss: 0.7081 - val_accuracy: 0.7538
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8722
# Epoch 97: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 145ms/step - loss: 0.3588 - accuracy: 0.8722 - val_loss: 0.7089 - val_accuracy: 0.7625
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.8791
# Epoch 98: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 147ms/step - loss: 0.3345 - accuracy: 0.8791 - val_loss: 0.6569 - val_accuracy: 0.7688
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.8712
# Epoch 99: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 14s 141ms/step - loss: 0.3434 - accuracy: 0.8712 - val_loss: 0.7365 - val_accuracy: 0.7837
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.8672
# Epoch 100: val_accuracy did not improve from 0.80875
# 100/100 [==============================] - 15s 154ms/step - loss: 0.3430 - accuracy: 0.8672 - val_loss: 0.6927 - val_accuracy: 0.7912

# %% [markdown]
# Resumen del modelo

# %%
clasificador.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 124, 124, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 16)      4624
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 8)         1160
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 29, 8)        0
#  2D)
#
#  flatten (Flatten)           (None, 6728)              0
#
#  dense (Dense)               (None, 32)                215328
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 222,041
# Trainable params: 222,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de Loss')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()

plt.tight_layout()

# Obteniendo el nombre de la imagen para la gráfica de entrenamiento
cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo

# %% [markdown]
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida = resul_eva[0]
accuracy = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))
# Out:
# Loss: 0.63
# Accuracy: 80.87%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp = conf_matrix.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	80.88%
# Sensitivity:	83.25%
# Specificity:	78.50%
# Precision:	79.47%
# F1-score:	81.32%

# %% [markdown]
# Curva roc y auc

# %%
# Calcular la curva ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Visualizar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid()

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

# Imprimir el AUC
print(f"Área Bajo la Curva (AUC): {roc_auc:.2f}")
# Out:
# Área Bajo la Curva (AUC): 0.88

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
