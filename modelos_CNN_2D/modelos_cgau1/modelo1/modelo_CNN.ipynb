# %%
from tensorflow.keras.models                import Sequential, load_model
from tensorflow.keras.layers                import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers            import Adam
from tensorflow.keras.preprocessing.image   import ImageDataGenerator
from tensorflow.keras.callbacks             import ModelCheckpoint
from tensorflow.keras.regularizers          import l2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix 
from sklearn.metrics import roc_curve, auc

from pathlib import Path

import pandas               as pd
import seaborn              as sns
import tensorflow           as tf
import matplotlib.pyplot    as plt

import shutil
import splitfolders
import os

# %% [markdown]
# Configurar TensorFlow para usar la GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], False)
    tf.config.experimental.set_virtual_device_configuration(physical_devices[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])

# %% [markdown]
# Elimina y recrea directorio split_imagenes, divide imágenes en carpetas de entrenamiento y validación

# %%
transformada = "cgau1"

#Ruta al directoria split_imagenes
ruta_imagenes = Path(f"../../../imagenes/{transformada}")
ruta_split_imagenes = Path(f"../../../split_imagenes/{transformada}")

#Si el directorio ya existe, eliminarlo junto con su contendio
if ruta_split_imagenes.exists():
    shutil.rmtree(ruta_split_imagenes)

#Crear el split de las imágenes de la transformada
splitfolders.ratio(input=ruta_imagenes, output=ruta_split_imagenes, ratio=(.8,.2))
# Out:
# Copying files: 4000 files [00:09, 413.07 files/s]

# %% [markdown]
# Se definen algunos parámetros

# %%
img_width, img_height = 250, 250

input_shape = (img_width, img_height, 3)
epochs      = 100
batch_size  = 32

# %% [markdown]
# Se crean los generadores de datos de imágenes

# %%
# Configurar el generador de datos de imágenes
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# Cargar imágenes de entrenamiento
generador_entrenamiento = train_datagen.flow_from_directory(
    ruta_split_imagenes/"train",
    target_size = (img_width, img_height),
    batch_size  = batch_size,
    class_mode  = 'binary',
    shuffle     = True
)

# Cargar imágenes de validación
generador_validacion = valid_datagen.flow_from_directory(
    ruta_split_imagenes/"val",
    target_size = (img_width, img_height),
    batch_size  = batch_size,
    class_mode  = 'binary',
    shuffle     = False
)
# Out:
# Found 3200 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Definir el modelo CNN
clasificador = Sequential()

clasificador.add(Conv2D(128, (3, 3), input_shape=input_shape, activation='relu'))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))
clasificador.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(l2=0.01)))
clasificador.add(MaxPooling2D(pool_size=(5,5)))


# Capa de aplanamiento
clasificador.add(Flatten())

# Se agregan las capas densas
clasificador.add(Dense(units=128, activation='relu', kernel_regularizer=l2(0.001)))
clasificador.add(Dropout(rate=0.5))

# Capa de salida
clasificador.add(Dense(units=1, activation='sigmoid'))

# %%
# Compilar el modelo
clasificador.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Se define un callback para guardar el mejor modelo basado en el val_accuracy
checkpoint_callback = ModelCheckpoint(
    filepath        = "modelo_generado/mejor_modelo.keras",
    monitor         = "val_accuracy",
    save_best_only  = True,
    mode            = "max",
    verbose         = 1
)

# Entrenar el modelo
history = clasificador.fit(
    generador_entrenamiento,
    steps_per_epoch     = generador_entrenamiento.samples // batch_size,
    epochs              = epochs,
    validation_data     = generador_validacion,
    validation_steps    = generador_validacion.samples // batch_size,
    callbacks           = [checkpoint_callback]
)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9535 - accuracy: 0.5494
# Epoch 1: val_accuracy improved from -inf to 0.62000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 38s 347ms/step - loss: 0.9535 - accuracy: 0.5494 - val_loss: 0.6911 - val_accuracy: 0.6200
# Epoch 2/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.6425
# Epoch 2: val_accuracy improved from 0.62000 to 0.64750, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 107ms/step - loss: 0.6689 - accuracy: 0.6425 - val_loss: 0.6652 - val_accuracy: 0.6475
# Epoch 3/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6659
# Epoch 3: val_accuracy did not improve from 0.64750
# 100/100 [==============================] - 11s 106ms/step - loss: 0.6392 - accuracy: 0.6659 - val_loss: 0.6426 - val_accuracy: 0.6425
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6414 - accuracy: 0.6587
# Epoch 4: val_accuracy improved from 0.64750 to 0.65250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 108ms/step - loss: 0.6414 - accuracy: 0.6587 - val_loss: 0.6456 - val_accuracy: 0.6525
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.6706
# Epoch 5: val_accuracy did not improve from 0.65250
# 100/100 [==============================] - 11s 107ms/step - loss: 0.6291 - accuracy: 0.6706 - val_loss: 0.6387 - val_accuracy: 0.6363
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6305 - accuracy: 0.6700
# Epoch 6: val_accuracy did not improve from 0.65250
# 100/100 [==============================] - 11s 107ms/step - loss: 0.6305 - accuracy: 0.6700 - val_loss: 0.6332 - val_accuracy: 0.6438
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.6709
# Epoch 7: val_accuracy did not improve from 0.65250
# 100/100 [==============================] - 11s 108ms/step - loss: 0.6265 - accuracy: 0.6709 - val_loss: 0.6359 - val_accuracy: 0.6338
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6233 - accuracy: 0.6822
# Epoch 8: val_accuracy did not improve from 0.65250
# 100/100 [==============================] - 11s 107ms/step - loss: 0.6233 - accuracy: 0.6822 - val_loss: 0.6377 - val_accuracy: 0.6488
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.6728
# Epoch 9: val_accuracy improved from 0.65250 to 0.65875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 109ms/step - loss: 0.6158 - accuracy: 0.6728 - val_loss: 0.6239 - val_accuracy: 0.6587
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.6812
# Epoch 10: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 108ms/step - loss: 0.6158 - accuracy: 0.6812 - val_loss: 0.6293 - val_accuracy: 0.6500
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6166 - accuracy: 0.6725
# Epoch 11: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 108ms/step - loss: 0.6166 - accuracy: 0.6725 - val_loss: 0.6296 - val_accuracy: 0.6475
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6209 - accuracy: 0.6712
# Epoch 12: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 109ms/step - loss: 0.6209 - accuracy: 0.6712 - val_loss: 0.6743 - val_accuracy: 0.5863
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6155 - accuracy: 0.6803
# Epoch 13: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 109ms/step - loss: 0.6155 - accuracy: 0.6803 - val_loss: 0.6498 - val_accuracy: 0.6475
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.6737
# Epoch 14: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 111ms/step - loss: 0.6182 - accuracy: 0.6737 - val_loss: 0.6274 - val_accuracy: 0.6475
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.6766
# Epoch 15: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 111ms/step - loss: 0.6151 - accuracy: 0.6766 - val_loss: 0.6397 - val_accuracy: 0.6375
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.6853
# Epoch 16: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 110ms/step - loss: 0.6136 - accuracy: 0.6853 - val_loss: 0.6306 - val_accuracy: 0.6500
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6176 - accuracy: 0.6794
# Epoch 17: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 11s 111ms/step - loss: 0.6176 - accuracy: 0.6794 - val_loss: 0.6224 - val_accuracy: 0.6538
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6079 - accuracy: 0.6900
# Epoch 18: val_accuracy did not improve from 0.65875
# 100/100 [==============================] - 12s 118ms/step - loss: 0.6079 - accuracy: 0.6900 - val_loss: 0.6338 - val_accuracy: 0.6550
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6073 - accuracy: 0.6888
# Epoch 19: val_accuracy improved from 0.65875 to 0.66000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6073 - accuracy: 0.6888 - val_loss: 0.6254 - val_accuracy: 0.6600
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6143 - accuracy: 0.6878
# Epoch 20: val_accuracy did not improve from 0.66000
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6143 - accuracy: 0.6878 - val_loss: 0.6340 - val_accuracy: 0.6450
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6056 - accuracy: 0.6878
# Epoch 21: val_accuracy improved from 0.66000 to 0.66375, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 113ms/step - loss: 0.6056 - accuracy: 0.6878 - val_loss: 0.6403 - val_accuracy: 0.6637
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.6812
# Epoch 22: val_accuracy did not improve from 0.66375
# 100/100 [==============================] - 11s 112ms/step - loss: 0.6137 - accuracy: 0.6812 - val_loss: 0.6311 - val_accuracy: 0.6625
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.6925
# Epoch 23: val_accuracy improved from 0.66375 to 0.67125, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 12s 115ms/step - loss: 0.6018 - accuracy: 0.6925 - val_loss: 0.6174 - val_accuracy: 0.6712
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6079 - accuracy: 0.6938
# Epoch 24: val_accuracy improved from 0.67125 to 0.67250, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6079 - accuracy: 0.6938 - val_loss: 0.6239 - val_accuracy: 0.6725
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6129 - accuracy: 0.6944
# Epoch 25: val_accuracy did not improve from 0.67250
# 100/100 [==============================] - 11s 113ms/step - loss: 0.6129 - accuracy: 0.6944 - val_loss: 0.6293 - val_accuracy: 0.6612
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6074 - accuracy: 0.6922
# Epoch 26: val_accuracy improved from 0.67250 to 0.67875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 11s 113ms/step - loss: 0.6074 - accuracy: 0.6922 - val_loss: 0.6125 - val_accuracy: 0.6787
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6085 - accuracy: 0.6909
# Epoch 27: val_accuracy did not improve from 0.67875
# 100/100 [==============================] - 11s 113ms/step - loss: 0.6085 - accuracy: 0.6909 - val_loss: 0.6184 - val_accuracy: 0.6762
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6100 - accuracy: 0.6891
# Epoch 28: val_accuracy did not improve from 0.67875
# 100/100 [==============================] - 11s 114ms/step - loss: 0.6100 - accuracy: 0.6891 - val_loss: 0.6220 - val_accuracy: 0.6775
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6107 - accuracy: 0.6969
# Epoch 29: val_accuracy did not improve from 0.67875
# 100/100 [==============================] - 16s 159ms/step - loss: 0.6107 - accuracy: 0.6969 - val_loss: 0.6259 - val_accuracy: 0.6675
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.6844
# Epoch 30: val_accuracy did not improve from 0.67875
# 100/100 [==============================] - 16s 155ms/step - loss: 0.6080 - accuracy: 0.6844 - val_loss: 0.6211 - val_accuracy: 0.6750
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6096 - accuracy: 0.6916
# Epoch 31: val_accuracy improved from 0.67875 to 0.68000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 16s 163ms/step - loss: 0.6096 - accuracy: 0.6916 - val_loss: 0.6239 - val_accuracy: 0.6800
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6003 - accuracy: 0.7053
# Epoch 32: val_accuracy did not improve from 0.68000
# 100/100 [==============================] - 18s 177ms/step - loss: 0.6003 - accuracy: 0.7053 - val_loss: 0.6246 - val_accuracy: 0.6725
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5968 - accuracy: 0.7053
# Epoch 33: val_accuracy did not improve from 0.68000
# 100/100 [==============================] - 17s 164ms/step - loss: 0.5968 - accuracy: 0.7053 - val_loss: 0.6450 - val_accuracy: 0.6212
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.6903
# Epoch 34: val_accuracy did not improve from 0.68000
# 100/100 [==============================] - 18s 178ms/step - loss: 0.6109 - accuracy: 0.6903 - val_loss: 0.6190 - val_accuracy: 0.6775
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.7031
# Epoch 35: val_accuracy did not improve from 0.68000
# 100/100 [==============================] - 16s 162ms/step - loss: 0.6023 - accuracy: 0.7031 - val_loss: 0.6257 - val_accuracy: 0.6625
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6063 - accuracy: 0.6862
# Epoch 36: val_accuracy did not improve from 0.68000
# 100/100 [==============================] - 15s 151ms/step - loss: 0.6063 - accuracy: 0.6862 - val_loss: 0.6232 - val_accuracy: 0.6712
# Epoch 37/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.6972
# Epoch 37: val_accuracy did not improve from 0.68000
# 100/100 [==============================] - 15s 149ms/step - loss: 0.6020 - accuracy: 0.6972 - val_loss: 0.6197 - val_accuracy: 0.6787
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6078 - accuracy: 0.7000
# Epoch 38: val_accuracy improved from 0.68000 to 0.68875, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 21s 213ms/step - loss: 0.6078 - accuracy: 0.7000 - val_loss: 0.6114 - val_accuracy: 0.6888
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6099 - accuracy: 0.7019
# Epoch 39: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6099 - accuracy: 0.7019 - val_loss: 0.6302 - val_accuracy: 0.6562
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.7016
# Epoch 40: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 17s 173ms/step - loss: 0.6021 - accuracy: 0.7016 - val_loss: 0.6162 - val_accuracy: 0.6800
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.7000
# Epoch 41: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 19s 186ms/step - loss: 0.5964 - accuracy: 0.7000 - val_loss: 0.6133 - val_accuracy: 0.6737
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.6919
# Epoch 42: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 20s 197ms/step - loss: 0.6020 - accuracy: 0.6919 - val_loss: 0.6886 - val_accuracy: 0.6025
# Epoch 43/100
# 100/100 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 18s 175ms/step - loss: 0.6035 - accuracy: 0.6925 - val_loss: 0.6212 - val_accuracy: 0.6800
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.6978
# Epoch 79: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 159ms/step - loss: 0.5999 - accuracy: 0.6978 - val_loss: 0.6169 - val_accuracy: 0.6888
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5985 - accuracy: 0.6978
# Epoch 80: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 18s 179ms/step - loss: 0.5985 - accuracy: 0.6978 - val_loss: 0.6283 - val_accuracy: 0.6787
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.6944
# Epoch 81: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 18s 178ms/step - loss: 0.6016 - accuracy: 0.6944 - val_loss: 0.6141 - val_accuracy: 0.6725
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6006 - accuracy: 0.6994
# Epoch 82: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 163ms/step - loss: 0.6006 - accuracy: 0.6994 - val_loss: 0.6162 - val_accuracy: 0.6812
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5990 - accuracy: 0.7022
# Epoch 83: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 18s 177ms/step - loss: 0.5990 - accuracy: 0.7022 - val_loss: 0.6128 - val_accuracy: 0.6812
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.6988
# Epoch 84: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 161ms/step - loss: 0.5991 - accuracy: 0.6988 - val_loss: 0.6730 - val_accuracy: 0.6025
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.6909
# Epoch 85: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 160ms/step - loss: 0.6032 - accuracy: 0.6909 - val_loss: 0.6164 - val_accuracy: 0.6787
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.6947
# Epoch 86: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 162ms/step - loss: 0.6048 - accuracy: 0.6947 - val_loss: 0.6166 - val_accuracy: 0.6787
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6036 - accuracy: 0.6981
# Epoch 87: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 18s 179ms/step - loss: 0.6036 - accuracy: 0.6981 - val_loss: 0.6107 - val_accuracy: 0.6787
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.7022
# Epoch 88: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 17s 166ms/step - loss: 0.5964 - accuracy: 0.7022 - val_loss: 0.6079 - val_accuracy: 0.6825
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5925 - accuracy: 0.7056
# Epoch 89: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 164ms/step - loss: 0.5925 - accuracy: 0.7056 - val_loss: 0.6131 - val_accuracy: 0.6712
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5992 - accuracy: 0.6991
# Epoch 90: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 160ms/step - loss: 0.5992 - accuracy: 0.6991 - val_loss: 0.6177 - val_accuracy: 0.6775
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5944 - accuracy: 0.7009
# Epoch 91: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 164ms/step - loss: 0.5944 - accuracy: 0.7009 - val_loss: 0.6079 - val_accuracy: 0.6837
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6060 - accuracy: 0.6934
# Epoch 92: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 16s 159ms/step - loss: 0.6060 - accuracy: 0.6934 - val_loss: 0.6202 - val_accuracy: 0.6750
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.7047
# Epoch 93: val_accuracy did not improve from 0.68875
# 100/100 [==============================] - 17s 166ms/step - loss: 0.5984 - accuracy: 0.7047 - val_loss: 0.6150 - val_accuracy: 0.6725
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6001 - accuracy: 0.6963
# Epoch 94: val_accuracy improved from 0.68875 to 0.69000, saving model to modelo_generado\mejor_modelo.keras
# 100/100 [==============================] - 17s 166ms/step - loss: 0.6001 - accuracy: 0.6963 - val_loss: 0.6097 - val_accuracy: 0.6900
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.7050
# Epoch 95: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 17s 167ms/step - loss: 0.5975 - accuracy: 0.7050 - val_loss: 0.6250 - val_accuracy: 0.6712
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.6991
# Epoch 96: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 16s 160ms/step - loss: 0.5989 - accuracy: 0.6991 - val_loss: 0.6261 - val_accuracy: 0.6525
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5980 - accuracy: 0.6988
# Epoch 97: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 18s 176ms/step - loss: 0.5980 - accuracy: 0.6988 - val_loss: 0.6123 - val_accuracy: 0.6812
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6089 - accuracy: 0.6944
# Epoch 98: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 18s 175ms/step - loss: 0.6089 - accuracy: 0.6944 - val_loss: 0.6198 - val_accuracy: 0.6750
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.6056 - accuracy: 0.6969
# Epoch 99: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 17s 172ms/step - loss: 0.6056 - accuracy: 0.6969 - val_loss: 0.6269 - val_accuracy: 0.6712
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5915 - accuracy: 0.7000
# Epoch 100: val_accuracy did not improve from 0.69000
# 100/100 [==============================] - 17s 165ms/step - loss: 0.5915 - accuracy: 0.7000 - val_loss: 0.6374 - val_accuracy: 0.6737

# %% [markdown]
# Resumen del modelo

# %%
clasificador.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 315,393
# Trainable params: 315,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se crean los directorios que almacenarán los resultados de las repeticiones

# %%
if not os.path.exists("repeticiones_experimento"):
    os.mkdir("repeticiones_experimento")
    os.mkdir("repeticiones_experimento/imagenes_curvas_roc_auc")
    os.mkdir("repeticiones_experimento/imagenes_entrenamientos/")
    os.mkdir("repeticiones_experimento/imagenes_matriz_confusion/")

# %%
# Graficar las curvas de pérdida y precisión durante el entrenamiento y la validación
plt.figure(figsize=(12, 6))

# Curvas de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Curvas de Loss')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid()

# Curvas de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Curvas de Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.grid()
plt.tight_layout()

# Obteniendo el nombre de la imagen para la gráfica de entrenamiento
cant_img_train = len(os.listdir(path="repeticiones_experimento/imagenes_entrenamientos"))
name_img_train = f"imagen_entrenamiento_{cant_img_train+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_entrenamientos/{name_img_train}", dpi=600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## **Parte 5:** Evaluación del modelo
#
# Se evalua el mejor modelo guardado

# %%
mejor_modelo = load_model("modelo_generado/mejor_modelo.keras")
generador_validacion.reset()
resul_eva = mejor_modelo.evaluate(generador_validacion, verbose=False)

# Obtener los resultados de pérdida y accuracy
perdida     = resul_eva[0]
accuracy    = resul_eva[1]

print("Loss: {:.2f}".format(perdida))
print("Accuracy: {:.2%}".format(accuracy))
# Out:
# Loss: 0.61
# Accuracy: 69.00%

# %% [markdown]
# Cálculo de diferentes métricas

# %%
# Obtener las predicciones del modelo
y_pred_prob = mejor_modelo.predict(generador_validacion, verbose=False)

# Convertir las probabilidades en clases binarias usando un umbral (por ejemplo, 0.85)
y_pred = (y_pred_prob > 0.5).astype(int)

# Obtener las etiquetas verdaderas
y_test = generador_validacion.classes

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# Calcular métricas
accuracy    = accuracy_score(y_test, y_pred)
precision   = precision_score(y_test, y_pred)
recall      = recall_score(y_test, y_pred)
f1          = f1_score(y_test, y_pred)

# Calcular sensitivity y specificity
tn, fp, fn, tp  = conf_matrix.ravel()
sensitivity     = tp / (tp + fn)
specificity     = tn / (tn + fp)

# Imprimir resultados
print("\nMatriz de Confusión:")

# Define las etiquetas para los valores en la matriz de confusión
labels = [['Verdaderos Negativos\n', 'Falsos Positivos\n'],
          ['Falsos Negativos\n', 'Verdaderos Positivos\n']]

# Crear una nueva matriz combinando la matriz de confusión y las etiquetas
annot_matrix = [['{} {}'.format(label, value) for label, value in zip(row_labels, row)] for row_labels, row in zip(labels, conf_matrix)]

# Crear un mapa de calor con Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=annot_matrix, cmap='Blues', fmt='', cbar=False, annot_kws={'size':14})
plt.title('Matriz de Confusión', fontsize=16)

# Obteniendo el nombre de la imagen para la matriz de confusión
cant_img_matrix = len(os.listdir(path="repeticiones_experimento/imagenes_matriz_confusion"))
name_img_matrix = f"matriz_confusion_{cant_img_matrix+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_matriz_confusion/{name_img_matrix}", dpi=600, bbox_inches='tight')

plt.show()

print("Accuracy:\t{:.2%}".format(accuracy))
print("Sensitivity:\t{:.2%}".format(sensitivity))
print("Specificity:\t{:.2%}".format(specificity))
print("Precision:\t{:.2%}".format(precision))
print("F1-score:\t{:.2%}".format(f1))
# Out:
# Matriz de Confusión:
# Accuracy:	69.00%
# Sensitivity:	62.75%
# Specificity:	75.25%
# Precision:	71.71%
# F1-score:	66.93%

# %% [markdown]
# Curva roc y auc

# %%
# Calcular la curva ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Visualizar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid()

# Obteniendo el nombre de la imagen para la curva ROC-AUC
cant_img_roc_auc = len(os.listdir(path="repeticiones_experimento/imagenes_curvas_roc_auc"))
name_img_roc_auc = f"roc_auc{cant_img_roc_auc+1}.png"
plt.savefig(f"repeticiones_experimento/imagenes_curvas_roc_auc/{name_img_roc_auc}", dpi=600, bbox_inches='tight')

plt.show()

# Imprimir el AUC
print(f"Área Bajo la Curva (AUC): {roc_auc:.2f}")
# Out:
# Área Bajo la Curva (AUC): 0.74

# %% [markdown]
# Se registran las métricas en cada iteración del experimento.

# %%
# Se crea un Dataframe con los nuevos resultados
new_data = pd.DataFrame({
    "Accuracy"      : [accuracy],
    "Sensitivity"   : [sensitivity],
    "Specificity"   : [specificity],
    "Precision"     : [precision],
    "F1"            : [f1],
    "Roc-Auc"       : [roc_auc]
})

# Especificar el nombre del archivo Excel
file_name = "repeticiones_experimento/metricas.xlsx"

#Verificar si el archivo ya existe
if os.path.exists(file_name):
    #Si el archivo existe, cargar los datos existentes
    existing_data = pd.read_excel(file_name, sheet_name="Métricas")
    #Concatenar los datos existentes con los nuevos datos
    df_metricas = pd.concat([existing_data, new_data], ignore_index=True)
else:
    #Si el archivo no existe, usar solo los nuevos datos
    df_metricas = new_data

#Guardar el Dataframe en el archivo Excel
df_metricas.to_excel(file_name, sheet_name="Métricas", index=False)
